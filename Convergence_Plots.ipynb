# %%
import numpy as np
from matplotlib import pyplot as plt
import matplotlib as mpl
plt.rcParams.update({
    "text.usetex": True,
    "text.latex.preamble": r"\usepackage{amsmath}",
    "font.family": "serif",
    "font.serif": ["Computer Modern"],
    "pdf.fonttype": 42,
    "ps.fonttype": 42,
    "font.size": 30,
    'font.weight': 'bold',
    'axes.titleweight': 'bold',
    'axes.labelweight': 'bold'
})

# %%
ES_Energies_8_Qubit_1_Layer_Delta_Half = np.loadtxt(r'/mnt/c/Users/Saavanth Velury/Desktop/Quasiparticle VQE/8 Qubit Data (Final)/Delta = one-half/Nf = 4/q = 0/1 Layer/8_Qubit_XXZ_1_Layer_HVA_Optimal_Values_BOBYQA_GPU_4_Filled_States_Antiperiodic_Boundary_Conditions_Delta_0.5.txt')
ES_Energies_8_Qubit_2_Layer_Delta_Half = np.loadtxt(r'/mnt/c/Users/Saavanth Velury/Desktop/Quasiparticle VQE/8 Qubit Data (Final)/Delta = one-half/Nf = 4/q = 0/2 Layers/8_Qubit_XXZ_2_Layer_HVA_Optimal_Values_BOBYQA_GPU_4_Filled_States_Antiperiodic_Boundary_Conditions_Delta_0.5.txt')
ES_Energies_8_Qubit_3_Layer_Delta_Half = np.loadtxt(r'/mnt/c/Users/Saavanth Velury/Desktop/Quasiparticle VQE/8 Qubit Data (Final)/Delta = one-half/Nf = 4/q = 0/3 Layers/8_Qubit_XXZ_3_Layer_HVA_Optimal_Values_BOBYQA_GPU_4_Filled_States_Antiperiodic_Boundary_Conditions_Delta_0.5.txt')
ES_Energies_8_Qubit_4_Layer_Delta_Half = np.loadtxt(r'/mnt/c/Users/Saavanth Velury/Desktop/Quasiparticle VQE/8 Qubit Data (Final)/Delta = one-half/Nf = 4/q = 0/4 Layers/8_Qubit_XXZ_4_Layer_HVA_Optimal_Values_BOBYQA_GPU_4_Filled_States_Antiperiodic_Boundary_Conditions_Delta_0.5.txt')
ES_Energies_8_Qubit_5_Layer_Delta_Half = np.loadtxt(r'/mnt/c/Users/Saavanth Velury/Desktop/Quasiparticle VQE/8 Qubit Data (Final)/Delta = one-half/Nf = 4/q = 0/5 Layers/8_Qubit_XXZ_5_Layer_HVA_Optimal_Values_BOBYQA_GPU_4_Filled_States_Antiperiodic_Boundary_Conditions_Delta_0.5.txt')
ES_Energies_8_Qubit_6_Layer_Delta_Half = np.loadtxt(r'/mnt/c/Users/Saavanth Velury/Desktop/Quasiparticle VQE/8 Qubit Data (Final)/Delta = one-half/Nf = 4/q = 0/6 Layers/8_Qubit_XXZ_6_Layer_HVA_Optimal_Values_BOBYQA_GPU_4_Filled_States_Antiperiodic_Boundary_Conditions_Delta_0.5.txt')
ES_Energies_8_Qubit_7_Layer_Delta_Half = np.loadtxt(r'/mnt/c/Users/Saavanth Velury/Desktop/Quasiparticle VQE/8 Qubit Data (Final)/Delta = one-half/Nf = 4/q = 0/7 Layers/8_Qubit_XXZ_7_Layer_HVA_Optimal_Values_BOBYQA_GPU_4_Filled_States_Antiperiodic_Boundary_Conditions_Delta_0.5.txt')
ES_Energies_8_Qubit_8_Layer_Delta_Half = np.loadtxt(r'/mnt/c/Users/Saavanth Velury/Desktop/Quasiparticle VQE/8 Qubit Data (Final)/Delta = one-half/Nf = 4/q = 0/8 Layers/8_Qubit_XXZ_8_Layer_HVA_Optimal_Values_BOBYQA_GPU_4_Filled_States_Antiperiodic_Boundary_Conditions_Delta_0.5.txt')

# %%
E_ED_ES_8_Qubit_Delta_Half = -12.347977
Errors_8_Qubit_1_Layer_ES_Delta_Half = np.flipud(np.sort(-(ES_Energies_8_Qubit_1_Layer_Delta_Half - E_ED_ES_8_Qubit_Delta_Half)/E_ED_ES_8_Qubit_Delta_Half))
Errors_8_Qubit_2_Layer_ES_Delta_Half = np.flipud(np.sort(-(ES_Energies_8_Qubit_2_Layer_Delta_Half - E_ED_ES_8_Qubit_Delta_Half)/E_ED_ES_8_Qubit_Delta_Half))
Errors_8_Qubit_3_Layer_ES_Delta_Half = np.flipud(np.sort(-(ES_Energies_8_Qubit_3_Layer_Delta_Half - E_ED_ES_8_Qubit_Delta_Half)/E_ED_ES_8_Qubit_Delta_Half))
Errors_8_Qubit_4_Layer_ES_Delta_Half = np.flipud(np.sort(-(ES_Energies_8_Qubit_4_Layer_Delta_Half - E_ED_ES_8_Qubit_Delta_Half)/E_ED_ES_8_Qubit_Delta_Half))
Errors_8_Qubit_5_Layer_ES_Delta_Half = np.flipud(np.sort(-(ES_Energies_8_Qubit_5_Layer_Delta_Half - E_ED_ES_8_Qubit_Delta_Half)/E_ED_ES_8_Qubit_Delta_Half))
Errors_8_Qubit_6_Layer_ES_Delta_Half = np.flipud(np.sort(-(ES_Energies_8_Qubit_6_Layer_Delta_Half - E_ED_ES_8_Qubit_Delta_Half)/E_ED_ES_8_Qubit_Delta_Half))
Errors_8_Qubit_7_Layer_ES_Delta_Half = np.flipud(np.sort(-(ES_Energies_8_Qubit_7_Layer_Delta_Half - E_ED_ES_8_Qubit_Delta_Half)/E_ED_ES_8_Qubit_Delta_Half))
Errors_8_Qubit_8_Layer_ES_Delta_Half = np.flipud(np.sort(-(ES_Energies_8_Qubit_8_Layer_Delta_Half - E_ED_ES_8_Qubit_Delta_Half)/E_ED_ES_8_Qubit_Delta_Half))

# %%
Another_ES_Energies_8_Qubit_1_Layer_Delta_Half = np.loadtxt(r'/mnt/c/Users/Saavanth Velury/Desktop/Quasiparticle VQE/8 Qubit Data (Final)/Delta = one-half/Nf = 4/q = pi over 2/1 Layer/8_Qubit_XXZ_1_Layer_HVA_Optimal_Values_BOBYQA_GPU_4_Filled_States_Antiperiodic_Boundary_Conditions_PH_State_2_Alternate_Delta_0.5.txt')
Another_ES_Energies_8_Qubit_2_Layer_Delta_Half = np.loadtxt(r'/mnt/c/Users/Saavanth Velury/Desktop/Quasiparticle VQE/8 Qubit Data (Final)/Delta = one-half/Nf = 4/q = pi over 2/2 Layers/8_Qubit_XXZ_2_Layer_HVA_Optimal_Values_BOBYQA_GPU_4_Filled_States_Antiperiodic_Boundary_Conditions_PH_State_2_Alternate_Delta_0.5.txt')
Another_ES_Energies_8_Qubit_3_Layer_Delta_Half = np.loadtxt(r'/mnt/c/Users/Saavanth Velury/Desktop/Quasiparticle VQE/8 Qubit Data (Final)/Delta = one-half/Nf = 4/q = pi over 2/3 Layers/8_Qubit_XXZ_3_Layer_HVA_Optimal_Values_BOBYQA_GPU_4_Filled_States_Antiperiodic_Boundary_Conditions_PH_State_2_Alternate_Delta_0.5.txt')
Another_ES_Energies_8_Qubit_4_Layer_Delta_Half = np.loadtxt(r'/mnt/c/Users/Saavanth Velury/Desktop/Quasiparticle VQE/8 Qubit Data (Final)/Delta = one-half/Nf = 4/q = pi over 2/4 Layers/8_Qubit_XXZ_4_Layer_HVA_Optimal_Values_BOBYQA_GPU_4_Filled_States_Antiperiodic_Boundary_Conditions_PH_State_2_Alternate_Delta_0.5.txt')
Another_ES_Energies_8_Qubit_5_Layer_Delta_Half = np.loadtxt(r'/mnt/c/Users/Saavanth Velury/Desktop/Quasiparticle VQE/8 Qubit Data (Final)/Delta = one-half/Nf = 4/q = pi over 2/5 Layers/8_Qubit_XXZ_5_Layer_HVA_Optimal_Values_BOBYQA_GPU_4_Filled_States_Antiperiodic_Boundary_Conditions_PH_State_2_Alternate_Delta_0.5.txt')
Another_ES_Energies_8_Qubit_6_Layer_Delta_Half = np.loadtxt(r'/mnt/c/Users/Saavanth Velury/Desktop/Quasiparticle VQE/8 Qubit Data (Final)/Delta = one-half/Nf = 4/q = pi over 2/6 Layers/8_Qubit_XXZ_6_Layer_HVA_Optimal_Values_BOBYQA_GPU_4_Filled_States_Antiperiodic_Boundary_Conditions_PH_State_2_Alternate_Delta_0.5.txt')
Another_ES_Energies_8_Qubit_7_Layer_Delta_Half = np.loadtxt(r'/mnt/c/Users/Saavanth Velury/Desktop/Quasiparticle VQE/8 Qubit Data (Final)/Delta = one-half/Nf = 4/q = pi over 2/7 Layers/8_Qubit_XXZ_7_Layer_HVA_Optimal_Values_BOBYQA_GPU_4_Filled_States_Antiperiodic_Boundary_Conditions_PH_State_2_Alternate_Delta_0.5.txt')
Another_ES_Energies_8_Qubit_8_Layer_Delta_Half = np.loadtxt(r'/mnt/c/Users/Saavanth Velury/Desktop/Quasiparticle VQE/8 Qubit Data (Final)/Delta = one-half/Nf = 4/q = pi over 2/8 Layers/8_Qubit_XXZ_8_Layer_HVA_Optimal_Values_BOBYQA_GPU_4_Filled_States_Antiperiodic_Boundary_Conditions_PH_State_2_Alternate_Delta_0.5.txt')

# %%
E_ED_Another_ES_8_Qubit_Delta_Half = -6.205550
Errors_8_Qubit_1_Layer_Another_ES_Delta_Half = np.flipud(np.sort(-(Another_ES_Energies_8_Qubit_1_Layer_Delta_Half - E_ED_Another_ES_8_Qubit_Delta_Half)/E_ED_Another_ES_8_Qubit_Delta_Half))
Errors_8_Qubit_2_Layer_Another_ES_Delta_Half = np.flipud(np.sort(-(Another_ES_Energies_8_Qubit_2_Layer_Delta_Half - E_ED_Another_ES_8_Qubit_Delta_Half)/E_ED_Another_ES_8_Qubit_Delta_Half))
Errors_8_Qubit_3_Layer_Another_ES_Delta_Half = np.flipud(np.sort(-(Another_ES_Energies_8_Qubit_3_Layer_Delta_Half - E_ED_Another_ES_8_Qubit_Delta_Half)/E_ED_Another_ES_8_Qubit_Delta_Half))
Errors_8_Qubit_4_Layer_Another_ES_Delta_Half = np.flipud(np.sort(-(Another_ES_Energies_8_Qubit_4_Layer_Delta_Half - E_ED_Another_ES_8_Qubit_Delta_Half)/E_ED_Another_ES_8_Qubit_Delta_Half))
Errors_8_Qubit_5_Layer_Another_ES_Delta_Half = np.flipud(np.sort(-(Another_ES_Energies_8_Qubit_5_Layer_Delta_Half - E_ED_Another_ES_8_Qubit_Delta_Half)/E_ED_Another_ES_8_Qubit_Delta_Half))
Errors_8_Qubit_6_Layer_Another_ES_Delta_Half = np.flipud(np.sort(-(Another_ES_Energies_8_Qubit_6_Layer_Delta_Half - E_ED_Another_ES_8_Qubit_Delta_Half)/E_ED_Another_ES_8_Qubit_Delta_Half))
Errors_8_Qubit_7_Layer_Another_ES_Delta_Half = np.flipud(np.sort(-(Another_ES_Energies_8_Qubit_7_Layer_Delta_Half - E_ED_Another_ES_8_Qubit_Delta_Half)/E_ED_Another_ES_8_Qubit_Delta_Half))
Errors_8_Qubit_8_Layer_Another_ES_Delta_Half = np.flipud(np.sort(-(Another_ES_Energies_8_Qubit_8_Layer_Delta_Half - E_ED_Another_ES_8_Qubit_Delta_Half)/E_ED_Another_ES_8_Qubit_Delta_Half))

# %%
ES_Energies_16_Qubit_1_Layer_Three_Parameter_Delta_Half = np.loadtxt(r'/mnt/c/Users/Saavanth Velury/Desktop/Quasiparticle VQE/16 Qubit Data (Final)/Delta = one-half/Nf = 8/q = 0/1 Layer/16_Qubit_XXZ_1_Layer_HVA_Optimal_Values_BOBYQA_8_Filled_States_Antiperiodic_Boundary_Conditions_Three_Parameters_Delta_0.5.txt')
ES_Energies_16_Qubit_2_Layer_Three_Parameter_Delta_Half = np.loadtxt(r'/mnt/c/Users/Saavanth Velury/Desktop/Quasiparticle VQE/16 Qubit Data (Final)/Delta = one-half/Nf = 8/q = 0/2 Layers/16_Qubit_XXZ_2_Layer_HVA_Optimal_Values_BOBYQA_8_Filled_States_Antiperiodic_Boundary_Conditions_Three_Parameters_Delta_0.5.txt')
ES_Energies_16_Qubit_3_Layer_Three_Parameter_Delta_Half = np.loadtxt(r'/mnt/c/Users/Saavanth Velury/Desktop/Quasiparticle VQE/16 Qubit Data (Final)/Delta = one-half/Nf = 8/q = 0/3 Layers/16_Qubit_XXZ_3_Layer_HVA_Optimal_Values_BOBYQA_8_Filled_States_Antiperiodic_Boundary_Conditions_Three_Parameters_Delta_0.5.txt')
ES_Energies_16_Qubit_4_Layer_Three_Parameter_Delta_Half = np.loadtxt(r'/mnt/c/Users/Saavanth Velury/Desktop/Quasiparticle VQE/16 Qubit Data (Final)/Delta = one-half/Nf = 8/q = 0/4 Layers/16_Qubit_XXZ_4_Layer_HVA_Optimal_Values_BOBYQA_8_Filled_States_Antiperiodic_Boundary_Conditions_Three_Parameters_Delta_0.5.txt')
ES_Energies_16_Qubit_5_Layer_Three_Parameter_Delta_Half = np.loadtxt(r'/mnt/c/Users/Saavanth Velury/Desktop/Quasiparticle VQE/16 Qubit Data (Final)/Delta = one-half/Nf = 8/q = 0/5 Layers/16_Qubit_XXZ_5_Layer_HVA_Optimal_Values_BOBYQA_8_Filled_States_Antiperiodic_Boundary_Conditions_Three_Parameters_Delta_0.5.txt')

# %%
E_ED_ES_16_Qubit_Delta_Half = -24.171053
Errors_16_Qubit_1_Layer_ES_Delta_Half = np.flipud(np.sort(-(ES_Energies_16_Qubit_1_Layer_Three_Parameter_Delta_Half - E_ED_ES_16_Qubit_Delta_Half)/E_ED_ES_16_Qubit_Delta_Half))
Errors_16_Qubit_2_Layer_ES_Delta_Half = np.flipud(np.sort(-(ES_Energies_16_Qubit_2_Layer_Three_Parameter_Delta_Half - E_ED_ES_16_Qubit_Delta_Half)/E_ED_ES_16_Qubit_Delta_Half))
Errors_16_Qubit_3_Layer_ES_Delta_Half = np.flipud(np.sort(-(ES_Energies_16_Qubit_3_Layer_Three_Parameter_Delta_Half - E_ED_ES_16_Qubit_Delta_Half)/E_ED_ES_16_Qubit_Delta_Half))
Errors_16_Qubit_4_Layer_ES_Delta_Half = np.flipud(np.sort(-(ES_Energies_16_Qubit_4_Layer_Three_Parameter_Delta_Half - E_ED_ES_16_Qubit_Delta_Half)/E_ED_ES_16_Qubit_Delta_Half))
Errors_16_Qubit_5_Layer_ES_Delta_Half = np.flipud(np.sort(-(ES_Energies_16_Qubit_5_Layer_Three_Parameter_Delta_Half - E_ED_ES_16_Qubit_Delta_Half)/E_ED_ES_16_Qubit_Delta_Half))

# %%
Another_ES_Energies_16_Qubit_1_Layer_Three_Parameter_Delta_Half = np.loadtxt(r'/mnt/c/Users/Saavanth Velury/Desktop/Quasiparticle VQE/16 Qubit Data (Final)/Delta = one-half/Nf = 8/q = pi over 4/1 Layer/16_Qubit_XXZ_1_Layer_HVA_Optimal_Values_BOBYQA_8_Filled_States_Antiperiodic_BC_PH_State_2_Alternate_Three_Parameters_Delta_0.5.txt')
Another_ES_Energies_16_Qubit_2_Layer_Three_Parameter_Delta_Half = np.loadtxt(r'/mnt/c/Users/Saavanth Velury/Desktop/Quasiparticle VQE/16 Qubit Data (Final)/Delta = one-half/Nf = 8/q = pi over 4/2 Layers/16_Qubit_XXZ_2_Layer_HVA_Optimal_Values_BOBYQA_8_Filled_States_Antiperiodic_BC_PH_State_2_Alternate_Three_Parameters_Delta_0.5.txt')
Another_ES_Energies_16_Qubit_3_Layer_Three_Parameter_Delta_Half = np.loadtxt(r'/mnt/c/Users/Saavanth Velury/Desktop/Quasiparticle VQE/16 Qubit Data (Final)/Delta = one-half/Nf = 8/q = pi over 4/3 Layers/16_Qubit_XXZ_3_Layer_HVA_Optimal_Values_BOBYQA_8_Filled_States_Antiperiodic_BC_PH_State_2_Alternate_Three_Parameters_Delta_0.5.txt')
Another_ES_Energies_16_Qubit_4_Layer_Three_Parameter_Delta_Half = np.loadtxt(r'/mnt/c/Users/Saavanth Velury/Desktop/Quasiparticle VQE/16 Qubit Data (Final)/Delta = one-half/Nf = 8/q = pi over 4/4 Layers/16_Qubit_XXZ_4_Layer_HVA_Optimal_Values_BOBYQA_8_Filled_States_Antiperiodic_BC_PH_State_2_Alternate_Three_Parameters_Delta_0.5.txt')
Another_ES_Energies_16_Qubit_5_Layer_Three_Parameter_Delta_Half = np.loadtxt(r'/mnt/c/Users/Saavanth Velury/Desktop/Quasiparticle VQE/16 Qubit Data (Final)/Delta = one-half/Nf = 8/q = pi over 4/5 Layers/16_Qubit_XXZ_5_Layer_HVA_Optimal_Values_BOBYQA_8_Filled_States_Antiperiodic_BC_PH_State_2_Alternate_Three_Parameters_Delta_0.5.txt')

# %%
E_ED_Another_ES_16_Qubit_Delta_Half = -20.361491
Errors_16_Qubit_1_Layer_Another_ES_Delta_Half = np.flipud(np.sort(-(Another_ES_Energies_16_Qubit_1_Layer_Three_Parameter_Delta_Half - E_ED_Another_ES_16_Qubit_Delta_Half)/E_ED_Another_ES_16_Qubit_Delta_Half))
Errors_16_Qubit_2_Layer_Another_ES_Delta_Half = np.flipud(np.sort(-(Another_ES_Energies_16_Qubit_2_Layer_Three_Parameter_Delta_Half - E_ED_Another_ES_16_Qubit_Delta_Half)/E_ED_Another_ES_16_Qubit_Delta_Half))
Errors_16_Qubit_3_Layer_Another_ES_Delta_Half = np.flipud(np.sort(-(Another_ES_Energies_16_Qubit_3_Layer_Three_Parameter_Delta_Half - E_ED_Another_ES_16_Qubit_Delta_Half)/E_ED_Another_ES_16_Qubit_Delta_Half))
Errors_16_Qubit_4_Layer_Another_ES_Delta_Half = np.flipud(np.sort(-(Another_ES_Energies_16_Qubit_4_Layer_Three_Parameter_Delta_Half - E_ED_Another_ES_16_Qubit_Delta_Half)/E_ED_Another_ES_16_Qubit_Delta_Half))
Errors_16_Qubit_5_Layer_Another_ES_Delta_Half = np.flipud(np.sort(-(Another_ES_Energies_16_Qubit_5_Layer_Three_Parameter_Delta_Half - E_ED_Another_ES_16_Qubit_Delta_Half)/E_ED_Another_ES_16_Qubit_Delta_Half))

# %%
Errors_8_Qubit_ES = [
    Errors_8_Qubit_1_Layer_ES_Delta_Half,
    Errors_8_Qubit_2_Layer_ES_Delta_Half,
    Errors_8_Qubit_3_Layer_ES_Delta_Half,
    Errors_8_Qubit_4_Layer_ES_Delta_Half,
    Errors_8_Qubit_5_Layer_ES_Delta_Half,
]

Errors_8_Qubit_Another_ES = [
    Errors_8_Qubit_1_Layer_Another_ES_Delta_Half,
    Errors_8_Qubit_2_Layer_Another_ES_Delta_Half,
    Errors_8_Qubit_3_Layer_Another_ES_Delta_Half,
    Errors_8_Qubit_4_Layer_Another_ES_Delta_Half,
    Errors_8_Qubit_5_Layer_Another_ES_Delta_Half,
]

Errors_16_Qubit_ES = [
    Errors_16_Qubit_1_Layer_ES_Delta_Half,
    Errors_16_Qubit_2_Layer_ES_Delta_Half,
    Errors_16_Qubit_3_Layer_ES_Delta_Half,
    Errors_16_Qubit_4_Layer_ES_Delta_Half,
    Errors_16_Qubit_5_Layer_ES_Delta_Half,
]

Errors_16_Qubit_Another_ES = [
    Errors_16_Qubit_1_Layer_Another_ES_Delta_Half,
    Errors_16_Qubit_2_Layer_Another_ES_Delta_Half,
    Errors_16_Qubit_3_Layer_Another_ES_Delta_Half,
    Errors_16_Qubit_4_Layer_Another_ES_Delta_Half,
    Errors_16_Qubit_5_Layer_Another_ES_Delta_Half,
]

Depths_8_Qubit  = list(range(1, 6))
Depths_16_Qubit = list(range(1, 6))

markers = ['o', 's', 'D', '^', 'v', '>', '<', 'p']
colors  = plt.rcParams['axes.prop_cycle'].by_key()['color']

fig, axs = plt.subplots(2, 2,
                        figsize=(24, 20),
                        sharex='col', sharey=False)

panels = [
    (axs[0,0], Errors_8_Qubit_ES,  Depths_8_Qubit,  8,  4, r"0"),
    (axs[0,1], Errors_8_Qubit_Another_ES,  Depths_8_Qubit,  8,  3, r"\frac{\pi}{2}"),
    (axs[1,0], Errors_16_Qubit_ES, Depths_16_Qubit, 16, 9, r"0"),
    (axs[1,1], Errors_16_Qubit_Another_ES, Depths_16_Qubit, 16, 7, r"\frac{\pi}{4}"),
]
panel_labels = [r'\textbf{(a)}', r'\textbf{(b)}', r'\textbf{(c)}', r'\textbf{(d)}']

for (ax, errors, deps, N, NF, q_lbl), pl in zip(panels, panel_labels):
    for i, (D, arr) in enumerate(zip(deps, errors)):
        ax.plot(
            np.arange(1, len(arr)+1), arr,
            marker=markers[i], mfc='none', mew=1.2, ms=12,
            lw=1.5, color=colors[i], label=rf"$p={D}$",
            zorder=1
        )

    ax.set_yscale("log")
    ax.tick_params(direction='in', which='both', top=True, right=True, pad=4, labelsize=40)
    ax.text(
        -0.2, 1.02, pl,
        transform=ax.transAxes,
        fontsize=70,          # <-- match your title size
        fontweight='bold',
        va='bottom'
    )
    ax.set_title(
        rf"$N={N},\;\mathcal{{N}}_F={NF},\;q={q_lbl}$",
        loc='center', pad=25, fontsize=60
    )

# legend & labels as before…
axs[0,0].legend(frameon=True, edgecolor='black', framealpha=1, loc='upper right')
for ax in axs[1,:]: ax.set_xlabel(r"Index", fontsize=60)
for ax in axs[:,0]: ax.set_ylabel(r"$(E_{\mathrm{VQE}}(\boldsymbol{\theta}^*)-E_{\mathrm{ED}})/\left|E_{\mathrm{ED}}\right|$", fontsize=40, labelpad = 25)

fig.subplots_adjust(
    wspace=0.3, hspace=0.3
)
plt.savefig("VQE Error Distributions (NF Even).pdf", bbox_inches="tight")
plt.show()
