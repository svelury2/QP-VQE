# %%
import numpy as np
from matplotlib import pyplot as plt
import matplotlib as mpl
plt.rcParams.update({
    "text.usetex": True,
    "text.latex.preamble": r"\usepackage{amsmath}",
    "font.family": "serif",
    "font.serif": ["Computer Modern"],
    "pdf.fonttype": 42,
    "ps.fonttype": 42,
    "font.size": 30,
    'font.weight': 'bold',
    'axes.titleweight': 'bold',
    'axes.labelweight': 'bold'
})
import os

# %%
print("Exists?", os.path.exists(r"/mnt/c/Users/Saavanth Velury/Desktop/Quasiparticle VQE/8 Qubit Data (Final)/Delta = one-half/Nf = 3/q = 0/1 Layer/8_Qubit_XXZ_1_Layer_HVA_Optimal_Values_BOBYQA_GPU_3_Filled_States_Periodic_Boundary_Conditions_PH_State_4_Alternate_Delta_0.5.txt"))
print("Is file?", os.path.isfile(r"/mnt/c/Users/Saavanth Velury/Desktop/Quasiparticle VQE/8 Qubit Data (Final)/Delta = one-half/Nf = 3/q = 0/1 Layer/8_Qubit_XXZ_1_Layer_HVA_Optimal_Values_BOBYQA_GPU_3_Filled_States_Periodic_Boundary_Conditions_PH_State_4_Alternate_Delta_0.5.txt"))
# Out:
# Exists? True
# Is file? True

# %%
#Nf = 3 (Δ = 0.1)

#q = pi
Energies_1_Layer_q_pi = np.loadtxt(r"/mnt/c/Users/Saavanth Velury/Desktop/Quasiparticle VQE/8 Qubit Data (Final)/Delta = one-tenth/Nf = 3/q = pi/1 Layer/8_Qubit_XXZ_1_Layer_HVA_Optimal_Values_BOBYQA_GPU_3_Filled_States_Periodic_Boundary_Conditions.txt")
Energies_2_Layer_q_pi = np.loadtxt(r"/mnt/c/Users/Saavanth Velury/Desktop/Quasiparticle VQE/8 Qubit Data (Final)/Delta = one-tenth/Nf = 3/q = pi/2 Layers/8_Qubit_XXZ_2_Layer_HVA_Optimal_Values_BOBYQA_GPU_3_Filled_States_Periodic_Boundary_Conditions.txt")
Energies_3_Layer_q_pi = np.loadtxt(r"/mnt/c/Users/Saavanth Velury/Desktop/Quasiparticle VQE/8 Qubit Data (Final)/Delta = one-tenth/Nf = 3/q = pi/3 Layers/8_Qubit_XXZ_3_Layer_HVA_Optimal_Values_BOBYQA_GPU_3_Filled_States_Periodic_Boundary_Conditions.txt")
Energies_4_Layer_q_pi = np.loadtxt(r"/mnt/c/Users/Saavanth Velury/Desktop/Quasiparticle VQE/8 Qubit Data (Final)/Delta = one-tenth/Nf = 3/q = pi/4 Layers/8_Qubit_XXZ_4_Layer_HVA_Optimal_Values_BOBYQA_GPU_3_Filled_States_Periodic_Boundary_Conditions.txt")
Energies_5_Layer_q_pi = np.loadtxt(r"/mnt/c/Users/Saavanth Velury/Desktop/Quasiparticle VQE/8 Qubit Data (Final)/Delta = one-tenth/Nf = 3/q = pi/5 Layers/8_Qubit_XXZ_5_Layer_HVA_Optimal_Values_BOBYQA_GPU_3_Filled_States_Periodic_Boundary_Conditions.txt")
Energies_6_Layer_q_pi = np.loadtxt(r"/mnt/c/Users/Saavanth Velury/Desktop/Quasiparticle VQE/8 Qubit Data (Final)/Delta = one-tenth/Nf = 3/q = pi/6 Layers/8_Qubit_XXZ_6_Layer_HVA_Optimal_Values_BOBYQA_GPU_3_Filled_States_Periodic_Boundary_Conditions.txt")
Energies_7_Layer_q_pi = np.loadtxt(r"/mnt/c/Users/Saavanth Velury/Desktop/Quasiparticle VQE/8 Qubit Data (Final)/Delta = one-tenth/Nf = 3/q = pi/7 Layers/8_Qubit_XXZ_7_Layer_HVA_Optimal_Values_BOBYQA_GPU_3_Filled_States_Periodic_Boundary_Conditions.txt")
Energies_8_Layer_q_pi = np.loadtxt(r"/mnt/c/Users/Saavanth Velury/Desktop/Quasiparticle VQE/8 Qubit Data (Final)/Delta = one-tenth/Nf = 3/q = pi/8 Layers/8_Qubit_XXZ_8_Layer_HVA_Optimal_Values_BOBYQA_GPU_3_Filled_States_Periodic_Boundary_Conditions.txt")
Optimal_Value_1_Layer_q_pi = Energies_1_Layer_q_pi[np.argmin(Energies_1_Layer_q_pi)]
Optimal_Value_2_Layer_q_pi = Energies_2_Layer_q_pi[np.argmin(Energies_2_Layer_q_pi)]
Optimal_Value_3_Layer_q_pi = Energies_3_Layer_q_pi[np.argmin(Energies_3_Layer_q_pi)]
Optimal_Value_4_Layer_q_pi = Energies_4_Layer_q_pi[np.argmin(Energies_4_Layer_q_pi)]
Optimal_Value_5_Layer_q_pi = Energies_5_Layer_q_pi[np.argmin(Energies_5_Layer_q_pi)]
Optimal_Value_6_Layer_q_pi = Energies_6_Layer_q_pi[np.argmin(Energies_6_Layer_q_pi)]
Optimal_Value_7_Layer_q_pi = Energies_7_Layer_q_pi[np.argmin(Energies_7_Layer_q_pi)]
Optimal_Value_8_Layer_q_pi = Energies_8_Layer_q_pi[np.argmin(Energies_8_Layer_q_pi)]
Optimal_Values_q_pi = [Optimal_Value_1_Layer_q_pi, Optimal_Value_2_Layer_q_pi, Optimal_Value_3_Layer_q_pi, Optimal_Value_4_Layer_q_pi, Optimal_Value_5_Layer_q_pi, Optimal_Value_6_Layer_q_pi, Optimal_Value_7_Layer_q_pi, Optimal_Value_8_Layer_q_pi]

#q = pi/4
Energies_1_Layer_q_pi_over_4 = np.loadtxt(r"/mnt/c/Users/Saavanth Velury/Desktop/Quasiparticle VQE/8 Qubit Data (Final)/Delta = one-tenth/Nf = 3/q = pi over 4/1 Layer/8_Qubit_XXZ_1_Layer_HVA_Optimal_Values_BOBYQA_GPU_3_Filled_States_Periodic_Boundary_Conditions_PH_State.txt")
Energies_2_Layer_q_pi_over_4 = np.loadtxt(r"/mnt/c/Users/Saavanth Velury/Desktop/Quasiparticle VQE/8 Qubit Data (Final)/Delta = one-tenth/Nf = 3/q = pi over 4/2 Layers/8_Qubit_XXZ_2_Layer_HVA_Optimal_Values_BOBYQA_GPU_3_Filled_States_Periodic_Boundary_Conditions_PH_State.txt")
Energies_3_Layer_q_pi_over_4 = np.loadtxt(r"/mnt/c/Users/Saavanth Velury/Desktop/Quasiparticle VQE/8 Qubit Data (Final)/Delta = one-tenth/Nf = 3/q = pi over 4/3 Layers/8_Qubit_XXZ_3_Layer_HVA_Optimal_Values_BOBYQA_GPU_3_Filled_States_Periodic_Boundary_Conditions_PH_State.txt")
Energies_4_Layer_q_pi_over_4 = np.loadtxt(r"/mnt/c/Users/Saavanth Velury/Desktop/Quasiparticle VQE/8 Qubit Data (Final)/Delta = one-tenth/Nf = 3/q = pi over 4/4 Layers/8_Qubit_XXZ_4_Layer_HVA_Optimal_Values_BOBYQA_GPU_3_Filled_States_Periodic_Boundary_Conditions_PH_State.txt")
Energies_5_Layer_q_pi_over_4 = np.loadtxt(r"/mnt/c/Users/Saavanth Velury/Desktop/Quasiparticle VQE/8 Qubit Data (Final)/Delta = one-tenth/Nf = 3/q = pi over 4/5 Layers/8_Qubit_XXZ_5_Layer_HVA_Optimal_Values_BOBYQA_GPU_3_Filled_States_Periodic_Boundary_Conditions_PH_State.txt")
Energies_6_Layer_q_pi_over_4 = np.loadtxt(r"/mnt/c/Users/Saavanth Velury/Desktop/Quasiparticle VQE/8 Qubit Data (Final)/Delta = one-tenth/Nf = 3/q = pi over 4/6 Layers/8_Qubit_XXZ_6_Layer_HVA_Optimal_Values_BOBYQA_GPU_3_Filled_States_Periodic_Boundary_Conditions_PH_State.txt")
Energies_7_Layer_q_pi_over_4 = np.loadtxt(r"/mnt/c/Users/Saavanth Velury/Desktop/Quasiparticle VQE/8 Qubit Data (Final)/Delta = one-tenth/Nf = 3/q = pi over 4/7 Layers/8_Qubit_XXZ_7_Layer_HVA_Optimal_Values_BOBYQA_GPU_3_Filled_States_Periodic_Boundary_Conditions_PH_State.txt")
Energies_8_Layer_q_pi_over_4 = np.loadtxt(r"/mnt/c/Users/Saavanth Velury/Desktop/Quasiparticle VQE/8 Qubit Data (Final)/Delta = one-tenth/Nf = 3/q = pi over 4/8 Layers/8_Qubit_XXZ_8_Layer_HVA_Optimal_Values_BOBYQA_GPU_3_Filled_States_Periodic_Boundary_Conditions_PH_State.txt")
Optimal_Value_1_Layer_q_pi_over_4 = Energies_1_Layer_q_pi_over_4[np.argmin(Energies_1_Layer_q_pi_over_4)]
Optimal_Value_2_Layer_q_pi_over_4 = Energies_2_Layer_q_pi_over_4[np.argmin(Energies_2_Layer_q_pi_over_4)]
Optimal_Value_3_Layer_q_pi_over_4 = Energies_3_Layer_q_pi_over_4[np.argmin(Energies_3_Layer_q_pi_over_4)]
Optimal_Value_4_Layer_q_pi_over_4 = Energies_4_Layer_q_pi_over_4[np.argmin(Energies_4_Layer_q_pi_over_4)]
Optimal_Value_5_Layer_q_pi_over_4 = Energies_5_Layer_q_pi_over_4[np.argmin(Energies_5_Layer_q_pi_over_4)]
Optimal_Value_6_Layer_q_pi_over_4 = Energies_6_Layer_q_pi_over_4[np.argmin(Energies_6_Layer_q_pi_over_4)]
Optimal_Value_7_Layer_q_pi_over_4 = Energies_7_Layer_q_pi_over_4[np.argmin(Energies_7_Layer_q_pi_over_4)]
Optimal_Value_8_Layer_q_pi_over_4 = Energies_8_Layer_q_pi_over_4[np.argmin(Energies_8_Layer_q_pi_over_4)]
Optimal_Values_q_pi_over_4 = [Optimal_Value_1_Layer_q_pi_over_4, Optimal_Value_2_Layer_q_pi_over_4, Optimal_Value_3_Layer_q_pi_over_4, Optimal_Value_4_Layer_q_pi_over_4, Optimal_Value_5_Layer_q_pi_over_4, Optimal_Value_6_Layer_q_pi_over_4, Optimal_Value_7_Layer_q_pi_over_4, Optimal_Value_8_Layer_q_pi_over_4]

#q = pi/2
Energies_1_Layer_q_pi_over_2 = np.loadtxt(r"/mnt/c/Users/Saavanth Velury/Desktop/Quasiparticle VQE/8 Qubit Data (Final)/Delta = one-tenth/Nf = 3/q = pi over 2/1 Layer/8_Qubit_XXZ_1_Layer_HVA_Optimal_Values_BOBYQA_GPU_3_Filled_States_Periodic_Boundary_Conditions_PH_State_2.txt")
Energies_2_Layer_q_pi_over_2 = np.loadtxt(r"/mnt/c/Users/Saavanth Velury/Desktop/Quasiparticle VQE/8 Qubit Data (Final)/Delta = one-tenth/Nf = 3/q = pi over 2/2 Layers/8_Qubit_XXZ_2_Layer_HVA_Optimal_Values_BOBYQA_GPU_3_Filled_States_Periodic_Boundary_Conditions_PH_State_2.txt")
Energies_3_Layer_q_pi_over_2 = np.loadtxt(r"/mnt/c/Users/Saavanth Velury/Desktop/Quasiparticle VQE/8 Qubit Data (Final)/Delta = one-tenth/Nf = 3/q = pi over 2/3 Layers/8_Qubit_XXZ_3_Layer_HVA_Optimal_Values_BOBYQA_GPU_3_Filled_States_Periodic_Boundary_Conditions_PH_State_2.txt")
Energies_4_Layer_q_pi_over_2 = np.loadtxt(r"/mnt/c/Users/Saavanth Velury/Desktop/Quasiparticle VQE/8 Qubit Data (Final)/Delta = one-tenth/Nf = 3/q = pi over 2/4 Layers/8_Qubit_XXZ_4_Layer_HVA_Optimal_Values_BOBYQA_GPU_3_Filled_States_Periodic_Boundary_Conditions_PH_State_2.txt")
Energies_5_Layer_q_pi_over_2 = np.loadtxt(r"/mnt/c/Users/Saavanth Velury/Desktop/Quasiparticle VQE/8 Qubit Data (Final)/Delta = one-tenth/Nf = 3/q = pi over 2/5 Layers/8_Qubit_XXZ_5_Layer_HVA_Optimal_Values_BOBYQA_GPU_3_Filled_States_Periodic_Boundary_Conditions_PH_State_2.txt")
Energies_6_Layer_q_pi_over_2 = np.loadtxt(r"/mnt/c/Users/Saavanth Velury/Desktop/Quasiparticle VQE/8 Qubit Data (Final)/Delta = one-tenth/Nf = 3/q = pi over 2/6 Layers/8_Qubit_XXZ_6_Layer_HVA_Optimal_Values_BOBYQA_GPU_3_Filled_States_Periodic_Boundary_Conditions_PH_State_2.txt")
Energies_7_Layer_q_pi_over_2 = np.loadtxt(r"/mnt/c/Users/Saavanth Velury/Desktop/Quasiparticle VQE/8 Qubit Data (Final)/Delta = one-tenth/Nf = 3/q = pi over 2/7 Layers/8_Qubit_XXZ_7_Layer_HVA_Optimal_Values_BOBYQA_GPU_3_Filled_States_Periodic_Boundary_Conditions_PH_State_2.txt")
Energies_8_Layer_q_pi_over_2 = np.loadtxt(r"/mnt/c/Users/Saavanth Velury/Desktop/Quasiparticle VQE/8 Qubit Data (Final)/Delta = one-tenth/Nf = 3/q = pi over 2/8 Layers/8_Qubit_XXZ_8_Layer_HVA_Optimal_Values_BOBYQA_GPU_3_Filled_States_Periodic_Boundary_Conditions_PH_State_2.txt")
Optimal_Value_1_Layer_q_pi_over_2 = Energies_1_Layer_q_pi_over_2[np.argmin(Energies_1_Layer_q_pi_over_2)]
Optimal_Value_2_Layer_q_pi_over_2 = Energies_2_Layer_q_pi_over_2[np.argmin(Energies_2_Layer_q_pi_over_2)]
Optimal_Value_3_Layer_q_pi_over_2 = Energies_3_Layer_q_pi_over_2[np.argmin(Energies_3_Layer_q_pi_over_2)]
Optimal_Value_4_Layer_q_pi_over_2 = Energies_4_Layer_q_pi_over_2[np.argmin(Energies_4_Layer_q_pi_over_2)]
Optimal_Value_5_Layer_q_pi_over_2 = Energies_5_Layer_q_pi_over_2[np.argmin(Energies_5_Layer_q_pi_over_2)]
Optimal_Value_6_Layer_q_pi_over_2 = Energies_6_Layer_q_pi_over_2[np.argmin(Energies_6_Layer_q_pi_over_2)]
Optimal_Value_7_Layer_q_pi_over_2 = Energies_7_Layer_q_pi_over_2[np.argmin(Energies_7_Layer_q_pi_over_2)]
Optimal_Value_8_Layer_q_pi_over_2 = Energies_8_Layer_q_pi_over_2[np.argmin(Energies_8_Layer_q_pi_over_2)]
Optimal_Values_q_pi_over_2 = [Optimal_Value_1_Layer_q_pi_over_2, Optimal_Value_2_Layer_q_pi_over_2, Optimal_Value_3_Layer_q_pi_over_2, Optimal_Value_4_Layer_q_pi_over_2, Optimal_Value_5_Layer_q_pi_over_2, Optimal_Value_6_Layer_q_pi_over_2, Optimal_Value_7_Layer_q_pi_over_2, Optimal_Value_8_Layer_q_pi_over_2]

#q = 3pi/4
Energies_1_Layer_q_3pi_over_4 = np.loadtxt(r"/mnt/c/Users/Saavanth Velury/Desktop/Quasiparticle VQE/8 Qubit Data (Final)/Delta = one-tenth/Nf = 3/q = 3pi over 4/1 Layer/8_Qubit_XXZ_1_Layer_HVA_Optimal_Values_BOBYQA_GPU_3_Filled_States_Periodic_Boundary_Conditions_PH_State_3.txt")
Energies_2_Layer_q_3pi_over_4 = np.loadtxt(r"/mnt/c/Users/Saavanth Velury/Desktop/Quasiparticle VQE/8 Qubit Data (Final)/Delta = one-tenth/Nf = 3/q = 3pi over 4/2 Layers/8_Qubit_XXZ_2_Layer_HVA_Optimal_Values_BOBYQA_GPU_3_Filled_States_Periodic_Boundary_Conditions_PH_State_3.txt")
Energies_3_Layer_q_3pi_over_4 = np.loadtxt(r"/mnt/c/Users/Saavanth Velury/Desktop/Quasiparticle VQE/8 Qubit Data (Final)/Delta = one-tenth/Nf = 3/q = 3pi over 4/3 Layers/8_Qubit_XXZ_3_Layer_HVA_Optimal_Values_BOBYQA_GPU_3_Filled_States_Periodic_Boundary_Conditions_PH_State_3.txt")
Energies_4_Layer_q_3pi_over_4 = np.loadtxt(r"/mnt/c/Users/Saavanth Velury/Desktop/Quasiparticle VQE/8 Qubit Data (Final)/Delta = one-tenth/Nf = 3/q = 3pi over 4/4 Layers/8_Qubit_XXZ_4_Layer_HVA_Optimal_Values_BOBYQA_GPU_3_Filled_States_Periodic_Boundary_Conditions_PH_State_3.txt")
Energies_5_Layer_q_3pi_over_4 = np.loadtxt(r"/mnt/c/Users/Saavanth Velury/Desktop/Quasiparticle VQE/8 Qubit Data (Final)/Delta = one-tenth/Nf = 3/q = 3pi over 4/5 Layers/8_Qubit_XXZ_5_Layer_HVA_Optimal_Values_BOBYQA_GPU_3_Filled_States_Periodic_Boundary_Conditions_PH_State_3.txt")
Energies_6_Layer_q_3pi_over_4 = np.loadtxt(r"/mnt/c/Users/Saavanth Velury/Desktop/Quasiparticle VQE/8 Qubit Data (Final)/Delta = one-tenth/Nf = 3/q = 3pi over 4/6 Layers/8_Qubit_XXZ_6_Layer_HVA_Optimal_Values_BOBYQA_GPU_3_Filled_States_Periodic_Boundary_Conditions_PH_State_3.txt")
Energies_7_Layer_q_3pi_over_4 = np.loadtxt(r"/mnt/c/Users/Saavanth Velury/Desktop/Quasiparticle VQE/8 Qubit Data (Final)/Delta = one-tenth/Nf = 3/q = 3pi over 4/7 Layers/8_Qubit_XXZ_7_Layer_HVA_Optimal_Values_BOBYQA_GPU_3_Filled_States_Periodic_Boundary_Conditions_PH_State_3.txt")
Energies_8_Layer_q_3pi_over_4 = np.loadtxt(r"/mnt/c/Users/Saavanth Velury/Desktop/Quasiparticle VQE/8 Qubit Data (Final)/Delta = one-tenth/Nf = 3/q = 3pi over 4/8 Layers/8_Qubit_XXZ_8_Layer_HVA_Optimal_Values_BOBYQA_GPU_3_Filled_States_Periodic_Boundary_Conditions_PH_State_3.txt")
Optimal_Value_1_Layer_q_3pi_over_4 = Energies_1_Layer_q_3pi_over_4[np.argmin(Energies_1_Layer_q_3pi_over_4)]
Optimal_Value_2_Layer_q_3pi_over_4 = Energies_2_Layer_q_3pi_over_4[np.argmin(Energies_2_Layer_q_3pi_over_4)]
Optimal_Value_3_Layer_q_3pi_over_4 = Energies_3_Layer_q_3pi_over_4[np.argmin(Energies_3_Layer_q_3pi_over_4)]
Optimal_Value_4_Layer_q_3pi_over_4 = Energies_4_Layer_q_3pi_over_4[np.argmin(Energies_4_Layer_q_3pi_over_4)]
Optimal_Value_5_Layer_q_3pi_over_4 = Energies_5_Layer_q_3pi_over_4[np.argmin(Energies_5_Layer_q_3pi_over_4)]
Optimal_Value_6_Layer_q_3pi_over_4 = Energies_6_Layer_q_3pi_over_4[np.argmin(Energies_6_Layer_q_3pi_over_4)]
Optimal_Value_7_Layer_q_3pi_over_4 = Energies_7_Layer_q_3pi_over_4[np.argmin(Energies_7_Layer_q_3pi_over_4)]
Optimal_Value_8_Layer_q_3pi_over_4 = Energies_8_Layer_q_3pi_over_4[np.argmin(Energies_8_Layer_q_3pi_over_4)]
Optimal_Values_q_3pi_over_4 = [Optimal_Value_1_Layer_q_3pi_over_4, Optimal_Value_2_Layer_q_3pi_over_4, Optimal_Value_3_Layer_q_3pi_over_4, Optimal_Value_4_Layer_q_3pi_over_4, Optimal_Value_5_Layer_q_3pi_over_4, Optimal_Value_6_Layer_q_3pi_over_4, Optimal_Value_7_Layer_q_3pi_over_4, Optimal_Value_8_Layer_q_3pi_over_4]

#q = 0
Energies_1_Layer_q0 = np.loadtxt(r"/mnt/c/Users/Saavanth Velury/Desktop/Quasiparticle VQE/8 Qubit Data (Final)/Delta = one-tenth/Nf = 3/q = 0/1 Layer/8_Qubit_XXZ_1_Layer_HVA_Optimal_Values_BOBYQA_GPU_3_Filled_States_Periodic_Boundary_Conditions_PH_State_4.txt")
Energies_2_Layer_q0 = np.loadtxt(r"/mnt/c/Users/Saavanth Velury/Desktop/Quasiparticle VQE/8 Qubit Data (Final)/Delta = one-tenth/Nf = 3/q = 0/2 Layers/8_Qubit_XXZ_2_Layer_HVA_Optimal_Values_BOBYQA_GPU_3_Filled_States_Periodic_Boundary_Conditions_PH_State_4.txt")
Energies_3_Layer_q0 = np.loadtxt(r"/mnt/c/Users/Saavanth Velury/Desktop/Quasiparticle VQE/8 Qubit Data (Final)/Delta = one-tenth/Nf = 3/q = 0/3 Layers/8_Qubit_XXZ_3_Layer_HVA_Optimal_Values_BOBYQA_GPU_3_Filled_States_Periodic_Boundary_Conditions_PH_State_4.txt")
Energies_4_Layer_q0 = np.loadtxt(r"/mnt/c/Users/Saavanth Velury/Desktop/Quasiparticle VQE/8 Qubit Data (Final)/Delta = one-tenth/Nf = 3/q = 0/4 Layers/8_Qubit_XXZ_4_Layer_HVA_Optimal_Values_BOBYQA_GPU_3_Filled_States_Periodic_Boundary_Conditions_PH_State_4.txt")
Energies_5_Layer_q0 = np.loadtxt(r"/mnt/c/Users/Saavanth Velury/Desktop/Quasiparticle VQE/8 Qubit Data (Final)/Delta = one-tenth/Nf = 3/q = 0/5 Layers/8_Qubit_XXZ_5_Layer_HVA_Optimal_Values_BOBYQA_GPU_3_Filled_States_Periodic_Boundary_Conditions_PH_State_4.txt")
Energies_6_Layer_q0 = np.loadtxt(r"/mnt/c/Users/Saavanth Velury/Desktop/Quasiparticle VQE/8 Qubit Data (Final)/Delta = one-tenth/Nf = 3/q = 0/6 Layers/8_Qubit_XXZ_6_Layer_HVA_Optimal_Values_BOBYQA_GPU_3_Filled_States_Periodic_Boundary_Conditions_PH_State_4.txt")
Energies_7_Layer_q0 = np.loadtxt(r"/mnt/c/Users/Saavanth Velury/Desktop/Quasiparticle VQE/8 Qubit Data (Final)/Delta = one-tenth/Nf = 3/q = 0/7 Layers/8_Qubit_XXZ_7_Layer_HVA_Optimal_Values_BOBYQA_GPU_3_Filled_States_Periodic_Boundary_Conditions_PH_State_4.txt")
Energies_8_Layer_q0 = np.loadtxt(r"/mnt/c/Users/Saavanth Velury/Desktop/Quasiparticle VQE/8 Qubit Data (Final)/Delta = one-tenth/Nf = 3/q = 0/8 Layers/8_Qubit_XXZ_8_Layer_HVA_Optimal_Values_BOBYQA_GPU_3_Filled_States_Periodic_Boundary_Conditions_PH_State_4.txt")
Optimal_Value_1_Layer_q0 = Energies_1_Layer_q0[np.argmin(Energies_1_Layer_q0)]
Optimal_Value_2_Layer_q0 = Energies_2_Layer_q0[np.argmin(Energies_2_Layer_q0)]
Optimal_Value_3_Layer_q0 = Energies_3_Layer_q0[np.argmin(Energies_3_Layer_q0)]
Optimal_Value_4_Layer_q0 = Energies_4_Layer_q0[np.argmin(Energies_4_Layer_q0)]
Optimal_Value_5_Layer_q0 = Energies_5_Layer_q0[np.argmin(Energies_5_Layer_q0)]
Optimal_Value_6_Layer_q0 = Energies_6_Layer_q0[np.argmin(Energies_6_Layer_q0)]
Optimal_Value_7_Layer_q0 = Energies_7_Layer_q0[np.argmin(Energies_7_Layer_q0)]
Optimal_Value_8_Layer_q0 = Energies_8_Layer_q0[np.argmin(Energies_8_Layer_q0)]
Optimal_Values_q0 = [Optimal_Value_1_Layer_q0, Optimal_Value_2_Layer_q0, Optimal_Value_3_Layer_q0, Optimal_Value_4_Layer_q0, Optimal_Value_5_Layer_q0, Optimal_Value_6_Layer_q0, Optimal_Value_7_Layer_q0, Optimal_Value_8_Layer_q0]

Energies_1_Layer_q0_Alternate = np.loadtxt(r"/mnt/c/Users/Saavanth Velury/Desktop/Quasiparticle VQE/8 Qubit Data (Final)/Delta = one-tenth/Nf = 3/q = 0/1 Layer/8_Qubit_XXZ_1_Layer_HVA_Optimal_Values_BOBYQA_GPU_3_Filled_States_Periodic_Boundary_Conditions_PH_State_4_Alternate.txt")
Energies_2_Layer_q0_Alternate = np.loadtxt(r"/mnt/c/Users/Saavanth Velury/Desktop/Quasiparticle VQE/8 Qubit Data (Final)/Delta = one-tenth/Nf = 3/q = 0/2 Layers/8_Qubit_XXZ_2_Layer_HVA_Optimal_Values_BOBYQA_GPU_3_Filled_States_Periodic_Boundary_Conditions_PH_State_4_Alternate.txt")
Energies_3_Layer_q0_Alternate = np.loadtxt(r"/mnt/c/Users/Saavanth Velury/Desktop/Quasiparticle VQE/8 Qubit Data (Final)/Delta = one-tenth/Nf = 3/q = 0/3 Layers/8_Qubit_XXZ_3_Layer_HVA_Optimal_Values_BOBYQA_GPU_3_Filled_States_Periodic_Boundary_Conditions_PH_State_4_Alternate.txt")
Energies_4_Layer_q0_Alternate = np.loadtxt(r"/mnt/c/Users/Saavanth Velury/Desktop/Quasiparticle VQE/8 Qubit Data (Final)/Delta = one-tenth/Nf = 3/q = 0/4 Layers/8_Qubit_XXZ_4_Layer_HVA_Optimal_Values_BOBYQA_GPU_3_Filled_States_Periodic_Boundary_Conditions_PH_State_4_Alternate.txt")
Energies_5_Layer_q0_Alternate = np.loadtxt(r"/mnt/c/Users/Saavanth Velury/Desktop/Quasiparticle VQE/8 Qubit Data (Final)/Delta = one-tenth/Nf = 3/q = 0/5 Layers/8_Qubit_XXZ_5_Layer_HVA_Optimal_Values_BOBYQA_GPU_3_Filled_States_Periodic_Boundary_Conditions_PH_State_4_Alternate.txt")
Energies_6_Layer_q0_Alternate = np.loadtxt(r"/mnt/c/Users/Saavanth Velury/Desktop/Quasiparticle VQE/8 Qubit Data (Final)/Delta = one-tenth/Nf = 3/q = 0/6 Layers/8_Qubit_XXZ_6_Layer_HVA_Optimal_Values_BOBYQA_GPU_3_Filled_States_Periodic_Boundary_Conditions_PH_State_4_Alternate.txt")
Energies_7_Layer_q0_Alternate = np.loadtxt(r"/mnt/c/Users/Saavanth Velury/Desktop/Quasiparticle VQE/8 Qubit Data (Final)/Delta = one-tenth/Nf = 3/q = 0/7 Layers/8_Qubit_XXZ_7_Layer_HVA_Optimal_Values_BOBYQA_GPU_3_Filled_States_Periodic_Boundary_Conditions_PH_State_4_Alternate.txt")
Energies_8_Layer_q0_Alternate = np.loadtxt(r"/mnt/c/Users/Saavanth Velury/Desktop/Quasiparticle VQE/8 Qubit Data (Final)/Delta = one-tenth/Nf = 3/q = 0/8 Layers/8_Qubit_XXZ_8_Layer_HVA_Optimal_Values_BOBYQA_GPU_3_Filled_States_Periodic_Boundary_Conditions_PH_State_4_Alternate.txt")
Optimal_Value_1_Layer_q0_Alternate = Energies_1_Layer_q0_Alternate[np.argmin(Energies_1_Layer_q0_Alternate)]
Optimal_Value_2_Layer_q0_Alternate = Energies_2_Layer_q0_Alternate[np.argmin(Energies_2_Layer_q0_Alternate)]
Optimal_Value_3_Layer_q0_Alternate = Energies_3_Layer_q0_Alternate[np.argmin(Energies_3_Layer_q0_Alternate)]
Optimal_Value_4_Layer_q0_Alternate = Energies_4_Layer_q0_Alternate[np.argmin(Energies_4_Layer_q0_Alternate)]
Optimal_Value_5_Layer_q0_Alternate = Energies_5_Layer_q0_Alternate[np.argmin(Energies_5_Layer_q0_Alternate)]
Optimal_Value_6_Layer_q0_Alternate = Energies_6_Layer_q0_Alternate[np.argmin(Energies_6_Layer_q0_Alternate)]
Optimal_Value_7_Layer_q0_Alternate = Energies_7_Layer_q0_Alternate[np.argmin(Energies_7_Layer_q0_Alternate)]
Optimal_Value_8_Layer_q0_Alternate = Energies_8_Layer_q0_Alternate[np.argmin(Energies_8_Layer_q0_Alternate)]
Optimal_Values_q0_Alternate = [Optimal_Value_1_Layer_q0_Alternate, Optimal_Value_2_Layer_q0_Alternate, Optimal_Value_3_Layer_q0_Alternate, Optimal_Value_4_Layer_q0_Alternate, Optimal_Value_5_Layer_q0_Alternate, Optimal_Value_6_Layer_q0_Alternate, Optimal_Value_7_Layer_q0_Alternate, Optimal_Value_8_Layer_q0_Alternate]

# %%
ED_Values_Delta_One_Tenth = [0, -6.936573+9.903723, -5.766229+9.903723, -7.077821+9.903723, -4.226665+9.903723, -7.077821+9.903723, -5.766229+9.903723, -6.936573+9.903723, 0]
VQE_Values_Delta_One_Tenth = [0, -6.93593956-min(Optimal_Values_q_pi), -5.76408032-min(Optimal_Values_q_pi), -7.07714926-min(Optimal_Values_q_pi), min(Optimal_Values_q0)-min(Optimal_Values_q_pi), min(Optimal_Values_q_pi_over_4)-min(Optimal_Values_q_pi), min(Optimal_Values_q_pi_over_2)-min(Optimal_Values_q_pi), min(Optimal_Values_q_3pi_over_4)-min(Optimal_Values_q_pi), 0]

# %%
#Nf = 3 (Δ = 0.5)

#q = pi
Energies_1_Layer_q_pi = np.loadtxt(r"/mnt/c/Users/Saavanth Velury/Desktop/Quasiparticle VQE/8 Qubit Data (Final)/Delta = one-half/Nf = 3/q = pi/1 Layer/8_Qubit_XXZ_1_Layer_HVA_Optimal_Values_BOBYQA_GPU_3_Filled_States_Periodic_Boundary_Conditions_Delta_0.5.txt")
Energies_2_Layer_q_pi = np.loadtxt(r"/mnt/c/Users/Saavanth Velury/Desktop/Quasiparticle VQE/8 Qubit Data (Final)/Delta = one-half/Nf = 3/q = pi/2 Layers/8_Qubit_XXZ_2_Layer_HVA_Optimal_Values_BOBYQA_GPU_3_Filled_States_Periodic_Boundary_Conditions_Delta_0.5.txt")
Energies_3_Layer_q_pi = np.loadtxt(r"/mnt/c/Users/Saavanth Velury/Desktop/Quasiparticle VQE/8 Qubit Data (Final)/Delta = one-half/Nf = 3/q = pi/3 Layers/8_Qubit_XXZ_3_Layer_HVA_Optimal_Values_BOBYQA_GPU_3_Filled_States_Periodic_Boundary_Conditions_Delta_0.5.txt")
Energies_4_Layer_q_pi = np.loadtxt(r"/mnt/c/Users/Saavanth Velury/Desktop/Quasiparticle VQE/8 Qubit Data (Final)/Delta = one-half/Nf = 3/q = pi/4 Layers/8_Qubit_XXZ_4_Layer_HVA_Optimal_Values_BOBYQA_GPU_3_Filled_States_Periodic_Boundary_Conditions_Delta_0.5.txt")
Energies_5_Layer_q_pi = np.loadtxt(r"/mnt/c/Users/Saavanth Velury/Desktop/Quasiparticle VQE/8 Qubit Data (Final)/Delta = one-half/Nf = 3/q = pi/5 Layers/8_Qubit_XXZ_5_Layer_HVA_Optimal_Values_BOBYQA_GPU_3_Filled_States_Periodic_Boundary_Conditions_Delta_0.5.txt")
Energies_6_Layer_q_pi = np.loadtxt(r"/mnt/c/Users/Saavanth Velury/Desktop/Quasiparticle VQE/8 Qubit Data (Final)/Delta = one-half/Nf = 3/q = pi/6 Layers/8_Qubit_XXZ_6_Layer_HVA_Optimal_Values_BOBYQA_GPU_3_Filled_States_Periodic_Boundary_Conditions_Delta_0.5.txt")
Energies_7_Layer_q_pi = np.loadtxt(r"/mnt/c/Users/Saavanth Velury/Desktop/Quasiparticle VQE/8 Qubit Data (Final)/Delta = one-half/Nf = 3/q = pi/7 Layers/8_Qubit_XXZ_7_Layer_HVA_Optimal_Values_BOBYQA_GPU_3_Filled_States_Periodic_Boundary_Conditions_Delta_0.5.txt")
Energies_8_Layer_q_pi = np.loadtxt(r"/mnt/c/Users/Saavanth Velury/Desktop/Quasiparticle VQE/8 Qubit Data (Final)/Delta = one-half/Nf = 3/q = pi/8 Layers/8_Qubit_XXZ_8_Layer_HVA_Optimal_Values_BOBYQA_GPU_3_Filled_States_Periodic_Boundary_Conditions_Delta_0.5.txt")
Optimal_Value_1_Layer_q_pi = Energies_1_Layer_q_pi[np.argmin(Energies_1_Layer_q_pi)]
Optimal_Value_2_Layer_q_pi = Energies_2_Layer_q_pi[np.argmin(Energies_2_Layer_q_pi)]
Optimal_Value_3_Layer_q_pi = Energies_3_Layer_q_pi[np.argmin(Energies_3_Layer_q_pi)]
Optimal_Value_4_Layer_q_pi = Energies_4_Layer_q_pi[np.argmin(Energies_4_Layer_q_pi)]
Optimal_Value_5_Layer_q_pi = Energies_5_Layer_q_pi[np.argmin(Energies_5_Layer_q_pi)]
Optimal_Value_6_Layer_q_pi = Energies_6_Layer_q_pi[np.argmin(Energies_6_Layer_q_pi)]
Optimal_Value_7_Layer_q_pi = Energies_7_Layer_q_pi[np.argmin(Energies_7_Layer_q_pi)]
Optimal_Value_8_Layer_q_pi = Energies_8_Layer_q_pi[np.argmin(Energies_8_Layer_q_pi)]
Optimal_Values_q_pi = [Optimal_Value_1_Layer_q_pi, Optimal_Value_2_Layer_q_pi, Optimal_Value_3_Layer_q_pi, Optimal_Value_4_Layer_q_pi, Optimal_Value_5_Layer_q_pi, Optimal_Value_6_Layer_q_pi, Optimal_Value_7_Layer_q_pi, Optimal_Value_8_Layer_q_pi]

#q = pi/4
Energies_1_Layer_q_pi_over_4 = np.loadtxt(r"/mnt/c/Users/Saavanth Velury/Desktop/Quasiparticle VQE/8 Qubit Data (Final)/Delta = one-half/Nf = 3/q = pi over 4/1 Layer/8_Qubit_XXZ_1_Layer_HVA_Optimal_Values_BOBYQA_GPU_3_Filled_States_Periodic_Boundary_Conditions_PH_State_Delta_0.5.txt")
Energies_2_Layer_q_pi_over_4 = np.loadtxt(r"/mnt/c/Users/Saavanth Velury/Desktop/Quasiparticle VQE/8 Qubit Data (Final)/Delta = one-half/Nf = 3/q = pi over 4/2 Layers/8_Qubit_XXZ_2_Layer_HVA_Optimal_Values_BOBYQA_GPU_3_Filled_States_Periodic_Boundary_Conditions_PH_State_Delta_0.5.txt")
Energies_3_Layer_q_pi_over_4 = np.loadtxt(r"/mnt/c/Users/Saavanth Velury/Desktop/Quasiparticle VQE/8 Qubit Data (Final)/Delta = one-half/Nf = 3/q = pi over 4/3 Layers/8_Qubit_XXZ_3_Layer_HVA_Optimal_Values_BOBYQA_GPU_3_Filled_States_Periodic_Boundary_Conditions_PH_State_Delta_0.5.txt")
Energies_4_Layer_q_pi_over_4 = np.loadtxt(r"/mnt/c/Users/Saavanth Velury/Desktop/Quasiparticle VQE/8 Qubit Data (Final)/Delta = one-half/Nf = 3/q = pi over 4/4 Layers/8_Qubit_XXZ_4_Layer_HVA_Optimal_Values_BOBYQA_GPU_3_Filled_States_Periodic_Boundary_Conditions_PH_State_Delta_0.5.txt")
Energies_5_Layer_q_pi_over_4 = np.loadtxt(r"/mnt/c/Users/Saavanth Velury/Desktop/Quasiparticle VQE/8 Qubit Data (Final)/Delta = one-half/Nf = 3/q = pi over 4/5 Layers/8_Qubit_XXZ_5_Layer_HVA_Optimal_Values_BOBYQA_GPU_3_Filled_States_Periodic_Boundary_Conditions_PH_State_Delta_0.5.txt")
Energies_6_Layer_q_pi_over_4 = np.loadtxt(r"/mnt/c/Users/Saavanth Velury/Desktop/Quasiparticle VQE/8 Qubit Data (Final)/Delta = one-half/Nf = 3/q = pi over 4/6 Layers/8_Qubit_XXZ_6_Layer_HVA_Optimal_Values_BOBYQA_GPU_3_Filled_States_Periodic_Boundary_Conditions_PH_State_Delta_0.5.txt")
Energies_7_Layer_q_pi_over_4 = np.loadtxt(r"/mnt/c/Users/Saavanth Velury/Desktop/Quasiparticle VQE/8 Qubit Data (Final)/Delta = one-half/Nf = 3/q = pi over 4/7 Layers/8_Qubit_XXZ_7_Layer_HVA_Optimal_Values_BOBYQA_GPU_3_Filled_States_Periodic_Boundary_Conditions_PH_State_Delta_0.5.txt")
Energies_8_Layer_q_pi_over_4 = np.loadtxt(r"/mnt/c/Users/Saavanth Velury/Desktop/Quasiparticle VQE/8 Qubit Data (Final)/Delta = one-half/Nf = 3/q = pi over 4/8 Layers/8_Qubit_XXZ_8_Layer_HVA_Optimal_Values_BOBYQA_GPU_3_Filled_States_Periodic_Boundary_Conditions_PH_State_Delta_0.5.txt")
Optimal_Value_1_Layer_q_pi_over_4 = Energies_1_Layer_q_pi_over_4[np.argmin(Energies_1_Layer_q_pi_over_4)]
Optimal_Value_2_Layer_q_pi_over_4 = Energies_2_Layer_q_pi_over_4[np.argmin(Energies_2_Layer_q_pi_over_4)]
Optimal_Value_3_Layer_q_pi_over_4 = Energies_3_Layer_q_pi_over_4[np.argmin(Energies_3_Layer_q_pi_over_4)]
Optimal_Value_4_Layer_q_pi_over_4 = Energies_4_Layer_q_pi_over_4[np.argmin(Energies_4_Layer_q_pi_over_4)]
Optimal_Value_5_Layer_q_pi_over_4 = Energies_5_Layer_q_pi_over_4[np.argmin(Energies_5_Layer_q_pi_over_4)]
Optimal_Value_6_Layer_q_pi_over_4 = Energies_6_Layer_q_pi_over_4[np.argmin(Energies_6_Layer_q_pi_over_4)]
Optimal_Value_7_Layer_q_pi_over_4 = Energies_7_Layer_q_pi_over_4[np.argmin(Energies_7_Layer_q_pi_over_4)]
Optimal_Value_8_Layer_q_pi_over_4 = Energies_8_Layer_q_pi_over_4[np.argmin(Energies_8_Layer_q_pi_over_4)]
Optimal_Values_q_pi_over_4 = [Optimal_Value_1_Layer_q_pi_over_4, Optimal_Value_2_Layer_q_pi_over_4, Optimal_Value_3_Layer_q_pi_over_4, Optimal_Value_4_Layer_q_pi_over_4, Optimal_Value_5_Layer_q_pi_over_4, Optimal_Value_6_Layer_q_pi_over_4, Optimal_Value_7_Layer_q_pi_over_4, Optimal_Value_8_Layer_q_pi_over_4]

#q = pi/2
Energies_1_Layer_q_pi_over_2 = np.loadtxt(r"/mnt/c/Users/Saavanth Velury/Desktop/Quasiparticle VQE/8 Qubit Data (Final)/Delta = one-half/Nf = 3/q = pi over 2/1 Layer/8_Qubit_XXZ_1_Layer_HVA_Optimal_Values_BOBYQA_GPU_3_Filled_States_Periodic_Boundary_Conditions_PH_State_2_Delta_0.5.txt")
Energies_2_Layer_q_pi_over_2 = np.loadtxt(r"/mnt/c/Users/Saavanth Velury/Desktop/Quasiparticle VQE/8 Qubit Data (Final)/Delta = one-half/Nf = 3/q = pi over 2/2 Layers/8_Qubit_XXZ_2_Layer_HVA_Optimal_Values_BOBYQA_GPU_3_Filled_States_Periodic_Boundary_Conditions_PH_State_2_Delta_0.5.txt")
Energies_3_Layer_q_pi_over_2 = np.loadtxt(r"/mnt/c/Users/Saavanth Velury/Desktop/Quasiparticle VQE/8 Qubit Data (Final)/Delta = one-half/Nf = 3/q = pi over 2/3 Layers/8_Qubit_XXZ_3_Layer_HVA_Optimal_Values_BOBYQA_GPU_3_Filled_States_Periodic_Boundary_Conditions_PH_State_2_Delta_0.5.txt")
Energies_4_Layer_q_pi_over_2 = np.loadtxt(r"/mnt/c/Users/Saavanth Velury/Desktop/Quasiparticle VQE/8 Qubit Data (Final)/Delta = one-half/Nf = 3/q = pi over 2/4 Layers/8_Qubit_XXZ_4_Layer_HVA_Optimal_Values_BOBYQA_GPU_3_Filled_States_Periodic_Boundary_Conditions_PH_State_2_Delta_0.5.txt")
Energies_5_Layer_q_pi_over_2 = np.loadtxt(r"/mnt/c/Users/Saavanth Velury/Desktop/Quasiparticle VQE/8 Qubit Data (Final)/Delta = one-half/Nf = 3/q = pi over 2/5 Layers/8_Qubit_XXZ_5_Layer_HVA_Optimal_Values_BOBYQA_GPU_3_Filled_States_Periodic_Boundary_Conditions_PH_State_2_Delta_0.5.txt")
Energies_6_Layer_q_pi_over_2 = np.loadtxt(r"/mnt/c/Users/Saavanth Velury/Desktop/Quasiparticle VQE/8 Qubit Data (Final)/Delta = one-half/Nf = 3/q = pi over 2/6 Layers/8_Qubit_XXZ_6_Layer_HVA_Optimal_Values_BOBYQA_GPU_3_Filled_States_Periodic_Boundary_Conditions_PH_State_2_Delta_0.5.txt")
Energies_7_Layer_q_pi_over_2 = np.loadtxt(r"/mnt/c/Users/Saavanth Velury/Desktop/Quasiparticle VQE/8 Qubit Data (Final)/Delta = one-half/Nf = 3/q = pi over 2/7 Layers/8_Qubit_XXZ_7_Layer_HVA_Optimal_Values_BOBYQA_GPU_3_Filled_States_Periodic_Boundary_Conditions_PH_State_2_Delta_0.5.txt")
Energies_8_Layer_q_pi_over_2 = np.loadtxt(r"/mnt/c/Users/Saavanth Velury/Desktop/Quasiparticle VQE/8 Qubit Data (Final)/Delta = one-half/Nf = 3/q = pi over 2/8 Layers/8_Qubit_XXZ_8_Layer_HVA_Optimal_Values_BOBYQA_GPU_3_Filled_States_Periodic_Boundary_Conditions_PH_State_2_Delta_0.5.txt")
Optimal_Value_1_Layer_q_pi_over_2 = Energies_1_Layer_q_pi_over_2[np.argmin(Energies_1_Layer_q_pi_over_2)]
Optimal_Value_2_Layer_q_pi_over_2 = Energies_2_Layer_q_pi_over_2[np.argmin(Energies_2_Layer_q_pi_over_2)]
Optimal_Value_3_Layer_q_pi_over_2 = Energies_3_Layer_q_pi_over_2[np.argmin(Energies_3_Layer_q_pi_over_2)]
Optimal_Value_4_Layer_q_pi_over_2 = Energies_4_Layer_q_pi_over_2[np.argmin(Energies_4_Layer_q_pi_over_2)]
Optimal_Value_5_Layer_q_pi_over_2 = Energies_5_Layer_q_pi_over_2[np.argmin(Energies_5_Layer_q_pi_over_2)]
Optimal_Value_6_Layer_q_pi_over_2 = Energies_6_Layer_q_pi_over_2[np.argmin(Energies_6_Layer_q_pi_over_2)]
Optimal_Value_7_Layer_q_pi_over_2 = Energies_7_Layer_q_pi_over_2[np.argmin(Energies_7_Layer_q_pi_over_2)]
Optimal_Value_8_Layer_q_pi_over_2 = Energies_8_Layer_q_pi_over_2[np.argmin(Energies_8_Layer_q_pi_over_2)]
Optimal_Values_q_pi_over_2 = [Optimal_Value_1_Layer_q_pi_over_2, Optimal_Value_2_Layer_q_pi_over_2, Optimal_Value_3_Layer_q_pi_over_2, Optimal_Value_4_Layer_q_pi_over_2, Optimal_Value_5_Layer_q_pi_over_2, Optimal_Value_6_Layer_q_pi_over_2, Optimal_Value_7_Layer_q_pi_over_2, Optimal_Value_8_Layer_q_pi_over_2]

#q = 3pi/4
Energies_1_Layer_q_3pi_over_4 = np.loadtxt(r"/mnt/c/Users/Saavanth Velury/Desktop/Quasiparticle VQE/8 Qubit Data (Final)/Delta = one-half/Nf = 3/q = 3pi over 4/1 Layer/8_Qubit_XXZ_1_Layer_HVA_Optimal_Values_BOBYQA_GPU_3_Filled_States_Periodic_Boundary_Conditions_PH_State_3_Delta_0.5.txt")
Energies_2_Layer_q_3pi_over_4 = np.loadtxt(r"/mnt/c/Users/Saavanth Velury/Desktop/Quasiparticle VQE/8 Qubit Data (Final)/Delta = one-half/Nf = 3/q = 3pi over 4/2 Layers/8_Qubit_XXZ_2_Layer_HVA_Optimal_Values_BOBYQA_GPU_3_Filled_States_Periodic_Boundary_Conditions_PH_State_3_Delta_0.5.txt")
Energies_3_Layer_q_3pi_over_4 = np.loadtxt(r"/mnt/c/Users/Saavanth Velury/Desktop/Quasiparticle VQE/8 Qubit Data (Final)/Delta = one-half/Nf = 3/q = 3pi over 4/3 Layers/8_Qubit_XXZ_3_Layer_HVA_Optimal_Values_BOBYQA_GPU_3_Filled_States_Periodic_Boundary_Conditions_PH_State_3_Delta_0.5.txt")
Energies_4_Layer_q_3pi_over_4 = np.loadtxt(r"/mnt/c/Users/Saavanth Velury/Desktop/Quasiparticle VQE/8 Qubit Data (Final)/Delta = one-half/Nf = 3/q = 3pi over 4/4 Layers/8_Qubit_XXZ_4_Layer_HVA_Optimal_Values_BOBYQA_GPU_3_Filled_States_Periodic_Boundary_Conditions_PH_State_3_Delta_0.5.txt")
Energies_5_Layer_q_3pi_over_4 = np.loadtxt(r"/mnt/c/Users/Saavanth Velury/Desktop/Quasiparticle VQE/8 Qubit Data (Final)/Delta = one-half/Nf = 3/q = 3pi over 4/5 Layers/8_Qubit_XXZ_5_Layer_HVA_Optimal_Values_BOBYQA_GPU_3_Filled_States_Periodic_Boundary_Conditions_PH_State_3_Delta_0.5.txt")
Energies_6_Layer_q_3pi_over_4 = np.loadtxt(r"/mnt/c/Users/Saavanth Velury/Desktop/Quasiparticle VQE/8 Qubit Data (Final)/Delta = one-half/Nf = 3/q = 3pi over 4/6 Layers/8_Qubit_XXZ_6_Layer_HVA_Optimal_Values_BOBYQA_GPU_3_Filled_States_Periodic_Boundary_Conditions_PH_State_3_Delta_0.5.txt")
Energies_7_Layer_q_3pi_over_4 = np.loadtxt(r"/mnt/c/Users/Saavanth Velury/Desktop/Quasiparticle VQE/8 Qubit Data (Final)/Delta = one-half/Nf = 3/q = 3pi over 4/7 Layers/8_Qubit_XXZ_7_Layer_HVA_Optimal_Values_BOBYQA_GPU_3_Filled_States_Periodic_Boundary_Conditions_PH_State_3_Delta_0.5.txt")
Energies_8_Layer_q_3pi_over_4 = np.loadtxt(r"/mnt/c/Users/Saavanth Velury/Desktop/Quasiparticle VQE/8 Qubit Data (Final)/Delta = one-half/Nf = 3/q = 3pi over 4/8 Layers/8_Qubit_XXZ_8_Layer_HVA_Optimal_Values_BOBYQA_GPU_3_Filled_States_Periodic_Boundary_Conditions_PH_State_3_Delta_0.5.txt")
Optimal_Value_1_Layer_q_3pi_over_4 = Energies_1_Layer_q_3pi_over_4[np.argmin(Energies_1_Layer_q_3pi_over_4)]
Optimal_Value_2_Layer_q_3pi_over_4 = Energies_2_Layer_q_3pi_over_4[np.argmin(Energies_2_Layer_q_3pi_over_4)]
Optimal_Value_3_Layer_q_3pi_over_4 = Energies_3_Layer_q_3pi_over_4[np.argmin(Energies_3_Layer_q_3pi_over_4)]
Optimal_Value_4_Layer_q_3pi_over_4 = Energies_4_Layer_q_3pi_over_4[np.argmin(Energies_4_Layer_q_3pi_over_4)]
Optimal_Value_5_Layer_q_3pi_over_4 = Energies_5_Layer_q_3pi_over_4[np.argmin(Energies_5_Layer_q_3pi_over_4)]
Optimal_Value_6_Layer_q_3pi_over_4 = Energies_6_Layer_q_3pi_over_4[np.argmin(Energies_6_Layer_q_3pi_over_4)]
Optimal_Value_7_Layer_q_3pi_over_4 = Energies_7_Layer_q_3pi_over_4[np.argmin(Energies_7_Layer_q_3pi_over_4)]
Optimal_Value_8_Layer_q_3pi_over_4 = Energies_8_Layer_q_3pi_over_4[np.argmin(Energies_8_Layer_q_3pi_over_4)]
Optimal_Values_q_3pi_over_4 = [Optimal_Value_1_Layer_q_3pi_over_4, Optimal_Value_2_Layer_q_3pi_over_4, Optimal_Value_3_Layer_q_3pi_over_4, Optimal_Value_4_Layer_q_3pi_over_4, Optimal_Value_5_Layer_q_3pi_over_4, Optimal_Value_6_Layer_q_3pi_over_4, Optimal_Value_7_Layer_q_3pi_over_4, Optimal_Value_8_Layer_q_3pi_over_4]

#q = 0
Energies_1_Layer_q0 = np.loadtxt(r"/mnt/c/Users/Saavanth Velury/Desktop/Quasiparticle VQE/8 Qubit Data (Final)/Delta = one-half/Nf = 3/q = 0/1 Layer/8_Qubit_XXZ_1_Layer_HVA_Optimal_Values_BOBYQA_GPU_3_Filled_States_Periodic_Boundary_Conditions_PH_State_4_Delta_0.5.txt")
Energies_2_Layer_q0 = np.loadtxt(r"/mnt/c/Users/Saavanth Velury/Desktop/Quasiparticle VQE/8 Qubit Data (Final)/Delta = one-half/Nf = 3/q = 0/2 Layers/8_Qubit_XXZ_2_Layer_HVA_Optimal_Values_BOBYQA_GPU_3_Filled_States_Periodic_Boundary_Conditions_PH_State_4_Delta_0.5.txt")
Energies_3_Layer_q0 = np.loadtxt(r"/mnt/c/Users/Saavanth Velury/Desktop/Quasiparticle VQE/8 Qubit Data (Final)/Delta = one-half/Nf = 3/q = 0/3 Layers/8_Qubit_XXZ_3_Layer_HVA_Optimal_Values_BOBYQA_GPU_3_Filled_States_Periodic_Boundary_Conditions_PH_State_4_Delta_0.5.txt")
Energies_4_Layer_q0 = np.loadtxt(r"/mnt/c/Users/Saavanth Velury/Desktop/Quasiparticle VQE/8 Qubit Data (Final)/Delta = one-half/Nf = 3/q = 0/4 Layers/8_Qubit_XXZ_4_Layer_HVA_Optimal_Values_BOBYQA_GPU_3_Filled_States_Periodic_Boundary_Conditions_PH_State_4_Delta_0.5.txt")
Energies_5_Layer_q0 = np.loadtxt(r"/mnt/c/Users/Saavanth Velury/Desktop/Quasiparticle VQE/8 Qubit Data (Final)/Delta = one-half/Nf = 3/q = 0/5 Layers/8_Qubit_XXZ_5_Layer_HVA_Optimal_Values_BOBYQA_GPU_3_Filled_States_Periodic_Boundary_Conditions_PH_State_4_Delta_0.5.txt")
Energies_6_Layer_q0 = np.loadtxt(r"/mnt/c/Users/Saavanth Velury/Desktop/Quasiparticle VQE/8 Qubit Data (Final)/Delta = one-half/Nf = 3/q = 0/6 Layers/8_Qubit_XXZ_6_Layer_HVA_Optimal_Values_BOBYQA_GPU_3_Filled_States_Periodic_Boundary_Conditions_PH_State_4_Delta_0.5.txt")
Energies_7_Layer_q0 = np.loadtxt(r"/mnt/c/Users/Saavanth Velury/Desktop/Quasiparticle VQE/8 Qubit Data (Final)/Delta = one-half/Nf = 3/q = 0/7 Layers/8_Qubit_XXZ_7_Layer_HVA_Optimal_Values_BOBYQA_GPU_3_Filled_States_Periodic_Boundary_Conditions_PH_State_4_Delta_0.5.txt")
Energies_8_Layer_q0 = np.loadtxt(r"/mnt/c/Users/Saavanth Velury/Desktop/Quasiparticle VQE/8 Qubit Data (Final)/Delta = one-half/Nf = 3/q = 0/8 Layers/8_Qubit_XXZ_8_Layer_HVA_Optimal_Values_BOBYQA_GPU_3_Filled_States_Periodic_Boundary_Conditions_PH_State_4_Delta_0.5.txt")
Optimal_Value_1_Layer_q0 = Energies_1_Layer_q0[np.argmin(Energies_1_Layer_q0)]
Optimal_Value_2_Layer_q0 = Energies_2_Layer_q0[np.argmin(Energies_2_Layer_q0)]
Optimal_Value_3_Layer_q0 = Energies_3_Layer_q0[np.argmin(Energies_3_Layer_q0)]
Optimal_Value_4_Layer_q0 = Energies_4_Layer_q0[np.argmin(Energies_4_Layer_q0)]
Optimal_Value_5_Layer_q0 = Energies_5_Layer_q0[np.argmin(Energies_5_Layer_q0)]
Optimal_Value_6_Layer_q0 = Energies_6_Layer_q0[np.argmin(Energies_6_Layer_q0)]
Optimal_Value_7_Layer_q0 = Energies_7_Layer_q0[np.argmin(Energies_7_Layer_q0)]
Optimal_Value_8_Layer_q0 = Energies_8_Layer_q0[np.argmin(Energies_8_Layer_q0)]
Optimal_Values_q0 = [Optimal_Value_1_Layer_q0, Optimal_Value_2_Layer_q0, Optimal_Value_3_Layer_q0, Optimal_Value_4_Layer_q0, Optimal_Value_5_Layer_q0, Optimal_Value_6_Layer_q0, Optimal_Value_7_Layer_q0, Optimal_Value_8_Layer_q0]

Energies_1_Layer_q0_Alternate = np.loadtxt(r"/mnt/c/Users/Saavanth Velury/Desktop/Quasiparticle VQE/8 Qubit Data (Final)/Delta = one-half/Nf = 3/q = 0/1 Layer/8_Qubit_XXZ_1_Layer_HVA_Optimal_Values_BOBYQA_GPU_3_Filled_States_Periodic_Boundary_Conditions_PH_State_4_Alternate_Delta_0.5.txt")
Energies_2_Layer_q0_Alternate = np.loadtxt(r"/mnt/c/Users/Saavanth Velury/Desktop/Quasiparticle VQE/8 Qubit Data (Final)/Delta = one-half/Nf = 3/q = 0/2 Layers/8_Qubit_XXZ_2_Layer_HVA_Optimal_Values_BOBYQA_GPU_3_Filled_States_Periodic_Boundary_Conditions_PH_State_4_Alternate_Delta_0.5.txt")
Energies_3_Layer_q0_Alternate = np.loadtxt(r"/mnt/c/Users/Saavanth Velury/Desktop/Quasiparticle VQE/8 Qubit Data (Final)/Delta = one-half/Nf = 3/q = 0/3 Layers/8_Qubit_XXZ_3_Layer_HVA_Optimal_Values_BOBYQA_GPU_3_Filled_States_Periodic_Boundary_Conditions_PH_State_4_Alternate_Delta_0.5.txt")
Energies_4_Layer_q0_Alternate = np.loadtxt(r"/mnt/c/Users/Saavanth Velury/Desktop/Quasiparticle VQE/8 Qubit Data (Final)/Delta = one-half/Nf = 3/q = 0/4 Layers/8_Qubit_XXZ_4_Layer_HVA_Optimal_Values_BOBYQA_GPU_3_Filled_States_Periodic_Boundary_Conditions_PH_State_4_Alternate_Delta_0.5.txt")
Energies_5_Layer_q0_Alternate = np.loadtxt(r"/mnt/c/Users/Saavanth Velury/Desktop/Quasiparticle VQE/8 Qubit Data (Final)/Delta = one-half/Nf = 3/q = 0/5 Layers/8_Qubit_XXZ_5_Layer_HVA_Optimal_Values_BOBYQA_GPU_3_Filled_States_Periodic_Boundary_Conditions_PH_State_4_Alternate_Delta_0.5.txt")
Energies_6_Layer_q0_Alternate = np.loadtxt(r"/mnt/c/Users/Saavanth Velury/Desktop/Quasiparticle VQE/8 Qubit Data (Final)/Delta = one-half/Nf = 3/q = 0/6 Layers/8_Qubit_XXZ_6_Layer_HVA_Optimal_Values_BOBYQA_GPU_3_Filled_States_Periodic_Boundary_Conditions_PH_State_4_Alternate_Delta_0.5.txt")
Energies_7_Layer_q0_Alternate = np.loadtxt(r"/mnt/c/Users/Saavanth Velury/Desktop/Quasiparticle VQE/8 Qubit Data (Final)/Delta = one-half/Nf = 3/q = 0/7 Layers/8_Qubit_XXZ_7_Layer_HVA_Optimal_Values_BOBYQA_GPU_3_Filled_States_Periodic_Boundary_Conditions_PH_State_4_Alternate_Delta_0.5.txt")
Energies_8_Layer_q0_Alternate = np.loadtxt(r"/mnt/c/Users/Saavanth Velury/Desktop/Quasiparticle VQE/8 Qubit Data (Final)/Delta = one-half/Nf = 3/q = 0/8 Layers/8_Qubit_XXZ_8_Layer_HVA_Optimal_Values_BOBYQA_GPU_3_Filled_States_Periodic_Boundary_Conditions_PH_State_4_Alternate_Delta_0.5.txt")
Optimal_Value_1_Layer_q0_Alternate = Energies_1_Layer_q0_Alternate[np.argmin(Energies_1_Layer_q0_Alternate)]
Optimal_Value_2_Layer_q0_Alternate = Energies_2_Layer_q0_Alternate[np.argmin(Energies_2_Layer_q0_Alternate)]
Optimal_Value_3_Layer_q0_Alternate = Energies_3_Layer_q0_Alternate[np.argmin(Energies_3_Layer_q0_Alternate)]
Optimal_Value_4_Layer_q0_Alternate = Energies_4_Layer_q0_Alternate[np.argmin(Energies_4_Layer_q0_Alternate)]
Optimal_Value_5_Layer_q0_Alternate = Energies_5_Layer_q0_Alternate[np.argmin(Energies_5_Layer_q0_Alternate)]
Optimal_Value_6_Layer_q0_Alternate = Energies_6_Layer_q0_Alternate[np.argmin(Energies_6_Layer_q0_Alternate)]
Optimal_Value_7_Layer_q0_Alternate = Energies_7_Layer_q0_Alternate[np.argmin(Energies_7_Layer_q0_Alternate)]
Optimal_Value_8_Layer_q0_Alternate = Energies_8_Layer_q0_Alternate[np.argmin(Energies_8_Layer_q0_Alternate)]
Optimal_Values_q0_Alternate = [Optimal_Value_1_Layer_q0_Alternate, Optimal_Value_2_Layer_q0_Alternate, Optimal_Value_3_Layer_q0_Alternate, Optimal_Value_4_Layer_q0_Alternate, Optimal_Value_5_Layer_q0_Alternate, Optimal_Value_6_Layer_q0_Alternate, Optimal_Value_7_Layer_q0_Alternate, Optimal_Value_8_Layer_q0_Alternate]

# %%
ED_Values_Delta_One_Half = [0, -7.525055+10.987918, -6.366553+10.987918, -8.210116+10.987918, -5.438684+10.987918, -8.210116+10.987918, -6.366553+10.987918, -7.525055+10.987918, 0]
VQE_Values_Delta_One_Half = [0, -7.51960668-min(Optimal_Values_q_pi), -6.35800601-min(Optimal_Values_q_pi), -8.20430905-min(Optimal_Values_q_pi), min(Optimal_Values_q0)-min(Optimal_Values_q_pi), min(Optimal_Values_q_pi_over_4)-min(Optimal_Values_q_pi), min(Optimal_Values_q_pi_over_2)-min(Optimal_Values_q_pi), min(Optimal_Values_q_3pi_over_4)-min(Optimal_Values_q_pi), 0]

# %%
#Nf = 3 (Δ = 0.9)

#q = 0
Energies_8_Layer_q0 = np.loadtxt(r"/mnt/c/Users/Saavanth Velury/Desktop/Quasiparticle VQE/8 Qubit Data (Final)/Delta = nine-tenths/Nf = 3/q = 0/8 Layers/8_Qubit_XXZ_8_Layer_HVA_Optimal_Values_BOBYQA_GPU_3_Filled_States_Periodic_BC_PH_State_4_Three_Parameters_Delta_0.9.txt")
Optimal_Values_8_Layer_q0 = Energies_8_Layer_q0[np.argmin(Energies_8_Layer_q0)]

#q = pi/4
Energies_8_Layer_q_pi_over_4 = np.loadtxt(r"/mnt/c/Users/Saavanth Velury/Desktop/Quasiparticle VQE/8 Qubit Data (Final)/Delta = nine-tenths/Nf = 3/q = pi over 4/8 Layers/8_Qubit_XXZ_8_Layer_HVA_Optimal_Values_BOBYQA_GPU_3_Filled_States_Periodic_Boundary_Conditions_PH_State_Three_Parameters_Delta_0.9.txt")
Optimal_Values_8_Layer_q_pi_over_4 = Energies_8_Layer_q_pi_over_4[np.argmin(Energies_8_Layer_q_pi_over_4)]

#q = pi/2
Energies_8_Layer_q_pi_over_2 = np.loadtxt(r"/mnt/c/Users/Saavanth Velury/Desktop/Quasiparticle VQE/8 Qubit Data (Final)/Delta = nine-tenths/Nf = 3/q = pi over 2/8 Layers/8_Qubit_XXZ_8_Layer_HVA_Optimal_Values_BOBYQA_GPU_3_Filled_States_Periodic_BC_PH_State_2_Three_Parameters_Delta_0.9.txt")
Optimal_Values_8_Layer_q_pi_over_2 = Energies_8_Layer_q_pi_over_2[np.argmin(Energies_8_Layer_q_pi_over_2)]

#q = 3pi/4
Energies_8_Layer_q_3pi_over_4 = np.loadtxt(r"/mnt/c/Users/Saavanth Velury/Desktop/Quasiparticle VQE/8 Qubit Data (Final)/Delta = nine-tenths/Nf = 3/q = 3pi over 4/8 Layers/8_Qubit_XXZ_8_Layer_HVA_Optimal_Values_BOBYQA_GPU_3_Filled_States_Periodic_BC_PH_State_3_Three_Parameters_Delta_0.9.txt")
Optimal_Values_8_Layer_q_3pi_over_4 = Energies_8_Layer_q_3pi_over_4[np.argmin(Energies_8_Layer_q_3pi_over_4)]

#q = pi
Energies_8_Layer_q_pi = np.loadtxt(r"/mnt/c/Users/Saavanth Velury/Desktop/Quasiparticle VQE/8 Qubit Data (Final)/Delta = nine-tenths/Nf = 3/q = pi/8 Layers/8_Qubit_XXZ_8_Layer_HVA_Optimal_Values_BOBYQA_GPU_3_Filled_States_Periodic_Boundary_Conditions_Three_Parameters_Delta_0.9.txt")
Optimal_Values_8_Layer_q_pi = Energies_8_Layer_q_pi[np.argmin(Energies_8_Layer_q_pi)]

# %%
ED_Values_Delta_Nine_Tenths = [0, -8.343680+12.196264, -7.184698+12.196264, -9.496703+12.196264, -6.843529+12.196264, -9.496703+12.196264, -7.184698+12.196264, -8.343680+12.196264, 0]
VQE_Values_Delta_Nine_Tenths = [0, -8.33570525-Optimal_Values_8_Layer_q_pi, -7.17849710-Optimal_Values_8_Layer_q_pi, -9.48915477-Optimal_Values_8_Layer_q_pi, Optimal_Values_8_Layer_q0-Optimal_Values_8_Layer_q_pi, Optimal_Values_8_Layer_q_pi_over_4 - Optimal_Values_8_Layer_q_pi, Optimal_Values_8_Layer_q_pi_over_2 - Optimal_Values_8_Layer_q_pi, Optimal_Values_8_Layer_q_3pi_over_4 - Optimal_Values_8_Layer_q_pi, 0]

# %%
Optimal_Values_8_Layer_q_pi
# Out:
# -12.195657068490982

# %%
# Momentum points
q = np.array([-np.pi, -3*np.pi/4, -np.pi/2, -np.pi/4, 0, np.pi/4, np.pi/2, 3*np.pi/4, np.pi])

# Ground‐state energies
E0_ED_0p1  = -9.903723
E0_VQE_0p1 = -9.903277
E0_ED_0p5  = -10.987918
E0_VQE_0p5 = -10.984197
E0_ED_0p9 = -12.196264
E0_VQE_0p9 = -12.195657

# Dispersion *relative* to the ground state (so first entry is 0 offset)
disp_ED_0p1  = np.array(ED_Values_Delta_One_Tenth)
disp_VQE_0p1 = np.array(VQE_Values_Delta_One_Tenth)
disp_ED_0p5  = np.array(ED_Values_Delta_One_Half)
disp_VQE_0p5 = np.array(VQE_Values_Delta_One_Half)
disp_ED_0p9  = np.array(ED_Values_Delta_Nine_Tenths)
disp_VQE_0p9 = np.array(VQE_Values_Delta_Nine_Tenths)

# Build *actual* energy arrays by adding back the ground‐state
E_ED_0p1   = E0_ED_0p1  + disp_ED_0p1
E_VQE_0p1  = E0_VQE_0p1 + disp_VQE_0p1
E_ED_0p5   = E0_ED_0p5  + disp_ED_0p5
E_VQE_0p5  = E0_VQE_0p5 + disp_VQE_0p5
E_ED_0p9   = E0_ED_0p9  + disp_ED_0p9
E_VQE_0p9  = E0_VQE_0p9 + disp_VQE_0p9

# --- Plotting ---
fig, ax = plt.subplots(figsize=(12,12))

c_ED_0p1   = "#0000FF"   
c_VQE_0p1  = "#FF0000"   
c_ED_0p5   = "#00CC00"   
c_VQE_0p5  = "#800080"
c_ED_0p9   = "#FFA500"
c_VQE_0p9  = "#00FFFF"

bg = ax.patch.get_facecolor()

# ED (filled markers)
ax.plot(q, E_ED_0p1, linestyle='-', linewidth=4, color=c_ED_0p1, alpha=0.25, zorder=1)
ax.scatter(q, E_ED_0p1, s=15**2, facecolor=c_ED_0p1, edgecolor=c_ED_0p1, linewidth=1, alpha=1, zorder=4, label=r'ED, $\Delta=0.1$')
ax.plot(q, E_ED_0p5, linestyle='-', linewidth=4, color=c_ED_0p5, alpha=0.25, zorder=1)
ax.scatter(q, E_ED_0p5, s=15**2, facecolor=c_ED_0p5, edgecolor=c_ED_0p5, linewidth=1, alpha=1, zorder=4, label=r'ED, $\Delta=0.5$')
ax.plot(q, E_ED_0p9, linestyle='-', linewidth=4, color=c_ED_0p9, alpha=0.25, zorder=1)
ax.scatter(q, E_ED_0p9, s=15**2, facecolor=c_ED_0p9, edgecolor=c_ED_0p9, linewidth=1, alpha=1, zorder=4, label=r'ED, $\Delta=0.9$')

# VQE (open markers)
ax.scatter(q, E_VQE_0p1, s=30**2, facecolor=bg, edgecolor='none', zorder=2)
ax.scatter(q, E_VQE_0p1, s=30**2, facecolor='none', edgecolor=c_VQE_0p1, linewidth=2, zorder=3, label=r'VQE, $\Delta=0.1$')
ax.scatter(q, E_VQE_0p5, s=30**2, facecolor=bg, edgecolor='none', zorder=2)
ax.scatter(q, E_VQE_0p5, s=30**2, facecolor='none', edgecolor=c_VQE_0p5, linewidth=2, zorder=3, label=r'VQE, $\Delta=0.5$')
ax.scatter(q, E_VQE_0p9, s=30**2, facecolor=bg, edgecolor='none', zorder=2)
ax.scatter(q, E_VQE_0p9, s=30**2, facecolor='none', edgecolor=c_VQE_0p9, linewidth=2, zorder=3, label=r'VQE, $\Delta=0.9$')

# Axis formatting
ax.set_xlabel(r'$q$', fontsize=30, fontweight='bold')
ax.set_ylabel(r'$E(q)$', fontsize=30, fontweight='bold')       
ax.set_xticks(q)
ax.set_xticklabels([r'$-\pi$', r'$-\tfrac{3\pi}{4}$', r'$-\tfrac{\pi}{2}$', r'$-\tfrac{\pi}{4}$', r'$0$', r'$\tfrac{\pi}{4}$', r'$\tfrac{\pi}{2}$',
                    r'$\tfrac{3\pi}{4}$', r'$\pi$'], fontsize=30, fontweight='bold')
ax.set_yticklabels(ax.get_yticks(), fontsize=30, fontweight='bold')

# Inset textbox
text_props = dict(boxstyle='round', facecolor='white', alpha=0.8, pad=0.3)
ax.text(0.35, 0.95,
        r'$N_{F}=3\;(S_{z}=-1)$',
        transform=ax.transAxes,
        ha='right', va='top',
        bbox=text_props)

#leg = ax.legend(frameon=True, framealpha=1, fancybox = True)
#for text in leg.get_texts():
    #text.set_fontweight('bold')
    #text.set_fontsize(30)

#frame = leg.get_frame()
#frame.set_edgecolor('black')
#frame.set_linewidth(1.2) 
#frame.set_facecolor('white')

plt.tight_layout()
#plt.savefig('XXZ_Dispersion_8_Qubit_Not_Half_Filling.pdf', dpi=300, bbox_inches='tight')
plt.show()
# Out:
# /tmp/ipykernel_2773/1025793736.py:62: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_yticklabels(ax.get_yticks(), fontsize=30, fontweight='bold')

# %%
#Save Arrays
np.savetxt('ED_Values_3_Filled_States_Delta_Nine_Tenths_8_Qubit.txt', ED_Values_Delta_Nine_Tenths)
np.savetxt('VQE_Values_3_Filled_States_Delta_Nine_Tenths_8_Qubit.txt', VQE_Values_Delta_Nine_Tenths)
