# %%
import numpy as np
from matplotlib import pyplot as plt
import matplotlib as mpl
plt.rcParams.update({
    "text.usetex": True,
    "text.latex.preamble": r"\usepackage{amsmath}",
    "font.family": "serif",
    "font.serif": ["Computer Modern"],
    "pdf.fonttype": 42,
    "ps.fonttype": 42,
    "font.size": 30,
    'font.weight': 'bold',
    'axes.titleweight': 'bold',
    'axes.labelweight': 'bold'
})
import os
import warnings
with warnings.catch_warnings():
    warnings.simplefilter('ignore', category=UserWarning)

# %%
print("Exists?", os.path.exists(r"/mnt/c/Users/Saavanth Velury/Desktop/Quasiparticle VQE/8 Qubit Data (Final)/Delta = one-half/Nf = 4/q = pi/1 Layer/8_Qubit_XXZ_1_Layer_HVA_Optimal_Values_BOBYQA_GPU_4_Filled_States_Antiperiodic_Boundary_Conditions_PH_State_4_Alternate_Delta_0.5.txt"))
print("Is file?", os.path.isfile(r"/mnt/c/Users/Saavanth Velury/Desktop/Quasiparticle VQE/8 Qubit Data (Final)/Delta = one-half/Nf = 4/q = pi/1 Layer/8_Qubit_XXZ_1_Layer_HVA_Optimal_Values_BOBYQA_GPU_4_Filled_States_Antiperiodic_Boundary_Conditions_PH_State_4_Alternate_Delta_0.5.txt"))
# Out:
# Exists? True
# Is file? True

# %%
#Nf = 4 (Δ = 0.1)

#q = 0
Energies_1_Layer_q0 = np.loadtxt(r"/mnt/c/Users/Saavanth Velury/Desktop/Quasiparticle VQE/8 Qubit Data (Final)/Delta = one-tenth/Nf = 4/q = 0/1 Layer/8_Qubit_XXZ_1_Layer_HVA_Optimal_Values_BOBYQA_GPU_4_Filled_States_Antiperiodic_Boundary_Conditions.txt")
Energies_2_Layer_q0 = np.loadtxt(r"/mnt/c/Users/Saavanth Velury/Desktop/Quasiparticle VQE/8 Qubit Data (Final)/Delta = one-tenth/Nf = 4/q = 0/2 Layers/8_Qubit_XXZ_2_Layer_HVA_Optimal_Values_BOBYQA_GPU_4_Filled_States_Antiperiodic_Boundary_Conditions.txt")
Energies_3_Layer_q0 = np.loadtxt(r"/mnt/c/Users/Saavanth Velury/Desktop/Quasiparticle VQE/8 Qubit Data (Final)/Delta = one-tenth/Nf = 4/q = 0/3 Layers/8_Qubit_XXZ_3_Layer_HVA_Optimal_Values_BOBYQA_GPU_4_Filled_States_Antiperiodic_Boundary_Conditions.txt")
Energies_4_Layer_q0 = np.loadtxt(r"/mnt/c/Users/Saavanth Velury/Desktop/Quasiparticle VQE/8 Qubit Data (Final)/Delta = one-tenth/Nf = 4/q = 0/4 Layers/8_Qubit_XXZ_4_Layer_HVA_Optimal_Values_BOBYQA_GPU_4_Filled_States_Antiperiodic_Boundary_Conditions.txt")
Energies_5_Layer_q0 = np.loadtxt(r"/mnt/c/Users/Saavanth Velury/Desktop/Quasiparticle VQE/8 Qubit Data (Final)/Delta = one-tenth/Nf = 4/q = 0/5 Layers/8_Qubit_XXZ_5_Layer_HVA_Optimal_Values_BOBYQA_GPU_4_Filled_States_Antiperiodic_Boundary_Conditions.txt")
Energies_6_Layer_q0 = np.loadtxt(r"/mnt/c/Users/Saavanth Velury/Desktop/Quasiparticle VQE/8 Qubit Data (Final)/Delta = one-tenth/Nf = 4/q = 0/6 Layers/8_Qubit_XXZ_6_Layer_HVA_Optimal_Values_BOBYQA_GPU_4_Filled_States_Antiperiodic_Boundary_Conditions.txt")
Energies_7_Layer_q0 = np.loadtxt(r"/mnt/c/Users/Saavanth Velury/Desktop/Quasiparticle VQE/8 Qubit Data (Final)/Delta = one-tenth/Nf = 4/q = 0/7 Layers/8_Qubit_XXZ_7_Layer_HVA_Optimal_Values_BOBYQA_GPU_4_Filled_States_Antiperiodic_Boundary_Conditions.txt")
Energies_8_Layer_q0 = np.loadtxt(r"/mnt/c/Users/Saavanth Velury/Desktop/Quasiparticle VQE/8 Qubit Data (Final)/Delta = one-tenth/Nf = 4/q = 0/8 Layers/8_Qubit_XXZ_8_Layer_HVA_Optimal_Values_BOBYQA_GPU_4_Filled_States_Antiperiodic_Boundary_Conditions.txt")
Optimal_Value_1_Layer_q0 = Energies_1_Layer_q0[np.argmin(Energies_1_Layer_q0)]
Optimal_Value_2_Layer_q0 = Energies_2_Layer_q0[np.argmin(Energies_2_Layer_q0)]
Optimal_Value_3_Layer_q0 = Energies_3_Layer_q0[np.argmin(Energies_3_Layer_q0)]
Optimal_Value_4_Layer_q0 = Energies_4_Layer_q0[np.argmin(Energies_4_Layer_q0)]
Optimal_Value_5_Layer_q0 = Energies_5_Layer_q0[np.argmin(Energies_5_Layer_q0)]
Optimal_Value_6_Layer_q0 = Energies_6_Layer_q0[np.argmin(Energies_6_Layer_q0)]
Optimal_Value_7_Layer_q0 = Energies_7_Layer_q0[np.argmin(Energies_7_Layer_q0)]
Optimal_Value_8_Layer_q0 = Energies_8_Layer_q0[np.argmin(Energies_8_Layer_q0)]
Optimal_Values_q0 = [Optimal_Value_1_Layer_q0, Optimal_Value_2_Layer_q0, Optimal_Value_3_Layer_q0, Optimal_Value_4_Layer_q0, Optimal_Value_5_Layer_q0, Optimal_Value_6_Layer_q0, Optimal_Value_7_Layer_q0, Optimal_Value_8_Layer_q0]

#q = pi/4
Energies_1_Layer_q_pi_over_4 = np.loadtxt(r"/mnt/c/Users/Saavanth Velury/Desktop/Quasiparticle VQE/8 Qubit Data (Final)/Delta = one-tenth/Nf = 4/q = pi over 4/1 Layer/8_Qubit_XXZ_1_Layer_HVA_Optimal_Values_BOBYQA_GPU_4_Filled_States_Antiperiodic_Boundary_Conditions_PH_State.txt")
Energies_2_Layer_q_pi_over_4 = np.loadtxt(r"/mnt/c/Users/Saavanth Velury/Desktop/Quasiparticle VQE/8 Qubit Data (Final)/Delta = one-tenth/Nf = 4/q = pi over 4/2 Layers/8_Qubit_XXZ_2_Layer_HVA_Optimal_Values_BOBYQA_GPU_4_Filled_States_Antiperiodic_Boundary_Conditions_PH_State.txt")
Energies_3_Layer_q_pi_over_4 = np.loadtxt(r"/mnt/c/Users/Saavanth Velury/Desktop/Quasiparticle VQE/8 Qubit Data (Final)/Delta = one-tenth/Nf = 4/q = pi over 4/3 Layers/8_Qubit_XXZ_3_Layer_HVA_Optimal_Values_BOBYQA_GPU_4_Filled_States_Antiperiodic_Boundary_Conditions_PH_State.txt")
Energies_4_Layer_q_pi_over_4 = np.loadtxt(r"/mnt/c/Users/Saavanth Velury/Desktop/Quasiparticle VQE/8 Qubit Data (Final)/Delta = one-tenth/Nf = 4/q = pi over 4/4 Layers/8_Qubit_XXZ_4_Layer_HVA_Optimal_Values_BOBYQA_GPU_4_Filled_States_Antiperiodic_Boundary_Conditions_PH_State.txt")
Energies_5_Layer_q_pi_over_4 = np.loadtxt(r"/mnt/c/Users/Saavanth Velury/Desktop/Quasiparticle VQE/8 Qubit Data (Final)/Delta = one-tenth/Nf = 4/q = pi over 4/5 Layers/8_Qubit_XXZ_5_Layer_HVA_Optimal_Values_BOBYQA_GPU_4_Filled_States_Antiperiodic_Boundary_Conditions_PH_State.txt")
Energies_6_Layer_q_pi_over_4 = np.loadtxt(r"/mnt/c/Users/Saavanth Velury/Desktop/Quasiparticle VQE/8 Qubit Data (Final)/Delta = one-tenth/Nf = 4/q = pi over 4/6 Layers/8_Qubit_XXZ_6_Layer_HVA_Optimal_Values_BOBYQA_GPU_4_Filled_States_Antiperiodic_Boundary_Conditions_PH_State.txt")
Energies_7_Layer_q_pi_over_4 = np.loadtxt(r"/mnt/c/Users/Saavanth Velury/Desktop/Quasiparticle VQE/8 Qubit Data (Final)/Delta = one-tenth/Nf = 4/q = pi over 4/7 Layers/8_Qubit_XXZ_7_Layer_HVA_Optimal_Values_BOBYQA_GPU_4_Filled_States_Antiperiodic_Boundary_Conditions_PH_State.txt")
Energies_8_Layer_q_pi_over_4 = np.loadtxt(r"/mnt/c/Users/Saavanth Velury/Desktop/Quasiparticle VQE/8 Qubit Data (Final)/Delta = one-tenth/Nf = 4/q = pi over 4/8 Layers/8_Qubit_XXZ_8_Layer_HVA_Optimal_Values_BOBYQA_GPU_4_Filled_States_Antiperiodic_Boundary_Conditions_PH_State.txt")
Optimal_Value_1_Layer_q_pi_over_4 = Energies_1_Layer_q_pi_over_4[np.argmin(Energies_1_Layer_q_pi_over_4)]
Optimal_Value_2_Layer_q_pi_over_4 = Energies_2_Layer_q_pi_over_4[np.argmin(Energies_2_Layer_q_pi_over_4)]
Optimal_Value_3_Layer_q_pi_over_4 = Energies_3_Layer_q_pi_over_4[np.argmin(Energies_3_Layer_q_pi_over_4)]
Optimal_Value_4_Layer_q_pi_over_4 = Energies_4_Layer_q_pi_over_4[np.argmin(Energies_4_Layer_q_pi_over_4)]
Optimal_Value_5_Layer_q_pi_over_4 = Energies_5_Layer_q_pi_over_4[np.argmin(Energies_5_Layer_q_pi_over_4)]
Optimal_Value_6_Layer_q_pi_over_4 = Energies_6_Layer_q_pi_over_4[np.argmin(Energies_6_Layer_q_pi_over_4)]
Optimal_Value_7_Layer_q_pi_over_4 = Energies_7_Layer_q_pi_over_4[np.argmin(Energies_7_Layer_q_pi_over_4)]
Optimal_Value_8_Layer_q_pi_over_4 = Energies_8_Layer_q_pi_over_4[np.argmin(Energies_8_Layer_q_pi_over_4)]
Optimal_Values_q_pi_over_4 = [Optimal_Value_1_Layer_q_pi_over_4, Optimal_Value_2_Layer_q_pi_over_4, Optimal_Value_3_Layer_q_pi_over_4, Optimal_Value_4_Layer_q_pi_over_4, Optimal_Value_5_Layer_q_pi_over_4, Optimal_Value_6_Layer_q_pi_over_4, Optimal_Value_7_Layer_q_pi_over_4, Optimal_Value_8_Layer_q_pi_over_4]

#q = pi/2
Energies_1_Layer_q_pi_over_2 = np.loadtxt(r"/mnt/c/Users/Saavanth Velury/Desktop/Quasiparticle VQE/8 Qubit Data (Final)/Delta = one-tenth/Nf = 4/q = pi over 2/1 Layer/8_Qubit_XXZ_1_Layer_HVA_Optimal_Values_BOBYQA_GPU_4_Filled_States_Antiperiodic_Boundary_Conditions_PH_State_2.txt")
Energies_2_Layer_q_pi_over_2 = np.loadtxt(r"/mnt/c/Users/Saavanth Velury/Desktop/Quasiparticle VQE/8 Qubit Data (Final)/Delta = one-tenth/Nf = 4/q = pi over 2/2 Layers/8_Qubit_XXZ_2_Layer_HVA_Optimal_Values_BOBYQA_GPU_4_Filled_States_Antiperiodic_Boundary_Conditions_PH_State_2.txt")
Energies_3_Layer_q_pi_over_2 = np.loadtxt(r"/mnt/c/Users/Saavanth Velury/Desktop/Quasiparticle VQE/8 Qubit Data (Final)/Delta = one-tenth/Nf = 4/q = pi over 2/3 Layers/8_Qubit_XXZ_3_Layer_HVA_Optimal_Values_BOBYQA_GPU_4_Filled_States_Antiperiodic_Boundary_Conditions_PH_State_2.txt")
Energies_4_Layer_q_pi_over_2 = np.loadtxt(r"/mnt/c/Users/Saavanth Velury/Desktop/Quasiparticle VQE/8 Qubit Data (Final)/Delta = one-tenth/Nf = 4/q = pi over 2/4 Layers/8_Qubit_XXZ_4_Layer_HVA_Optimal_Values_BOBYQA_GPU_4_Filled_States_Antiperiodic_Boundary_Conditions_PH_State_2.txt")
Energies_5_Layer_q_pi_over_2 = np.loadtxt(r"/mnt/c/Users/Saavanth Velury/Desktop/Quasiparticle VQE/8 Qubit Data (Final)/Delta = one-tenth/Nf = 4/q = pi over 2/5 Layers/8_Qubit_XXZ_5_Layer_HVA_Optimal_Values_BOBYQA_GPU_4_Filled_States_Antiperiodic_Boundary_Conditions_PH_State_2.txt")
Energies_6_Layer_q_pi_over_2 = np.loadtxt(r"/mnt/c/Users/Saavanth Velury/Desktop/Quasiparticle VQE/8 Qubit Data (Final)/Delta = one-tenth/Nf = 4/q = pi over 2/6 Layers/8_Qubit_XXZ_6_Layer_HVA_Optimal_Values_BOBYQA_GPU_4_Filled_States_Antiperiodic_Boundary_Conditions_PH_State_2.txt")
Energies_7_Layer_q_pi_over_2 = np.loadtxt(r"/mnt/c/Users/Saavanth Velury/Desktop/Quasiparticle VQE/8 Qubit Data (Final)/Delta = one-tenth/Nf = 4/q = pi over 2/7 Layers/8_Qubit_XXZ_7_Layer_HVA_Optimal_Values_BOBYQA_GPU_4_Filled_States_Antiperiodic_Boundary_Conditions_PH_State_2.txt")
Energies_8_Layer_q_pi_over_2 = np.loadtxt(r"/mnt/c/Users/Saavanth Velury/Desktop/Quasiparticle VQE/8 Qubit Data (Final)/Delta = one-tenth/Nf = 4/q = pi over 2/8 Layers/8_Qubit_XXZ_8_Layer_HVA_Optimal_Values_BOBYQA_GPU_4_Filled_States_Antiperiodic_Boundary_Conditions_PH_State_2.txt")
Optimal_Value_1_Layer_q_pi_over_2 = Energies_1_Layer_q_pi_over_2[np.argmin(Energies_1_Layer_q_pi_over_2)]
Optimal_Value_2_Layer_q_pi_over_2 = Energies_2_Layer_q_pi_over_2[np.argmin(Energies_2_Layer_q_pi_over_2)]
Optimal_Value_3_Layer_q_pi_over_2 = Energies_3_Layer_q_pi_over_2[np.argmin(Energies_3_Layer_q_pi_over_2)]
Optimal_Value_4_Layer_q_pi_over_2 = Energies_4_Layer_q_pi_over_2[np.argmin(Energies_4_Layer_q_pi_over_2)]
Optimal_Value_5_Layer_q_pi_over_2 = Energies_5_Layer_q_pi_over_2[np.argmin(Energies_5_Layer_q_pi_over_2)]
Optimal_Value_6_Layer_q_pi_over_2 = Energies_6_Layer_q_pi_over_2[np.argmin(Energies_6_Layer_q_pi_over_2)]
Optimal_Value_7_Layer_q_pi_over_2 = Energies_7_Layer_q_pi_over_2[np.argmin(Energies_7_Layer_q_pi_over_2)]
Optimal_Value_8_Layer_q_pi_over_2 = Energies_8_Layer_q_pi_over_2[np.argmin(Energies_8_Layer_q_pi_over_2)]
Optimal_Values_q_pi_over_2 = [Optimal_Value_1_Layer_q_pi_over_2, Optimal_Value_2_Layer_q_pi_over_2, Optimal_Value_3_Layer_q_pi_over_2, Optimal_Value_4_Layer_q_pi_over_2, Optimal_Value_5_Layer_q_pi_over_2, Optimal_Value_6_Layer_q_pi_over_2, Optimal_Value_7_Layer_q_pi_over_2, Optimal_Value_8_Layer_q_pi_over_2]

Energies_1_Layer_q_pi_over_2_Alternate = np.loadtxt(r"/mnt/c/Users/Saavanth Velury/Desktop/Quasiparticle VQE/8 Qubit Data (Final)/Delta = one-tenth/Nf = 4/q = pi over 2/1 Layer/8_Qubit_XXZ_1_Layer_HVA_Optimal_Values_BOBYQA_GPU_4_Filled_States_Antiperiodic_Boundary_Conditions_PH_State_2_Alternate.txt")
Energies_2_Layer_q_pi_over_2_Alternate = np.loadtxt(r"/mnt/c/Users/Saavanth Velury/Desktop/Quasiparticle VQE/8 Qubit Data (Final)/Delta = one-tenth/Nf = 4/q = pi over 2/2 Layers/8_Qubit_XXZ_2_Layer_HVA_Optimal_Values_BOBYQA_GPU_4_Filled_States_Antiperiodic_Boundary_Conditions_PH_State_2_Alternate.txt")
Energies_3_Layer_q_pi_over_2_Alternate = np.loadtxt(r"/mnt/c/Users/Saavanth Velury/Desktop/Quasiparticle VQE/8 Qubit Data (Final)/Delta = one-tenth/Nf = 4/q = pi over 2/3 Layers/8_Qubit_XXZ_3_Layer_HVA_Optimal_Values_BOBYQA_GPU_4_Filled_States_Antiperiodic_Boundary_Conditions_PH_State_2_Alternate.txt")
Energies_4_Layer_q_pi_over_2_Alternate = np.loadtxt(r"/mnt/c/Users/Saavanth Velury/Desktop/Quasiparticle VQE/8 Qubit Data (Final)/Delta = one-tenth/Nf = 4/q = pi over 2/4 Layers/8_Qubit_XXZ_4_Layer_HVA_Optimal_Values_BOBYQA_GPU_4_Filled_States_Antiperiodic_Boundary_Conditions_PH_State_2_Alternate.txt")
Energies_5_Layer_q_pi_over_2_Alternate = np.loadtxt(r"/mnt/c/Users/Saavanth Velury/Desktop/Quasiparticle VQE/8 Qubit Data (Final)/Delta = one-tenth/Nf = 4/q = pi over 2/5 Layers/8_Qubit_XXZ_5_Layer_HVA_Optimal_Values_BOBYQA_GPU_4_Filled_States_Antiperiodic_Boundary_Conditions_PH_State_2_Alternate.txt")
Energies_6_Layer_q_pi_over_2_Alternate = np.loadtxt(r"/mnt/c/Users/Saavanth Velury/Desktop/Quasiparticle VQE/8 Qubit Data (Final)/Delta = one-tenth/Nf = 4/q = pi over 2/6 Layers/8_Qubit_XXZ_6_Layer_HVA_Optimal_Values_BOBYQA_GPU_4_Filled_States_Antiperiodic_Boundary_Conditions_PH_State_2_Alternate.txt")
Energies_7_Layer_q_pi_over_2_Alternate = np.loadtxt(r"/mnt/c/Users/Saavanth Velury/Desktop/Quasiparticle VQE/8 Qubit Data (Final)/Delta = one-tenth/Nf = 4/q = pi over 2/7 Layers/8_Qubit_XXZ_7_Layer_HVA_Optimal_Values_BOBYQA_GPU_4_Filled_States_Antiperiodic_Boundary_Conditions_PH_State_2_Alternate.txt")
Energies_8_Layer_q_pi_over_2_Alternate = np.loadtxt(r"/mnt/c/Users/Saavanth Velury/Desktop/Quasiparticle VQE/8 Qubit Data (Final)/Delta = one-tenth/Nf = 4/q = pi over 2/8 Layers/8_Qubit_XXZ_8_Layer_HVA_Optimal_Values_BOBYQA_GPU_4_Filled_States_Antiperiodic_Boundary_Conditions_PH_State_2_Alternate.txt")
Optimal_Value_1_Layer_q_pi_over_2_Alternate = Energies_1_Layer_q_pi_over_2_Alternate[np.argmin(Energies_1_Layer_q_pi_over_2_Alternate)]
Optimal_Value_2_Layer_q_pi_over_2_Alternate = Energies_2_Layer_q_pi_over_2_Alternate[np.argmin(Energies_2_Layer_q_pi_over_2_Alternate)]
Optimal_Value_3_Layer_q_pi_over_2_Alternate = Energies_3_Layer_q_pi_over_2_Alternate[np.argmin(Energies_3_Layer_q_pi_over_2_Alternate)]
Optimal_Value_4_Layer_q_pi_over_2_Alternate = Energies_4_Layer_q_pi_over_2_Alternate[np.argmin(Energies_4_Layer_q_pi_over_2_Alternate)]
Optimal_Value_5_Layer_q_pi_over_2_Alternate = Energies_5_Layer_q_pi_over_2_Alternate[np.argmin(Energies_5_Layer_q_pi_over_2_Alternate)]
Optimal_Value_6_Layer_q_pi_over_2_Alternate = Energies_6_Layer_q_pi_over_2_Alternate[np.argmin(Energies_6_Layer_q_pi_over_2_Alternate)]
Optimal_Value_7_Layer_q_pi_over_2_Alternate = Energies_7_Layer_q_pi_over_2_Alternate[np.argmin(Energies_7_Layer_q_pi_over_2_Alternate)]
Optimal_Value_8_Layer_q_pi_over_2_Alternate = Energies_8_Layer_q_pi_over_2_Alternate[np.argmin(Energies_8_Layer_q_pi_over_2_Alternate)]
Optimal_Values_q_pi_over_2_Alternate = [Optimal_Value_1_Layer_q_pi_over_2_Alternate, Optimal_Value_2_Layer_q_pi_over_2_Alternate, Optimal_Value_3_Layer_q_pi_over_2_Alternate, Optimal_Value_4_Layer_q_pi_over_2_Alternate, Optimal_Value_5_Layer_q_pi_over_2_Alternate, Optimal_Value_6_Layer_q_pi_over_2_Alternate, Optimal_Value_7_Layer_q_pi_over_2_Alternate, Optimal_Value_8_Layer_q_pi_over_2_Alternate]

#q = 3pi/4
Energies_1_Layer_q_3pi_over_4 = np.loadtxt(r"/mnt/c/Users/Saavanth Velury/Desktop/Quasiparticle VQE/8 Qubit Data (Final)/Delta = one-tenth/Nf = 4/q = 3pi over 4/1 Layer/8_Qubit_XXZ_1_Layer_HVA_Optimal_Values_BOBYQA_GPU_4_Filled_States_Antiperiodic_Boundary_Conditions_PH_State_3.txt")
Energies_2_Layer_q_3pi_over_4 = np.loadtxt(r"/mnt/c/Users/Saavanth Velury/Desktop/Quasiparticle VQE/8 Qubit Data (Final)/Delta = one-tenth/Nf = 4/q = 3pi over 4/2 Layers/8_Qubit_XXZ_2_Layer_HVA_Optimal_Values_BOBYQA_GPU_4_Filled_States_Antiperiodic_Boundary_Conditions_PH_State_3.txt")
Energies_3_Layer_q_3pi_over_4 = np.loadtxt(r"/mnt/c/Users/Saavanth Velury/Desktop/Quasiparticle VQE/8 Qubit Data (Final)/Delta = one-tenth/Nf = 4/q = 3pi over 4/3 Layers/8_Qubit_XXZ_3_Layer_HVA_Optimal_Values_BOBYQA_GPU_4_Filled_States_Antiperiodic_Boundary_Conditions_PH_State_3.txt")
Energies_4_Layer_q_3pi_over_4 = np.loadtxt(r"/mnt/c/Users/Saavanth Velury/Desktop/Quasiparticle VQE/8 Qubit Data (Final)/Delta = one-tenth/Nf = 4/q = 3pi over 4/4 Layers/8_Qubit_XXZ_4_Layer_HVA_Optimal_Values_BOBYQA_GPU_4_Filled_States_Antiperiodic_Boundary_Conditions_PH_State_3.txt")
Energies_5_Layer_q_3pi_over_4 = np.loadtxt(r"/mnt/c/Users/Saavanth Velury/Desktop/Quasiparticle VQE/8 Qubit Data (Final)/Delta = one-tenth/Nf = 4/q = 3pi over 4/5 Layers/8_Qubit_XXZ_5_Layer_HVA_Optimal_Values_BOBYQA_GPU_4_Filled_States_Antiperiodic_Boundary_Conditions_PH_State_3.txt")
Energies_6_Layer_q_3pi_over_4 = np.loadtxt(r"/mnt/c/Users/Saavanth Velury/Desktop/Quasiparticle VQE/8 Qubit Data (Final)/Delta = one-tenth/Nf = 4/q = 3pi over 4/6 Layers/8_Qubit_XXZ_6_Layer_HVA_Optimal_Values_BOBYQA_GPU_4_Filled_States_Antiperiodic_Boundary_Conditions_PH_State_3.txt")
Energies_7_Layer_q_3pi_over_4 = np.loadtxt(r"/mnt/c/Users/Saavanth Velury/Desktop/Quasiparticle VQE/8 Qubit Data (Final)/Delta = one-tenth/Nf = 4/q = 3pi over 4/7 Layers/8_Qubit_XXZ_7_Layer_HVA_Optimal_Values_BOBYQA_GPU_4_Filled_States_Antiperiodic_Boundary_Conditions_PH_State_3.txt")
Energies_8_Layer_q_3pi_over_4 = np.loadtxt(r"/mnt/c/Users/Saavanth Velury/Desktop/Quasiparticle VQE/8 Qubit Data (Final)/Delta = one-tenth/Nf = 4/q = 3pi over 4/8 Layers/8_Qubit_XXZ_8_Layer_HVA_Optimal_Values_BOBYQA_GPU_4_Filled_States_Antiperiodic_Boundary_Conditions_PH_State_3.txt")
Optimal_Value_1_Layer_q_3pi_over_4 = Energies_1_Layer_q_3pi_over_4[np.argmin(Energies_1_Layer_q_3pi_over_4)]
Optimal_Value_2_Layer_q_3pi_over_4 = Energies_2_Layer_q_3pi_over_4[np.argmin(Energies_2_Layer_q_3pi_over_4)]
Optimal_Value_3_Layer_q_3pi_over_4 = Energies_3_Layer_q_3pi_over_4[np.argmin(Energies_3_Layer_q_3pi_over_4)]
Optimal_Value_4_Layer_q_3pi_over_4 = Energies_4_Layer_q_3pi_over_4[np.argmin(Energies_4_Layer_q_3pi_over_4)]
Optimal_Value_5_Layer_q_3pi_over_4 = Energies_5_Layer_q_3pi_over_4[np.argmin(Energies_5_Layer_q_3pi_over_4)]
Optimal_Value_6_Layer_q_3pi_over_4 = Energies_6_Layer_q_3pi_over_4[np.argmin(Energies_6_Layer_q_3pi_over_4)]
Optimal_Value_7_Layer_q_3pi_over_4 = Energies_7_Layer_q_3pi_over_4[np.argmin(Energies_7_Layer_q_3pi_over_4)]
Optimal_Value_8_Layer_q_3pi_over_4 = Energies_8_Layer_q_3pi_over_4[np.argmin(Energies_8_Layer_q_3pi_over_4)]
Optimal_Values_q_3pi_over_4 = [Optimal_Value_1_Layer_q_3pi_over_4, Optimal_Value_2_Layer_q_3pi_over_4, Optimal_Value_3_Layer_q_3pi_over_4, Optimal_Value_4_Layer_q_3pi_over_4, Optimal_Value_5_Layer_q_3pi_over_4, Optimal_Value_6_Layer_q_3pi_over_4, Optimal_Value_7_Layer_q_3pi_over_4, Optimal_Value_8_Layer_q_3pi_over_4]

Energies_1_Layer_q_3pi_over_4_Alternate = np.loadtxt(r"/mnt/c/Users/Saavanth Velury/Desktop/Quasiparticle VQE/8 Qubit Data (Final)/Delta = one-tenth/Nf = 4/q = 3pi over 4/1 Layer/8_Qubit_XXZ_1_Layer_HVA_Optimal_Values_BOBYQA_GPU_4_Filled_States_Antiperiodic_Boundary_Conditions_PH_State_3_Alternate.txt")
Energies_2_Layer_q_3pi_over_4_Alternate = np.loadtxt(r"/mnt/c/Users/Saavanth Velury/Desktop/Quasiparticle VQE/8 Qubit Data (Final)/Delta = one-tenth/Nf = 4/q = 3pi over 4/2 Layers/8_Qubit_XXZ_2_Layer_HVA_Optimal_Values_BOBYQA_GPU_4_Filled_States_Antiperiodic_Boundary_Conditions_PH_State_3_Alternate.txt")
Energies_3_Layer_q_3pi_over_4_Alternate = np.loadtxt(r"/mnt/c/Users/Saavanth Velury/Desktop/Quasiparticle VQE/8 Qubit Data (Final)/Delta = one-tenth/Nf = 4/q = 3pi over 4/3 Layers/8_Qubit_XXZ_3_Layer_HVA_Optimal_Values_BOBYQA_GPU_4_Filled_States_Antiperiodic_Boundary_Conditions_PH_State_3_Alternate.txt")
Energies_4_Layer_q_3pi_over_4_Alternate = np.loadtxt(r"/mnt/c/Users/Saavanth Velury/Desktop/Quasiparticle VQE/8 Qubit Data (Final)/Delta = one-tenth/Nf = 4/q = 3pi over 4/4 Layers/8_Qubit_XXZ_4_Layer_HVA_Optimal_Values_BOBYQA_GPU_4_Filled_States_Antiperiodic_Boundary_Conditions_PH_State_3_Alternate.txt")
Energies_5_Layer_q_3pi_over_4_Alternate = np.loadtxt(r"/mnt/c/Users/Saavanth Velury/Desktop/Quasiparticle VQE/8 Qubit Data (Final)/Delta = one-tenth/Nf = 4/q = 3pi over 4/5 Layers/8_Qubit_XXZ_5_Layer_HVA_Optimal_Values_BOBYQA_GPU_4_Filled_States_Antiperiodic_Boundary_Conditions_PH_State_3_Alternate.txt")
Energies_6_Layer_q_3pi_over_4_Alternate = np.loadtxt(r"/mnt/c/Users/Saavanth Velury/Desktop/Quasiparticle VQE/8 Qubit Data (Final)/Delta = one-tenth/Nf = 4/q = 3pi over 4/6 Layers/8_Qubit_XXZ_6_Layer_HVA_Optimal_Values_BOBYQA_GPU_4_Filled_States_Antiperiodic_Boundary_Conditions_PH_State_3_Alternate.txt")
Energies_7_Layer_q_3pi_over_4_Alternate = np.loadtxt(r"/mnt/c/Users/Saavanth Velury/Desktop/Quasiparticle VQE/8 Qubit Data (Final)/Delta = one-tenth/Nf = 4/q = 3pi over 4/7 Layers/8_Qubit_XXZ_7_Layer_HVA_Optimal_Values_BOBYQA_GPU_4_Filled_States_Antiperiodic_Boundary_Conditions_PH_State_3_Alternate.txt")
Energies_8_Layer_q_3pi_over_4_Alternate = np.loadtxt(r"/mnt/c/Users/Saavanth Velury/Desktop/Quasiparticle VQE/8 Qubit Data (Final)/Delta = one-tenth/Nf = 4/q = 3pi over 4/8 Layers/8_Qubit_XXZ_8_Layer_HVA_Optimal_Values_BOBYQA_GPU_4_Filled_States_Antiperiodic_Boundary_Conditions_PH_State_3_Alternate.txt")
Optimal_Value_1_Layer_q_3pi_over_4_Alternate = Energies_1_Layer_q_3pi_over_4_Alternate[np.argmin(Energies_1_Layer_q_3pi_over_4_Alternate)]
Optimal_Value_2_Layer_q_3pi_over_4_Alternate = Energies_2_Layer_q_3pi_over_4_Alternate[np.argmin(Energies_2_Layer_q_3pi_over_4_Alternate)]
Optimal_Value_3_Layer_q_3pi_over_4_Alternate = Energies_3_Layer_q_3pi_over_4_Alternate[np.argmin(Energies_3_Layer_q_3pi_over_4_Alternate)]
Optimal_Value_4_Layer_q_3pi_over_4_Alternate = Energies_4_Layer_q_3pi_over_4_Alternate[np.argmin(Energies_4_Layer_q_3pi_over_4_Alternate)]
Optimal_Value_5_Layer_q_3pi_over_4_Alternate = Energies_5_Layer_q_3pi_over_4_Alternate[np.argmin(Energies_5_Layer_q_3pi_over_4_Alternate)]
Optimal_Value_6_Layer_q_3pi_over_4_Alternate = Energies_6_Layer_q_3pi_over_4_Alternate[np.argmin(Energies_6_Layer_q_3pi_over_4_Alternate)]
Optimal_Value_7_Layer_q_3pi_over_4_Alternate = Energies_7_Layer_q_3pi_over_4_Alternate[np.argmin(Energies_7_Layer_q_3pi_over_4_Alternate)]
Optimal_Value_8_Layer_q_3pi_over_4_Alternate = Energies_8_Layer_q_3pi_over_4_Alternate[np.argmin(Energies_8_Layer_q_3pi_over_4_Alternate)]
Optimal_Values_q_3pi_over_4_Alternate = [Optimal_Value_1_Layer_q_3pi_over_4_Alternate, Optimal_Value_2_Layer_q_3pi_over_4_Alternate, Optimal_Value_3_Layer_q_3pi_over_4_Alternate, Optimal_Value_4_Layer_q_3pi_over_4_Alternate, Optimal_Value_5_Layer_q_3pi_over_4_Alternate, Optimal_Value_6_Layer_q_3pi_over_4_Alternate, Optimal_Value_7_Layer_q_3pi_over_4_Alternate, Optimal_Value_8_Layer_q_3pi_over_4_Alternate]

#q = pi
Energies_1_Layer_q_pi = np.loadtxt(r"/mnt/c/Users/Saavanth Velury/Desktop/Quasiparticle VQE/8 Qubit Data (Final)/Delta = one-tenth/Nf = 4/q = pi/1 Layer/8_Qubit_XXZ_1_Layer_HVA_Optimal_Values_BOBYQA_GPU_4_Filled_States_Antiperiodic_Boundary_Conditions_PH_State_4.txt")
Energies_2_Layer_q_pi = np.loadtxt(r"/mnt/c/Users/Saavanth Velury/Desktop/Quasiparticle VQE/8 Qubit Data (Final)/Delta = one-tenth/Nf = 4/q = pi/2 Layers/8_Qubit_XXZ_2_Layer_HVA_Optimal_Values_BOBYQA_GPU_4_Filled_States_Antiperiodic_Boundary_Conditions_PH_State_4.txt")
Energies_3_Layer_q_pi = np.loadtxt(r"/mnt/c/Users/Saavanth Velury/Desktop/Quasiparticle VQE/8 Qubit Data (Final)/Delta = one-tenth/Nf = 4/q = pi/3 Layers/8_Qubit_XXZ_3_Layer_HVA_Optimal_Values_BOBYQA_GPU_4_Filled_States_Antiperiodic_Boundary_Conditions_PH_State_4.txt")
Energies_4_Layer_q_pi = np.loadtxt(r"/mnt/c/Users/Saavanth Velury/Desktop/Quasiparticle VQE/8 Qubit Data (Final)/Delta = one-tenth/Nf = 4/q = pi/4 Layers/8_Qubit_XXZ_4_Layer_HVA_Optimal_Values_BOBYQA_GPU_4_Filled_States_Antiperiodic_Boundary_Conditions_PH_State_4.txt")
Energies_5_Layer_q_pi = np.loadtxt(r"/mnt/c/Users/Saavanth Velury/Desktop/Quasiparticle VQE/8 Qubit Data (Final)/Delta = one-tenth/Nf = 4/q = pi/5 Layers/8_Qubit_XXZ_5_Layer_HVA_Optimal_Values_BOBYQA_GPU_4_Filled_States_Antiperiodic_Boundary_Conditions_PH_State_4.txt")
Energies_6_Layer_q_pi = np.loadtxt(r"/mnt/c/Users/Saavanth Velury/Desktop/Quasiparticle VQE/8 Qubit Data (Final)/Delta = one-tenth/Nf = 4/q = pi/6 Layers/8_Qubit_XXZ_6_Layer_HVA_Optimal_Values_BOBYQA_GPU_4_Filled_States_Antiperiodic_Boundary_Conditions_PH_State_4.txt")
Energies_7_Layer_q_pi = np.loadtxt(r"/mnt/c/Users/Saavanth Velury/Desktop/Quasiparticle VQE/8 Qubit Data (Final)/Delta = one-tenth/Nf = 4/q = pi/7 Layers/8_Qubit_XXZ_7_Layer_HVA_Optimal_Values_BOBYQA_GPU_4_Filled_States_Antiperiodic_Boundary_Conditions_PH_State_4.txt")
Energies_8_Layer_q_pi = np.loadtxt(r"/mnt/c/Users/Saavanth Velury/Desktop/Quasiparticle VQE/8 Qubit Data (Final)/Delta = one-tenth/Nf = 4/q = pi/8 Layers/8_Qubit_XXZ_8_Layer_HVA_Optimal_Values_BOBYQA_GPU_4_Filled_States_Antiperiodic_Boundary_Conditions_PH_State_4.txt")
Optimal_Value_1_Layer_q_pi = Energies_1_Layer_q_pi[np.argmin(Energies_1_Layer_q_pi)]
Optimal_Value_2_Layer_q_pi = Energies_2_Layer_q_pi[np.argmin(Energies_2_Layer_q_pi)]
Optimal_Value_3_Layer_q_pi = Energies_3_Layer_q_pi[np.argmin(Energies_3_Layer_q_pi)]
Optimal_Value_4_Layer_q_pi = Energies_4_Layer_q_pi[np.argmin(Energies_4_Layer_q_pi)]
Optimal_Value_5_Layer_q_pi = Energies_5_Layer_q_pi[np.argmin(Energies_5_Layer_q_pi)]
Optimal_Value_6_Layer_q_pi = Energies_6_Layer_q_pi[np.argmin(Energies_6_Layer_q_pi)]
Optimal_Value_7_Layer_q_pi = Energies_7_Layer_q_pi[np.argmin(Energies_7_Layer_q_pi)]
Optimal_Value_8_Layer_q_pi = Energies_8_Layer_q_pi[np.argmin(Energies_8_Layer_q_pi)]
Optimal_Values_q_pi = [Optimal_Value_1_Layer_q_pi, Optimal_Value_2_Layer_q_pi, Optimal_Value_3_Layer_q_pi, Optimal_Value_4_Layer_q_pi, Optimal_Value_5_Layer_q_pi, Optimal_Value_6_Layer_q_pi, Optimal_Value_7_Layer_q_pi, Optimal_Value_8_Layer_q_pi]

Energies_1_Layer_q_pi_Alternate = np.loadtxt(r"/mnt/c/Users/Saavanth Velury/Desktop/Quasiparticle VQE/8 Qubit Data (Final)/Delta = one-tenth/Nf = 4/q = pi/1 Layer/8_Qubit_XXZ_1_Layer_HVA_Optimal_Values_BOBYQA_GPU_4_Filled_States_Antiperiodic_Boundary_Conditions_PH_State_4_Alternate.txt")
Energies_2_Layer_q_pi_Alternate = np.loadtxt(r"/mnt/c/Users/Saavanth Velury/Desktop/Quasiparticle VQE/8 Qubit Data (Final)/Delta = one-tenth/Nf = 4/q = pi/2 Layers/8_Qubit_XXZ_2_Layer_HVA_Optimal_Values_BOBYQA_GPU_4_Filled_States_Antiperiodic_Boundary_Conditions_PH_State_4_Alternate.txt")
Energies_3_Layer_q_pi_Alternate = np.loadtxt(r"/mnt/c/Users/Saavanth Velury/Desktop/Quasiparticle VQE/8 Qubit Data (Final)/Delta = one-tenth/Nf = 4/q = pi/3 Layers/8_Qubit_XXZ_3_Layer_HVA_Optimal_Values_BOBYQA_GPU_4_Filled_States_Antiperiodic_Boundary_Conditions_PH_State_4_Alternate.txt")
Energies_4_Layer_q_pi_Alternate = np.loadtxt(r"/mnt/c/Users/Saavanth Velury/Desktop/Quasiparticle VQE/8 Qubit Data (Final)/Delta = one-tenth/Nf = 4/q = pi/4 Layers/8_Qubit_XXZ_4_Layer_HVA_Optimal_Values_BOBYQA_GPU_4_Filled_States_Antiperiodic_Boundary_Conditions_PH_State_4_Alternate.txt")
Energies_5_Layer_q_pi_Alternate = np.loadtxt(r"/mnt/c/Users/Saavanth Velury/Desktop/Quasiparticle VQE/8 Qubit Data (Final)/Delta = one-tenth/Nf = 4/q = pi/5 Layers/8_Qubit_XXZ_5_Layer_HVA_Optimal_Values_BOBYQA_GPU_4_Filled_States_Antiperiodic_Boundary_Conditions_PH_State_4_Alternate.txt")
Energies_6_Layer_q_pi_Alternate = np.loadtxt(r"/mnt/c/Users/Saavanth Velury/Desktop/Quasiparticle VQE/8 Qubit Data (Final)/Delta = one-tenth/Nf = 4/q = pi/6 Layers/8_Qubit_XXZ_6_Layer_HVA_Optimal_Values_BOBYQA_GPU_4_Filled_States_Antiperiodic_Boundary_Conditions_PH_State_4_Alternate.txt")
Energies_7_Layer_q_pi_Alternate = np.loadtxt(r"/mnt/c/Users/Saavanth Velury/Desktop/Quasiparticle VQE/8 Qubit Data (Final)/Delta = one-tenth/Nf = 4/q = pi/7 Layers/8_Qubit_XXZ_7_Layer_HVA_Optimal_Values_BOBYQA_GPU_4_Filled_States_Antiperiodic_Boundary_Conditions_PH_State_4_Alternate.txt")
Energies_8_Layer_q_pi_Alternate = np.loadtxt(r"/mnt/c/Users/Saavanth Velury/Desktop/Quasiparticle VQE/8 Qubit Data (Final)/Delta = one-tenth/Nf = 4/q = pi/8 Layers/8_Qubit_XXZ_8_Layer_HVA_Optimal_Values_BOBYQA_GPU_4_Filled_States_Antiperiodic_Boundary_Conditions_PH_State_4_Alternate.txt")
Optimal_Value_1_Layer_q_pi_Alternate = Energies_1_Layer_q_pi_Alternate[np.argmin(Energies_1_Layer_q_pi_Alternate)]
Optimal_Value_2_Layer_q_pi_Alternate = Energies_2_Layer_q_pi_Alternate[np.argmin(Energies_2_Layer_q_pi_Alternate)]
Optimal_Value_3_Layer_q_pi_Alternate = Energies_3_Layer_q_pi_Alternate[np.argmin(Energies_3_Layer_q_pi_Alternate)]
Optimal_Value_4_Layer_q_pi_Alternate = Energies_4_Layer_q_pi_Alternate[np.argmin(Energies_4_Layer_q_pi_Alternate)]
Optimal_Value_5_Layer_q_pi_Alternate = Energies_5_Layer_q_pi_Alternate[np.argmin(Energies_5_Layer_q_pi_Alternate)]
Optimal_Value_6_Layer_q_pi_Alternate = Energies_6_Layer_q_pi_Alternate[np.argmin(Energies_6_Layer_q_pi_Alternate)]
Optimal_Value_7_Layer_q_pi_Alternate = Energies_7_Layer_q_pi_Alternate[np.argmin(Energies_7_Layer_q_pi_Alternate)]
Optimal_Value_8_Layer_q_pi_Alternate = Energies_8_Layer_q_pi_Alternate[np.argmin(Energies_8_Layer_q_pi_Alternate)]
Optimal_Values_q_pi_Alternate = [Optimal_Value_1_Layer_q_pi_Alternate, Optimal_Value_2_Layer_q_pi_Alternate, Optimal_Value_3_Layer_q_pi_Alternate, Optimal_Value_4_Layer_q_pi_Alternate, Optimal_Value_5_Layer_q_pi_Alternate, Optimal_Value_6_Layer_q_pi_Alternate, Optimal_Value_7_Layer_q_pi_Alternate, Optimal_Value_8_Layer_q_pi_Alternate]

# %%
ED_Values_1_Delta_One_Tenth = [-7.780020+10.801697, -5.487729+10.801697, -5.402057+10.801697, -7.570638+10.801697, 0, -7.570638+10.801697, -5.402057+10.801697, -5.487729+10.801697, -7.780020+10.801697]
VQE_Values_1_Delta_One_Tenth = [min(Optimal_Values_q_pi)-min(Optimal_Values_q0), -5.48739844-min(Optimal_Values_q0), -5.40180587-min(Optimal_Values_q0), -7.57044272-min(Optimal_Values_q0), 0, min(Optimal_Values_q_pi_over_4)-min(Optimal_Values_q0), min(Optimal_Values_q_pi_over_2_Alternate)-min(Optimal_Values_q0), min(Optimal_Values_q_3pi_over_4_Alternate)-min(Optimal_Values_q0), min(Optimal_Values_q_pi)-min(Optimal_Values_q0)]
ED_Values_2_Delta_One_Tenth = [-7.707320+10.801697, -5.331182+10.801697, -5.265481+10.801697, -7.570638+10.801697, 0, -7.570638+10.801697, -5.265481+10.801697, -5.331182+10.801697, -7.707320+10.801697]
VQE_Values_2_Delta_One_Tenth = [min(Optimal_Values_q_pi_Alternate)-min(Optimal_Values_q0), -5.33111609-min(Optimal_Values_q0), -5.265021570-min(Optimal_Values_q0), -7.57044272-min(Optimal_Values_q_pi_over_4), 0, min(Optimal_Values_q_pi_over_4)-min(Optimal_Values_q0), min(Optimal_Values_q_pi_over_2)-min(Optimal_Values_q0), min(Optimal_Values_q_3pi_over_4)-min(Optimal_Values_q0), min(Optimal_Values_q_pi_Alternate)-min(Optimal_Values_q0)]

# %%
#Nf = 4 (Δ = 0.5)

#q = 0
Energies_1_Layer_q0 = np.loadtxt(r"/mnt/c/Users/Saavanth Velury/Desktop/Quasiparticle VQE/8 Qubit Data (Final)/Delta = one-half/Nf = 4/q = 0/1 Layer/8_Qubit_XXZ_1_Layer_HVA_Optimal_Values_BOBYQA_GPU_4_Filled_States_Antiperiodic_Boundary_Conditions_Delta_0.5.txt")
Energies_2_Layer_q0 = np.loadtxt(r"/mnt/c/Users/Saavanth Velury/Desktop/Quasiparticle VQE/8 Qubit Data (Final)/Delta = one-half/Nf = 4/q = 0/2 Layers/8_Qubit_XXZ_2_Layer_HVA_Optimal_Values_BOBYQA_GPU_4_Filled_States_Antiperiodic_Boundary_Conditions_Delta_0.5.txt")
Energies_3_Layer_q0 = np.loadtxt(r"/mnt/c/Users/Saavanth Velury/Desktop/Quasiparticle VQE/8 Qubit Data (Final)/Delta = one-half/Nf = 4/q = 0/3 Layers/8_Qubit_XXZ_3_Layer_HVA_Optimal_Values_BOBYQA_GPU_4_Filled_States_Antiperiodic_Boundary_Conditions_Delta_0.5.txt")
Energies_4_Layer_q0 = np.loadtxt(r"/mnt/c/Users/Saavanth Velury/Desktop/Quasiparticle VQE/8 Qubit Data (Final)/Delta = one-half/Nf = 4/q = 0/4 Layers/8_Qubit_XXZ_4_Layer_HVA_Optimal_Values_BOBYQA_GPU_4_Filled_States_Antiperiodic_Boundary_Conditions_Delta_0.5.txt")
Energies_5_Layer_q0 = np.loadtxt(r"/mnt/c/Users/Saavanth Velury/Desktop/Quasiparticle VQE/8 Qubit Data (Final)/Delta = one-half/Nf = 4/q = 0/5 Layers/8_Qubit_XXZ_5_Layer_HVA_Optimal_Values_BOBYQA_GPU_4_Filled_States_Antiperiodic_Boundary_Conditions_Delta_0.5.txt")
Energies_6_Layer_q0 = np.loadtxt(r"/mnt/c/Users/Saavanth Velury/Desktop/Quasiparticle VQE/8 Qubit Data (Final)/Delta = one-half/Nf = 4/q = 0/6 Layers/8_Qubit_XXZ_6_Layer_HVA_Optimal_Values_BOBYQA_GPU_4_Filled_States_Antiperiodic_Boundary_Conditions_Delta_0.5.txt")
Energies_7_Layer_q0 = np.loadtxt(r"/mnt/c/Users/Saavanth Velury/Desktop/Quasiparticle VQE/8 Qubit Data (Final)/Delta = one-half/Nf = 4/q = 0/7 Layers/8_Qubit_XXZ_7_Layer_HVA_Optimal_Values_BOBYQA_GPU_4_Filled_States_Antiperiodic_Boundary_Conditions_Delta_0.5.txt")
Energies_8_Layer_q0 = np.loadtxt(r"/mnt/c/Users/Saavanth Velury/Desktop/Quasiparticle VQE/8 Qubit Data (Final)/Delta = one-half/Nf = 4/q = 0/8 Layers/8_Qubit_XXZ_8_Layer_HVA_Optimal_Values_BOBYQA_GPU_4_Filled_States_Antiperiodic_Boundary_Conditions_Delta_0.5.txt")
Optimal_Value_1_Layer_q0 = Energies_1_Layer_q0[np.argmin(Energies_1_Layer_q0)]
Optimal_Value_2_Layer_q0 = Energies_2_Layer_q0[np.argmin(Energies_2_Layer_q0)]
Optimal_Value_3_Layer_q0 = Energies_3_Layer_q0[np.argmin(Energies_3_Layer_q0)]
Optimal_Value_4_Layer_q0 = Energies_4_Layer_q0[np.argmin(Energies_4_Layer_q0)]
Optimal_Value_5_Layer_q0 = Energies_5_Layer_q0[np.argmin(Energies_5_Layer_q0)]
Optimal_Value_6_Layer_q0 = Energies_6_Layer_q0[np.argmin(Energies_6_Layer_q0)]
Optimal_Value_7_Layer_q0 = Energies_7_Layer_q0[np.argmin(Energies_7_Layer_q0)]
Optimal_Value_8_Layer_q0 = Energies_8_Layer_q0[np.argmin(Energies_8_Layer_q0)]
Optimal_Values_q0 = [Optimal_Value_1_Layer_q0, Optimal_Value_2_Layer_q0, Optimal_Value_3_Layer_q0, Optimal_Value_4_Layer_q0, Optimal_Value_5_Layer_q0, Optimal_Value_6_Layer_q0, Optimal_Value_7_Layer_q0, Optimal_Value_8_Layer_q0]

#q = pi/4
Energies_1_Layer_q_pi_over_4 = np.loadtxt(r"/mnt/c/Users/Saavanth Velury/Desktop/Quasiparticle VQE/8 Qubit Data (Final)/Delta = one-half/Nf = 4/q = pi over 4/1 Layer/8_Qubit_XXZ_1_Layer_HVA_Optimal_Values_BOBYQA_GPU_4_Filled_States_Antiperiodic_Boundary_Conditions_PH_State_Delta_0.5.txt")
Energies_2_Layer_q_pi_over_4 = np.loadtxt(r"/mnt/c/Users/Saavanth Velury/Desktop/Quasiparticle VQE/8 Qubit Data (Final)/Delta = one-half/Nf = 4/q = pi over 4/2 Layers/8_Qubit_XXZ_2_Layer_HVA_Optimal_Values_BOBYQA_GPU_4_Filled_States_Antiperiodic_Boundary_Conditions_PH_State_Delta_0.5.txt")
Energies_3_Layer_q_pi_over_4 = np.loadtxt(r"/mnt/c/Users/Saavanth Velury/Desktop/Quasiparticle VQE/8 Qubit Data (Final)/Delta = one-half/Nf = 4/q = pi over 4/3 Layers/8_Qubit_XXZ_3_Layer_HVA_Optimal_Values_BOBYQA_GPU_4_Filled_States_Antiperiodic_Boundary_Conditions_PH_State_Delta_0.5.txt")
Energies_4_Layer_q_pi_over_4 = np.loadtxt(r"/mnt/c/Users/Saavanth Velury/Desktop/Quasiparticle VQE/8 Qubit Data (Final)/Delta = one-half/Nf = 4/q = pi over 4/4 Layers/8_Qubit_XXZ_4_Layer_HVA_Optimal_Values_BOBYQA_GPU_4_Filled_States_Antiperiodic_Boundary_Conditions_PH_State_Delta_0.5.txt")
Energies_5_Layer_q_pi_over_4 = np.loadtxt(r"/mnt/c/Users/Saavanth Velury/Desktop/Quasiparticle VQE/8 Qubit Data (Final)/Delta = one-half/Nf = 4/q = pi over 4/5 Layers/8_Qubit_XXZ_5_Layer_HVA_Optimal_Values_BOBYQA_GPU_4_Filled_States_Antiperiodic_Boundary_Conditions_PH_State_Delta_0.5.txt")
Energies_6_Layer_q_pi_over_4 = np.loadtxt(r"/mnt/c/Users/Saavanth Velury/Desktop/Quasiparticle VQE/8 Qubit Data (Final)/Delta = one-half/Nf = 4/q = pi over 4/6 Layers/8_Qubit_XXZ_6_Layer_HVA_Optimal_Values_BOBYQA_GPU_4_Filled_States_Antiperiodic_Boundary_Conditions_PH_State_Delta_0.5.txt")
Energies_7_Layer_q_pi_over_4 = np.loadtxt(r"/mnt/c/Users/Saavanth Velury/Desktop/Quasiparticle VQE/8 Qubit Data (Final)/Delta = one-half/Nf = 4/q = pi over 4/7 Layers/8_Qubit_XXZ_7_Layer_HVA_Optimal_Values_BOBYQA_GPU_4_Filled_States_Antiperiodic_Boundary_Conditions_PH_State_Delta_0.5.txt")
Energies_8_Layer_q_pi_over_4 = np.loadtxt(r"/mnt/c/Users/Saavanth Velury/Desktop/Quasiparticle VQE/8 Qubit Data (Final)/Delta = one-half/Nf = 4/q = pi over 4/8 Layers/8_Qubit_XXZ_8_Layer_HVA_Optimal_Values_BOBYQA_GPU_4_Filled_States_Antiperiodic_Boundary_Conditions_PH_State_Delta_0.5.txt")
Optimal_Value_1_Layer_q_pi_over_4 = Energies_1_Layer_q_pi_over_4[np.argmin(Energies_1_Layer_q_pi_over_4)]
Optimal_Value_2_Layer_q_pi_over_4 = Energies_2_Layer_q_pi_over_4[np.argmin(Energies_2_Layer_q_pi_over_4)]
Optimal_Value_3_Layer_q_pi_over_4 = Energies_3_Layer_q_pi_over_4[np.argmin(Energies_3_Layer_q_pi_over_4)]
Optimal_Value_4_Layer_q_pi_over_4 = Energies_4_Layer_q_pi_over_4[np.argmin(Energies_4_Layer_q_pi_over_4)]
Optimal_Value_5_Layer_q_pi_over_4 = Energies_5_Layer_q_pi_over_4[np.argmin(Energies_5_Layer_q_pi_over_4)]
Optimal_Value_6_Layer_q_pi_over_4 = Energies_6_Layer_q_pi_over_4[np.argmin(Energies_6_Layer_q_pi_over_4)]
Optimal_Value_7_Layer_q_pi_over_4 = Energies_7_Layer_q_pi_over_4[np.argmin(Energies_7_Layer_q_pi_over_4)]
Optimal_Value_8_Layer_q_pi_over_4 = Energies_8_Layer_q_pi_over_4[np.argmin(Energies_8_Layer_q_pi_over_4)]
Optimal_Values_q_pi_over_4 = [Optimal_Value_1_Layer_q_pi_over_4, Optimal_Value_2_Layer_q_pi_over_4, Optimal_Value_3_Layer_q_pi_over_4, Optimal_Value_4_Layer_q_pi_over_4, Optimal_Value_5_Layer_q_pi_over_4, Optimal_Value_6_Layer_q_pi_over_4, Optimal_Value_7_Layer_q_pi_over_4, Optimal_Value_8_Layer_q_pi_over_4]

#q = pi/2
Energies_1_Layer_q_pi_over_2 = np.loadtxt(r"/mnt/c/Users/Saavanth Velury/Desktop/Quasiparticle VQE/8 Qubit Data (Final)/Delta = one-half/Nf = 4/q = pi over 2/1 Layer/8_Qubit_XXZ_1_Layer_HVA_Optimal_Values_BOBYQA_GPU_4_Filled_States_Antiperiodic_Boundary_Conditions_PH_State_2_Delta_0.5.txt")
Energies_2_Layer_q_pi_over_2 = np.loadtxt(r"/mnt/c/Users/Saavanth Velury/Desktop/Quasiparticle VQE/8 Qubit Data (Final)/Delta = one-half/Nf = 4/q = pi over 2/2 Layers/8_Qubit_XXZ_2_Layer_HVA_Optimal_Values_BOBYQA_GPU_4_Filled_States_Antiperiodic_Boundary_Conditions_PH_State_2_Delta_0.5.txt")
Energies_3_Layer_q_pi_over_2 = np.loadtxt(r"/mnt/c/Users/Saavanth Velury/Desktop/Quasiparticle VQE/8 Qubit Data (Final)/Delta = one-half/Nf = 4/q = pi over 2/3 Layers/8_Qubit_XXZ_3_Layer_HVA_Optimal_Values_BOBYQA_GPU_4_Filled_States_Antiperiodic_Boundary_Conditions_PH_State_2_Delta_0.5.txt")
Energies_4_Layer_q_pi_over_2 = np.loadtxt(r"/mnt/c/Users/Saavanth Velury/Desktop/Quasiparticle VQE/8 Qubit Data (Final)/Delta = one-half/Nf = 4/q = pi over 2/4 Layers/8_Qubit_XXZ_4_Layer_HVA_Optimal_Values_BOBYQA_GPU_4_Filled_States_Antiperiodic_Boundary_Conditions_PH_State_2_Delta_0.5.txt")
Energies_5_Layer_q_pi_over_2 = np.loadtxt(r"/mnt/c/Users/Saavanth Velury/Desktop/Quasiparticle VQE/8 Qubit Data (Final)/Delta = one-half/Nf = 4/q = pi over 2/5 Layers/8_Qubit_XXZ_5_Layer_HVA_Optimal_Values_BOBYQA_GPU_4_Filled_States_Antiperiodic_Boundary_Conditions_PH_State_2_Delta_0.5.txt")
Energies_6_Layer_q_pi_over_2 = np.loadtxt(r"/mnt/c/Users/Saavanth Velury/Desktop/Quasiparticle VQE/8 Qubit Data (Final)/Delta = one-half/Nf = 4/q = pi over 2/6 Layers/8_Qubit_XXZ_6_Layer_HVA_Optimal_Values_BOBYQA_GPU_4_Filled_States_Antiperiodic_Boundary_Conditions_PH_State_2_Delta_0.5.txt")
Energies_7_Layer_q_pi_over_2 = np.loadtxt(r"/mnt/c/Users/Saavanth Velury/Desktop/Quasiparticle VQE/8 Qubit Data (Final)/Delta = one-half/Nf = 4/q = pi over 2/7 Layers/8_Qubit_XXZ_7_Layer_HVA_Optimal_Values_BOBYQA_GPU_4_Filled_States_Antiperiodic_Boundary_Conditions_PH_State_2_Delta_0.5.txt")
Energies_8_Layer_q_pi_over_2 = np.loadtxt(r"/mnt/c/Users/Saavanth Velury/Desktop/Quasiparticle VQE/8 Qubit Data (Final)/Delta = one-half/Nf = 4/q = pi over 2/8 Layers/8_Qubit_XXZ_8_Layer_HVA_Optimal_Values_BOBYQA_GPU_4_Filled_States_Antiperiodic_Boundary_Conditions_PH_State_2_Delta_0.5.txt")
Optimal_Value_1_Layer_q_pi_over_2 = Energies_1_Layer_q_pi_over_2[np.argmin(Energies_1_Layer_q_pi_over_2)]
Optimal_Value_2_Layer_q_pi_over_2 = Energies_2_Layer_q_pi_over_2[np.argmin(Energies_2_Layer_q_pi_over_2)]
Optimal_Value_3_Layer_q_pi_over_2 = Energies_3_Layer_q_pi_over_2[np.argmin(Energies_3_Layer_q_pi_over_2)]
Optimal_Value_4_Layer_q_pi_over_2 = Energies_4_Layer_q_pi_over_2[np.argmin(Energies_4_Layer_q_pi_over_2)]
Optimal_Value_5_Layer_q_pi_over_2 = Energies_5_Layer_q_pi_over_2[np.argmin(Energies_5_Layer_q_pi_over_2)]
Optimal_Value_6_Layer_q_pi_over_2 = Energies_6_Layer_q_pi_over_2[np.argmin(Energies_6_Layer_q_pi_over_2)]
Optimal_Value_7_Layer_q_pi_over_2 = Energies_7_Layer_q_pi_over_2[np.argmin(Energies_7_Layer_q_pi_over_2)]
Optimal_Value_8_Layer_q_pi_over_2 = Energies_8_Layer_q_pi_over_2[np.argmin(Energies_8_Layer_q_pi_over_2)]
Optimal_Values_q_pi_over_2 = [Optimal_Value_1_Layer_q_pi_over_2, Optimal_Value_2_Layer_q_pi_over_2, Optimal_Value_3_Layer_q_pi_over_2, Optimal_Value_4_Layer_q_pi_over_2, Optimal_Value_5_Layer_q_pi_over_2, Optimal_Value_6_Layer_q_pi_over_2, Optimal_Value_7_Layer_q_pi_over_2, Optimal_Value_8_Layer_q_pi_over_2]

Energies_1_Layer_q_pi_over_2_Alternate = np.loadtxt(r"/mnt/c/Users/Saavanth Velury/Desktop/Quasiparticle VQE/8 Qubit Data (Final)/Delta = one-half/Nf = 4/q = pi over 2/1 Layer/8_Qubit_XXZ_1_Layer_HVA_Optimal_Values_BOBYQA_GPU_4_Filled_States_Antiperiodic_Boundary_Conditions_PH_State_2_Alternate_Delta_0.5.txt")
Energies_2_Layer_q_pi_over_2_Alternate = np.loadtxt(r"/mnt/c/Users/Saavanth Velury/Desktop/Quasiparticle VQE/8 Qubit Data (Final)/Delta = one-half/Nf = 4/q = pi over 2/2 Layers/8_Qubit_XXZ_2_Layer_HVA_Optimal_Values_BOBYQA_GPU_4_Filled_States_Antiperiodic_Boundary_Conditions_PH_State_2_Alternate_Delta_0.5.txt")
Energies_3_Layer_q_pi_over_2_Alternate = np.loadtxt(r"/mnt/c/Users/Saavanth Velury/Desktop/Quasiparticle VQE/8 Qubit Data (Final)/Delta = one-half/Nf = 4/q = pi over 2/3 Layers/8_Qubit_XXZ_3_Layer_HVA_Optimal_Values_BOBYQA_GPU_4_Filled_States_Antiperiodic_Boundary_Conditions_PH_State_2_Alternate_Delta_0.5.txt")
Energies_4_Layer_q_pi_over_2_Alternate = np.loadtxt(r"/mnt/c/Users/Saavanth Velury/Desktop/Quasiparticle VQE/8 Qubit Data (Final)/Delta = one-half/Nf = 4/q = pi over 2/4 Layers/8_Qubit_XXZ_4_Layer_HVA_Optimal_Values_BOBYQA_GPU_4_Filled_States_Antiperiodic_Boundary_Conditions_PH_State_2_Alternate_Delta_0.5.txt")
Energies_5_Layer_q_pi_over_2_Alternate = np.loadtxt(r"/mnt/c/Users/Saavanth Velury/Desktop/Quasiparticle VQE/8 Qubit Data (Final)/Delta = one-half/Nf = 4/q = pi over 2/5 Layers/8_Qubit_XXZ_5_Layer_HVA_Optimal_Values_BOBYQA_GPU_4_Filled_States_Antiperiodic_Boundary_Conditions_PH_State_2_Alternate_Delta_0.5.txt")
Energies_6_Layer_q_pi_over_2_Alternate = np.loadtxt(r"/mnt/c/Users/Saavanth Velury/Desktop/Quasiparticle VQE/8 Qubit Data (Final)/Delta = one-half/Nf = 4/q = pi over 2/6 Layers/8_Qubit_XXZ_6_Layer_HVA_Optimal_Values_BOBYQA_GPU_4_Filled_States_Antiperiodic_Boundary_Conditions_PH_State_2_Alternate_Delta_0.5.txt")
Energies_7_Layer_q_pi_over_2_Alternate = np.loadtxt(r"/mnt/c/Users/Saavanth Velury/Desktop/Quasiparticle VQE/8 Qubit Data (Final)/Delta = one-half/Nf = 4/q = pi over 2/7 Layers/8_Qubit_XXZ_7_Layer_HVA_Optimal_Values_BOBYQA_GPU_4_Filled_States_Antiperiodic_Boundary_Conditions_PH_State_2_Alternate_Delta_0.5.txt")
Energies_8_Layer_q_pi_over_2_Alternate = np.loadtxt(r"/mnt/c/Users/Saavanth Velury/Desktop/Quasiparticle VQE/8 Qubit Data (Final)/Delta = one-half/Nf = 4/q = pi over 2/8 Layers/8_Qubit_XXZ_8_Layer_HVA_Optimal_Values_BOBYQA_GPU_4_Filled_States_Antiperiodic_Boundary_Conditions_PH_State_2_Alternate_Delta_0.5.txt")
Optimal_Value_1_Layer_q_pi_over_2_Alternate = Energies_1_Layer_q_pi_over_2_Alternate[np.argmin(Energies_1_Layer_q_pi_over_2_Alternate)]
Optimal_Value_2_Layer_q_pi_over_2_Alternate = Energies_2_Layer_q_pi_over_2_Alternate[np.argmin(Energies_2_Layer_q_pi_over_2_Alternate)]
Optimal_Value_3_Layer_q_pi_over_2_Alternate = Energies_3_Layer_q_pi_over_2_Alternate[np.argmin(Energies_3_Layer_q_pi_over_2_Alternate)]
Optimal_Value_4_Layer_q_pi_over_2_Alternate = Energies_4_Layer_q_pi_over_2_Alternate[np.argmin(Energies_4_Layer_q_pi_over_2_Alternate)]
Optimal_Value_5_Layer_q_pi_over_2_Alternate = Energies_5_Layer_q_pi_over_2_Alternate[np.argmin(Energies_5_Layer_q_pi_over_2_Alternate)]
Optimal_Value_6_Layer_q_pi_over_2_Alternate = Energies_6_Layer_q_pi_over_2_Alternate[np.argmin(Energies_6_Layer_q_pi_over_2_Alternate)]
Optimal_Value_7_Layer_q_pi_over_2_Alternate = Energies_7_Layer_q_pi_over_2_Alternate[np.argmin(Energies_7_Layer_q_pi_over_2_Alternate)]
Optimal_Value_8_Layer_q_pi_over_2_Alternate = Energies_8_Layer_q_pi_over_2_Alternate[np.argmin(Energies_8_Layer_q_pi_over_2_Alternate)]
Optimal_Values_q_pi_over_2_Alternate = [Optimal_Value_1_Layer_q_pi_over_2_Alternate, Optimal_Value_2_Layer_q_pi_over_2_Alternate, Optimal_Value_3_Layer_q_pi_over_2_Alternate, Optimal_Value_4_Layer_q_pi_over_2_Alternate, Optimal_Value_5_Layer_q_pi_over_2_Alternate, Optimal_Value_6_Layer_q_pi_over_2_Alternate, Optimal_Value_7_Layer_q_pi_over_2_Alternate, Optimal_Value_8_Layer_q_pi_over_2_Alternate]

#q = 3pi/4
Energies_1_Layer_q_3pi_over_4 = np.loadtxt(r"/mnt/c/Users/Saavanth Velury/Desktop/Quasiparticle VQE/8 Qubit Data (Final)/Delta = one-half/Nf = 4/q = 3pi over 4/1 Layer/8_Qubit_XXZ_1_Layer_HVA_Optimal_Values_BOBYQA_GPU_4_Filled_States_Antiperiodic_Boundary_Conditions_PH_State_3_Delta_0.5.txt")
Energies_2_Layer_q_3pi_over_4 = np.loadtxt(r"/mnt/c/Users/Saavanth Velury/Desktop/Quasiparticle VQE/8 Qubit Data (Final)/Delta = one-half/Nf = 4/q = 3pi over 4/2 Layers/8_Qubit_XXZ_2_Layer_HVA_Optimal_Values_BOBYQA_GPU_4_Filled_States_Antiperiodic_Boundary_Conditions_PH_State_3_Delta_0.5.txt")
Energies_3_Layer_q_3pi_over_4 = np.loadtxt(r"/mnt/c/Users/Saavanth Velury/Desktop/Quasiparticle VQE/8 Qubit Data (Final)/Delta = one-half/Nf = 4/q = 3pi over 4/3 Layers/8_Qubit_XXZ_3_Layer_HVA_Optimal_Values_BOBYQA_GPU_4_Filled_States_Antiperiodic_Boundary_Conditions_PH_State_3_Delta_0.5.txt")
Energies_4_Layer_q_3pi_over_4 = np.loadtxt(r"/mnt/c/Users/Saavanth Velury/Desktop/Quasiparticle VQE/8 Qubit Data (Final)/Delta = one-half/Nf = 4/q = 3pi over 4/4 Layers/8_Qubit_XXZ_4_Layer_HVA_Optimal_Values_BOBYQA_GPU_4_Filled_States_Antiperiodic_Boundary_Conditions_PH_State_3_Delta_0.5.txt")
Energies_5_Layer_q_3pi_over_4 = np.loadtxt(r"/mnt/c/Users/Saavanth Velury/Desktop/Quasiparticle VQE/8 Qubit Data (Final)/Delta = one-half/Nf = 4/q = 3pi over 4/5 Layers/8_Qubit_XXZ_5_Layer_HVA_Optimal_Values_BOBYQA_GPU_4_Filled_States_Antiperiodic_Boundary_Conditions_PH_State_3_Delta_0.5.txt")
Energies_6_Layer_q_3pi_over_4 = np.loadtxt(r"/mnt/c/Users/Saavanth Velury/Desktop/Quasiparticle VQE/8 Qubit Data (Final)/Delta = one-half/Nf = 4/q = 3pi over 4/6 Layers/8_Qubit_XXZ_6_Layer_HVA_Optimal_Values_BOBYQA_GPU_4_Filled_States_Antiperiodic_Boundary_Conditions_PH_State_3_Delta_0.5.txt")
Energies_7_Layer_q_3pi_over_4 = np.loadtxt(r"/mnt/c/Users/Saavanth Velury/Desktop/Quasiparticle VQE/8 Qubit Data (Final)/Delta = one-half/Nf = 4/q = 3pi over 4/7 Layers/8_Qubit_XXZ_7_Layer_HVA_Optimal_Values_BOBYQA_GPU_4_Filled_States_Antiperiodic_Boundary_Conditions_PH_State_3_Delta_0.5.txt")
Energies_8_Layer_q_3pi_over_4 = np.loadtxt(r"/mnt/c/Users/Saavanth Velury/Desktop/Quasiparticle VQE/8 Qubit Data (Final)/Delta = one-half/Nf = 4/q = 3pi over 4/8 Layers/8_Qubit_XXZ_8_Layer_HVA_Optimal_Values_BOBYQA_GPU_4_Filled_States_Antiperiodic_Boundary_Conditions_PH_State_3_Delta_0.5.txt")
Optimal_Value_1_Layer_q_3pi_over_4 = Energies_1_Layer_q_3pi_over_4[np.argmin(Energies_1_Layer_q_3pi_over_4)]
Optimal_Value_2_Layer_q_3pi_over_4 = Energies_2_Layer_q_3pi_over_4[np.argmin(Energies_2_Layer_q_3pi_over_4)]
Optimal_Value_3_Layer_q_3pi_over_4 = Energies_3_Layer_q_3pi_over_4[np.argmin(Energies_3_Layer_q_3pi_over_4)]
Optimal_Value_4_Layer_q_3pi_over_4 = Energies_4_Layer_q_3pi_over_4[np.argmin(Energies_4_Layer_q_3pi_over_4)]
Optimal_Value_5_Layer_q_3pi_over_4 = Energies_5_Layer_q_3pi_over_4[np.argmin(Energies_5_Layer_q_3pi_over_4)]
Optimal_Value_6_Layer_q_3pi_over_4 = Energies_6_Layer_q_3pi_over_4[np.argmin(Energies_6_Layer_q_3pi_over_4)]
Optimal_Value_7_Layer_q_3pi_over_4 = Energies_7_Layer_q_3pi_over_4[np.argmin(Energies_7_Layer_q_3pi_over_4)]
Optimal_Value_8_Layer_q_3pi_over_4 = Energies_8_Layer_q_3pi_over_4[np.argmin(Energies_8_Layer_q_3pi_over_4)]
Optimal_Values_q_3pi_over_4 = [Optimal_Value_1_Layer_q_3pi_over_4, Optimal_Value_2_Layer_q_3pi_over_4, Optimal_Value_3_Layer_q_3pi_over_4, Optimal_Value_4_Layer_q_3pi_over_4, Optimal_Value_5_Layer_q_3pi_over_4, Optimal_Value_6_Layer_q_3pi_over_4, Optimal_Value_7_Layer_q_3pi_over_4, Optimal_Value_8_Layer_q_3pi_over_4]

Energies_1_Layer_q_3pi_over_4_Alternate = np.loadtxt(r"/mnt/c/Users/Saavanth Velury/Desktop/Quasiparticle VQE/8 Qubit Data (Final)/Delta = one-half/Nf = 4/q = 3pi over 4/1 Layer/8_Qubit_XXZ_1_Layer_HVA_Optimal_Values_BOBYQA_GPU_4_Filled_States_Antiperiodic_Boundary_Conditions_PH_State_3_Alternate_Delta_0.5.txt")
Energies_2_Layer_q_3pi_over_4_Alternate = np.loadtxt(r"/mnt/c/Users/Saavanth Velury/Desktop/Quasiparticle VQE/8 Qubit Data (Final)/Delta = one-half/Nf = 4/q = 3pi over 4/2 Layers/8_Qubit_XXZ_2_Layer_HVA_Optimal_Values_BOBYQA_GPU_4_Filled_States_Antiperiodic_Boundary_Conditions_PH_State_3_Alternate_Delta_0.5.txt")
Energies_3_Layer_q_3pi_over_4_Alternate = np.loadtxt(r"/mnt/c/Users/Saavanth Velury/Desktop/Quasiparticle VQE/8 Qubit Data (Final)/Delta = one-half/Nf = 4/q = 3pi over 4/3 Layers/8_Qubit_XXZ_3_Layer_HVA_Optimal_Values_BOBYQA_GPU_4_Filled_States_Antiperiodic_Boundary_Conditions_PH_State_3_Alternate_Delta_0.5.txt")
Energies_4_Layer_q_3pi_over_4_Alternate = np.loadtxt(r"/mnt/c/Users/Saavanth Velury/Desktop/Quasiparticle VQE/8 Qubit Data (Final)/Delta = one-half/Nf = 4/q = 3pi over 4/4 Layers/8_Qubit_XXZ_4_Layer_HVA_Optimal_Values_BOBYQA_GPU_4_Filled_States_Antiperiodic_Boundary_Conditions_PH_State_3_Alternate_Delta_0.5.txt")
Energies_5_Layer_q_3pi_over_4_Alternate = np.loadtxt(r"/mnt/c/Users/Saavanth Velury/Desktop/Quasiparticle VQE/8 Qubit Data (Final)/Delta = one-half/Nf = 4/q = 3pi over 4/5 Layers/8_Qubit_XXZ_5_Layer_HVA_Optimal_Values_BOBYQA_GPU_4_Filled_States_Antiperiodic_Boundary_Conditions_PH_State_3_Alternate_Delta_0.5.txt")
Energies_6_Layer_q_3pi_over_4_Alternate = np.loadtxt(r"/mnt/c/Users/Saavanth Velury/Desktop/Quasiparticle VQE/8 Qubit Data (Final)/Delta = one-half/Nf = 4/q = 3pi over 4/6 Layers/8_Qubit_XXZ_6_Layer_HVA_Optimal_Values_BOBYQA_GPU_4_Filled_States_Antiperiodic_Boundary_Conditions_PH_State_3_Alternate_Delta_0.5.txt")
Energies_7_Layer_q_3pi_over_4_Alternate = np.loadtxt(r"/mnt/c/Users/Saavanth Velury/Desktop/Quasiparticle VQE/8 Qubit Data (Final)/Delta = one-half/Nf = 4/q = 3pi over 4/7 Layers/8_Qubit_XXZ_7_Layer_HVA_Optimal_Values_BOBYQA_GPU_4_Filled_States_Antiperiodic_Boundary_Conditions_PH_State_3_Alternate_Delta_0.5.txt")
Energies_8_Layer_q_3pi_over_4_Alternate = np.loadtxt(r"/mnt/c/Users/Saavanth Velury/Desktop/Quasiparticle VQE/8 Qubit Data (Final)/Delta = one-half/Nf = 4/q = 3pi over 4/8 Layers/8_Qubit_XXZ_8_Layer_HVA_Optimal_Values_BOBYQA_GPU_4_Filled_States_Antiperiodic_Boundary_Conditions_PH_State_3_Alternate_Delta_0.5.txt")
Optimal_Value_1_Layer_q_3pi_over_4_Alternate = Energies_1_Layer_q_3pi_over_4_Alternate[np.argmin(Energies_1_Layer_q_3pi_over_4_Alternate)]
Optimal_Value_2_Layer_q_3pi_over_4_Alternate = Energies_2_Layer_q_3pi_over_4_Alternate[np.argmin(Energies_2_Layer_q_3pi_over_4_Alternate)]
Optimal_Value_3_Layer_q_3pi_over_4_Alternate = Energies_3_Layer_q_3pi_over_4_Alternate[np.argmin(Energies_3_Layer_q_3pi_over_4_Alternate)]
Optimal_Value_4_Layer_q_3pi_over_4_Alternate = Energies_4_Layer_q_3pi_over_4_Alternate[np.argmin(Energies_4_Layer_q_3pi_over_4_Alternate)]
Optimal_Value_5_Layer_q_3pi_over_4_Alternate = Energies_5_Layer_q_3pi_over_4_Alternate[np.argmin(Energies_5_Layer_q_3pi_over_4_Alternate)]
Optimal_Value_6_Layer_q_3pi_over_4_Alternate = Energies_6_Layer_q_3pi_over_4_Alternate[np.argmin(Energies_6_Layer_q_3pi_over_4_Alternate)]
Optimal_Value_7_Layer_q_3pi_over_4_Alternate = Energies_7_Layer_q_3pi_over_4_Alternate[np.argmin(Energies_7_Layer_q_3pi_over_4_Alternate)]
Optimal_Value_8_Layer_q_3pi_over_4_Alternate = Energies_8_Layer_q_3pi_over_4_Alternate[np.argmin(Energies_8_Layer_q_3pi_over_4_Alternate)]
Optimal_Values_q_3pi_over_4_Alternate = [Optimal_Value_1_Layer_q_3pi_over_4_Alternate, Optimal_Value_2_Layer_q_3pi_over_4_Alternate, Optimal_Value_3_Layer_q_3pi_over_4_Alternate, Optimal_Value_4_Layer_q_3pi_over_4_Alternate, Optimal_Value_5_Layer_q_3pi_over_4_Alternate, Optimal_Value_6_Layer_q_3pi_over_4_Alternate, Optimal_Value_7_Layer_q_3pi_over_4_Alternate, Optimal_Value_8_Layer_q_3pi_over_4_Alternate]

#q = pi
Energies_1_Layer_q_pi = np.loadtxt(r"/mnt/c/Users/Saavanth Velury/Desktop/Quasiparticle VQE/8 Qubit Data (Final)/Delta = one-half/Nf = 4/q = pi/1 Layer/8_Qubit_XXZ_1_Layer_HVA_Optimal_Values_BOBYQA_GPU_4_Filled_States_Antiperiodic_Boundary_Conditions_PH_State_4_Delta_0.5.txt")
Energies_2_Layer_q_pi = np.loadtxt(r"/mnt/c/Users/Saavanth Velury/Desktop/Quasiparticle VQE/8 Qubit Data (Final)/Delta = one-half/Nf = 4/q = pi/2 Layers/8_Qubit_XXZ_2_Layer_HVA_Optimal_Values_BOBYQA_GPU_4_Filled_States_Antiperiodic_Boundary_Conditions_PH_State_4_Delta_0.5.txt")
Energies_3_Layer_q_pi = np.loadtxt(r"/mnt/c/Users/Saavanth Velury/Desktop/Quasiparticle VQE/8 Qubit Data (Final)/Delta = one-half/Nf = 4/q = pi/3 Layers/8_Qubit_XXZ_3_Layer_HVA_Optimal_Values_BOBYQA_GPU_4_Filled_States_Antiperiodic_Boundary_Conditions_PH_State_4_Delta_0.5.txt")
Energies_4_Layer_q_pi = np.loadtxt(r"/mnt/c/Users/Saavanth Velury/Desktop/Quasiparticle VQE/8 Qubit Data (Final)/Delta = one-half/Nf = 4/q = pi/4 Layers/8_Qubit_XXZ_4_Layer_HVA_Optimal_Values_BOBYQA_GPU_4_Filled_States_Antiperiodic_Boundary_Conditions_PH_State_4_Delta_0.5.txt")
Energies_5_Layer_q_pi = np.loadtxt(r"/mnt/c/Users/Saavanth Velury/Desktop/Quasiparticle VQE/8 Qubit Data (Final)/Delta = one-half/Nf = 4/q = pi/5 Layers/8_Qubit_XXZ_5_Layer_HVA_Optimal_Values_BOBYQA_GPU_4_Filled_States_Antiperiodic_Boundary_Conditions_PH_State_4_Delta_0.5.txt")
Energies_6_Layer_q_pi = np.loadtxt(r"/mnt/c/Users/Saavanth Velury/Desktop/Quasiparticle VQE/8 Qubit Data (Final)/Delta = one-half/Nf = 4/q = pi/6 Layers/8_Qubit_XXZ_6_Layer_HVA_Optimal_Values_BOBYQA_GPU_4_Filled_States_Antiperiodic_Boundary_Conditions_PH_State_4_Delta_0.5.txt")
Energies_7_Layer_q_pi = np.loadtxt(r"/mnt/c/Users/Saavanth Velury/Desktop/Quasiparticle VQE/8 Qubit Data (Final)/Delta = one-half/Nf = 4/q = pi/7 Layers/8_Qubit_XXZ_7_Layer_HVA_Optimal_Values_BOBYQA_GPU_4_Filled_States_Antiperiodic_Boundary_Conditions_PH_State_4_Delta_0.5.txt")
Energies_8_Layer_q_pi = np.loadtxt(r"/mnt/c/Users/Saavanth Velury/Desktop/Quasiparticle VQE/8 Qubit Data (Final)/Delta = one-half/Nf = 4/q = pi/8 Layers/8_Qubit_XXZ_8_Layer_HVA_Optimal_Values_BOBYQA_GPU_4_Filled_States_Antiperiodic_Boundary_Conditions_PH_State_4_Delta_0.5.txt")
Optimal_Value_1_Layer_q_pi = Energies_1_Layer_q_pi[np.argmin(Energies_1_Layer_q_pi)]
Optimal_Value_2_Layer_q_pi = Energies_2_Layer_q_pi[np.argmin(Energies_2_Layer_q_pi)]
Optimal_Value_3_Layer_q_pi = Energies_3_Layer_q_pi[np.argmin(Energies_3_Layer_q_pi)]
Optimal_Value_4_Layer_q_pi = Energies_4_Layer_q_pi[np.argmin(Energies_4_Layer_q_pi)]
Optimal_Value_5_Layer_q_pi = Energies_5_Layer_q_pi[np.argmin(Energies_5_Layer_q_pi)]
Optimal_Value_6_Layer_q_pi = Energies_6_Layer_q_pi[np.argmin(Energies_6_Layer_q_pi)]
Optimal_Value_7_Layer_q_pi = Energies_7_Layer_q_pi[np.argmin(Energies_7_Layer_q_pi)]
Optimal_Value_8_Layer_q_pi = Energies_8_Layer_q_pi[np.argmin(Energies_8_Layer_q_pi)]
Optimal_Values_q_pi = [Optimal_Value_1_Layer_q_pi, Optimal_Value_2_Layer_q_pi, Optimal_Value_3_Layer_q_pi, Optimal_Value_4_Layer_q_pi, Optimal_Value_5_Layer_q_pi, Optimal_Value_6_Layer_q_pi, Optimal_Value_7_Layer_q_pi, Optimal_Value_8_Layer_q_pi]

Energies_1_Layer_q_pi_Alternate = np.loadtxt(r"/mnt/c/Users/Saavanth Velury/Desktop/Quasiparticle VQE/8 Qubit Data (Final)/Delta = one-half/Nf = 4/q = pi/1 Layer/8_Qubit_XXZ_1_Layer_HVA_Optimal_Values_BOBYQA_GPU_4_Filled_States_Antiperiodic_Boundary_Conditions_PH_State_4_Alternate_Delta_0.5.txt")
Energies_2_Layer_q_pi_Alternate = np.loadtxt(r"/mnt/c/Users/Saavanth Velury/Desktop/Quasiparticle VQE/8 Qubit Data (Final)/Delta = one-half/Nf = 4/q = pi/2 Layers/8_Qubit_XXZ_2_Layer_HVA_Optimal_Values_BOBYQA_GPU_4_Filled_States_Antiperiodic_Boundary_Conditions_PH_State_4_Alternate_Delta_0.5.txt")
Energies_3_Layer_q_pi_Alternate = np.loadtxt(r"/mnt/c/Users/Saavanth Velury/Desktop/Quasiparticle VQE/8 Qubit Data (Final)/Delta = one-half/Nf = 4/q = pi/3 Layers/8_Qubit_XXZ_3_Layer_HVA_Optimal_Values_BOBYQA_GPU_4_Filled_States_Antiperiodic_Boundary_Conditions_PH_State_4_Alternate_Delta_0.5.txt")
Energies_4_Layer_q_pi_Alternate = np.loadtxt(r"/mnt/c/Users/Saavanth Velury/Desktop/Quasiparticle VQE/8 Qubit Data (Final)/Delta = one-half/Nf = 4/q = pi/4 Layers/8_Qubit_XXZ_4_Layer_HVA_Optimal_Values_BOBYQA_GPU_4_Filled_States_Antiperiodic_Boundary_Conditions_PH_State_4_Alternate_Delta_0.5.txt")
Energies_5_Layer_q_pi_Alternate = np.loadtxt(r"/mnt/c/Users/Saavanth Velury/Desktop/Quasiparticle VQE/8 Qubit Data (Final)/Delta = one-half/Nf = 4/q = pi/5 Layers/8_Qubit_XXZ_5_Layer_HVA_Optimal_Values_BOBYQA_GPU_4_Filled_States_Antiperiodic_Boundary_Conditions_PH_State_4_Alternate_Delta_0.5.txt")
Energies_6_Layer_q_pi_Alternate = np.loadtxt(r"/mnt/c/Users/Saavanth Velury/Desktop/Quasiparticle VQE/8 Qubit Data (Final)/Delta = one-half/Nf = 4/q = pi/6 Layers/8_Qubit_XXZ_6_Layer_HVA_Optimal_Values_BOBYQA_GPU_4_Filled_States_Antiperiodic_Boundary_Conditions_PH_State_4_Alternate_Delta_0.5.txt")
Energies_7_Layer_q_pi_Alternate = np.loadtxt(r"/mnt/c/Users/Saavanth Velury/Desktop/Quasiparticle VQE/8 Qubit Data (Final)/Delta = one-half/Nf = 4/q = pi/7 Layers/8_Qubit_XXZ_7_Layer_HVA_Optimal_Values_BOBYQA_GPU_4_Filled_States_Antiperiodic_Boundary_Conditions_PH_State_4_Alternate_Delta_0.5.txt")
Energies_8_Layer_q_pi_Alternate = np.loadtxt(r"/mnt/c/Users/Saavanth Velury/Desktop/Quasiparticle VQE/8 Qubit Data (Final)/Delta = one-half/Nf = 4/q = pi/8 Layers/8_Qubit_XXZ_8_Layer_HVA_Optimal_Values_BOBYQA_GPU_4_Filled_States_Antiperiodic_Boundary_Conditions_PH_State_4_Alternate_Delta_0.5.txt")
Optimal_Value_1_Layer_q_pi_Alternate = Energies_1_Layer_q_pi_Alternate[np.argmin(Energies_1_Layer_q_pi_Alternate)]
Optimal_Value_2_Layer_q_pi_Alternate = Energies_2_Layer_q_pi_Alternate[np.argmin(Energies_2_Layer_q_pi_Alternate)]
Optimal_Value_3_Layer_q_pi_Alternate = Energies_3_Layer_q_pi_Alternate[np.argmin(Energies_3_Layer_q_pi_Alternate)]
Optimal_Value_4_Layer_q_pi_Alternate = Energies_4_Layer_q_pi_Alternate[np.argmin(Energies_4_Layer_q_pi_Alternate)]
Optimal_Value_5_Layer_q_pi_Alternate = Energies_5_Layer_q_pi_Alternate[np.argmin(Energies_5_Layer_q_pi_Alternate)]
Optimal_Value_6_Layer_q_pi_Alternate = Energies_6_Layer_q_pi_Alternate[np.argmin(Energies_6_Layer_q_pi_Alternate)]
Optimal_Value_7_Layer_q_pi_Alternate = Energies_7_Layer_q_pi_Alternate[np.argmin(Energies_7_Layer_q_pi_Alternate)]
Optimal_Value_8_Layer_q_pi_Alternate = Energies_8_Layer_q_pi_Alternate[np.argmin(Energies_8_Layer_q_pi_Alternate)]
Optimal_Values_q_pi_Alternate = [Optimal_Value_1_Layer_q_pi_Alternate, Optimal_Value_2_Layer_q_pi_Alternate, Optimal_Value_3_Layer_q_pi_Alternate, Optimal_Value_4_Layer_q_pi_Alternate, Optimal_Value_5_Layer_q_pi_Alternate, Optimal_Value_6_Layer_q_pi_Alternate, Optimal_Value_7_Layer_q_pi_Alternate, Optimal_Value_8_Layer_q_pi_Alternate]

# %%
ED_Values_1_Delta_One_Half = [-9.656854+12.347977, -6.770218+12.347977, -6.205550+12.347977, -8.449831+12.347977, 0, -8.449831+12.347977, -6.205550+12.347977, -6.770218+12.347977, -9.656854+12.347977]
VQE_Values_1_Delta_One_Half = [min(Optimal_Values_q_pi)-min(Optimal_Values_q0), -6.76993275-min(Optimal_Values_q0), -6.20508136-min(Optimal_Values_q0), -8.44949576-min(Optimal_Values_q0), 0, min(Optimal_Values_q_pi_over_4)-min(Optimal_Values_q0), min(Optimal_Values_q_pi_over_2_Alternate)-min(Optimal_Values_q0), min(Optimal_Values_q_3pi_over_4_Alternate)-min(Optimal_Values_q0), min(Optimal_Values_q_pi)-min(Optimal_Values_q0)]
ED_Values_2_Delta_One_Half = [-9.037633+12.347977, -5.863703+12.347977, -5.615041+12.347977, -8.449831+12.347977, 0, -8.449831+12.347977, -5.615041+12.347977, -5.863703+12.347977, -9.037633+12.347977]
VQE_Values_2_Delta_One_Half = [min(Optimal_Values_q_pi_Alternate)-min(Optimal_Values_q0), -5.86364128-min(Optimal_Values_q0), -5.61401460-min(Optimal_Values_q0), -8.44949576-min(Optimal_Values_q0), 0, min(Optimal_Values_q_pi_over_4)-min(Optimal_Values_q0), min(Optimal_Values_q_pi_over_2)-min(Optimal_Values_q0), min(Optimal_Values_q_3pi_over_4)-min(Optimal_Values_q0), min(Optimal_Values_q_pi_Alternate)-min(Optimal_Values_q0)]

# %%
#Nf = 4 (Δ = 0.9)

#q = 0
Energies_8_Layer_q0 = np.loadtxt(r"/mnt/c/Users/Saavanth Velury/Desktop/Quasiparticle VQE/8 Qubit Data (Final)/Delta = nine-tenths/Nf = 4/q = 0/8 Layers/8_Qubit_XXZ_8_Layer_HVA_Optimal_Values_BOBYQA_GPU_4_Filled_States_Antiperiodic_Boundary_Conditions_Three_Parameters_Delta_0.9.txt")
Optimal_Values_8_Layer_q0 = Energies_8_Layer_q0[np.argmin(Energies_8_Layer_q0)]

#q = pi/8
Energies_8_Layer_q_pi_over_4 = np.loadtxt(r"/mnt/c/Users/Saavanth Velury/Desktop/Quasiparticle VQE/8 Qubit Data (Final)/Delta = nine-tenths/Nf = 4/q = pi over 4/8 Layers/8_Qubit_XXZ_8_Layer_HVA_Optimal_Values_BOBYQA_GPU_4_Filled_States_Antiperiodic_BC_PH_State_Three_Parameters_Delta_0.9.txt")
Optimal_Values_8_Layer_q_pi_over_4 = Energies_8_Layer_q_pi_over_4[np.argmin(Energies_8_Layer_q_pi_over_4)]

#q = pi/2
Energies_8_Layer_q_pi_over_2 = np.loadtxt(r"/mnt/c/Users/Saavanth Velury/Desktop/Quasiparticle VQE/8 Qubit Data (Final)/Delta = nine-tenths/Nf = 4/q = pi over 2/8 Layers/8_Qubit_XXZ_8_Layer_HVA_Optimal_Values_BOBYQA_GPU_4_Filled_States_Antiperiodic_BC_PH_State_2_Alternate_Three_Parameters_Delta_0.9.txt")
Optimal_Values_8_Layer_q_pi_over_2 = Energies_8_Layer_q_pi_over_2[np.argmin(Energies_8_Layer_q_pi_over_2)]

#q = 3pi/4
Energies_8_Layer_q_3pi_over_4 = np.loadtxt(r"/mnt/c/Users/Saavanth Velury/Desktop/Quasiparticle VQE/8 Qubit Data (Final)/Delta = nine-tenths/Nf = 4/q = 3pi over 4/8 Layers/8_Qubit_XXZ_8_Layer_HVA_Optimal_Values_BOBYQA_GPU_4_Filled_States_Antiperiodic_BC_PH_State_3_Alternate_Three_Parameters_Delta_0.9.txt")
Optimal_Values_8_Layer_q_3pi_over_4 = Energies_8_Layer_q_3pi_over_4[np.argmin(Energies_8_Layer_q_3pi_over_4)]

#q = pi
Energies_8_Layer_q_pi = np.loadtxt(r"/mnt/c/Users/Saavanth Velury/Desktop/Quasiparticle VQE/8 Qubit Data (Final)/Delta = nine-tenths/Nf = 4/q = pi/8 Layers/8_Qubit_XXZ_8_Layer_HVA_Optimal_Values_BOBYQA_GPU_4_Filled_States_Antiperiodic_BC_PH_State_4_Three_Parameters_Delta_0.9.txt")
Optimal_Values_8_Layer_q_pi = Energies_8_Layer_q_pi[np.argmin(Energies_8_Layer_q_pi)]

# %%
ED_Values_Delta_Nine_Tenths = [-11.909332+14.124658, -8.209779+14.124658, -7.159075+14.124658, -9.537671+14.124658, 0, -9.537671+14.124658, -7.159075+14.124658, -8.209779+14.124658, -11.909332+14.124658]
VQE_Values_Delta_Nine_Tenths = [-11.90924788-Optimal_Values_8_Layer_q0, -8.20961424-Optimal_Values_8_Layer_q0, -7.15889928-Optimal_Values_8_Layer_q0, -9.53752994-Optimal_Values_8_Layer_q0, 0, Optimal_Values_8_Layer_q_pi_over_4-Optimal_Values_8_Layer_q0, Optimal_Values_8_Layer_q_pi_over_2-Optimal_Values_8_Layer_q0, Optimal_Values_8_Layer_q_3pi_over_4-Optimal_Values_8_Layer_q0, Optimal_Values_8_Layer_q_pi-Optimal_Values_8_Layer_q0]

# %%
Optimal_Values_8_Layer_q0
# Out:
# -14.123731231689453

# %%
# Momentum points
q = np.array([-np.pi, -3*np.pi/4, -np.pi/2, -np.pi/4, 0, np.pi/4, np.pi/2, 3*np.pi/4, np.pi])

# Ground‐state energies
E0_ED_0p1  = -10.801697
E0_VQE_0p1 = -10.801155
E0_ED_0p5  = -12.347977
E0_VQE_0p5 = -12.343965
E0_ED_0p9 = -14.124658
E0_VQE_0p9 = -14.123731

# Dispersion *relative* to the ground state (so first entry is 0 offset)
disp_ED_0p1  = np.array(ED_Values_1_Delta_One_Tenth)
disp_VQE_0p1 = np.array(VQE_Values_1_Delta_One_Tenth)
disp_ED_0p5  = np.array(ED_Values_1_Delta_One_Half)
disp_VQE_0p5 = np.array(VQE_Values_1_Delta_One_Half)
disp_ED_0p9 = np.array(ED_Values_Delta_Nine_Tenths)
disp_VQE_0p9 = np.array(VQE_Values_Delta_Nine_Tenths)

# Build *actual* energy arrays by adding back the ground‐state
E_ED_0p1   = E0_ED_0p1  + disp_ED_0p1
E_VQE_0p1  = E0_VQE_0p1 + disp_VQE_0p1
E_ED_0p5   = E0_ED_0p5  + disp_ED_0p5
E_VQE_0p5  = E0_VQE_0p5 + disp_VQE_0p5
E_ED_0p9   = E0_ED_0p9  + disp_ED_0p9
E_VQE_0p9  = E0_VQE_0p9 + disp_VQE_0p9

# --- Plotting ---
fig, ax = plt.subplots(figsize=(12,12))

c_ED_0p1   = "#0000FF"   
c_VQE_0p1  = "#FF0000"   
c_ED_0p5   = "#00CC00"   
c_VQE_0p5  = "#800080"
c_ED_0p9   = "#FFA500"
c_VQE_0p9  = "#00FFFF"

bg = ax.patch.get_facecolor()

# ED (filled markers)
ax.plot(q, E_ED_0p1, linestyle='-', linewidth=4, color=c_ED_0p1, alpha=0.25, zorder=1)
ax.scatter(q, E_ED_0p1, s=15**2, facecolor=c_ED_0p1, edgecolor=c_ED_0p1, linewidth=1, alpha=1, zorder=4, label=r'ED, $\Delta=0.1$')
ax.plot(q, E_ED_0p5, linestyle='-', linewidth=4, color=c_ED_0p5, alpha=0.25, zorder=1)
ax.scatter(q, E_ED_0p5, s=15**2, facecolor=c_ED_0p5, edgecolor=c_ED_0p5, linewidth=1, alpha=1, zorder=4, label=r'ED, $\Delta=0.5$')
ax.plot(q, E_ED_0p9, linestyle='-', linewidth=4, color=c_ED_0p9, alpha=0.25, zorder=1)
ax.scatter(q, E_ED_0p9, s=15**2, facecolor=c_ED_0p9, edgecolor=c_ED_0p9, linewidth=1, alpha=1, zorder=4, label=r'ED, $\Delta=0.9$')

# VQE (open markers)
ax.scatter(q, E_VQE_0p1, s=30**2, facecolor=bg, edgecolor='none', zorder=2)
ax.scatter(q, E_VQE_0p1, s=30**2, facecolor='none', edgecolor=c_VQE_0p1, linewidth=2, zorder=3, label=r'VQE, $\Delta=0.1$')
ax.scatter(q, E_VQE_0p5, s=30**2, facecolor=bg, edgecolor='none', zorder=2)
ax.scatter(q, E_VQE_0p5, s=30**2, facecolor='none', edgecolor=c_VQE_0p5, linewidth=2, zorder=3, label=r'VQE, $\Delta=0.5$')
ax.scatter(q, E_VQE_0p9, s=30**2, facecolor=bg, edgecolor='none', zorder=2)
ax.scatter(q, E_VQE_0p9, s=30**2, facecolor='none', edgecolor=c_VQE_0p9, linewidth=2, zorder=3, label=r'VQE, $\Delta=0.9$')

# Axis formatting
ax.set_xlabel(r'$q$', fontsize=30, fontweight='bold')
ax.set_ylabel(r'$E(q)$', fontsize=30, fontweight='bold')       
ax.set_xticks(q)
ax.set_xticklabels([r'$-\pi$', r'$-\tfrac{3\pi}{4}$', r'$-\tfrac{\pi}{2}$', r'$-\tfrac{\pi}{4}$', r'$0$', r'$\tfrac{\pi}{4}$', r'$\tfrac{\pi}{2}$',
                    r'$\tfrac{3\pi}{4}$', r'$\pi$'], fontsize=30, fontweight='bold')
ax.set_yticklabels(ax.get_yticks(), fontsize=30, fontweight='bold')

# Inset textbox
text_props = dict(boxstyle='round', facecolor='white', alpha=0.8, pad=0.3)
ax.text(0.65, 0.95,
        r'$N_{F}=4\;(S_{z}=0)$',
        transform=ax.transAxes,
        ha='right', va='top',
        fontsize=30,
        fontweight='bold',
        bbox=text_props)

leg = ax.legend(frameon=True, framealpha=1, fancybox = True)
for text in leg.get_texts():
    text.set_fontweight('bold')
    text.set_fontsize(30)

frame = leg.get_frame()
frame.set_edgecolor('black')
frame.set_linewidth(1.2) 
frame.set_facecolor('white')

plt.tight_layout()
#plt.savefig('XXZ_Dispersion_8_Qubit.pdf', dpi=300, bbox_inches='tight')
plt.show()
# Out:
# /tmp/ipykernel_1721/3304305141.py:62: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_yticklabels(ax.get_yticks(), fontsize=30, fontweight='bold')

# %%
#Save Arrays
np.savetxt('ED_Values_4_Filled_States_Delta_Nine_Tenths_8_Qubit.txt', ED_Values_Delta_Nine_Tenths)
np.savetxt('VQE_Values_4_Filled_States_Delta_Nine_Tenths_8_Qubit.txt', VQE_Values_Delta_Nine_Tenths)
