# %%
import numpy as np
from matplotlib import pyplot as plt
import matplotlib as mpl
plt.rcParams.update({
    "text.usetex": True,
    "text.latex.preamble": r"\usepackage{amsmath}",
    "font.family": "serif",
    "font.serif": ["Computer Modern"],
    "pdf.fonttype": 42,
    "ps.fonttype": 42,
    "font.size": 30,
    'font.weight': 'bold',
    'axes.titleweight': 'bold',
    'axes.labelweight': 'bold'
})
import os
import warnings
with warnings.catch_warnings():
    warnings.simplefilter('ignore', category=UserWarning)

# %%
print("Exists?", os.path.exists(r"/mnt/c/Users/Saavanth Velury/Desktop/Quasiparticle VQE/16 Qubit Data (Final)/Delta = one-tenth/Nf = 8/q = pi/1 Layer/16_Qubit_XXZ_1_Layer_HVA_Optimal_Values_BOBYQA_8_Filled_States_Antiperiodic_Boundary_Conditions_PH_State_8.txt"))
print("Is file?", os.path.isfile(r"/mnt/c/Users/Saavanth Velury/Desktop/Quasiparticle VQE/16 Qubit Data (Final)/Delta = one-tenth/Nf = 8/q = pi/1 Layer/16_Qubit_XXZ_1_Layer_HVA_Optimal_Values_BOBYQA_8_Filled_States_Antiperiodic_Boundary_Conditions_PH_State_8.txt"))
# Out:
# Exists? True
# Is file? True

# %%
#Nf = 8 (Δ = 0.1)

#q = 0
Energies_1_Layer_q0 = np.loadtxt(r"/mnt/c/Users/Saavanth Velury/Desktop/Quasiparticle VQE/16 Qubit Data (Final)/Delta = one-tenth/Nf = 8/q = 0/1 Layer/16_Qubit_XXZ_1_Layer_HVA_Optimal_Values_BOBYQA_8_Filled_States_Antiperiodic_Boundary_Conditions.txt")
Energies_2_Layer_q0 = np.loadtxt(r"/mnt/c/Users/Saavanth Velury/Desktop/Quasiparticle VQE/16 Qubit Data (Final)/Delta = one-tenth/Nf = 8/q = 0/2 Layers/16_Qubit_XXZ_2_Layer_HVA_Optimal_Values_BOBYQA_8_Filled_States_Antiperiodic_Boundary_Conditions.txt")
Energies_3_Layer_q0 = np.loadtxt(r"/mnt/c/Users/Saavanth Velury/Desktop/Quasiparticle VQE/16 Qubit Data (Final)/Delta = one-tenth/Nf = 8/q = 0/3 Layers/16_Qubit_XXZ_3_Layer_HVA_Optimal_Values_BOBYQA_8_Filled_States_Antiperiodic_Boundary_Conditions.txt")
Energies_4_Layer_q0 = np.loadtxt(r"/mnt/c/Users/Saavanth Velury/Desktop/Quasiparticle VQE/16 Qubit Data (Final)/Delta = one-tenth/Nf = 8/q = 0/4 Layers/16_Qubit_XXZ_4_Layer_HVA_Optimal_Values_BOBYQA_8_Filled_States_Antiperiodic_Boundary_Conditions.txt")
Energies_5_Layer_q0 = np.loadtxt(r"/mnt/c/Users/Saavanth Velury/Desktop/Quasiparticle VQE/16 Qubit Data (Final)/Delta = one-tenth/Nf = 8/q = 0/5 Layers/16_Qubit_XXZ_5_Layer_HVA_Optimal_Values_BOBYQA_8_Filled_States_Antiperiodic_Boundary_Conditions.txt")
Optimal_Value_1_Layer_q0 = Energies_1_Layer_q0[np.argmin(Energies_1_Layer_q0)]
Optimal_Value_2_Layer_q0 = Energies_2_Layer_q0[np.argmin(Energies_2_Layer_q0)]
Optimal_Value_3_Layer_q0 = Energies_3_Layer_q0[np.argmin(Energies_3_Layer_q0)]
Optimal_Value_4_Layer_q0 = Energies_4_Layer_q0[np.argmin(Energies_4_Layer_q0)]
Optimal_Value_5_Layer_q0 = Energies_5_Layer_q0[np.argmin(Energies_5_Layer_q0)]
Optimal_Values_q0 = [Optimal_Value_1_Layer_q0, Optimal_Value_2_Layer_q0, Optimal_Value_3_Layer_q0, Optimal_Value_4_Layer_q0, Optimal_Value_5_Layer_q0]

#q = pi/8
Energies_1_Layer_q_pi_over_8 = np.loadtxt(r"/mnt/c/Users/Saavanth Velury/Desktop/Quasiparticle VQE/16 Qubit Data (Final)/Delta = one-tenth/Nf = 8/q = pi over 8/1 Layer/16_Qubit_XXZ_1_Layer_HVA_Optimal_Values_BOBYQA_8_Filled_States_Antiperiodic_Boundary_Conditions_PH_State.txt")
Energies_2_Layer_q_pi_over_8 = np.loadtxt(r"/mnt/c/Users/Saavanth Velury/Desktop/Quasiparticle VQE/16 Qubit Data (Final)/Delta = one-tenth/Nf = 8/q = pi over 8/2 Layers/16_Qubit_XXZ_2_Layer_HVA_Optimal_Values_BOBYQA_8_Filled_States_Antiperiodic_Boundary_Conditions_PH_State.txt")
Energies_3_Layer_q_pi_over_8 = np.loadtxt(r"/mnt/c/Users/Saavanth Velury/Desktop/Quasiparticle VQE/16 Qubit Data (Final)/Delta = one-tenth/Nf = 8/q = pi over 8/3 Layers/16_Qubit_XXZ_3_Layer_HVA_Optimal_Values_BOBYQA_8_Filled_States_Antiperiodic_Boundary_Conditions_PH_State.txt")
Energies_4_Layer_q_pi_over_8 = np.loadtxt(r"/mnt/c/Users/Saavanth Velury/Desktop/Quasiparticle VQE/16 Qubit Data (Final)/Delta = one-tenth/Nf = 8/q = pi over 8/4 Layers/16_Qubit_XXZ_4_Layer_HVA_Optimal_Values_BOBYQA_8_Filled_States_Antiperiodic_Boundary_Conditions_PH_State.txt")
Energies_5_Layer_q_pi_over_8 = np.loadtxt(r"/mnt/c/Users/Saavanth Velury/Desktop/Quasiparticle VQE/16 Qubit Data (Final)/Delta = one-tenth/Nf = 8/q = pi over 8/5 Layers/16_Qubit_XXZ_5_Layer_HVA_Optimal_Values_BOBYQA_8_Filled_States_Antiperiodic_Boundary_Conditions_PH_State.txt")
Optimal_Value_1_Layer_q_pi_over_8 = Energies_1_Layer_q_pi_over_8[np.argmin(Energies_1_Layer_q_pi_over_8)]
Optimal_Value_2_Layer_q_pi_over_8 = Energies_2_Layer_q_pi_over_8[np.argmin(Energies_2_Layer_q_pi_over_8)]
Optimal_Value_3_Layer_q_pi_over_8 = Energies_3_Layer_q_pi_over_8[np.argmin(Energies_3_Layer_q_pi_over_8)]
Optimal_Value_4_Layer_q_pi_over_8 = Energies_4_Layer_q_pi_over_8[np.argmin(Energies_4_Layer_q_pi_over_8)]
Optimal_Value_5_Layer_q_pi_over_8 = Energies_5_Layer_q_pi_over_8[np.argmin(Energies_5_Layer_q_pi_over_8)]
Optimal_Values_q_pi_over_8 = [Optimal_Value_1_Layer_q_pi_over_8, Optimal_Value_2_Layer_q_pi_over_8, Optimal_Value_3_Layer_q_pi_over_8, Optimal_Value_4_Layer_q_pi_over_8, Optimal_Value_5_Layer_q_pi_over_8]

#q = pi/4
Energies_1_Layer_q_pi_over_4 = np.loadtxt(r"/mnt/c/Users/Saavanth Velury/Desktop/Quasiparticle VQE/16 Qubit Data (Final)/Delta = one-tenth/Nf = 8/q = pi over 4/1 Layer/16_Qubit_XXZ_1_Layer_HVA_Optimal_Values_BOBYQA_8_Filled_States_Antiperiodic_Boundary_Conditions_PH_State_2.txt")
Energies_2_Layer_q_pi_over_4 = np.loadtxt(r"/mnt/c/Users/Saavanth Velury/Desktop/Quasiparticle VQE/16 Qubit Data (Final)/Delta = one-tenth/Nf = 8/q = pi over 4/2 Layers/16_Qubit_XXZ_2_Layer_HVA_Optimal_Values_BOBYQA_8_Filled_States_Antiperiodic_Boundary_Conditions_PH_State_2.txt")
Energies_3_Layer_q_pi_over_4 = np.loadtxt(r"/mnt/c/Users/Saavanth Velury/Desktop/Quasiparticle VQE/16 Qubit Data (Final)/Delta = one-tenth/Nf = 8/q = pi over 4/3 Layers/16_Qubit_XXZ_3_Layer_HVA_Optimal_Values_BOBYQA_8_Filled_States_Antiperiodic_Boundary_Conditions_PH_State_2.txt")
Energies_4_Layer_q_pi_over_4 = np.loadtxt(r"/mnt/c/Users/Saavanth Velury/Desktop/Quasiparticle VQE/16 Qubit Data (Final)/Delta = one-tenth/Nf = 8/q = pi over 4/4 Layers/16_Qubit_XXZ_4_Layer_HVA_Optimal_Values_BOBYQA_8_Filled_States_Antiperiodic_Boundary_Conditions_PH_State_2.txt")
Energies_5_Layer_q_pi_over_4 = np.loadtxt(r"/mnt/c/Users/Saavanth Velury/Desktop/Quasiparticle VQE/16 Qubit Data (Final)/Delta = one-tenth/Nf = 8/q = pi over 4/5 Layers/16_Qubit_XXZ_5_Layer_HVA_Optimal_Values_BOBYQA_8_Filled_States_Antiperiodic_Boundary_Conditions_PH_State_2.txt")
Optimal_Value_1_Layer_q_pi_over_4 = Energies_1_Layer_q_pi_over_4[np.argmin(Energies_1_Layer_q_pi_over_4)]
Optimal_Value_2_Layer_q_pi_over_4 = Energies_2_Layer_q_pi_over_4[np.argmin(Energies_2_Layer_q_pi_over_4)]
Optimal_Value_3_Layer_q_pi_over_4 = Energies_3_Layer_q_pi_over_4[np.argmin(Energies_3_Layer_q_pi_over_4)]
Optimal_Value_4_Layer_q_pi_over_4 = Energies_4_Layer_q_pi_over_4[np.argmin(Energies_4_Layer_q_pi_over_4)]
Optimal_Value_5_Layer_q_pi_over_4 = Energies_5_Layer_q_pi_over_4[np.argmin(Energies_5_Layer_q_pi_over_4)]
Optimal_Values_q_pi_over_4 = [Optimal_Value_1_Layer_q_pi_over_4, Optimal_Value_2_Layer_q_pi_over_4, Optimal_Value_3_Layer_q_pi_over_4, Optimal_Value_4_Layer_q_pi_over_4, Optimal_Value_5_Layer_q_pi_over_4]

Energies_1_Layer_q_pi_over_4_Alternate = np.loadtxt(r"/mnt/c/Users/Saavanth Velury/Desktop/Quasiparticle VQE/16 Qubit Data (Final)/Delta = one-tenth/Nf = 8/q = pi over 4/1 Layer/16_Qubit_XXZ_1_Layer_HVA_Optimal_Values_BOBYQA_8_Filled_States_Antiperiodic_Boundary_Conditions_PH_State_2_Alternate.txt")
Energies_2_Layer_q_pi_over_4_Alternate = np.loadtxt(r"/mnt/c/Users/Saavanth Velury/Desktop/Quasiparticle VQE/16 Qubit Data (Final)/Delta = one-tenth/Nf = 8/q = pi over 4/2 Layers/16_Qubit_XXZ_2_Layer_HVA_Optimal_Values_BOBYQA_8_Filled_States_Antiperiodic_Boundary_Conditions_PH_State_2_Alternate.txt")
Energies_3_Layer_q_pi_over_4_Alternate = np.loadtxt(r"/mnt/c/Users/Saavanth Velury/Desktop/Quasiparticle VQE/16 Qubit Data (Final)/Delta = one-tenth/Nf = 8/q = pi over 4/3 Layers/16_Qubit_XXZ_3_Layer_HVA_Optimal_Values_BOBYQA_8_Filled_States_Antiperiodic_Boundary_Conditions_PH_State_2_Alternate.txt")
Energies_4_Layer_q_pi_over_4_Alternate = np.loadtxt(r"/mnt/c/Users/Saavanth Velury/Desktop/Quasiparticle VQE/16 Qubit Data (Final)/Delta = one-tenth/Nf = 8/q = pi over 4/4 Layers/16_Qubit_XXZ_4_Layer_HVA_Optimal_Values_BOBYQA_8_Filled_States_Antiperiodic_Boundary_Conditions_PH_State_2_Alternate.txt")
Energies_5_Layer_q_pi_over_4_Alternate = np.loadtxt(r"/mnt/c/Users/Saavanth Velury/Desktop/Quasiparticle VQE/16 Qubit Data (Final)/Delta = one-tenth/Nf = 8/q = pi over 4/5 Layers/16_Qubit_XXZ_5_Layer_HVA_Optimal_Values_BOBYQA_8_Filled_States_Antiperiodic_Boundary_Conditions_PH_State_2_Alternate.txt")
Optimal_Value_1_Layer_q_pi_over_4_Alternate = Energies_1_Layer_q_pi_over_4_Alternate[np.argmin(Energies_1_Layer_q_pi_over_4_Alternate)]
Optimal_Value_2_Layer_q_pi_over_4_Alternate = Energies_2_Layer_q_pi_over_4_Alternate[np.argmin(Energies_2_Layer_q_pi_over_4_Alternate)]
Optimal_Value_3_Layer_q_pi_over_4_Alternate = Energies_3_Layer_q_pi_over_4_Alternate[np.argmin(Energies_3_Layer_q_pi_over_4_Alternate)]
Optimal_Value_4_Layer_q_pi_over_4_Alternate = Energies_4_Layer_q_pi_over_4_Alternate[np.argmin(Energies_4_Layer_q_pi_over_4_Alternate)]
Optimal_Value_5_Layer_q_pi_over_4_Alternate = Energies_5_Layer_q_pi_over_4_Alternate[np.argmin(Energies_5_Layer_q_pi_over_4_Alternate)]
Optimal_Values_q_pi_over_4_Alternate = [Optimal_Value_1_Layer_q_pi_over_4_Alternate, Optimal_Value_2_Layer_q_pi_over_4_Alternate, Optimal_Value_3_Layer_q_pi_over_4_Alternate, Optimal_Value_4_Layer_q_pi_over_4_Alternate, Optimal_Value_5_Layer_q_pi_over_4_Alternate]

#q = 3pi/8
Energies_1_Layer_q_3pi_over_8 = np.loadtxt(r"/mnt/c/Users/Saavanth Velury/Desktop/Quasiparticle VQE/16 Qubit Data (Final)/Delta = one-tenth/Nf = 8/q = 3pi over 8/1 Layer/16_Qubit_XXZ_1_Layer_HVA_Optimal_Values_BOBYQA_8_Filled_States_Antiperiodic_Boundary_Conditions_PH_State_3.txt")
Energies_2_Layer_q_3pi_over_8 = np.loadtxt(r"/mnt/c/Users/Saavanth Velury/Desktop/Quasiparticle VQE/16 Qubit Data (Final)/Delta = one-tenth/Nf = 8/q = 3pi over 8/2 Layers/16_Qubit_XXZ_2_Layer_HVA_Optimal_Values_BOBYQA_8_Filled_States_Antiperiodic_Boundary_Conditions_PH_State_3.txt")
Energies_3_Layer_q_3pi_over_8 = np.loadtxt(r"/mnt/c/Users/Saavanth Velury/Desktop/Quasiparticle VQE/16 Qubit Data (Final)/Delta = one-tenth/Nf = 8/q = 3pi over 8/3 Layers/16_Qubit_XXZ_3_Layer_HVA_Optimal_Values_BOBYQA_8_Filled_States_Antiperiodic_Boundary_Conditions_PH_State_3.txt")
Energies_4_Layer_q_3pi_over_8 = np.loadtxt(r"/mnt/c/Users/Saavanth Velury/Desktop/Quasiparticle VQE/16 Qubit Data (Final)/Delta = one-tenth/Nf = 8/q = 3pi over 8/4 Layers/16_Qubit_XXZ_4_Layer_HVA_Optimal_Values_BOBYQA_8_Filled_States_Antiperiodic_Boundary_Conditions_PH_State_3.txt")
Energies_5_Layer_q_3pi_over_8 = np.loadtxt(r"/mnt/c/Users/Saavanth Velury/Desktop/Quasiparticle VQE/16 Qubit Data (Final)/Delta = one-tenth/Nf = 8/q = 3pi over 8/5 Layers/16_Qubit_XXZ_5_Layer_HVA_Optimal_Values_BOBYQA_8_Filled_States_Antiperiodic_Boundary_Conditions_PH_State_
Layer_q_5pi_over_8 = np.loadtxt(r"/mnt/c/Users/Saavanth Velury/Desktop/Quasiparticle VQE/16 Qubit Data (Final)/Delta = one-tenth/Nf = 8/q = 5pi over 8/5 Layers/16_Qubit_XXZ_5_Layer_HVA_Optimal_Values_BOBYQA_8_Filled_States_Antiperiodic_Boundary_Conditions_PH_State_5.txt")
Optimal_Value_1_Layer_q_5pi_over_8 = Energies_1_Layer_q_5pi_over_8[np.argmin(Energies_1_Layer_q_5pi_over_8)]
Optimal_Value_2_Layer_q_5pi_over_8 = Energies_2_Layer_q_5pi_over_8[np.argmin(Energies_2_Layer_q_5pi_over_8)]
Optimal_Value_3_Layer_q_5pi_over_8 = Energies_3_Layer_q_5pi_over_8[np.argmin(Energies_3_Layer_q_5pi_over_8)]
Optimal_Value_4_Layer_q_5pi_over_8 = Energies_4_Layer_q_5pi_over_8[np.argmin(Energies_4_Layer_q_5pi_over_8)]
Optimal_Value_5_Layer_q_5pi_over_8 = Energies_5_Layer_q_5pi_over_8[np.argmin(Energies_5_Layer_q_5pi_over_8)]
Optimal_Values_q_5pi_over_8 = [Optimal_Value_1_Layer_q_5pi_over_8, Optimal_Value_2_Layer_q_5pi_over_8, Optimal_Value_3_Layer_q_5pi_over_8, Optimal_Value_4_Layer_q_5pi_over_8, Optimal_Value_5_Layer_q_5pi_over_8]

Energies_1_Layer_q_5pi_over_8_Alternate = np.loadtxt(r"/mnt/c/Users/Saavanth Velury/Desktop/Quasiparticle VQE/16 Qubit Data (Final)/Delta = one-tenth/Nf = 8/q = 5pi over 8/1 Layer/16_Qubit_XXZ_1_Layer_HVA_Optimal_Values_BOBYQA_8_Filled_States_Antiperiodic_Boundary_Conditions_PH_State_5_Alternate.txt")
Energies_2_Layer_q_5pi_over_8_Alternate = np.loadtxt(r"/mnt/c/Users/Saavanth Velury/Desktop/Quasiparticle VQE/16 Qubit Data (Final)/Delta = one-tenth/Nf = 8/q = 5pi over 8/2 Layers/16_Qubit_XXZ_2_Layer_HVA_Optimal_Values_BOBYQA_8_Filled_States_Antiperiodic_Boundary_Conditions_PH_State_5_Alternate.txt")
Energies_3_Layer_q_5pi_over_8_Alternate = np.loadtxt(r"/mnt/c/Users/Saavanth Velury/Desktop/Quasiparticle VQE/16 Qubit Data (Final)/Delta = one-tenth/Nf = 8/q = 5pi over 8/3 Layers/16_Qubit_XXZ_3_Layer_HVA_Optimal_Values_BOBYQA_8_Filled_States_Antiperiodic_Boundary_Conditions_PH_State_5_Alternate.txt")
Energies_4_Layer_q_5pi_over_8_Alternate = np.loadtxt(r"/mnt/c/Users/Saavanth Velury/Desktop/Quasiparticle VQE/16 Qubit Data (Final)/Delta = one-tenth/Nf = 8/q = 5pi over 8/4 Layers/16_Qubit_XXZ_4_Layer_HVA_Optimal_Values_BOBYQA_8_Filled_States_Antiperiodic_Boundary_Conditions_PH_State_5_Alternate.txt")
Energies_5_Layer_q_5pi_over_8_Alternate = np.loadtxt(r"/mnt/c/Users/Saavanth Velury/Desktop/Quasiparticle VQE/16 Qubit Data (Final)/Delta = one-tenth/Nf = 8/q = 5pi over 8/5 Layers/16_Qubit_XXZ_5_Layer_HVA_Optimal_Values_BOBYQA_8_Filled_States_Antiperiodic_Boundary_Conditions_PH_State_5_Alternate.txt")
Optimal_Value_1_Layer_q_5pi_over_8_Alternate = Energies_1_Layer_q_5pi_over_8_Alternate[np.argmin(Energies_1_Layer_q_5pi_over_8_Alternate)]
Optimal_Value_2_Layer_q_5pi_over_8_Alternate = Energies_2_Layer_q_5pi_over_8_Alternate[np.argmin(Energies_2_Layer_q_5pi_over_8_Alternate)]
Optimal_Value_3_Layer_q_5pi_over_8_Alternate = Energies_3_Layer_q_5pi_over_8_Alternate[np.argmin(Energies_3_Layer_q_5pi_over_8_Alternate)]
Optimal_Value_4_Layer_q_5pi_over_8_Alternate = Energies_4_Layer_q_5pi_over_8_Alternate[np.argmin(Energies_4_Layer_q_5pi_over_8_Alternate)]
Optimal_Value_5_Layer_q_5pi_over_8_Alternate = Energies_5_Layer_q_5pi_over_8_Alternate[np.argmin(Energies_5_Layer_q_5pi_over_8_Alternate)]
Optimal_Values_q_5pi_over_8_Alternate = [Optimal_Value_1_Layer_q_5pi_over_8_Alternate, Optimal_Value_2_Layer_q_5pi_over_8_Alternate, Optimal_Value_3_Layer_q_5pi_over_8_Alternate, Optimal_Value_4_Layer_q_5pi_over_8_Alternate, Optimal_Value_5_Layer_q_5pi_over_8_Alternate]

#q = 3pi/4
Energies_1_Layer_q_3pi_over_4 = np.loadtxt(r"/mnt/c/Users/Saavanth Velury/Desktop/Quasiparticle VQE/16 Qubit Data (Final)/Delta = one-tenth/Nf = 8/q = 3pi over 4/1 Layer/16_Qubit_XXZ_1_Layer_HVA_Optimal_Values_BOBYQA_8_Filled_States_Antiperiodic_Boundary_Conditions_PH_State_6.txt")
Energies_2_Layer_q_3pi_over_4 = np.loadtxt(r"/mnt/c/Users/Saavanth Velury/Desktop/Quasiparticle VQE/16 Qubit Data (Final)/Delta = one-tenth/Nf = 8/q = 3pi over 4/2 Layers/16_Qubit_XXZ_2_Layer_HVA_Optimal_Values_BOBYQA_8_Filled_States_Antiperiodic_Boundary_Conditions_PH_State_6.txt")
Energies_3_Layer_q_3pi_over_4 = np.loadtxt(r"/mnt/c/Users/Saavanth Velury/Desktop/Quasiparticle VQE/16 Qubit Data (Final)/Delta = one-tenth/Nf = 8/q = 3pi over 4/3 Layers/16_Qubit_XXZ_3_Layer_HVA_Optimal_Values_BOBYQA_8_Filled_States_Antiperiodic_Boundary_Conditions_PH_State_6.txt")
Energies_4_Layer_q_3pi_over_4 = np.loadtxt(r"/mnt/c/Users/Saavanth Velury/Desktop/Quasiparticle VQE/16 Qubit Data (Final)/Delta = one-tenth/Nf = 8/q = 3pi over 4/4 Layers/16_Qubit_XXZ_4_Layer_HVA_Optimal_Values_BOBYQA_8_Filled_States_Antiperiodic_Boundary_Conditions_PH_State_6.txt")
Energies_5_Layer_q_3pi_over_4 = np.loadtxt(r"/mnt/c/Users/Saavanth Velury/Desktop/Quasiparticle VQE/16 Qubit Data (Final)/Delta = one-tenth/Nf = 8/q = 3pi over 4/5 Layers/16_Qubit_XXZ_5_Layer_HVA_Optimal_Values_BOBYQA_8_Filled_States_Antiperiodic_Boundary_Conditions_PH_State_6.txt")
Optimal_Value_1_Layer_q_3pi_over_4 = Energies_1_Layer_q_3pi_over_4[np.argmin(Energies_1_Layer_q_3pi_over_4)]
Optimal_Value_2_Layer_q_3pi_over_4 = Energies_2_Layer_q_3pi_over_4[np.argmin(Energies_2_Layer_q_3pi_over_4)]
Optimal_Value_3_Layer_q_3pi_over_4 = Energies_3_Layer_q_3pi_over_4[np.argmin(Energies_3_Layer_q_3pi_over_4)]
Optimal_Value_4_Layer_q_3pi_over_4 = Energies_4_Layer_q_3pi_over_4[np.argmin(Energies_4_Layer_q_3pi_over_4)]
Optimal_Value_5_Layer_q_3pi_over_4 = Energies_5_Layer_q_3pi_over_4[np.argmin(Energies_5_Layer_q_3pi_over_4)]
Optimal_Values_q_3pi_over_4 = [Optimal_Value_1_Layer_q_3pi_over_4, Optimal_Value_2_Layer_q_3pi_over_4, Optimal_Value_3_Layer_q_3pi_over_4, Optimal_Value_4_Layer_q_3pi_over_4, Optimal_Value_5_Layer_q_3pi_over_4]

Energies_1_Layer_q_3pi_over_4_Alternate = np.loadtxt(r"/mnt/c/Users/Saavanth Velury/Desktop/Quasiparticle VQE/16 Qubit Data (Final)/Delta = one-tenth/Nf = 8/q = 3pi over 4/1 Layer/16_Qubit_XXZ_1_Layer_HVA_Optimal_Values_BOBYQA_8_Filled_States_Antiperiodic_Boundary_Conditions_PH_State_6_Alternate.txt")
Energies_2_Layer_q_3pi_over_4_Alternate = np.loadtxt(r"/mnt/c/Users/Saavanth Velury/Desktop/Quasiparticle VQE/16 Qubit Data (Final)/Delta = one-tenth/Nf = 8/q = 3pi over 4/2 Layers/16_Qubit_XXZ_2_Layer_HVA_Optimal_Values_BOBYQA_8_Filled_States_Antiperiodic_Boundary_Conditions_PH_State_6_Alternate.txt")
Energies_3_Layer_q_3pi_over_4_Alternate = np.loadtxt(r"/mnt/c/Users/Saavanth Velury/Desktop/Quasiparticle VQE/16 Qubit Data (Final)/Delta = one-tenth/Nf = 8/q = 3pi over 4/3 Layers/16_Qubit_XXZ_3_Layer_HVA_Optimal_Values_BOBYQA_8_Filled_States_Antiperiodic_Boundary_Conditions_PH_State_6_Alternate.txt")
Energies_4_Layer_q_3pi_over_4_Alternate = np.loadtxt(r"/mnt/c/Users/Saavanth Velury/Desktop/Quasiparticle VQE/16 Qubit Data (Final)/Delta = one-tenth/Nf = 8/q = 3pi over 4/4 Layers/16_Qubit_XXZ_4_Layer_HVA_Optimal_Values_BOBYQA_8_Filled_States_Antiperiodic_Boundary_Conditions_PH_State_6_Alternate.txt")
Energies_5_Layer_q_3pi_over_4_Alternate = np.loadtxt(r"/mnt/c/Users/Saavanth Velury/Desktop/Quasiparticle VQE/16 Qubit Data (Final)/Delta = one-tenth/Nf = 8/q = 3pi over 4/5 Layers/16_Qubit_XXZ_5_Layer_HVA_Optimal_Values_BOBYQA_8_Filled_States_Antiperiodic_Boundary_Conditions_PH_State_6_Alternate.txt")
Optimal_Value_1_Layer_q_3pi_over_4_Alternate = Energies_1_Layer_q_3pi_over_4_Alternate[np.argmin(Energies_1_Layer_q_3pi_over_4_Alternate)]
Optimal_Value_2_Layer_q_3pi_over_4_Alternate = Energies_2_Layer_q_3pi_over_4_Alternate[np.argmin(Energies_2_Layer_q_3pi_over_4_Alternate)]
Optimal_Value_3_Layer_q_3pi_over_4_Alternate = Energies_3_Layer_q_3pi_over_4_Alternate[np.argmin(Energies_3_Layer_q_3pi_over_4_Alternate)]
Optimal_Value_4_Layer_q_3pi_over_4_Alternate = Energies_4_Layer_q_3pi_over_4_Alternate[np.argmin(Energies_4_Layer_q_3pi_over_4_Alternate)]
Optimal_Value_5_Layer_q_3pi_over_4_Alternate = Energies_5_Layer_q_3pi_over_4_Alternate[np.argmin(Energies_5_Layer_q_3pi_over_4_Alternate)]
Optimal_Values_q_3pi_over_4_Alternate = [Optimal_Value_1_Layer_q_3pi_over_4_Alternate, Optimal_Value_2_Layer_q_3pi_over_4_Alternate, Optimal_Value_3_Layer_q_3pi_over_4_Alternate, Optimal_Value_4_Layer_q_3pi_over_4_Alternate, Optimal_Value_5_Layer_q_3pi_over_4_Alternate]

#q = 7pi/8
Energies_1_Layer_q_7pi_over_8 = np.loadtxt(r"/mnt/c/Users/Saavanth Velury/Desktop/Quasiparticle VQE/16 Qubit Data (Final)/Delta = one-tenth/Nf = 8/q = 7pi over 8/1 Layer/16_Qubit_XXZ_1_Layer_HVA_Optimal_Values_BOBYQA_8_Filled_States_Antiperiodic_Boundary_Conditions_PH_State_7.txt")
Energies_2_Layer_q_7pi_over_8 = np.loadtxt(r"/mnt/c/Users/Saavanth Velury/Desktop/Quasiparticle VQE/16 Qubit Data (Final)/Delta = one-tenth/Nf = 8/q = 7pi over 8/2 Layers/16_Qubit_XXZ_2_Layer_HVA_Optimal_Values_BOBYQA_8_Filled_States_Antiperiodic_Boundary_Conditions_PH_State_7.txt")
Energies_3_Layer_q_7pi_over_8 = np.loadtxt(r"/mnt/c/Users/Saavanth Velury/Desktop/Quasiparticle VQE/16 Qubit Data (Final)/Delta = one-tenth/Nf = 8/q = 7pi over 8/3 Layers/16_Qubit_XXZ_3_Layer_HVA_Optimal_Values_BOBYQA_8_Filled_States_Antiperiodic_Boundary_Conditions_PH_State_7.txt")
Energies_4_Layer_q_7pi_over_8 = np.loadtxt(r"/mnt/c/Users/Saavanth Velury/Desktop/Quasiparticle VQE/16 Qubit Data (Final)/Delta = one-tenth/Nf = 8/q = 7pi over 8/4 Layers/16_Qubit_XXZ_4_Layer_HVA_Optimal_Values_BOBYQA_8_Filled_States_Antiperiodic_Boundary_Conditions_PH_State_7.txt")
Energies_5_Layer_q_7pi_over_8 = np.loadtxt(r"/mnt/c/Users/Saavanth Velury/Desktop/Quasiparticle VQE/16 Qubit Data (Final)/Delta = one-tenth/Nf = 8/q = 7pi over 8/5 Layers/16_Qubit_XXZ_5_Layer_HVA_Optimal_Values_BOBYQA_8_Filled_States_Antiperiodic_Boundary_Conditions_PH_State_
ED_Values_Delta_One_Tenth = [-19.622596 + 21.176072, -18.095099 + 21.176072, -16.916995 + 21.176072, -16.268147 + 21.176072, -16.247542 + 21.176072, -16.858442 + 21.176072, -18.007869 + 21.176072, -19.520339 + 21.176072, 0, -19.520339 + 21.176072, -18.007869 + 21.176072, -16.858442 + 21.176072, -16.247542 + 21.176072, -16.268147 + 21.176072, -16.916995 + 21.176072, -18.095099 + 21.176072, -19.622596 + 21.176072]

# %%
VQE_Values_Delta_One_Tenth = [min(Optimal_Values_q_pi) - min(Optimal_Values_q0), -18.08264689-min(Optimal_Values_q0), -16.90208331-min(Optimal_Values_q0), -16.25294834-min(Optimal_Values_q0), -16.23398125-min(Optimal_Values_q0), -16.84798471-min(Optimal_Values_q0), -18.00138243-min(Optimal_Values_q0), -19.51256650-min(Optimal_Values_q0), 0, min(Optimal_Values_q_pi_over_8) - min(Optimal_Values_q0), min(Optimal_Values_q_pi_over_4_Alternate) - min(Optimal_Values_q0), min(Optimal_Values_q_3pi_over_8) - min(Optimal_Values_q0), min(Optimal_Values_q_pi_over_2_Alternate) - min(Optimal_Values_q0), min(Optimal_Values_q_5pi_over_8_Alternate) - min(Optimal_Values_q0), min(Optimal_Values_q_3pi_over_4) - min(Optimal_Values_q0), min(Optimal_Values_q_7pi_over_8_Alternate) - min(Optimal_Values_q0), min(Optimal_Values_q_pi) - min(Optimal_Values_q0)]

# %%
ED_Values_2_Delta_One_Tenth = [-19.611321 + 21.176072, -18.065746 + 21.176072, -16.875754 + 21.176072, -16.222008 + 21.176072, -16.203799 + 21.176072, -16.823716 + 21.176072, -17.987182 + 21.176072, -19.520339 + 21.176072, 0, -19.520339 + 21.176072, -17.987182 + 21.176072, -16.823716 + 21.176072, -16.203799 + 21.176072, -16.222008 + 21.176072, -16.875754 + 21.176072, -18.065746 + 21.176072, -19.611321 + 21.176072]

# %%
VQE_Values_2_Delta_One_Tenth = [min(Optimal_Values_q_pi_Alternate) - min(Optimal_Values_q0), -18.058942300-min(Optimal_Values_q0), -16.86826194-min(Optimal_Values_q0), -16.21453767-min(Optimal_Values_q0), -16.19620399-min(Optimal_Values_q0), -16.81539447-min(Optimal_Values_q0), -17.97744140-min(Optimal_Values_q0), -19.51256650-min(Optimal_Values_q0), 0, min(Optimal_Values_q_pi_over_8) - min(Optimal_Values_q0), min(Optimal_Values_q_pi_over_4) - min(Optimal_Values_q0), min(Optimal_Values_q_3pi_over_8_Alternate) - min(Optimal_Values_q0), min(Optimal_Values_q_pi_over_2) - min(Optimal_Values_q0), min(Optimal_Values_q_5pi_over_8) - min(Optimal_Values_q0), min(Optimal_Values_q_3pi_over_4_Alternate) - min(Optimal_Values_q0), min(Optimal_Values_q_7pi_over_8) - min(Optimal_Values_q0), min(Optimal_Values_q_pi_Alternate) - min(Optimal_Values_q0)]

# %%
#Nf = 8 (Δ = 0.5)

#q = 0
Energies_1_Layer_q0 = np.loadtxt(r"/mnt/c/Users/Saavanth Velury/Desktop/Quasiparticle VQE/16 Qubit Data (Final)/Delta = one-half/Nf = 8/q = 0/1 Layer/16_Qubit_XXZ_1_Layer_HVA_Optimal_Values_BOBYQA_8_Filled_States_Antiperiodic_Boundary_Conditions_Three_Parameters_Delta_0.5.txt")
Energies_2_Layer_q0 = np.loadtxt(r"/mnt/c/Users/Saavanth Velury/Desktop/Quasiparticle VQE/16 Qubit Data (Final)/Delta = one-half/Nf = 8/q = 0/2 Layers/16_Qubit_XXZ_2_Layer_HVA_Optimal_Values_BOBYQA_8_Filled_States_Antiperiodic_Boundary_Conditions_Three_Parameters_Delta_0.5.txt")
Energies_3_Layer_q0 = np.loadtxt(r"/mnt/c/Users/Saavanth Velury/Desktop/Quasiparticle VQE/16 Qubit Data (Final)/Delta = one-half/Nf = 8/q = 0/3 Layers/16_Qubit_XXZ_3_Layer_HVA_Optimal_Values_BOBYQA_8_Filled_States_Antiperiodic_Boundary_Conditions_Three_Parameters_Delta_0.5.txt")
Energies_4_Layer_q0 = np.loadtxt(r"/mnt/c/Users/Saavanth Velury/Desktop/Quasiparticle VQE/16 Qubit Data (Final)/Delta = one-half/Nf = 8/q = 0/4 Layers/16_Qubit_XXZ_4_Layer_HVA_Optimal_Values_BOBYQA_8_Filled_States_Antiperiodic_Boundary_Conditions_Three_Parameters_Delta_0.5.txt")
Energies_5_Layer_q0 = np.loadtxt(r"/mnt/c/Users/Saavanth Velury/Desktop/Quasiparticle VQE/16 Qubit Data (Final)/Delta = one-half/Nf = 8/q = 0/5 Layers/16_Qubit_XXZ_5_Layer_HVA_Optimal_Values_BOBYQA_8_Filled_States_Antiperiodic_Boundary_Conditions_Three_Parameters_Delta_0.5.txt")
Optimal_Value_1_Layer_q0 = Energies_1_Layer_q0[np.argmin(Energies_1_Layer_q0)]
Optimal_Value_2_Layer_q0 = Energies_2_Layer_q0[np.argmin(Energies_2_Layer_q0)]
Optimal_Value_3_Layer_q0 = Energies_3_Layer_q0[np.argmin(Energies_3_Layer_q0)]
Optimal_Value_4_Layer_q0 = Energies_4_Layer_q0[np.argmin(Energies_4_Layer_q0)]
Optimal_Value_5_Layer_q0 = Energies_5_Layer_q0[np.argmin(Energies_5_Layer_q0)]
Optimal_Values_q0 = [Optimal_Value_1_Layer_q0, Optimal_Value_2_Layer_q0, Optimal_Value_3_Layer_q0, Optimal_Value_4_Layer_q0, Optimal_Value_5_Layer_q0]

#q = pi/8
Energies_1_Layer_q_pi_over_8 = np.loadtxt(r"/mnt/c/Users/Saavanth Velury/Desktop/Quasiparticle VQE/16 Qubit Data (Final)/Delta = one-half/Nf = 8/q = pi over 8/1 Layer/16_Qubit_XXZ_1_Layer_HVA_Optimal_Values_BOBYQA_8_Filled_States_Antiperiodic_Boundary_Conditions_PH_State_Three_Parameters_Delta_0.5.txt")
Energies_2_Layer_q_pi_over_8 = np.loadtxt(r"/mnt/c/Users/Saavanth Velury/Desktop/Quasiparticle VQE/16 Qubit Data (Final)/Delta = one-half/Nf = 8/q = pi over 8/2 Layers/16_Qubit_XXZ_2_Layer_HVA_Optimal_Values_BOBYQA_8_Filled_States_Antiperiodic_Boundary_Conditions_PH_State_Three_Parameters_Delta_0.5.txt")
Energies_3_Layer_q_pi_over_8 = np.loadtxt(r"/mnt/c/Users/Saavanth Velury/Desktop/Quasiparticle VQE/16 Qubit Data (Final)/Delta = one-half/Nf = 8/q = pi over 8/3 Layers/16_Qubit_XXZ_3_Layer_HVA_Optimal_Values_BOBYQA_8_Filled_States_Antiperiodic_Boundary_Conditions_PH_State_Three_Parameters_Delta_0.5.txt")
Energies_4_Layer_q_pi_over_8 = np.loadtxt(r"/mnt/c/Users/Saavanth Velury/Desktop/Quasiparticle VQE/16 Qubit Data (Final)/Delta = one-half/Nf = 8/q = pi over 8/4 Layers/16_Qubit_XXZ_4_Layer_HVA_Optimal_Values_BOBYQA_8_Filled_States_Antiperiodic_Boundary_Conditions_PH_State_Three_Parameters_Delta_0.5.txt")
Energies_5_Layer_q_pi_over_8 = np.loadtxt(r"/mnt/c/Users/Saavanth Velury/Desktop/Quasiparticle VQE/16 Qubit Data (Final)/Delta = one-half/Nf = 8/q = pi over 8/5 Layers/16_Qubit_XXZ_5_Layer_HVA_Optimal_Values_BOBYQA_8_Filled_States_Antiperiodic_Boundary_Conditions_PH_State_Three_Parameters_Delta_0.5.txt")
Optimal_Value_1_Layer_q_pi_over_8 = Energies_1_Layer_q_pi_over_8[np.argmin(Energies_1_Layer_q_pi_over_8)]
Optimal_Value_2_Layer_q_pi_over_8 = Energies_2_Layer_q_pi_over_8[np.argmin(Energies_2_Layer_q_pi_over_8)]
Optimal_Value_3_Layer_q_pi_over_8 = Energies_3_Layer_q_pi_over_8[np.argmin(Energies_3_Layer_q_pi_over_8)]
Optimal_Value_4_Layer_q_pi_over_8 = Energies_4_Layer_q_pi_over_8[np.argmin(Energies_4_Layer_q_pi_over_8)]
Optimal_Value_5_Layer_q_pi_over_8 = Energies_5_Layer_q_pi_over_8[np.argmin(Energies_5_Layer_q_pi_over_8)]
Optimal_Values_q_pi_over_8 = [Optimal_Value_1_Layer_q_pi_over_8, Optimal_Value_2_Layer_q_pi_over_8, Optimal_Value_3_Layer_q_pi_over_8, Optimal_Value_4_Layer_q_pi_over_8, Optimal_Value_5_Layer_q_pi_over_8]

#q = pi/4
Energies_1_Layer_q_pi_over_4 = np.loadtxt(r"/mnt/c/Users/Saavanth Velury/Desktop/Quasiparticle VQE/16 Qubit Data (Final)/Delta = one-half/Nf = 8/q = pi over 4/1 Layer/16_Qubit_XXZ_1_Layer_HVA_Optimal_Values_BOBYQA_8_Filled_States_Antiperiodic_BC_PH_State_2_Three_Parameters_Delta_0.5.txt")
Energies_2_Layer_q_pi_over_4 = np.loadtxt(r"/mnt/c/Users/Saavanth Velury/Desktop/Quasiparticle VQE/16 Qubit Data (Final)/Delta = one-half/Nf = 8/q = pi over 4/2 Layers/16_Qubit_XXZ_2_Layer_HVA_Optimal_Values_BOBYQA_8_Filled_States_Antiperiodic_BC_PH_State_2_Three_Parameters_Delta_0.5.txt")
Energies_3_Layer_q_pi_over_4 = np.loadtxt(r"/mnt/c/Users/Saavanth Velury/Desktop/Quasiparticle VQE/16 Qubit Data (Final)/Delta = one-half/Nf = 8/q = pi over 4/3 Layers/16_Qubit_XXZ_3_Layer_HVA_Optimal_Values_BOBYQA_8_Filled_States_Antiperiodic_BC_PH_State_2_Three_Parameters_Delta_0.5.txt")
Energies_4_Layer_q_pi_over_4 = np.loadtxt(r"/mnt/c/Users/Saavanth Velury/Desktop/Quasiparticle VQE/16 Qubit Data (Final)/Delta = one-half/Nf = 8/q = pi over 4/4 Layers/16_Qubit_XXZ_4_Layer_HVA_Optimal_Values_BOBYQA_8_Filled_States_Antiperiodic_BC_PH_State_2_Three_Parameters_Delta_0.5.txt")
Energies_5_Layer_q_pi_over_4 = np.loadtxt(r"/mnt/c/Users/Saavanth Velury/Desktop/Quasiparticle VQE/16 Qubit Data (Final)/Delta = one-half/Nf = 8/q = pi over 4/5 Layers/16_Qubit_XXZ_5_Layer_HVA_Optimal_Values_BOBYQA_8_Filled_States_Antiperiodic_BC_PH_State_2_Three_Parameters_Delta_0.5.txt")
Optimal_Value_1_Layer_q_pi_over_4 = Energies_1_Layer_q_pi_over_4[np.argmin(Energies_1_Layer_q_pi_over_4)]
Optimal_Value_2_Layer_q_pi_over_4 = Energies_2_Layer_q_pi_over_4[np.argmin(Energies_2_Layer_q_pi_over_4)]
Optimal_Value_3_Layer_q_pi_over_4 = Energies_3_Layer_q_pi_over_4[np.argmin(Energies_3_Layer_q_pi_over_4)]
Optimal_Value_4_Layer_q_pi_over_4 = Energies_4_Layer_q_pi_over_4[np.argmin(Energies_4_Layer_q_pi_over_4)]
Optimal_Value_5_Layer_q_pi_over_4 = Energies_5_Layer_q_pi_over_4[np.argmin(Energies_5_Layer_q_pi_over_4)]
Optimal_Values_q_pi_over_4 = [Optimal_Value_1_Layer_q_pi_over_4, Optimal_Value_2_Layer_q_pi_over_4, Optimal_Value_3_Layer_q_pi_over_4, Optimal_Value_4_Layer_q_pi_over_4, Optimal_Value_5_Layer_q_pi_over_4]

Energies_1_Layer_q_pi_over_4_Alternate = np.loadtxt(r"/mnt/c/Users/Saavanth Velury/Desktop/Quasiparticle VQE/16 Qubit Data (Final)/Delta = one-half/Nf = 8/q = pi over 4/1 Layer/16_Qubit_XXZ_1_Layer_HVA_Optimal_Values_BOBYQA_8_Filled_States_Antiperiodic_BC_PH_State_2_Alternate_Three_Parameters_Delta_0.5.txt")
Energies_2_Layer_q_pi_over_4_Alternate = np.loadtxt(r"/mnt/c/Users/Saavanth Velury/Desktop/Quasiparticle VQE/16 Qubit Data (Final)/Delta = one-half/Nf = 8/q = pi over 4/2 Layers/16_Qubit_XXZ_2_Layer_HVA_Optimal_Values_BOBYQA_8_Filled_States_Antiperiodic_BC_PH_State_2_Alternate_Three_Parameters_Delta_0.5.txt")
Energies_3_Layer_q_pi_over_4_Alternate = np.loadtxt(r"/mnt/c/Users/Saavanth Velury/Desktop/Quasiparticle VQE/16 Qubit Data (Final)/Delta = one-half/Nf = 8/q = pi over 4/3 Layers/16_Qubit_XXZ_3_Layer_HVA_Optimal_Values_BOBYQA_8_Filled_States_Antiperiodic_BC_PH_State_2_Alternate_Three_Parameters_Delta_0.5.txt")
Energies_4_Layer_q_pi_over_4_Alternate = np.loadtxt(r"/mnt/c/Users/Saavanth Velury/Desktop/Quasiparticle VQE/16 Qubit Data (Final)/Delta = one-half/Nf = 8/q = pi over 4/4 Layers/16_Qubit_XXZ_4_Layer_HVA_Optimal_Values_BOBYQA_8_Filled_States_Antiperiodic_BC_PH_State_2_Alternate_Three_Parameters_Delta_0.5.txt")
Energies_5_Layer_q_pi_over_4_Alternate = np.loadtxt(r"/mnt/c/Users/Saavanth Velury/Desktop/Quasiparticle VQE/16 Qubit Data (Final)/Delta = one-half/Nf = 8/q = pi over 4/5 Layers/16_Qubit_XXZ_5_Layer_HVA_Optimal_Values_BOBYQA_8_Filled_States_Antiperiodic_BC_PH_State_2_Alternate_Three_Parameters_Delta_0.5.txt")
Optimal_Value_1_Layer_q_pi_over
1 Layer/16_Qubit_XXZ_1_Layer_HVA_Optimal_Values_BOBYQA_8_Filled_States_Antiperiodic_BC_PH_State_4_Alternate_Three_Parameters_Delta_0.5.txt")
Energies_2_Layer_q_pi_over_2_Alternate = np.loadtxt(r"/mnt/c/Users/Saavanth Velury/Desktop/Quasiparticle VQE/16 Qubit Data (Final)/Delta = one-half/Nf = 8/q = pi over 2/2 Layers/16_Qubit_XXZ_2_Layer_HVA_Optimal_Values_BOBYQA_8_Filled_States_Antiperiodic_BC_PH_State_4_Alternate_Three_Parameters_Delta_0.5.txt")
Energies_3_Layer_q_pi_over_2_Alternate = np.loadtxt(r"/mnt/c/Users/Saavanth Velury/Desktop/Quasiparticle VQE/16 Qubit Data (Final)/Delta = one-half/Nf = 8/q = pi over 2/3 Layers/16_Qubit_XXZ_3_Layer_HVA_Optimal_Values_BOBYQA_8_Filled_States_Antiperiodic_BC_PH_State_4_Alternate_Three_Parameters_Delta_0.5.txt")
Energies_4_Layer_q_pi_over_2_Alternate = np.loadtxt(r"/mnt/c/Users/Saavanth Velury/Desktop/Quasiparticle VQE/16 Qubit Data (Final)/Delta = one-half/Nf = 8/q = pi over 2/4 Layers/16_Qubit_XXZ_4_Layer_HVA_Optimal_Values_BOBYQA_8_Filled_States_Antiperiodic_BC_PH_State_4_Alternate_Three_Parameters_Delta_0.5.txt")
Energies_5_Layer_q_pi_over_2_Alternate = np.loadtxt(r"/mnt/c/Users/Saavanth Velury/Desktop/Quasiparticle VQE/16 Qubit Data (Final)/Delta = one-half/Nf = 8/q = pi over 2/5 Layers/16_Qubit_XXZ_5_Layer_HVA_Optimal_Values_BOBYQA_8_Filled_States_Antiperiodic_BC_PH_State_4_Alternate_Three_Parameters_Delta_0.5.txt")
Optimal_Value_1_Layer_q_pi_over_2_Alternate = Energies_1_Layer_q_pi_over_2_Alternate[np.argmin(Energies_1_Layer_q_pi_over_2_Alternate)]
Optimal_Value_2_Layer_q_pi_over_2_Alternate = Energies_2_Layer_q_pi_over_2_Alternate[np.argmin(Energies_2_Layer_q_pi_over_2_Alternate)]
Optimal_Value_3_Layer_q_pi_over_2_Alternate = Energies_3_Layer_q_pi_over_2_Alternate[np.argmin(Energies_3_Layer_q_pi_over_2_Alternate)]
Optimal_Value_4_Layer_q_pi_over_2_Alternate = Energies_4_Layer_q_pi_over_2_Alternate[np.argmin(Energies_4_Layer_q_pi_over_2_Alternate)]
Optimal_Value_5_Layer_q_pi_over_2_Alternate = Energies_5_Layer_q_pi_over_2_Alternate[np.argmin(Energies_5_Layer_q_pi_over_2_Alternate)]
Optimal_Values_q_pi_over_2_Alternate = [Optimal_Value_1_Layer_q_pi_over_2_Alternate, Optimal_Value_2_Layer_q_pi_over_2_Alternate, Optimal_Value_3_Layer_q_pi_over_2_Alternate, Optimal_Value_4_Layer_q_pi_over_2_Alternate, Optimal_Value_5_Layer_q_pi_over_2_Alternate]

#q = 5pi/8
Energies_1_Layer_q_5pi_over_8 = np.loadtxt(r"/mnt/c/Users/Saavanth Velury/Desktop/Quasiparticle VQE/16 Qubit Data (Final)/Delta = one-half/Nf = 8/q = 5pi over 8/1 Layer/16_Qubit_XXZ_1_Layer_HVA_Optimal_Values_BOBYQA_8_Filled_States_Antiperiodic_BC_PH_State_5_Three_Parameters_Delta_0.5.txt")
Energies_2_Layer_q_5pi_over_8 = np.loadtxt(r"/mnt/c/Users/Saavanth Velury/Desktop/Quasiparticle VQE/16 Qubit Data (Final)/Delta = one-half/Nf = 8/q = 5pi over 8/2 Layers/16_Qubit_XXZ_2_Layer_HVA_Optimal_Values_BOBYQA_8_Filled_States_Antiperiodic_BC_PH_State_5_Three_Parameters_Delta_0.5.txt")
Energies_3_Layer_q_5pi_over_8 = np.loadtxt(r"/mnt/c/Users/Saavanth Velury/Desktop/Quasiparticle VQE/16 Qubit Data (Final)/Delta = one-half/Nf = 8/q = 5pi over 8/3 Layers/16_Qubit_XXZ_3_Layer_HVA_Optimal_Values_BOBYQA_8_Filled_States_Antiperiodic_BC_PH_State_5_Three_Parameters_Delta_0.5.txt")
Energies_4_Layer_q_5pi_over_8 = np.loadtxt(r"/mnt/c/Users/Saavanth Velury/Desktop/Quasiparticle VQE/16 Qubit Data (Final)/Delta = one-half/Nf = 8/q = 5pi over 8/4 Layers/16_Qubit_XXZ_4_Layer_HVA_Optimal_Values_BOBYQA_8_Filled_States_Antiperiodic_BC_PH_State_5_Three_Parameters_Delta_0.5.txt")
Energies_5_Layer_q_5pi_over_8 = np.loadtxt(r"/mnt/c/Users/Saavanth Velury/Desktop/Quasiparticle VQE/16 Qubit Data (Final)/Delta = one-half/Nf = 8/q = 5pi over 8/5 Layers/16_Qubit_XXZ_5_Layer_HVA_Optimal_Values_BOBYQA_8_Filled_States_Antiperiodic_BC_PH_State_5_Three_Parameters_Delta_0.5.txt")
Optimal_Value_1_Layer_q_5pi_over_8 = Energies_1_Layer_q_5pi_over_8[np.argmin(Energies_1_Layer_q_5pi_over_8)]
Optimal_Value_2_Layer_q_5pi_over_8 = Energies_2_Layer_q_5pi_over_8[np.argmin(Energies_2_Layer_q_5pi_over_8)]
Optimal_Value_3_Layer_q_5pi_over_8 = Energies_3_Layer_q_5pi_over_8[np.argmin(Energies_3_Layer_q_5pi_over_8)]
Optimal_Value_4_Layer_q_5pi_over_8 = Energies_4_Layer_q_5pi_over_8[np.argmin(Energies_4_Layer_q_5pi_over_8)]
Optimal_Value_5_Layer_q_5pi_over_8 = Energies_5_Layer_q_5pi_over_8[np.argmin(Energies_5_Layer_q_5pi_over_8)]
Optimal_Values_q_5pi_over_8 = [Optimal_Value_1_Layer_q_5pi_over_8, Optimal_Value_2_Layer_q_5pi_over_8, Optimal_Value_3_Layer_q_5pi_over_8, Optimal_Value_4_Layer_q_5pi_over_8, Optimal_Value_5_Layer_q_5pi_over_8]

Energies_1_Layer_q_5pi_over_8_Alternate = np.loadtxt(r"/mnt/c/Users/Saavanth Velury/Desktop/Quasiparticle VQE/16 Qubit Data (Final)/Delta = one-half/Nf = 8/q = 5pi over 8/1 Layer/16_Qubit_XXZ_1_Layer_HVA_Optimal_Values_BOBYQA_8_Filled_States_Antiperiodic_BC_PH_State_5_Alternate_Three_Parameters_Delta_0.5.txt")
Energies_2_Layer_q_5pi_over_8_Alternate = np.loadtxt(r"/mnt/c/Users/Saavanth Velury/Desktop/Quasiparticle VQE/16 Qubit Data (Final)/Delta = one-half/Nf = 8/q = 5pi over 8/2 Layers/16_Qubit_XXZ_2_Layer_HVA_Optimal_Values_BOBYQA_8_Filled_States_Antiperiodic_BC_PH_State_5_Alternate_Three_Parameters_Delta_0.5.txt")
Energies_3_Layer_q_5pi_over_8_Alternate = np.loadtxt(r"/mnt/c/Users/Saavanth Velury/Desktop/Quasiparticle VQE/16 Qubit Data (Final)/Delta = one-half/Nf = 8/q = 5pi over 8/3 Layers/16_Qubit_XXZ_3_Layer_HVA_Optimal_Values_BOBYQA_8_Filled_States_Antiperiodic_BC_PH_State_5_Alternate_Three_Parameters_Delta_0.5.txt")
Energies_4_Layer_q_5pi_over_8_Alternate = np.loadtxt(r"/mnt/c/Users/Saavanth Velury/Desktop/Quasiparticle VQE/16 Qubit Data (Final)/Delta = one-half/Nf = 8/q = 5pi over 8/4 Layers/16_Qubit_XXZ_4_Layer_HVA_Optimal_Values_BOBYQA_8_Filled_States_Antiperiodic_BC_PH_State_5_Alternate_Three_Parameters_Delta_0.5.txt")
Energies_5_Layer_q_5pi_over_8_Alternate = np.loadtxt(r"/mnt/c/Users/Saavanth Velury/Desktop/Quasiparticle VQE/16 Qubit Data (Final)/Delta = one-half/Nf = 8/q = 5pi over 8/5 Layers/16_Qubit_XXZ_5_Layer_HVA_Optimal_Values_BOBYQA_8_Filled_States_Antiperiodic_BC_PH_State_5_Alternate_Three_Parameters_Delta_0.5.txt")
Optimal_Value_1_Layer_q_5pi_over_8_Alternate = Energies_1_Layer_q_5pi_over_8_Alternate[np.argmin(Energies_1_Layer_q_5pi_over_8_Alternate)]
Optimal_Value_2_Layer_q_5pi_over_8_Alternate = Energies_2_Layer_q_5pi_over_8_Alternate[np.argmin(Energies_2_Layer_q_5pi_over_8_Alternate)]
Optimal_Value_3_Layer_q_5pi_over_8_Alternate = Energies_3_Layer_q_5pi_over_8_Alternate[np.argmin(Energies_3_Layer_q_5pi_over_8_Alternate)]
Optimal_Value_4_Layer_q_5pi_over_8_Alternate = Energies_4_Layer_q_5pi_over_8_Alternate[np.argmin(Energies_4_Layer_q_5pi_over_8_Alternate)]
Optimal_Value_5_Layer_q_5pi_over_8_Alternate = Energies_5_Layer_q_5pi_over_8_Alternate[np.argmin(Energies_5_Layer_q_5pi_over_8_Alternate)]
Optimal_Values_q_5pi_over_8_Alternate = [Optimal_Value_1_Layer_q_5pi_over_8_Alternate, Optimal_Value_2_Layer_q_5pi_over_8_Alternate, Optimal_Value_3_Layer_q_5pi_over_8_Alternate, Optimal_Value_4_Layer_q_5pi_over_8_Alternate, Optimal_Value_5_Layer_q_5pi_over_8_Alternate]

#q = 3pi/4
Energies_1_Layer_q_3pi_over_4 = np.loadtxt(r"/mnt/c/Users/Saavanth Velury/Desktop/Quasiparticle VQE/16 Qubit Data (Final)/Delta = one-half/Nf = 8/q = 3pi over 4/1 Layer/16_Qubit_XXZ_1_Layer_HVA_Optimal_Values_BOBYQA_8_Filled_States_Antiperiodic_BC_PH_State_6_Three_Parameters_Delta_0.5.txt")
Energies_2_Layer_q_3pi_over_4 = np.loadtxt(r"/mnt/c/Users/Saavanth Velury/Desktop/Quasiparticle VQE/16 Qubit Data (Final)/Delta = one-half/Nf = 8/q = 3pi over 4/2 Layers/16_Qubit_XXZ_2_Layer_HVA_Optimal_Values_BOBYQA_8_Filled_States_Antiperiodic_BC_PH_State_6_Three_Parameters_Delta_0.5.txt")
Energies_3_Layer_q_3pi_over_4 = np.loadtxt(r"/mnt/c/Users/Saavanth Velury/Desktop/Quasiparticle VQE/16 Qubit Data (Final)/Delta = one-half/Nf = 8/q = 3pi over 4/3 Layers/16_Qubit_XXZ_3_Layer_HVA_Optimal_Values_BOBYQA_8_Filled_States_Antiperiodic_BC_PH_State_6_Three_Parameters_Delta_0.5.txt")
Energies_4_Layer_q_3pi_over_4 = np.loadtxt(r"/mnt/c/Users/Saavanth Velury/Desktop/Quasiparticle VQE/16 Qubit Data (Final)/Delta = one-half/Nf = 8/q = 3pi over 4/4 Layers/16_Qubit_XXZ_4_Layer_HVA_Optimal_Values_BOBYQA_8_Filled_States_Antiperiodic_BC_PH_State_6_Three_Parameters_Delta_0.5.txt")
Energies_5_Layer_q_3pi_over_4 = np.loadtxt(r"/mnt/c/Users/Saavanth Velury/Desktop/Quasiparticle VQE/16 Qubit Data (Final)/Delta = one-half/Nf = 8/q = 3pi over 4/5 Layers/16_Qubit_XXZ_5_Layer_HVA_Optimal_Values_BOBYQA_8_Filled_States_Antiperiodic_BC_PH_State_6_Three_Parameters_Delta_0.5.txt")
Optimal_Value_1_Layer_q_3pi_over_4 = Energies_1_Layer_q_3pi_over_4[np.argmin(Energies_1_Layer_q_3pi_over_4)]
Optimal_Value_2_Layer_q_3pi_over_4 = Energies_2_Layer_q_3pi_over_4[np.argmin(Energies_2_Layer_q_3pi_over_4)]
Optimal_Value_3_Layer_q_3pi_over_4 = Energies_3_Layer_q_3pi_over_4[np.argmin(Energies_3_Layer_q_3pi_over_4)]
Optimal_Value_4_Layer_q_3pi_over_4 = Energies_4_Layer_q_3pi_over_4[np.argmin(Energies_4_Layer_q_3pi_over_4)]
Optimal_Value_5_Layer_q_3pi_over_4 = Energies_5_Layer_q_3pi_over_4[np.argmin(Energies_5_Layer_q_3pi_over_4)]
Optimal_Values_q_3pi_over_4 = [Optimal_Value_1_Layer_q_3pi_over_4, Optimal_Value_2_Layer_q_3pi_over_4, Optimal_Value_3_Layer_q_3pi_over_4, Optimal_Value_4_Layer_q_3pi_over_4, Optimal_Value_5_Layer_q_3pi_over_4]

Energies_1_Layer_q_3pi_over_4_Alternate = np.loadtxt(r"/mnt/c/Users/Saavanth Velury/Desktop/Quasiparticle VQE/16 Qubit Data (Final)/Delta = one-half/Nf = 8/q = 3pi over 4/1 Layer/16_Qubit_XXZ_1_Layer_HVA_Optimal_Values_BOBYQA_8_Filled_States_Antiperiodic_BC_PH_State_6_Alternate_Three_Parameters_Delta_0.5.txt")
Energies_2_Layer_q_3pi_over_4_Alternate = np.loadtxt(r"/mnt/c/Users/Saavanth Velury/Desktop/Quasiparticle VQE/16 Qubit Data (Final)/Delta = one-half/Nf = 8/q = 3pi over 4/2 Layers/16_Qubit_XXZ_2_Layer_HVA_Optimal_Values_BOBYQA_8_Filled_States_Antiperiodic_BC_PH_State_6_Alternate_Three_Parameters_Delta_0.5.txt")
Energies_3_Layer_q_3pi_over_4_Alternate = np.loadtxt(r"/mnt/c/Users/Saavanth Velury/Desktop/Quasiparticle VQE/16 Qubit Data (Final)/Delta = one-half/Nf = 8/q = 3pi over 4/3 Layers/16_Qubit_XXZ_3_Layer_HVA_Optimal_Values_BOBYQA_8_Filled_States_Antiperiodic_BC_PH_State_6_Alternate_Three_Parameters_Delta_0.5.txt")
Energies_4_Layer_q_3pi_over_4_Alternate = np.loadtxt(r"/mnt/c/Users/Saavanth Velury/Desktop/Quasiparticle VQE/16 Qubit Data (Final)/Delta = one-half/Nf = 8/q = 3pi over 4/4 Layers/16_Qubit_XXZ_4_Layer_HVA_Optimal_Values_BOBYQA_8_Filled_States_Antiperiodic_BC_PH_State_6_Alternate_Three_Parameters_Delta_0.5.txt")
Energies_5_Layer_q_3pi_over_4_Alternate = np.loadtxt(r"/mnt/c/Users/Saavanth Velury/Desktop/Quasiparticle VQE/16 Qubit Data (Final)/Delta = one-half/Nf = 8/q = 3pi over 4/5 Layers/16_Qubit_XXZ_5_Layer_HVA_Optimal_Values_BOBYQA_8_Filled_States_Antiperiodic_BC_PH_State_6_Alternate_Three_Parameters_Delta_0.5.txt")
Optimal_Value_1_Layer_q_3pi_over_4_Alternate = Energies_1_Layer_q_3pi_over_4_Alternate[np.argmin(Energies_1_Layer_q_3pi_over_4_Alternate)]
Optimal_Value_2_Layer_q_3pi_over_4_Alternate = Energies_2_Layer_q_3pi_over_4_Alternate[np.argmin(Energies_2_Layer_q_3pi_over_4_Alternate)]
Optimal_Value_3_Layer_q_3pi_over_4_Alternate = Energies_3_Layer_q_3pi_over_4_Alternate[np.argmin(Energies_3_Layer_q_3pi_over_4_Alternate)]
Optimal_Value_4_Layer_q_3pi_over_4_Alternate = Energies_4_Layer_q_3pi_over_4_Alternate[np.argmin(Energies
Optimal_Value_5_Layer_q_pi_Alternate = Energies_5_Layer_q_pi_Alternate[np.argmin(Energies_5_Layer_q_pi_Alternate)]
Optimal_Values_q_pi_Alternate = [Optimal_Value_1_Layer_q_pi_Alternate, Optimal_Value_2_Layer_q_pi_Alternate, Optimal_Value_3_Layer_q_pi_Alternate, Optimal_Value_4_Layer_q_pi_Alternate, Optimal_Value_5_Layer_q_pi_Alternate]

# %%
ED_Values_Delta_One_Half = [-22.732966 + 24.171053, -20.906491 + 24.171053, -19.430916 + 24.171053, -18.555171 + 24.171053, -18.420713 + 24.171053, -19.053279 + 24.171053, -20.361491 + 24.171053, -22.152780 + 24.171053, 0, -22.152780 + 24.171053, -20.361491 + 24.171053, -19.053279 + 24.171053, -18.420713 + 24.171053, -18.555171 + 24.171053, -19.430916 + 24.171053, -20.906491 + 24.171053, -22.732966 + 24.171053]

# %%
VQE_Values_Delta_One_Half = [min(Optimal_Values_q_pi)-min(Optimal_Values_q0), -20.85228117-min(Optimal_Values_q0), -19.33834235-min(Optimal_Values_q0), -18.39415427-min(Optimal_Values_q0), -18.24807478-min(Optimal_Values_q0), -18.94762912-min(Optimal_Values_q0), -20.33042051-min(Optimal_Values_q0), -22.10061580-min(Optimal_Values_q0), 0, min(Optimal_Values_q_pi_over_8) - min(Optimal_Values_q0), min(Optimal_Values_q_pi_over_4_Alternate) - min(Optimal_Values_q0), min(Optimal_Values_q_3pi_over_8) - min(Optimal_Values_q0), min(Optimal_Values_q_pi_over_2_Alternate) - min(Optimal_Values_q0), min(Optimal_Values_q_5pi_over_8_Alternate) - min(Optimal_Values_q0), min(Optimal_Values_q_3pi_over_4) - min(Optimal_Values_q0), min(Optimal_Values_q_7pi_over_8_Alternate) - min(Optimal_Values_q0), min(Optimal_Values_q_pi) - min(Optimal_Values_q0)]

# %%
ED_Values_2_Delta_One_Half = [-22.567725 + 24.171053, -20.601851 + 24.171053, -19.084006 + 24.171053, -18.226470 + 24.171053, -18.154126 + 24.171053, -18.874607 + 24.171053, -20.275336 + 24.171053, -22.152780 + 24.171053, 0, -22.152780 + 24.171053, -20.275336 + 24.171053, -18.874607 + 24.171053, -18.154126 + 24.171053, -18.226470 + 24.171053, -19.084006 + 24.171053, -20.601851 + 24.171053, -22.567725 + 24.171053]

# %%
VQE_Values_2_Delta_One_Half = [min(Optimal_Values_q_pi_Alternate)-min(Optimal_Values_q0), -20.55590646-min(Optimal_Values_q0), -19.03018154-min(Optimal_Values_q0), -18.15469015-min(Optimal_Values_q0), -18.07159431-min(Optimal_Values_q0), -18.821829680-min(Optimal_Values_q0), -20.21394990-min(Optimal_Values_q0), -22.10061580-min(Optimal_Values_q0), 0, min(Optimal_Values_q_pi_over_8) - min(Optimal_Values_q0), min(Optimal_Values_q_pi_over_4) - min(Optimal_Values_q0), min(Optimal_Values_q_3pi_over_8_Alternate) - min(Optimal_Values_q0), min(Optimal_Values_q_pi_over_2) - min(Optimal_Values_q0), min(Optimal_Values_q_5pi_over_8) - min(Optimal_Values_q0), min(Optimal_Values_q_3pi_over_4_Alternate) - min(Optimal_Values_q0), min(Optimal_Values_q_7pi_over_8) - min(Optimal_Values_q0), min(Optimal_Values_q_pi_Alternate) - min(Optimal_Values_q0)]

# %%
#Nf = 8 (Δ = 0.9)

#q = 0
Energies_8_Layer_q0 = np.loadtxt(r'/mnt/c/Users/Saavanth Velury/Desktop/Quasiparticle VQE/16 Qubit Data (Final)/Delta = nine-tenths/Nf = 8/q = 0/8 Layers/16_Qubit_XXZ_8_Layer_HVA_Optimal_Values_BOBYQA_8_Filled_States_Antiperiodic_Boundary_Conditions_Three_Parameters_Delta_0.9.txt')
Optimal_Values_8_Layer_q0 = min(Energies_8_Layer_q0)

#q = pi/8
Energies_8_Layer_q_pi_over_8 = np.loadtxt(r'/mnt/c/Users/Saavanth Velury/Desktop/Quasiparticle VQE/16 Qubit Data (Final)/Delta = nine-tenths/Nf = 8/q = pi over 8/8 Layers/16_Qubit_XXZ_8_Layer_HVA_Optimal_Values_BOBYQA_8_Filled_States_Antiperiodic_BC_PH_State_Three_Parameters_Delta_0.9.txt')
Optimal_Values_8_Layer_q_pi_over_8 = min(Energies_8_Layer_q_pi_over_8)

#q = pi/4
Energies_8_Layer_q_pi_over_4 = np.loadtxt(r'/mnt/c/Users/Saavanth Velury/Desktop/Quasiparticle VQE/16 Qubit Data (Final)/Delta = nine-tenths/Nf = 8/q = pi over 4/8 Layers/16_Qubit_XXZ_8_Layer_HVA_Optimal_Values_BOBYQA_8_Filled_States_Antiperiodic_BC_PH_State_2_Alternate_Three_Parameters_Delta_0.9.txt')
Optimal_Values_8_Layer_q_pi_over_4 = min(Energies_8_Layer_q_pi_over_4)

#q = 3pi/8
Energies_8_Layer_q_3pi_over_8 = np.loadtxt(r'/mnt/c/Users/Saavanth Velury/Desktop/Quasiparticle VQE/16 Qubit Data (Final)/Delta = nine-tenths/Nf = 8/q = 3pi over 8/8 Layers/16_Qubit_XXZ_8_Layer_HVA_Optimal_Values_BOBYQA_8_Filled_States_Antiperiodic_BC_PH_State_3_Three_Parameters_Delta_0.9.txt')
Optimal_Values_8_Layer_q_3pi_over_8 = min(Energies_8_Layer_q_3pi_over_8)

#q = pi/2
Energies_8_Layer_q_pi_over_2 = np.loadtxt(r'/mnt/c/Users/Saavanth Velury/Desktop/Quasiparticle VQE/16 Qubit Data (Final)/Delta = nine-tenths/Nf = 8/q = pi over 2/8 Layers/16_Qubit_XXZ_8_Layer_HVA_Optimal_Values_BOBYQA_8_Filled_States_Antiperiodic_BC_PH_State_4_Alternate_Three_Parameters_Delta_0.9.txt')
Optimal_Values_8_Layer_q_pi_over_2 = min(Energies_8_Layer_q_pi_over_2)

#q = 5pi/8
Energies_8_Layer_q_5pi_over_8 = np.loadtxt(r'/mnt/c/Users/Saavanth Velury/Desktop/Quasiparticle VQE/16 Qubit Data (Final)/Delta = nine-tenths/Nf = 8/q = 5pi over 8/8 Layers/16_Qubit_XXZ_8_Layer_HVA_Optimal_Values_BOBYQA_8_Filled_States_Antiperiodic_BC_PH_State_5_Alternate_Three_Parameters_Delta_0.9.txt')
Optimal_Values_8_Layer_q_5pi_over_8 = min(Energies_8_Layer_q_5pi_over_8)

#q = 3pi/4
Energies_8_Layer_q_3pi_over_4 = np.loadtxt(r'/mnt/c/Users/Saavanth Velury/Desktop/Quasiparticle VQE/16 Qubit Data (Final)/Delta = nine-tenths/Nf = 8/q = 3pi over 4/8 Layers/16_Qubit_XXZ_8_Layer_HVA_Optimal_Values_BOBYQA_8_Filled_States_Antiperiodic_BC_PH_State_6_Three_Parameters_Delta_0.9.txt')
Optimal_Values_8_Layer_q_3pi_over_4 = min(Energies_8_Layer_q_3pi_over_4)

#q = 7pi/8
Energies_8_Layer_q_7pi_over_8 = np.loadtxt(r'/mnt/c/Users/Saavanth Velury/Desktop/Quasiparticle VQE/16 Qubit Data (Final)/Delta = nine-tenths/Nf = 8/q = 7pi over 8/8 Layers/16_Qubit_XXZ_8_Layer_HVA_Optimal_Values_BOBYQA_8_Filled_States_Antiperiodic_BC_PH_State_7_Alternate_Three_Parameters_Delta_0.9.txt')
Optimal_Values_8_Layer_q_7pi_over_8 = min(Energies_8_Layer_q_7pi_over_8)

#q = pi
Energies_8_Layer_q_pi = np.loadtxt(r'/mnt/c/Users/Saavanth Velury/Desktop/Quasiparticle VQE/16 Qubit Data (Final)/Delta = nine-tenths/Nf = 8/q = pi/8 Layers/16_Qubit_XXZ_8_Layer_HVA_Optimal_Values_BOBYQA_8_Filled_States_Antiperiodic_BC_PH_State_8_Three_Parameters_Delta_0.9.txt')
Optimal_Values_8_Layer_q_pi = min(Energies_8_Layer_q_pi)

# %%
ED_Values_Delta_Nine_Tenths = [-26.464116 + 27.631604, -24.284279 + 27.631604, -22.470367 + 27.631604, -21.341125 + 27.631604, -21.077652 + 27.631604, -21.725115 + 27.631604, -23.189256 + 27.631604, -25.252845 + 27.631604, 0, -25.252845 + 27.631604, -23.189256 + 27.631604, -21.725115 + 27.631604, -21.077652 + 27.631604, -21.341125 + 27.631604, -22.470367 + 27.631604, -24.284279 + 27.631604, -26.464116 + 27.631604]

# %%
VQE_Values_Delta_Nine_Tenths = [-26.35992782 - Optimal_Values_8_Layer_q0, -24.17374630 - Optimal_Values_8_Layer_q0, -22.29082085 - Optimal_Values_8_Layer_q0, -21.08158050 - Optimal_Values_8_Layer_q0, -20.71863449 - Optimal_Values_8_Layer_q0, -21.50620840 - Optimal_Values_8_Layer_q0, -23.12119688 - Optimal_Values_8_Layer_q0, -25.20907257 - Optimal_Values_8_Layer_q0, 0, Optimal_Values_8_Layer_q_pi_over_8 - Optimal_Values_8_Layer_q0, Optimal_Values_8_Layer_q_pi_over_4 - Optimal_Values_8_Layer_q0, Optimal_Values_8_Layer_q_3pi_over_8 - Optimal_Values_8_Layer_q0, Optimal_Values_8_Layer_q_pi_over_2 - Optimal_Values_8_Layer_q0, Optimal_Values_8_Layer_q_5pi_over_8 - Optimal_Values_8_Layer_q0, Optimal_Values_8_Layer_q_3pi_over_4 - Optimal_Values_8_Layer_q0, Optimal_Values_8_Layer_q_7pi_over_8 - Optimal_Values_8_Layer_q0, Optimal_Values_8_Layer_q_pi - Optimal_Values_8_Layer_q0]

# %%
# Momentum points
q = np.array([-np.pi, -7*np.pi/8, -3*np.pi/4, -5*np.pi/8, -np.pi/2, -3*np.pi/8, -np.pi/4, -np.pi/8, 0, np.pi/8, np.pi/4, 3*np.pi/8, np.pi/2, 5*np.pi/8, 3*np.pi/4, 7*np.pi/8, np.pi])

# Ground‐state energies
E0_ED_0p1  = -21.176072
E0_VQE_0p1 = -21.171132
E0_ED_0p5  = -24.171053
E0_VQE_0p5 = -24.136340
E0_ED_0p9 = -27.631604
E0_VQE_0p9 = -27.577134

# Dispersion *relative* to the ground state (so first entry is 0 offset)
disp_ED_0p1  = np.array(ED_Values_Delta_One_Tenth)
disp_VQE_0p1 = np.array(VQE_Values_Delta_One_Tenth)
disp_ED_0p5  = np.array(ED_Values_Delta_One_Half)
disp_VQE_0p5 = np.array(VQE_Values_Delta_One_Half)
disp_ED_0p9 = np.array(ED_Values_Delta_Nine_Tenths)
disp_VQE_0p9 = np.array(VQE_Values_Delta_Nine_Tenths)

# Build *actual* energy arrays by adding back the ground‐state
E_ED_0p1   = E0_ED_0p1  + disp_ED_0p1
E_VQE_0p1  = E0_VQE_0p1 + disp_VQE_0p1
E_ED_0p5   = E0_ED_0p5  + disp_ED_0p5
E_VQE_0p5  = E0_VQE_0p5 + disp_VQE_0p5
E_ED_0p9   = E0_ED_0p9  + disp_ED_0p9
E_VQE_0p9  = E0_VQE_0p9 + disp_VQE_0p9

# --- Plotting ---
fig, ax = plt.subplots(figsize=(12,12))

c_ED_0p1   = "#0000FF"   
c_VQE_0p1  = "#FF0000"   
c_ED_0p5   = "#00CC00"   
c_VQE_0p5  = "#800080"
c_ED_0p9   = "#FFA500"
c_VQE_0p9  = "#00FFFF"

bg = ax.patch.get_facecolor()

major_q = np.array([-np.pi, -3*np.pi/4, -np.pi/2, -np.pi/4, 0, np.pi/4,  np.pi/2,  3*np.pi/4,  np.pi])
# ED (filled markers)
ax.plot(q, E_ED_0p1, linestyle='-', linewidth=4, color=c_ED_0p1, alpha=0.25, zorder=1)
ax.scatter(q, E_ED_0p1, s=15**2, facecolor=c_ED_0p1, edgecolor=c_ED_0p1, linewidth=1, alpha=1, zorder=4, label=r'ED, $\Delta=0.1$')
ax.plot(q, E_ED_0p5, linestyle='-', linewidth=4, color=c_ED_0p5, alpha=0.25, zorder=1)
ax.scatter(q, E_ED_0p5, s=15**2, facecolor=c_ED_0p5, edgecolor=c_ED_0p5, linewidth=1, alpha=1, zorder=4, label=r'ED, $\Delta=0.5$')
ax.plot(q, E_ED_0p9, linestyle='-', linewidth=4, color=c_ED_0p9, alpha=0.25, zorder=1)
ax.scatter(q, E_ED_0p9, s=15**2, facecolor=c_ED_0p9, edgecolor=c_ED_0p9, linewidth=1, alpha=1, zorder=4, label=r'ED, $\Delta=0.9$')

# VQE (open markers)
ax.scatter(q, E_VQE_0p1, s=30**2, facecolor=bg, edgecolor='none', zorder=2)
ax.scatter(q, E_VQE_0p1, s=30**2, facecolor='none', edgecolor=c_VQE_0p1, linewidth=2, zorder=3, label=r'VQE, $\Delta=0.1$')
ax.scatter(q, E_VQE_0p5, s=30**2, facecolor=bg, edgecolor='none', zorder=2)
ax.scatter(q, E_VQE_0p5, s=30**2, facecolor='none', edgecolor=c_VQE_0p5, linewidth=2, zorder=3, label=r'VQE, $\Delta=0.5$')
ax.scatter(q, E_VQE_0p9, s=30**2, facecolor=bg, edgecolor='none', zorder=2)
ax.scatter(q, E_VQE_0p9, s=30**2, facecolor='none', edgecolor=c_VQE_0p9, linewidth=2, zorder=3, label=r'VQE, $\Delta=0.9$')

# Axis formatting
ax.set_xlabel(r'$q$', fontsize=30, fontweight='bold')
ax.set_ylabel(r'$E(q)$', fontsize=30, fontweight='bold')       
ax.set_xticks(major_q)
ax.set_xticklabels([r'$-\pi$', r'$-\tfrac{3\pi}{4}$', r'$-\tfrac{\pi}{2}$', r'$-\tfrac{\pi}{4}$', r'$0$', r'$\tfrac{\pi}{4}$', r'$\tfrac{\pi}{2}$', r'$\tfrac{3\pi}{4}$', r'$\pi$'], fontsize=30, fontweight='bold')
ax.set_yticklabels(ax.get_yticks(), fontsize=30, fontweight='bold')

# Inset textbox
text_props = dict(boxstyle='round', facecolor='white', alpha=0.8, pad=0.3)
ax.text(0.65, 0.975,
        r'$N_{F}=8\;(S_{z}=0)$',
        transform=ax.transAxes,
        ha='right', va='top',
        fontsize=30,
        fontweight='bold',
        bbox=text_props)

#leg = ax.legend(loc='best', frameon=True, framealpha=1, fancybox = True)
#leg.set_bbox_to_anchor((0.9, 0.5))
#for text in leg.get_texts():
    #text.set_fontweight('bold')
    #text.set_fontsize(30)

#frame = leg.get_frame()
#frame.set_edgecolor('black')
#frame.set_linewidth(1.2) 
#frame.set_facecolor('white')

plt.tight_layout()
#plt.savefig('XXZ_Dispersion_16_Qubit.pdf', dpi=300, bbox_inches='tight')
plt.show()
# Out:
# /tmp/ipykernel_6953/3566406704.py:62: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_yticklabels(ax.get_yticks(), fontsize=30, fontweight='bold')

# %%
#Save Arrays
np.savetxt('ED_Values_8_Filled_States_Delta_Nine_Tenths_16_Qubit.txt', ED_Values_Delta_One_Tenth)
np.savetxt('VQE_Values_8_Filled_States_Delta_Nine_Tenths_16_Qubit.txt', VQE_Values_Delta_One_Tenth)
