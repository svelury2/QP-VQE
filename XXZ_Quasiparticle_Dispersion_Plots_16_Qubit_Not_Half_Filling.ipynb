# %%
import numpy as np
from matplotlib import pyplot as plt
import matplotlib as mpl
plt.rcParams.update({
    "text.usetex": True,
    "text.latex.preamble": r"\usepackage{amsmath}",
    "font.family": "serif",
    "font.serif": ["Computer Modern"],
    "pdf.fonttype": 42,
    "ps.fonttype": 42,
    "font.size": 14,
    'font.weight': 'bold',
    'axes.titleweight': 'bold',
    'axes.labelweight': 'bold'
})
import os
import warnings
with warnings.catch_warnings():
    warnings.simplefilter('ignore', category=UserWarning)

# %%
print("Exists?", os.path.exists(r"/mnt/c/Users/Saavanth Velury/Desktop/Quasiparticle VQE/16 Qubit Data (Final)/Delta = one-tenth/Nf = 7/q = pi/1 Layer/16_Qubit_XXZ_1_Layer_HVA_Optimal_Values_BOBYQA_7_Filled_States_Periodic_Boundary_Conditions.txt"))
print("Is file?", os.path.isfile(r"/mnt/c/Users/Saavanth Velury/Desktop/Quasiparticle VQE/16 Qubit Data (Final)/Delta = one-tenth/Nf = 7/q = pi/1 Layer/16_Qubit_XXZ_1_Layer_HVA_Optimal_Values_BOBYQA_7_Filled_States_Periodic_Boundary_Conditions.txt"))

# %%
#Nf = 7 (Δ = 0.1)

#q = 0
Energies_1_Layer_q0 = np.loadtxt(r"/mnt/c/Users/Saavanth Velury/Desktop/Quasiparticle VQE/16 Qubit Data (Final)/Delta = one-tenth/Nf = 7/q = 0/1 Layer/16_Qubit_XXZ_1_Layer_HVA_Optimal_Values_BOBYQA_7_Filled_States_Periodic_Boundary_Conditions_PH_State_8.txt")
Energies_2_Layer_q0 = np.loadtxt(r"/mnt/c/Users/Saavanth Velury/Desktop/Quasiparticle VQE/16 Qubit Data (Final)/Delta = one-tenth/Nf = 7/q = 0/2 Layers/16_Qubit_XXZ_2_Layer_HVA_Optimal_Values_BOBYQA_7_Filled_States_Periodic_Boundary_Conditions_PH_State_8.txt")
Energies_3_Layer_q0 = np.loadtxt(r"/mnt/c/Users/Saavanth Velury/Desktop/Quasiparticle VQE/16 Qubit Data (Final)/Delta = one-tenth/Nf = 7/q = 0/3 Layers/16_Qubit_XXZ_3_Layer_HVA_Optimal_Values_BOBYQA_7_Filled_States_Periodic_Boundary_Conditions_PH_State_8.txt")
Energies_4_Layer_q0 = np.loadtxt(r"/mnt/c/Users/Saavanth Velury/Desktop/Quasiparticle VQE/16 Qubit Data (Final)/Delta = one-tenth/Nf = 7/q = 0/4 Layers/16_Qubit_XXZ_4_Layer_HVA_Optimal_Values_BOBYQA_7_Filled_States_Periodic_Boundary_Conditions_PH_State_8.txt")
Energies_5_Layer_q0 = np.loadtxt(r"/mnt/c/Users/Saavanth Velury/Desktop/Quasiparticle VQE/16 Qubit Data (Final)/Delta = one-tenth/Nf = 7/q = 0/5 Layers/16_Qubit_XXZ_5_Layer_HVA_Optimal_Values_BOBYQA_7_Filled_States_Periodic_Boundary_Conditions_PH_State_8.txt")
Optimal_Value_1_Layer_q0 = Energies_1_Layer_q0[np.argmin(Energies_1_Layer_q0)]
Optimal_Value_2_Layer_q0 = Energies_2_Layer_q0[np.argmin(Energies_2_Layer_q0)]
Optimal_Value_3_Layer_q0 = Energies_3_Layer_q0[np.argmin(Energies_3_Layer_q0)]
Optimal_Value_4_Layer_q0 = Energies_4_Layer_q0[np.argmin(Energies_4_Layer_q0)]
Optimal_Value_5_Layer_q0 = Energies_5_Layer_q0[np.argmin(Energies_5_Layer_q0)]
Optimal_Values_q0 = [Optimal_Value_1_Layer_q0, Optimal_Value_2_Layer_q0, Optimal_Value_3_Layer_q0, Optimal_Value_4_Layer_q0, Optimal_Value_5_Layer_q0]

Energies_1_Layer_q0_Alternate = np.loadtxt(r"/mnt/c/Users/Saavanth Velury/Desktop/Quasiparticle VQE/16 Qubit Data (Final)/Delta = one-tenth/Nf = 7/q = 0/1 Layer/16_Qubit_XXZ_1_Layer_HVA_Optimal_Values_BOBYQA_7_Filled_States_Periodic_Boundary_Conditions_PH_State_8_Alternate.txt")
Energies_2_Layer_q0_Alternate = np.loadtxt(r"/mnt/c/Users/Saavanth Velury/Desktop/Quasiparticle VQE/16 Qubit Data (Final)/Delta = one-tenth/Nf = 7/q = 0/2 Layers/16_Qubit_XXZ_2_Layer_HVA_Optimal_Values_BOBYQA_7_Filled_States_Periodic_Boundary_Conditions_PH_State_8_Alternate.txt")
Energies_3_Layer_q0_Alternate = np.loadtxt(r"/mnt/c/Users/Saavanth Velury/Desktop/Quasiparticle VQE/16 Qubit Data (Final)/Delta = one-tenth/Nf = 7/q = 0/3 Layers/16_Qubit_XXZ_3_Layer_HVA_Optimal_Values_BOBYQA_7_Filled_States_Periodic_Boundary_Conditions_PH_State_8_Alternate.txt")
Energies_4_Layer_q0_Alternate = np.loadtxt(r"/mnt/c/Users/Saavanth Velury/Desktop/Quasiparticle VQE/16 Qubit Data (Final)/Delta = one-tenth/Nf = 7/q = 0/4 Layers/16_Qubit_XXZ_4_Layer_HVA_Optimal_Values_BOBYQA_7_Filled_States_Periodic_Boundary_Conditions_PH_State_8_Alternate.txt")
Energies_5_Layer_q0_Alternate = np.loadtxt(r"/mnt/c/Users/Saavanth Velury/Desktop/Quasiparticle VQE/16 Qubit Data (Final)/Delta = one-tenth/Nf = 7/q = 0/5 Layers/16_Qubit_XXZ_5_Layer_HVA_Optimal_Values_BOBYQA_7_Filled_States_Periodic_Boundary_Conditions_PH_State_8_Alternate.txt")
Optimal_Value_1_Layer_q0_Alternate = Energies_1_Layer_q0_Alternate[np.argmin(Energies_1_Layer_q0_Alternate)]
Optimal_Value_2_Layer_q0_Alternate = Energies_2_Layer_q0_Alternate[np.argmin(Energies_2_Layer_q0_Alternate)]
Optimal_Value_3_Layer_q0_Alternate = Energies_3_Layer_q0_Alternate[np.argmin(Energies_3_Layer_q0_Alternate)]
Optimal_Value_4_Layer_q0_Alternate = Energies_4_Layer_q0_Alternate[np.argmin(Energies_4_Layer_q0_Alternate)]
Optimal_Value_5_Layer_q0_Alternate = Energies_5_Layer_q0_Alternate[np.argmin(Energies_5_Layer_q0_Alternate)]
Optimal_Values_q0_Alternate = [Optimal_Value_1_Layer_q0_Alternate, Optimal_Value_2_Layer_q0_Alternate, Optimal_Value_3_Layer_q0_Alternate, Optimal_Value_4_Layer_q0_Alternate, Optimal_Value_5_Layer_q0_Alternate]

#q = pi/8
Energies_1_Layer_q_pi_over_8 = np.loadtxt(r"/mnt/c/Users/Saavanth Velury/Desktop/Quasiparticle VQE/16 Qubit Data (Final)/Delta = one-tenth/Nf = 7/q = pi over 8/1 Layer/16_Qubit_XXZ_1_Layer_HVA_Optimal_Values_BOBYQA_7_Filled_States_Periodic_Boundary_Conditions_PH_State.txt")
Energies_2_Layer_q_pi_over_8 = np.loadtxt(r"/mnt/c/Users/Saavanth Velury/Desktop/Quasiparticle VQE/16 Qubit Data (Final)/Delta = one-tenth/Nf = 7/q = pi over 8/2 Layers/16_Qubit_XXZ_2_Layer_HVA_Optimal_Values_BOBYQA_7_Filled_States_Periodic_Boundary_Conditions_PH_State.txt")
Energies_3_Layer_q_pi_over_8 = np.loadtxt(r"/mnt/c/Users/Saavanth Velury/Desktop/Quasiparticle VQE/16 Qubit Data (Final)/Delta = one-tenth/Nf = 7/q = pi over 8/3 Layers/16_Qubit_XXZ_3_Layer_HVA_Optimal_Values_BOBYQA_7_Filled_States_Periodic_Boundary_Conditions_PH_State.txt")
Energies_4_Layer_q_pi_over_8 = np.loadtxt(r"/mnt/c/Users/Saavanth Velury/Desktop/Quasiparticle VQE/16 Qubit Data (Final)/Delta = one-tenth/Nf = 7/q = pi over 8/4 Layers/16_Qubit_XXZ_4_Layer_HVA_Optimal_Values_BOBYQA_7_Filled_States_Periodic_Boundary_Conditions_PH_State.txt")
Energies_5_Layer_q_pi_over_8 = np.loadtxt(r"/mnt/c/Users/Saavanth Velury/Desktop/Quasiparticle VQE/16 Qubit Data (Final)/Delta = one-tenth/Nf = 7/q = pi over 8/5 Layers/16_Qubit_XXZ_5_Layer_HVA_Optimal_Values_BOBYQA_7_Filled_States_Periodic_Boundary_Conditions_PH_State.txt")
Optimal_Value_1_Layer_q_pi_over_8 = Energies_1_Layer_q_pi_over_8[np.argmin(Energies_1_Layer_q_pi_over_8)]
Optimal_Value_2_Layer_q_pi_over_8 = Energies_2_Layer_q_pi_over_8[np.argmin(Energies_2_Layer_q_pi_over_8)]
Optimal_Value_3_Layer_q_pi_over_8 = Energies_3_Layer_q_pi_over_8[np.argmin(Energies_3_Layer_q_pi_over_8)]
Optimal_Value_4_Layer_q_pi_over_8 = Energies_4_Layer_q_pi_over_8[np.argmin(Energies_4_Layer_q_pi_over_8)]
Optimal_Value_5_Layer_q_pi_over_8 = Energies_5_Layer_q_pi_over_8[np.argmin(Energies_5_Layer_q_pi_over_8)]
Optimal_Values_q_pi_over_8 = [Optimal_Value_1_Layer_q_pi_over_8, Optimal_Value_2_Layer_q_pi_over_8, Optimal_Value_3_Layer_q_pi_over_8, Optimal_Value_4_Layer_q_pi_over_8, Optimal_Value_5_Layer_q_pi_over_8]

#q = pi/4
Energies_1_Layer_q_pi_over_4 = np.loadtxt(r"/mnt/c/Users/Saavanth Velury/Desktop/Quasiparticle VQE/16 Qubit Data (Final)/Delta = one-tenth/Nf = 7/q = pi over 4/1 Layer/16_Qubit_XXZ_1_Layer_HVA_Optimal_Values_BOBYQA_7_Filled_States_Periodic_Boundary_Conditions_PH_State_2.txt")
Energies_2_Layer_q_pi_over_4 = np.loadtxt(r"/mnt/c/Users/Saavanth Velury/Desktop/Quasiparticle VQE/16 Qubit Data (Final)/Delta = one-tenth/Nf = 7/q = pi over 4/2 Layers/16_Qubit_XXZ_2_Layer_HVA_Optimal_Values_BOBYQA_7_Filled_States_Periodic_Boundary_Conditions_PH_State_2.txt")
Energies_3_Layer_q_pi_over_4 = np.loadtxt(r"/mnt/c/Users/Saavanth Velury/Desktop/Quasiparticle VQE/16 Qubit Data (Final)/Delta = one-tenth/Nf = 7/q = pi over 4/3 Layers/16_Qubit_XXZ_3_Layer_HVA_Optimal_Values_BOBYQA_7_Filled_States_Periodic_Boundary_Conditions_PH_State_2.txt")
Energies_4_Layer_q_pi_over_4 = np.loadtxt(r"/mnt/c/Users/Saavanth Velury/Desktop/Quasiparticle VQE/16 Qubit Data (Final)/Delta = one-tenth/Nf = 7/q = pi over 4/4 Layers/16_Qubit_XXZ_4_Layer_HVA_Optimal_Values_BOBYQA_7_Filled_States_Periodic_Boundary_Conditions_PH_State_2.txt")
Energies_5_Layer_q_pi_over_4 = np.loadtxt(r"/mnt/c/Users/Saavanth Velury/Desktop/Quasiparticle VQE/16 Qubit Data (Final)/Delta = one-tenth/Nf = 7/q = pi over 4/5 Layers/16_Qubit_XXZ_5_Layer_HVA_Optimal_Values_BOBYQA_7_Filled_States_Periodic_Boundary_Conditions_PH_State_2.txt")
Optimal_Value_1_Layer_q_pi_over_4 = Energies_1_Layer_q_pi_over_4[np.argmin(Energies_1_Layer_q_pi_over_4)]
Optimal_Value_2_Layer_q_pi_over_4 = Energies_2_Layer_q_pi_over_4[np.argmin(Energies_2_Layer_q_pi_over_4)]
Optimal_Value_3_Layer_q_pi_over_4 = Energies_3_Layer_q_pi_over_4[np.argmin(Energies_3_Layer_q_pi_over_4)]
Optimal_Value_4_Layer_q_pi_over_4 = Energies_4_Layer_q_pi_over_4[np.argmin(Energies_4_Layer_q_pi_over_4)]
Optimal_Value_5_Layer_q_pi_over_4 = Energies_5_Layer_q_pi_over_4[np.argmin(Energies_5_Layer_q_pi_over_4)]
Optimal_Values_q_pi_over_4 = [Optimal_Value_1_Layer_q_pi_over_4, Optimal_Value_2_Layer_q_pi_over_4, Optimal_Value_3_Layer_q_pi_over_4, Optimal_Value_4_Layer_q_pi_over_4, Optimal_Value_5_Layer_q_pi_over_4]

#q = 3pi/8
Energies_1_Layer_q_3pi_over_8 = np.loadtxt(r"/mnt/c/Users/Saavanth Velury/Desktop/Quasiparticle VQE/16 Qubit Data (Final)/Delta = one-tenth/Nf = 7/q = 3pi over 8/1 Layer/16_Qubit_XXZ_1_Layer_HVA_Optimal_Values_BOBYQA_7_Filled_States_Periodic_Boundary_Conditions_PH_State_3.txt")
Energies_2_Layer_q_3pi_over_8 = np.loadtxt(r"/mnt/c/Users/Saavanth Velury/Desktop/Quasiparticle VQE/16 Qubit Data (Final)/Delta = one-tenth/Nf = 7/q = 3pi over 8/2 Layers/16_Qubit_XXZ_2_Layer_HVA_Optimal_Values_BOBYQA_7_Filled_States_Periodic_Boundary_Conditions_PH_State_3.txt")
Energies_3_Layer_q_3pi_over_8 = np.loadtxt(r"/mnt/c/Users/Saavanth Velury/Desktop/Quasiparticle VQE/16 Qubit Data (Final)/Delta = one-tenth/Nf = 7/q = 3pi over 8/3 Layers/16_Qubit_XXZ_3_Layer_HVA_Optimal_Values_BOBYQA_7_Filled_States_Periodic_Boundary_Conditions_PH_State_3.txt")
Energies_4_Layer_q_3pi_over_8 = np.loadtxt(r"/mnt/c/Users/Saavanth Velury/Desktop/Quasiparticle VQE/16 Qubit Data (Final)/Delta = one-tenth/Nf = 7/q = 3pi over 8/4 Layers/16_Qubit_XXZ_4_Layer_HVA_Optimal_Values_BOBYQA_7_Filled_States_Periodic_Boundary_Conditions_PH_State_3.txt")
Energies_5_Layer_q_3pi_over_8 = np.loadtxt(r"/mnt/c/Users/Saavanth Velury/Desktop/Quasiparticle VQE/16 Qubit Data (Final)/Delta = one-tenth/Nf = 7/q = 3pi over 8/5 Layers/16_Qubit_XXZ_5_Layer_HVA_Optimal_Values_BOBYQA_7_Filled_States_Periodic_Boundary_Conditions_PH_State_3.txt")
Optimal_Value_1_Layer_q_3pi_over_8 = Energies_1_Layer_q_3pi_over_8[np.argmin(Energies_1_Layer_q_3pi_over_8)]
Optimal_Value_2_Layer_q_3pi_over_8 = Energies_2_Layer_q_3pi_over_8[np.argmin(Energies_2_Layer_q_3pi_over_8)]
Optimal_Value_3_Layer_q_3pi_over_8 = Energies_3_Layer_q_3pi_over_8[np.argmin(Energies_3_Layer_q_3pi_over_8)]
Optimal_Value_4_Layer_q_3pi_over_8 = Energies_4_Layer_q_3pi_over_8[np.argmin(Energies_4_Layer_q_3pi_over_8)]
Optimal_Value_5_Layer_q_3pi_over_8 = Energies_5_Layer_q_3pi_over_8[np.argmin(Energies_5_Layer_q_3pi_over_8)]
Optimal_Values_q_3pi_over_8 = [Optimal_Value_1_Layer_q_3pi_over_8, Optimal_Value_2_Layer_q_3pi_over_8, Optimal_Value_3_Layer_q_3pi_over_8, Optimal_Value_4_Layer_q_3pi_over_8, Optimal_Value_5_Layer_q_3pi_over_8]

#q = pi/2
Energies_1_Layer_q_pi_over_2 = np.loadtxt(r"/mnt/c/Users/Saavanth Velury/Desktop/Quasiparticle VQE/16 Qubit Data (Final)/Delta = one-tenth/Nf = 7/q = pi over 2/1 Layer/16_Qubit_XXZ_1_Layer_HVA_Optimal_Values_BOBYQA_7_Filled_States_Periodic_Boundary_Conditions_PH_State_4.txt")
Energies_2_Layer_q_pi_over_2 = np.loadtxt(r"/mnt/c/Users/Saavanth Velury/Desktop/Quasiparticle VQE/16 Qubit Data (Final)/Delta = one-tenth/Nf = 7/q = pi over 2/2 Layers/16_Qubit_XXZ_2_Layer_HVA_Optimal_Values_BOBYQA_7_Filled_States_Periodic_Boundary_Conditions_PH_State_4.txt")
Energies_3_Layer_q_pi_over_2 = np.loadtxt(r"/mnt/c/Users/Saavanth Velury/Desktop/Quasiparticle VQE/16 Qubit Data (Final)/Delta = one-tenth/Nf = 7/q = pi over 2/3 Layers/16_Qubit_XXZ_3_Layer_HVA_Optimal_Values_BOBYQA_7_Filled_States_Periodic_Boundary_Conditions_PH_State_4.txt")
Energies_4_Layer_q_pi_over_2 = np.loadtxt(r"/mnt/c/Users/Saavanth Velury/Desktop/Quasiparticle VQE/16 Qubit Data (Final)/Delta = one-tenth/Nf = 7/q = pi over 2/4 Layers/16_Qubit_XXZ_4_Layer_HVA_Optimal_Values_BOBYQA_7_Filled_States_Periodic_Boundary_Conditions_PH_State_4.txt")
Energies_5_Layer_q_pi_over_2 = np.loadtxt(r"/mnt/c/Users/Saavanth Velury/Desktop/Quasiparticle VQE/16 Qubit Data (Final)/Delta = one-tenth/Nf = 7/q = pi over 2/5 Layers/16_Qubit_XXZ_5_Layer_HVA_Optimal_Values_BOBYQA_7_Filled_States_Periodic_Boundary_Conditions_PH_State_4.txt")
Optimal_Value_1_Layer_q_pi_over_2 = Energies_1_Layer_q_pi_over_2[np.argmin(Energies_1_Layer_q_pi_over_2)]
Optimal_Value_2_Layer_q_pi_over_2 = Energies_2_Layer_q_pi_over_2[np.argmin(Energies_2_Layer_q_pi_over_2)]
Optimal_Value_3_Layer_q_pi_over_2 = Energies_3_Layer_q_pi_over_2[np.argmin(Energies_3_Layer_q_pi_over_2)]
Optimal_Value_4_Layer_q_pi_over_2 = Energies_4_Layer_q_pi_over_2[np.argmin(Energies_4_Layer_q_pi_over_2)]
Optimal_Value_5_Layer_q_pi_over_2 = Energies_5_Layer_q_pi_over_2[np.argmin(Energies_5_Layer_q_pi_over_2)]
Optimal_Values_q_pi_over_2 = [Optimal_Value_1_Layer_q_pi_over_2, Optimal_Value_2_Layer_q_pi_over_2, Optimal_Value_3_Layer_q_pi_over_2, Optimal_Value_4_Layer_q_pi_over_2, Optimal_Value_5_Layer_q_pi_over_2]

#q = 5pi/8
Energies_1_Layer_q_5pi_over_8 = np.loadtxt(r"/mnt/c/Users/Saavanth Velury/Desktop/Quasiparticle VQE/16 Qubit Data (Final)/Delta = one-tenth/Nf = 7/q = 5pi over 8/1 Layer/16_Qubit_XXZ_1_Layer_HVA_Optimal_Values_BOBYQA_7_Filled_States_Periodic_Boundary_Conditions_PH_State_5.txt")
Energies_2_Layer_q_5pi_over_8 = np.loadtxt(r"/mnt/c/Users/Saavanth Velury/Desktop/Quasiparticle VQE/16 Qubit Data (Final)/Delta = one-tenth/Nf = 7/q = 5pi over 8/2 Layers/16_Qubit_XXZ_2_Layer_HVA_Optimal_Values_BOBYQA_7_Filled_States_Periodic_Boundary_Conditions_PH_State_5.txt")
Energies_3_Layer_q_5pi_over_8 = np.loadtxt(r"/mnt/c/Users/Saavanth Velury/Desktop/Quasiparticle VQE/16 Qubit Data (Final)/Delta = one-tenth/Nf = 7/q = 5pi over 8/3 Layers/16_Qubit_XXZ_3_Layer_HVA_Optimal_Values_BOBYQA_7_Filled_States_Periodic_Boundary_Conditions_PH_State_5.txt")
Energies_4_Layer_q_5pi_over_8 = np.loadtxt(r"/mnt/c/Users/Saavanth Velury/Desktop/Quasiparticle VQE/16 Qubit Data (Final)/Delta = one-tenth/Nf = 7/q = 5pi over 8/4 Layers/16_Qubit_XXZ_4_Layer_HVA_Optimal_Values_BOBYQA_7_Filled_States_Periodic_Boundary_Conditions_PH_State_5.txt")
Energies_5_Layer_q_5pi_over_8 = np.loadtxt(r"/mnt/c/Users/Saavanth Velury/Desktop/Quasiparticle VQE/16 Qubit Data (Final)/Delta = one-tenth/Nf = 7/q = 5pi over 8/5 Layers/16_Qubit_XXZ_5_Layer_HVA_Optimal_Values_BOBYQA_7_Filled_States_Periodic_Boundary_Conditions_PH_State_5.txt")
Optimal_Value_1_Layer_q_5pi_over_8 = Energies_1_Layer_q_5pi_over_8[np.argmin(Energies_1_Layer_q_5pi_over_8)]
Optimal_Value_2_Layer_q_5pi_over_8 = Energies_2_Layer_q_5pi_over_8[np.argmin(Energies_2_Layer_q_5pi_over_8)]
Optimal_Value_3_Layer_q_5pi_over_8 = Energies_3_Layer_q_5pi_over_8[np.argmin(Energies_3_Layer_q_5pi_over_8)]
Optimal_Value_4_Layer_q_5pi_over_8 = Energies_4_Layer_q_5pi_over_8[np.argmin(Energies_4_Layer_q_5pi_over_8)]
Optimal_Value_5_Layer_q_5pi_over_8 = Energies_5_Layer_q_5pi_over_8[np.argmin(Energies_5_Layer_q_5pi_over_8)]
Optimal_Values_q_5pi_over_8 = [Optimal_Value_1_Layer_q_5pi_over_8, Optimal_Value_2_Layer_q_5pi_over_8, Optimal_Value_3_Layer_q_5pi_over_8, Optimal_Value_4_Layer_q_5pi_over_8, Optimal_Value_5_Layer_q_5pi_over_8]

#q = 3pi/4
Energies_1_Layer_q_3pi_over_4 = np.loadtxt(r"/mnt/c/Users/Saavanth Velury/Desktop/Quasiparticle VQE/16 Qubit Data (Final)/Delta = one-tenth/Nf = 7/q = 3pi over 4/1 Layer/16_Qubit_XXZ_1_Layer_HVA_Optimal_Values_BOBYQA_7_Filled_States_Periodic_Boundary_Conditions_PH_State_6.txt")
Energies_2_Layer_q_3pi_over_4 = np.loadtxt(r"/mnt/c/Users/Saavanth Velury/Desktop/Quasiparticle VQE/16 Qubit Data (Final)/Delta = one-tenth/Nf = 7/q = 3pi over 4/2 Layers/16_Qubit_XXZ_2_Layer_HVA_Optimal_Values_BOBYQA_7_Filled_States_Periodic_Boundary_Conditions_PH_State_6.txt")
Energies_3_Layer_q_3pi_over_4 = np.loadtxt(r"/mnt/c/Users/Saavanth Velury/Desktop/Quasiparticle VQE/16 Qubit Data (Final)/Delta = one-tenth/Nf = 7/q = 3pi over 4/3 Layers/16_Qubit_XXZ_3_Layer_HVA_Optimal_Values_BOBYQA_7_Filled_States_Periodic_Boundary_Conditions_PH_State_6.txt")
Energies_4_Layer_q_3pi_over_4 = np.loadtxt(r"/mnt/c/Users/Saavanth Velury/Desktop/Quasiparticle VQE/16 Qubit Data (Final)/Delta = one-tenth/Nf = 7/q = 3pi over 4/4 Layers/16_Qubit_XXZ_4_Layer_HVA_Optimal_Values_BOBYQA_7_Filled_States_Periodic_Boundary_Conditions_PH_State_6.txt")
Energies_5_Layer_q_3pi_over_4 = np.loadtxt(r"/mnt/c/Users/Saavanth Velury/Desktop/Quasiparticle VQE/16 Qubit Data (Final)/Delta = one-tenth/Nf = 7/q = 3pi over 4/5 Layers/16_Qubit_XXZ_5_Layer_HVA_Optimal_Values_BOBYQA_7_Filled_States_Periodic_Boundary_Conditions_PH_State_6.txt")
Optimal_Value_1_Layer_q_3pi_over_4 = Energies_1_Layer_q_3pi_over_4[np.argmin(Energies_1_Layer_q_3pi_over_4)]
Optimal_Value_2_Layer_q_3pi_over_4 = Energies_2_Layer_q_3pi_over_4[np.argmin(Energies_2_Layer_q_3pi_over_4)]
Optimal_Value_3_Layer_q_3pi_over_4 = Energies_3_Layer_q_3pi_over_4[np.argmin(Energies_3_Layer_q_3pi_over_4)]
Optimal_Value_4_Layer_q_3pi_over_4 = Energies_4_Layer_q_3pi_over_4[np.argmin(Energies_4_Layer_q_3pi_over_4)]
Optimal_Value_5_Layer_q_3pi_over_4 = Energies_5_Layer_q_3pi_over_4[np.argmin(Energies_5_Layer_q_3pi_over_4)]
Optimal_Values_q_3pi_over_4 = [Optimal_Value_1_Layer_q_3pi_over_4, Optimal_Value_2_Layer_q_3pi_over_4, Optimal_Value_3_Layer_q_3pi_over_4, Optimal_Value_4_Layer_q_3pi_over_4, Optimal_Value_5_Layer_q_3pi_over_4]

#q = 7pi/8
Energies_1_Layer_q_7pi_over_8 = np.loadtxt(r"/mnt/c/Users/Saavanth Velury/Desktop/Quasiparticle VQE/16 Qubit Data (Final)/Delta = one-tenth/Nf = 7/q = 7pi over 8/1 Layer/16_Qubit_XXZ_1_Layer_HVA_Optimal_Values_BOBYQA_7_Filled_States_Periodic_Boundary_Conditions_PH_State_7.txt")
Energies_2_Layer_q_7pi_over_8 = np.loadtxt(r"/mnt/c/Users/Saavanth Velury/Desktop/Quasiparticle VQE/16 Qubit Data (Final)/Delta = one-tenth/Nf = 7/q = 7pi over 8/2 Layers/16_Qubit_XXZ_2_Layer_HVA_Optimal_Values_BOBYQA_7_Filled_States_Periodic_Boundary_Conditions_PH_State_7.txt")
Energies_3_Layer_q_7pi_over_8 = np.loadtxt(r"/mnt/c/Users/Saavanth Velury/Desktop/Quasiparticle VQE/16 Qubit Data (Final)/Delta = one-tenth/Nf = 7/q = 7pi over 8/3 Layers/16_Qubit_XXZ_3_Layer_HVA_Optimal_Values_BOBYQA_7_Filled_States_Periodic_Boundary_Conditions_PH_State_7.txt")
Energies_4_Layer_q_7pi_over_8 = np.loadtxt(r"/mnt/c/Users/Saavanth Velury/Desktop/Quasiparticle VQE/16 Qubit Data (Final)/Delta = one-tenth/Nf = 7/q = 7pi over 8/4 Layers/16_Qubit_XXZ_4_Layer_HVA_Optimal_Values_BOBYQA_7_Filled_States_Periodic_Boundary_Conditions_PH_State_7.txt")
Energies_5_Layer_q_7pi_over_8 = np.loadtxt(r"/mnt/c/Users/Saavanth Velury/Desktop/Quasiparticle VQE/16 Qubit Data (Final)/Delta = one-tenth/Nf = 7/q = 7pi over 8/5 Layers/16_Qubit_XXZ_5_Layer_HVA_Optimal_Values_BOBYQA_7_Filled_States_Periodic_Boundary_Conditions_PH_State_7.txt")
Optimal_Value_1_Layer_q_7pi_over_8 = Energies_1_Layer_q_7pi_over_8[np.argmin(Energies_1_Layer_q_7pi_over_8)]
Optimal_Value_2_Layer_q_7pi_over_8 = Energies_2_Layer_q_7pi_over_8[np.argmin(Energies_2_Layer_q_7pi_over_8)]
Optimal_Value_3_Layer_q_7pi_over_8 = Energies_3_Layer_q_7pi_over_8[np.argmin(Energies_3_Layer_q_7pi_over_8)]
Optimal_Value_4_Layer_q_7pi_over_8 = Energies_4_Layer_q_7pi_over_8[np.argmin(Energies_4_Layer_q_7pi_over_8)]
Optimal_Value_5_Layer_q_7pi_over_8 = Energies_5_Layer_q_7pi_over_8[np.argmin(Energies_5_Layer_q_7pi_over_8)]
Optimal_Values_q_7pi_over_8 = [Optimal_Value_1_Layer_q_7pi_over_8, Optimal_Value_2_Layer_q_7pi_over_8, Optimal_Value_3_Layer_q_7pi_over_8, Optimal_Value_4_Layer_q_7pi_over_8, Optimal_Value_5_Layer_q_7pi_over_8]

#q = pi
Energies_1_Layer_q_pi = np.loadtxt(r"/mnt/c/Users/Saavanth Velury/Desktop/Quasiparticle VQE/16 Qubit Data (Final)/Delta = one-tenth/Nf = 7/q = pi/1 Layer/16_Qubit_XXZ_1_Layer_HVA_Optimal_Values_BOBYQA_7_Filled_States_Periodic_Boundary_Conditions.txt")
Energies_2_Layer_q_pi = np.loadtxt(r"/mnt/c/Users/Saavanth Velury/Desktop/Quasiparticle VQE/16 Qubit Data (Final)/Delta = one-tenth/Nf = 7/q = pi/2 Layers/16_Qubit_XXZ_2_Layer_HVA_Optimal_Values_BOBYQA_7_Filled_States_Periodic_Boundary_Conditions.txt")
Energies_3_Layer_q_pi = np.loadtxt(r"/mnt/c/Users/Saavanth Velury/Desktop/Quasiparticle VQE/16 Qubit Data (Final)/Delta = one-tenth/Nf = 7/q = pi/3 Layers/16_Qubit_XXZ_3_Layer_HVA_Optimal_Values_BOBYQA_7_Filled_States_Periodic_Boundary_Conditions.txt")
Energies_4_Layer_q_pi = np.loadtxt(r"/mnt/c/Users/Saavanth Velury/Desktop/Quasiparticle VQE/16 Qubit Data (Final)/Delta = one-tenth/Nf = 7/q = pi/4 Layers/16_Qubit_XXZ_4_Layer_HVA_Optimal_Values_BOBYQA_7_Filled_States_Periodic_Boundary_Conditions.txt")
Energies_5_Layer_q_pi = np.loadtxt(r"/mnt/c/Users/Saavanth Velury/Desktop/Quasiparticle VQE/16 Qubit Data (Final)/Delta = one-tenth/Nf = 7/q = pi/5 Layers/16_Qubit_XXZ_5_Layer_HVA_Optimal_Values_BOBYQA_7_Filled_States_Periodic_Boundary_Conditions.txt")
Optimal_Value_1_Layer_q_pi = Energies_1_Layer_q_pi[np.argmin(Energies_1_Layer_q_pi)]
Optimal_Value_2_Layer_q_pi = Energies_2_Layer_q_pi[np.argmin(Energies_2_Layer_q_pi)]
Optimal_Value_3_Layer_q_pi = Energies_3_Layer_q_pi[np.argmin(Energies_3_Layer_q_pi)]
Optimal_Value_4_Layer_q_pi = Energies_4_Layer_q_pi[np.argmin(Energies_4_Layer_q_pi)]
Optimal_Value_5_Layer_q_pi = Energies_5_Layer_q_pi[np.argmin(Energies_5_Layer_q_pi)]
Optimal_Values_q_pi = [Optimal_Value_1_Layer_q_pi, Optimal_Value_2_Layer_q_pi, Optimal_Value_3_Layer_q_pi, Optimal_Value_4_Layer_q_pi, Optimal_Value_5_Layer_q_pi]

# %%
ED_Values_Delta_One_Tenth = [0, -19.109184 + 20.730872, -17.742059 + 20.730872, -16.837565 + 20.730872, -16.533393 + 20.730872, -16.875846 + 20.730872, -17.812790 + 20.730872, -19.201595 + 20.730872, -17.601170 + 20.730872, -19.201595 + 20.730872, -17.812790 + 20.730872, -16.875846 + 20.730872, -16.533393 + 20.730872, -16.837565 + 20.730872, -17.742059 + 20.730872, -19.109184 + 20.730872, 0]

# %%
VQE_Values_Delta_One_Tenth = [0, -19.10199631-min(Optimal_Values_q_pi), -17.73446237-min(Optimal_Values_q_pi), -16.82957430-min(Optimal_Values_q_pi), -16.52488992-min(Optimal_Values_q_pi), -16.86697075-min(Optimal_Values_q_pi), -17.80429229-min(Optimal_Values_q_pi), -19.19528963-min(Optimal_Values_q_pi), min(Optimal_Values_q0) - min(Optimal_Values_q_pi), min(Optimal_Values_q_pi_over_8) - min(Optimal_Values_q_pi), min(Optimal_Values_q_pi_over_4) - min(Optimal_Values_q_pi), min(Optimal_Values_q_3pi_over_8) - min(Optimal_Values_q_pi), min(Optimal_Values_q_pi_over_2) - min(Optimal_Values_q_pi), min(Optimal_Values_q_5pi_over_8) - min(Optimal_Values_q_pi), min(Optimal_Values_q_3pi_over_4) - min(Optimal_Values_q_pi), min(Optimal_Values_q_7pi_over_8) - min(Optimal_Values_q_pi), 0]

# %%
#Nf = 7 (Δ = 0.5)

#q = 0
Energies_1_Layer_q0 = np.loadtxt(r"/mnt/c/Users/Saavanth Velury/Desktop/Quasiparticle VQE/16 Qubit Data (Final)/Delta = one-half/Nf = 7/q = 0/1 Layer/16_Qubit_XXZ_1_Layer_HVA_Optimal_Values_BOBYQA_7_Filled_States_Periodic_BC_PH_State_8_Three_Parameters_Delta_0.5.txt")
Energies_2_Layer_q0 = np.loadtxt(r"/mnt/c/Users/Saavanth Velury/Desktop/Quasiparticle VQE/16 Qubit Data (Final)/Delta = one-half/Nf = 7/q = 0/2 Layers/16_Qubit_XXZ_2_Layer_HVA_Optimal_Values_BOBYQA_7_Filled_States_Periodic_BC_PH_State_8_Three_Parameters_Delta_0.5.txt")
Energies_3_Layer_q0 = np.loadtxt(r"/mnt/c/Users/Saavanth Velury/Desktop/Quasiparticle VQE/16 Qubit Data (Final)/Delta = one-half/Nf = 7/q = 0/3 Layers/16_Qubit_XXZ_3_Layer_HVA_Optimal_Values_BOBYQA_7_Filled_States_Periodic_BC_PH_State_8_Three_Parameters_Delta_0.5.txt")
Energies_4_Layer_q0 = np.loadtxt(r"/mnt/c/Users/Saavanth Velury/Desktop/Quasiparticle VQE/16 Qubit Data (Final)/Delta = one-half/Nf = 7/q = 0/4 Layers/16_Qubit_XXZ_4_Layer_HVA_Optimal_Values_BOBYQA_7_Filled_States_Periodic_BC_PH_State_8_Three_Parameters_Delta_0.5.txt")
Energies_5_Layer_q0 = np.loadtxt(r"/mnt/c/Users/Saavanth Velury/Desktop/Quasiparticle VQE/16 Qubit Data (Final)/Delta = one-half/Nf = 7/q = 0/5 Layers/16_Qubit_XXZ_5_Layer_HVA_Optimal_Values_BOBYQA_7_Filled_States_Periodic_BC_PH_State_8_Three_Parameters_Delta_0.5.txt")
Optimal_Value_1_Layer_q0 = Energies_1_Layer_q0[np.argmin(Energies_1_Layer_q0)]
Optimal_Value_2_Layer_q0 = Energies_2_Layer_q0[np.argmin(Energies_2_Layer_q0)]
Optimal_Value_3_Layer_q0 = Energies_3_Layer_q0[np.argmin(Energies_3_Layer_q0)]
Optimal_Value_4_Layer_q0 = Energies_4_Layer_q0[np.argmin(Energies_4_Layer_q0)]
Optimal_Value_5_Layer_q0 = Energies_5_Layer_q0[np.argmin(Energies_5_Layer_q0)]
Optimal_Values_q0 = [Optimal_Value_1_Layer_q0, Optimal_Value_2_Layer_q0, Optimal_Value_3_Layer_q0, Optimal_Value_4_Layer_q0, Optimal_Value_5_Layer_q0]

Energies_1_Layer_q0_Alternate = np.loadtxt(r"/mnt/c/Users/Saavanth Velury/Desktop/Quasiparticle VQE/16 Qubit Data (Final)/Delta = one-half/Nf = 7/q = 0/1 Layer/16_Qubit_XXZ_1_Layer_HVA_Optimal_Values_BOBYQA_7_Filled_States_Periodic_BC_PH_State_8_Alternate_Three_Parameters_Delta_0.5.txt")
Energies_2_Layer_q0_Alternate = np.loadtxt(r"/mnt/c/Users/Saavanth Velury/Desktop/Quasiparticle VQE/16 Qubit Data (Final)/Delta = one-half/Nf = 7/q = 0/2 Layers/16_Qubit_XXZ_2_Layer_HVA_Optimal_Values_BOBYQA_7_Filled_States_Periodic_BC_PH_State_8_Alternate_Three_Parameters_Delta_0.5.txt")
Energies_3_Layer_q0_Alternate = np.loadtxt(r"/mnt/c/Users/Saavanth Velury/Desktop/Quasiparticle VQE/16 Qubit Data (Final)/Delta = one-half/Nf = 7/q = 0/3 Layers/16_Qubit_XXZ_3_Layer_HVA_Optimal_Values_BOBYQA_7_Filled_States_Periodic_BC_PH_State_8_Alternate_Three_Parameters_Delta_0.5.txt")
Energies_4_Layer_q0_Alternate = np.loadtxt(r"/mnt/c/Users/Saavanth Velury/Desktop/Quasiparticle VQE/16 Qubit Data (Final)/Delta = one-half/Nf = 7/q = 0/4 Layers/16_Qubit_XXZ_4_Layer_HVA_Optimal_Values_BOBYQA_7_Filled_States_Periodic_BC_PH_State_8_Alternate_Three_Parameters_Delta_0.5.txt")
Energies_5_Layer_q0_Alternate = np.loadtxt(r"/mnt/c/Users/Saavanth Velury/Desktop/Quasiparticle VQE/16 Qubit Data (Final)/Delta = one-half/Nf = 7/q = 0/5 Layers/16_Qubit_XXZ_5_Layer_HVA_Optimal_Values_BOBYQA_7_Filled_States_Periodic_BC_PH_State_8_Alternate_Three_Parameters_Delta_0.5.txt")
Optimal_Value_1_Layer_q0_Alternate = Energies_1_Layer_q0_Alternate[np.argmin(Energies_1_Layer_q0_Alternate)]
Optimal_Value_2_Layer_q0_Alternate = Energies_2_Layer_q0_Alternate[np.argmin(Energies_2_Layer_q0_Alternate)]
Optimal_Value_3_Layer_q0_Alternate = Energies_3_Layer_q0_Alternate[np.argmin(Energies_3_Layer_q0_Alternate)]
Optimal_Value_4_Layer_q0_Alternate = Energies_4_Layer_q0_Alternate[np.argmin(Energies_4_Layer_q0_Alternate)]
Optimal_Value_5_Layer_q0_Alternate = Energies_5_Layer_q0_Alternate[np.argmin(Energies_5_Layer_q0_Alternate)]
Optimal_Values_q0_Alternate = [Optimal_Value_1_Layer_q0_Alternate, Optimal_Value_2_Layer_q0_Alternate, Optimal_Value_3_Layer_q0_Alternate, Optimal_Value_4_Layer_q0_Alternate, Optimal_Value_5_Layer_q0_Alternate]

#q = pi/8
Energies_1_Layer_q_pi_over_8 = np.loadtxt(r"/mnt/c/Users/Saavanth Velury/Desktop/Quasiparticle VQE/16 Qubit Data (Final)/Delta = one-half/Nf = 7/q = pi over 8/1 Layer/16_Qubit_XXZ_1_Layer_HVA_Optimal_Values_BOBYQA_7_Filled_States_Periodic_BC_PH_State_Three_Parameters_Delta_0.5.txt")
Energies_2_Layer_q_pi_over_8 = np.loadtxt(r"/mnt/c/Users/Saavanth Velury/Desktop/Quasiparticle VQE/16 Qubit Data (Final)/Delta = one-half/Nf = 7/q = pi over 8/2 Layers/16_Qubit_XXZ_2_Layer_HVA_Optimal_Values_BOBYQA_7_Filled_States_Periodic_BC_PH_State_Three_Parameters_Delta_0.5.txt")
Energies_3_Layer_q_pi_over_8 = np.loadtxt(r"/mnt/c/Users/Saavanth Velury/Desktop/Quasiparticle VQE/16 Qubit Data (Final)/Delta = one-half/Nf = 7/q = pi over 8/3 Layers/16_Qubit_XXZ_3_Layer_HVA_Optimal_Values_BOBYQA_7_Filled_States_Periodic_BC_PH_State_Three_Parameters_Delta_0.5.txt")
Energies_4_Layer_q_pi_over_8 = np.loadtxt(r"/mnt/c/Users/Saavanth Velury/Desktop/Quasiparticle VQE/16 Qubit Data (Final)/Delta = one-half/Nf = 7/q = pi over 8/4 Layers/16_Qubit_XXZ_4_Layer_HVA_Optimal_Values_BOBYQA_7_Filled_States_Periodic_BC_PH_State_Three_Parameters_Delta_0.5.txt")
Energies_5_Layer_q_pi_over_8 = np.loadtxt(r"/mnt/c/Users/Saavanth Velury/Desktop/Quasiparticle VQE/16 Qubit Data (Final)/Delta = one-half/Nf = 7/q = pi over 8/5 Layers/16_Qubit_XXZ_5_Layer_HVA_Optimal_Values_BOBYQA_7_Filled_States_Periodic_BC_PH_State_Three_Parameters_Delta_0.5.txt")
Optimal_Value_1_Layer_q_pi_over_8 = Energies_1_Layer_q_pi_over_8[np.argmin(Energies_1_Layer_q_pi_over_8)]
Optimal_Value_2_Layer_q_pi_over_8 = Energies_2_Layer_q_pi_over_8[np.argmin(Energies_2_Layer_q_pi_over_8)]
Optimal_Value_3_Layer_q_pi_over_8 = Energies_3_Layer_q_pi_over_8[np.argmin(Energies_3_Layer_q_pi_over_8)]
Optimal_Value_4_Layer_q_pi_over_8 = Energies_4_Layer_q_pi_over_8[np.argmin(Energies_4_Layer_q_pi_over_8)]
Optimal_Value_5_Layer_q_pi_over_8 = Energies_5_Layer_q_pi_over_8[np.argmin(Energies_5_Layer_q_pi_over_8)]
Optimal_Values_q_pi_over_8 = [Optimal_Value_1_Layer_q_pi_over_8, Optimal_Value_2_Layer_q_pi_over_8, Optimal_Value_3_Layer_q_pi_over_8, Optimal_Value_4_Layer_q_pi_over_8, Optimal_Value_5_Layer_q_pi_over_8]

#q = pi/4
Energies_1_Layer_q_pi_over_4 = np.loadtxt(r"/mnt/c/Users/Saavanth Velury/Desktop/Quasiparticle VQE/16 Qubit Data (Final)/Delta = one-half/Nf = 7/q = pi over 4/1 Layer/16_Qubit_XXZ_1_Layer_HVA_Optimal_Values_BOBYQA_7_Filled_States_Periodic_BC_PH_State_2_Three_Parameters_Delta_0.5.txt")
Energies_2_Layer_q_pi_over_4 = np.loadtxt(r"/mnt/c/Users/Saavanth Velury/Desktop/Quasiparticle VQE/16 Qubit Data (Final)/Delta = one-half/Nf = 7/q = pi over 4/2 Layers/16_Qubit_XXZ_2_Layer_HVA_Optimal_Values_BOBYQA_7_Filled_States_Periodic_BC_PH_State_2_Three_Parameters_Delta_0.5.txt")
Energies_3_Layer_q_pi_over_4 = np.loadtxt(r"/mnt/c/Users/Saavanth Velury/Desktop/Quasiparticle VQE/16 Qubit Data (Final)/Delta = one-half/Nf = 7/q = pi over 4/3 Layers/16_Qubit_XXZ_3_Layer_HVA_Optimal_Values_BOBYQA_7_Filled_States_Periodic_BC_PH_State_2_Three_Parameters_Delta_0.5.txt")
Energies_4_Layer_q_pi_over_4 = np.loadtxt(r"/mnt/c/Users/Saavanth Velury/Desktop/Quasiparticle VQE/16 Qubit Data (Final)/Delta = one-half/Nf = 7/q = pi over 4/4 Layers/16_Qubit_XXZ_4_Layer_HVA_Optimal_Values_BOBYQA_7_Filled_States_Periodic_BC_PH_State_2_Three_Parameters_Delta_0.5.txt")
Energies_5_Layer_q_pi_over_4 = np.loadtxt(r"/mnt/c/Users/Saavanth Velury/Desktop/Quasiparticle VQE/16 Qubit Data (Final)/Delta = one-half/Nf = 7/q = pi over 4/5 Layers/16_Qubit_XXZ_5_Layer_HVA_Optimal_Values_BOBYQA_7_Filled_States_Periodic_BC_PH_State_2_Three_Parameters_Delta_0.5.txt")
Optimal_Value_1_Layer_q_pi_over_4 = Energies_1_Layer_q_pi_over_4[np.argmin(Energies_1_Layer_q_pi_over_4)]
Optimal_Value_2_Layer_q_pi_over_4 = Energies_2_Layer_q_pi_over_4[np.argmin(Energies_2_Layer_q_pi_over_4)]
Optimal_Value_3_Layer_q_pi_over_4 = Energies_3_Layer_q_pi_over_4[np.argmin(Energies_3_Layer_q_pi_over_4)]
Optimal_Value_4_Layer_q_pi_over_4 = Energies_4_Layer_q_pi_over_4[np.argmin(Energies_4_Layer_q_pi_over_4)]
Optimal_Value_5_Layer_q_pi_over_4 = Energies_5_Layer_q_pi_over_4[np.argmin(Energies_5_Layer_q_pi_over_4)]
Optimal_Values_q_pi_over_4 = [Optimal_Value_1_Layer_q_pi_over_4, Optimal_Value_2_Layer_q_pi_over_4, Optimal_Value_3_Layer_q_pi_over_4, Optimal_Value_4_Layer_q_pi_over_4, Optimal_Value_5_Layer_q_pi_over_4]

#q = 3pi/8
Energies_1_Layer_q_3pi_over_8 = np.loadtxt(r"/mnt/c/Users/Saavanth Velury/Desktop/Quasiparticle VQE/16 Qubit Data (Final)/Delta = one-half/Nf = 7/q = 3pi over 8/1 Layer/16_Qubit_XXZ_1_Layer_HVA_Optimal_Values_BOBYQA_7_Filled_States_Periodic_BC_PH_State_3_Three_Parameters_Delta_0.5.txt")
Energies_2_Layer_q_3pi_over_8 = np.loadtxt(r"/mnt/c/Users/Saavanth Velury/Desktop/Quasiparticle VQE/16 Qubit Data (Final)/Delta = one-half/Nf = 7/q = 3pi over 8/2 Layers/16_Qubit_XXZ_2_Layer_HVA_Optimal_Values_BOBYQA_7_Filled_States_Periodic_BC_PH_State_3_Three_Parameters_Delta_0.5.txt")
Energies_3_Layer_q_3pi_over_8 = np.loadtxt(r"/mnt/c/Users/Saavanth Velury/Desktop/Quasiparticle VQE/16 Qubit Data (Final)/Delta = one-half/Nf = 7/q = 3pi over 8/3 Layers/16_Qubit_XXZ_3_Layer_HVA_Optimal_Values_BOBYQA_7_Filled_States_Periodic_BC_PH_State_3_Three_Parameters_Delta_0.5.txt")
Energies_4_Layer_q_3pi_over_8 = np.loadtxt(r"/mnt/c/Users/Saavanth Velury/Desktop/Quasiparticle VQE/16 Qubit Data (Final)/Delta = one-half/Nf = 7/q = 3pi over 8/4 Layers/16_Qubit_XXZ_4_Layer_HVA_Optimal_Values_BOBYQA_7_Filled_States_Periodic_BC_PH_State_3_Three_Parameters_Delta_0.5.txt")
Energies_5_Layer_q_3pi_over_8 = np.loadtxt(r"/mnt/c/Users/Saavanth Velury/Desktop/Quasiparticle VQE/16 Qubit Data (Final)/Delta = one-half/Nf = 7/q = 3pi over 8/5 Layers/16_Qubit_XXZ_5_Layer_HVA_Optimal_Values_BOBYQA_7_Filled_States_Periodic_BC_PH_State_3_Three_Parameters_Delta_0.5.txt")
Optimal_Value_1_Layer_q_3pi_over_8 = Energies_1_Layer_q_3pi_over_8[np.argmin(Energies_1_Layer_q_3pi_over_8)]
Optimal_Value_2_Layer_q_3pi_over_8 = Energies_2_Layer_q_3pi_over_8[np.argmin(Energies_2_Layer_q_3pi_over_8)]
Optimal_Value_3_Layer_q_3pi_over_8 = Energies_3_Layer_q_3pi_over_8[np.argmin(Energies_3_Layer_q_3pi_over_8)]
Optimal_Value_4_Layer_q_3pi_over_8 = Energies_4_Layer_q_3pi_over_8[np.argmin(Energies_4_Layer_q_3pi_over_8)]
Optimal_Value_5_Layer_q_3pi_over_8 = Energies_5_Layer_q_3pi_over_8[np.argmin(Energies_5_Layer_q_3pi_over_8)]
Optimal_Values_q_3pi_over_8 = [Optimal_Value_1_Layer_q_3pi_over_8, Optimal_Value_2_Layer_q_3pi_over_8, Optimal_Value_3_Layer_q_3pi_over_8, Optimal_Value_4_Layer_q_3pi_over_8, Optimal_Value_5_Layer_q_3pi_over_8]

#q = pi/2
Energies_1_Layer_q_pi_over_2 = np.loadtxt(r"/mnt/c/Users/Saavanth Velury/Desktop/Quasiparticle VQE/16 Qubit Data (Final)/Delta = one-half/Nf = 7/q = pi over 2/1 Layer/16_Qubit_XXZ_1_Layer_HVA_Optimal_Values_BOBYQA_7_Filled_States_Periodic_BC_PH_State_4_Three_Parameters_Delta_0.5.txt")
Energies_2_Layer_q_pi_over_2 = np.loadtxt(r"/mnt/c/Users/Saavanth Velury/Desktop/Quasiparticle VQE/16 Qubit Data (Final)/Delta = one-half/Nf = 7/q = pi over 2/2 Layers/16_Qubit_XXZ_2_Layer_HVA_Optimal_Values_BOBYQA_7_Filled_States_Periodic_BC_PH_State_4_Three_Parameters_Delta_0.5.txt")
Energies_3_Layer_q_pi_over_2 = np.loadtxt(r"/mnt/c/Users/Saavanth Velury/Desktop/Quasiparticle VQE/16 Qubit Data (Final)/Delta = one-half/Nf = 7/q = pi over 2/3 Layers/16_Qubit_XXZ_3_Layer_HVA_Optimal_Values_BOBYQA_7_Filled_States_Periodic_BC_PH_State_4_Three_Parameters_Delta_0.5.txt")
Energies_4_Layer_q_pi_over_2 = np.loadtxt(r"/mnt/c/Users/Saavanth Velury/Desktop/Quasiparticle VQE/16 Qubit Data (Final)/Delta = one-half/Nf = 7/q = pi over 2/4 Layers/16_Qubit_XXZ_4_Layer_HVA_Optimal_Values_BOBYQA_7_Filled_States_Periodic_BC_PH_State_4_Three_Parameters_Delta_0.5.txt")
Energies_5_Layer_q_pi_over_2 = np.loadtxt(r"/mnt/c/Users/Saavanth Velury/Desktop/Quasiparticle VQE/16 Qubit Data (Final)/Delta = one-half/Nf = 7/q = pi over 2/5 Layers/16_Qubit_XXZ_5_Layer_HVA_Optimal_Values_BOBYQA_7_Filled_States_Periodic_BC_PH_State_4_Three_Parameters_Delta_0.5.txt")
Optimal_Value_1_Layer_q_pi_over_2 = Energies_1_Layer_q_pi_over_2[np.argmin(Energies_1_Layer_q_pi_over_2)]
Optimal_Value_2_Layer_q_pi_over_2 = Energies_2_Layer_q_pi_over_2[np.argmin(Energies_2_Layer_q_pi_over_2)]
Optimal_Value_3_Layer_q_pi_over_2 = Energies_3_Layer_q_pi_over_2[np.argmin(Energies_3_Layer_q_pi_over_2)]
Optimal_Value_4_Layer_q_pi_over_2 = Energies_4_Layer_q_pi_over_2[np.argmin(Energies_4_Layer_q_pi_over_2)]
Optimal_Value_5_Layer_q_pi_over_2 = Energies_5_Layer_q_pi_over_2[np.argmin(Energies_5_Layer_q_pi_over_2)]
Optimal_Values_q_pi_over_2 = [Optimal_Value_1_Layer_q_pi_over_2, Optimal_Value_2_Layer_q_pi_over_2, Optimal_Value_3_Layer_q_pi_over_2, Optimal_Value_4_Layer_q_pi_over_2, Optimal_Value_5_Layer_q_pi_over_2]

#q = 5pi/8
Energies_1_Layer_q_5pi_over_8 = np.loadtxt(r"/mnt/c/Users/Saavanth Velury/Desktop/Quasiparticle VQE/16 Qubit Data (Final)/Delta = one-half/Nf = 7/q = 5pi over 8/1 Layer/16_Qubit_XXZ_1_Layer_HVA_Optimal_Values_BOBYQA_7_Filled_States_Periodic_BC_PH_State_5_Three_Parameters_Delta_0.5.txt")
Energies_2_Layer_q_5pi_over_8 = np.loadtxt(r"/mnt/c/Users/Saavanth Velury/Desktop/Quasiparticle VQE/16 Qubit Data (Final)/Delta = one-half/Nf = 7/q = 5pi over 8/2 Layers/16_Qubit_XXZ_2_Layer_HVA_Optimal_Values_BOBYQA_7_Filled_States_Periodic_BC_PH_State_5_Three_Parameters_Delta_0.5.txt")
Energies_3_Layer_q_5pi_over_8 = np.loadtxt(r"/mnt/c/Users/Saavanth Velury/Desktop/Quasiparticle VQE/16 Qubit Data (Final)/Delta = one-half/Nf = 7/q = 5pi over 8/3 Layers/16_Qubit_XXZ_3_Layer_HVA_Optimal_Values_BOBYQA_7_Filled_States_Periodic_BC_PH_State_5_Three_Parameters_Delta_0.5.txt")
Energies_4_Layer_q_5pi_over_8 = np.loadtxt(r"/mnt/c/Users/Saavanth Velury/Desktop/Quasiparticle VQE/16 Qubit Data (Final)/Delta = one-half/Nf = 7/q = 5pi over 8/4 Layers/16_Qubit_XXZ_4_Layer_HVA_Optimal_Values_BOBYQA_7_Filled_States_Periodic_BC_PH_State_5_Three_Parameters_Delta_0.5.txt")
Energies_5_Layer_q_5pi_over_8 = np.loadtxt(r"/mnt/c/Users/Saavanth Velury/Desktop/Quasiparticle VQE/16 Qubit Data (Final)/Delta = one-half/Nf = 7/q = 5pi over 8/5 Layers/16_Qubit_XXZ_5_Layer_HVA_Optimal_Values_BOBYQA_7_Filled_States_Periodic_BC_PH_State_5_Three_Parameters_Delta_0.5.txt")
Optimal_Value_1_Layer_q_5pi_over_8 = Energies_1_Layer_q_5pi_over_8[np.argmin(Energies_1_Layer_q_5pi_over_8)]
Optimal_Value_2_Layer_q_5pi_over_8 = Energies_2_Layer_q_5pi_over_8[np.argmin(Energies_2_Layer_q_5pi_over_8)]
Optimal_Value_3_Layer_q_5pi_over_8 = Energies_3_Layer_q_5pi_over_8[np.argmin(Energies_3_Layer_q_5pi_over_8)]
Optimal_Value_4_Layer_q_5pi_over_8 = Energies_4_Layer_q_5pi_over_8[np.argmin(Energies_4_Layer_q_5pi_over_8)]
Optimal_Value_5_Layer_q_5pi_over_8 = Energies_5_Layer_q_5pi_over_8[np.argmin(Energies_5_Layer_q_5pi_over_8)]
Optimal_Values_q_5pi_over_8 = [Optimal_Value_1_Layer_q_5pi_over_8, Optimal_Value_2_Layer_q_5pi_over_8, Optimal_Value_3_Layer_q_5pi_over_8, Optimal_Value_4_Layer_q_5pi_over_8, Optimal_Value_5_Layer_q_5pi_over_8]

#q = 3pi/4
Energies_1_Layer_q_3pi_over_4 = np.loadtxt(r"/mnt/c/Users/Saavanth Velury/Desktop/Quasiparticle VQE/16 Qubit Data (Final)/Delta = one-half/Nf = 7/q = 3pi over 4/1 Layer/16_Qubit_XXZ_1_Layer_HVA_Optimal_Values_BOBYQA_7_Filled_States_Periodic_BC_PH_State_6_Three_Parameters_Delta_0.5.txt")
Energies_2_Layer_q_3pi_over_4 = np.loadtxt(r"/mnt/c/Users/Saavanth Velury/Desktop/Quasiparticle VQE/16 Qubit Data (Final)/Delta = one-half/Nf = 7/q = 3pi over 4/2 Layers/16_Qubit_XXZ_2_Layer_HVA_Optimal_Values_BOBYQA_7_Filled_States_Periodic_BC_PH_State_6_Three_Parameters_Delta_0.5.txt")
Energies_3_Layer_q_3pi_over_4 = np.loadtxt(r"/mnt/c/Users/Saavanth Velury/Desktop/Quasiparticle VQE/16 Qubit Data (Final)/Delta = one-half/Nf = 7/q = 3pi over 4/3 Layers/16_Qubit_XXZ_3_Layer_HVA_Optimal_Values_BOBYQA_7_Filled_States_Periodic_BC_PH_State_6_Three_Parameters_Delta_0.5.txt")
Energies_4_Layer_q_3pi_over_4 = np.loadtxt(r"/mnt/c/Users/Saavanth Velury/Desktop/Quasiparticle VQE/16 Qubit Data (Final)/Delta = one-half/Nf = 7/q = 3pi over 4/4 Layers/16_Qubit_XXZ_4_Layer_HVA_Optimal_Values_BOBYQA_7_Filled_States_Periodic_BC_PH_State_6_Three_Parameters_Delta_0.5.txt")
Energies_5_Layer_q_3pi_over_4 = np.loadtxt(r"/mnt/c/Users/Saavanth Velury/Desktop/Quasiparticle VQE/16 Qubit Data (Final)/Delta = one-half/Nf = 7/q = 3pi over 4/5 Layers/16_Qubit_XXZ_5_Layer_HVA_Optimal_Values_BOBYQA_7_Filled_States_Periodic_BC_PH_State_6_Three_Parameters_Delta_0.5.txt")
Optimal_Value_1_Layer_q_3pi_over_4 = Energies_1_Layer_q_3pi_over_4[np.argmin(Energies_1_Layer_q_3pi_over_4)]
Optimal_Value_2_Layer_q_3pi_over_4 = Energies_2_Layer_q_3pi_over_4[np.argmin(Energies_2_Layer_q_3pi_over_4)]
Optimal_Value_3_Layer_q_3pi_over_4 = Energies_3_Layer_q_3pi_over_4[np.argmin(Energies_3_Layer_q_3pi_over_4)]
Optimal_Value_4_Layer_q_3pi_over_4 = Energies_4_Layer_q_3pi_over_4[np.argmin(Energies_4_Layer_q_3pi_over_4)]
Optimal_Value_5_Layer_q_3pi_over_4 = Energies_5_Layer_q_3pi_over_4[np.argmin(Energies_5_Layer_q_3pi_over_4)]
Optimal_Values_q_3pi_over_4 = [Optimal_Value_1_Layer_q_3pi_over_4, Optimal_Value_2_Layer_q_3pi_over_4, Optimal_Value_3_Layer_q_3pi_over_4, Optimal_Value_4_Layer_q_3pi_over_4, Optimal_Value_5_Layer_q_3pi_over_4]

#q = 7pi/8
Energies_1_Layer_q_7pi_over_8 = np.loadtxt(r"/mnt/c/Users/Saavanth Velury/Desktop/Quasiparticle VQE/16 Qubit Data (Final)/Delta = one-half/Nf = 7/q = 7pi over 8/1 Layer/16_Qubit_XXZ_1_Layer_HVA_Optimal_Values_BOBYQA_7_Filled_States_Periodic_BC_PH_State_7_Three_Parameters_Delta_0.5.txt")
Energies_2_Layer_q_7pi_over_8 = np.loadtxt(r"/mnt/c/Users/Saavanth Velury/Desktop/Quasiparticle VQE/16 Qubit Data (Final)/Delta = one-half/Nf = 7/q = 7pi over 8/2 Layers/16_Qubit_XXZ_2_Layer_HVA_Optimal_Values_BOBYQA_7_Filled_States_Periodic_BC_PH_State_7_Three_Parameters_Delta_0.5.txt")
Energies_3_Layer_q_7pi_over_8 = np.loadtxt(r"/mnt/c/Users/Saavanth Velury/Desktop/Quasiparticle VQE/16 Qubit Data (Final)/Delta = one-half/Nf = 7/q = 7pi over 8/3 Layers/16_Qubit_XXZ_3_Layer_HVA_Optimal_Values_BOBYQA_7_Filled_States_Periodic_BC_PH_State_7_Three_Parameters_Delta_0.5.txt")
Energies_4_Layer_q_7pi_over_8 = np.loadtxt(r"/mnt/c/Users/Saavanth Velury/Desktop/Quasiparticle VQE/16 Qubit Data (Final)/Delta = one-half/Nf = 7/q = 7pi over 8/4 Layers/16_Qubit_XXZ_4_Layer_HVA_Optimal_Values_BOBYQA_7_Filled_States_Periodic_BC_PH_State_7_Three_Parameters_Delta_0.5.txt")
Energies_5_Layer_q_7pi_over_8 = np.loadtxt(r"/mnt/c/Users/Saavanth Velury/Desktop/Quasiparticle VQE/16 Qubit Data (Final)/Delta = one-half/Nf = 7/q = 7pi over 8/5 Layers/16_Qubit_XXZ_5_Layer_HVA_Optimal_Values_BOBYQA_7_Filled_States_Periodic_BC_PH_State_7_Three_Parameters_Delta_0.5.txt")
Optimal_Value_1_Layer_q_7pi_over_8 = Energies_1_Layer_q_7pi_over_8[np.argmin(Energies_1_Layer_q_7pi_over_8)]
Optimal_Value_2_Layer_q_7pi_over_8 = Energies_2_Layer_q_7pi_over_8[np.argmin(Energies_2_Layer_q_7pi_over_8)]
Optimal_Value_3_Layer_q_7pi_over_8 = Energies_3_Layer_q_7pi_over_8[np.argmin(Energies_3_Layer_q_7pi_over_8)]
Optimal_Value_4_Layer_q_7pi_over_8 = Energies_4_Layer_q_7pi_over_8[np.argmin(Energies_4_Layer_q_7pi_over_8)]
Optimal_Value_5_Layer_q_7pi_over_8 = Energies_5_Layer_q_7pi_over_8[np.argmin(Energies_5_Layer_q_7pi_over_8)]
Optimal_Values_q_7pi_over_8 = [Optimal_Value_1_Layer_q_7pi_over_8, Optimal_Value_2_Layer_q_7pi_over_8, Optimal_Value_3_Layer_q_7pi_over_8, Optimal_Value_4_Layer_q_7pi_over_8, Optimal_Value_5_Layer_q_7pi_over_8]

#q = pi
Energies_1_Layer_q_pi = np.loadtxt(r"/mnt/c/Users/Saavanth Velury/Desktop/Quasiparticle VQE/16 Qubit Data (Final)/Delta = one-half/Nf = 7/q = pi/1 Layer/16_Qubit_XXZ_1_Layer_HVA_Optimal_Values_BOBYQA_7_Filled_States_Periodic_Boundary_Conditions_Three_Parameters_Delta_0.5.txt")
Energies_2_Layer_q_pi = np.loadtxt(r"/mnt/c/Users/Saavanth Velury/Desktop/Quasiparticle VQE/16 Qubit Data (Final)/Delta = one-half/Nf = 7/q = pi/2 Layers/16_Qubit_XXZ_2_Layer_HVA_Optimal_Values_BOBYQA_7_Filled_States_Periodic_Boundary_Conditions_Three_Parameters_Delta_0.5.txt")
Energies_3_Layer_q_pi = np.loadtxt(r"/mnt/c/Users/Saavanth Velury/Desktop/Quasiparticle VQE/16 Qubit Data (Final)/Delta = one-half/Nf = 7/q = pi/3 Layers/16_Qubit_XXZ_3_Layer_HVA_Optimal_Values_BOBYQA_7_Filled_States_Periodic_Boundary_Conditions_Three_Parameters_Delta_0.5.txt")
Energies_4_Layer_q_pi = np.loadtxt(r"/mnt/c/Users/Saavanth Velury/Desktop/Quasiparticle VQE/16 Qubit Data (Final)/Delta = one-half/Nf = 7/q = pi/4 Layers/16_Qubit_XXZ_4_Layer_HVA_Optimal_Values_BOBYQA_7_Filled_States_Periodic_Boundary_Conditions_Three_Parameters_Delta_0.5.txt")
Energies_5_Layer_q_pi = np.loadtxt(r"/mnt/c/Users/Saavanth Velury/Desktop/Quasiparticle VQE/16 Qubit Data (Final)/Delta = one-half/Nf = 7/q = pi/5 Layers/16_Qubit_XXZ_5_Layer_HVA_Optimal_Values_BOBYQA_7_Filled_States_Periodic_Boundary_Conditions_Three_Parameters_Delta_0.5.txt")
Optimal_Value_1_Layer_q_pi = Energies_1_Layer_q_pi[np.argmin(Energies_1_Layer_q_pi)]
Optimal_Value_2_Layer_q_pi = Energies_2_Layer_q_pi[np.argmin(Energies_2_Layer_q_pi)]
Optimal_Value_3_Layer_q_pi = Energies_3_Layer_q_pi[np.argmin(Energies_3_Layer_q_pi)]
Optimal_Value_4_Layer_q_pi = Energies_4_Layer_q_pi[np.argmin(Energies_4_Layer_q_pi)]
Optimal_Value_5_Layer_q_pi = Energies_5_Layer_q_pi[np.argmin(Energies_5_Layer_q_pi)]
Optimal_Values_q_pi = [Optimal_Value_1_Layer_q_pi, Optimal_Value_2_Layer_q_pi, Optimal_Value_3_Layer_q_pi, Optimal_Value_4_Layer_q_pi, Optimal_Value_5_Layer_q_pi]

# %%
ED_Values_Delta_One_Half = [0, -21.533910 + 23.491255, -19.910573 + 23.491255, -18.870041 + 23.491255, -18.571280 + 23.491255, -19.060175 + 23.491255, -20.262717 + 23.491255, -21.996490 + 23.491255, -20.284712 + 23.491255, -21.996490 + 23.491255, -20.262717 + 23.491255, -19.060175 + 23.491255, -18.571280 + 23.491255, -18.870041 + 23.491255, -19.910573 + 23.491255, -21.533910 + 23.491255, 0]

# %%
VQE_Values_Delta_One_Half = [0, -21.49020714-min(Optimal_Values_q_pi), -19.85853097-min(Optimal_Values_q_pi), -18.79335690-min(Optimal_Values_q_pi), -18.47396530-min(Optimal_Values_q_pi), -18.97425978-min(Optimal_Values_q_pi), -20.19878691-min(Optimal_Values_q_pi), -21.95562546-min(Optimal_Values_q_pi), min(Optimal_Values_q0) - min(Optimal_Values_q_pi), min(Optimal_Values_q_pi_over_8) - min(Optimal_Values_q_pi), min(Optimal_Values_q_pi_over_4) - min(Optimal_Values_q_pi), min(Optimal_Values_q_3pi_over_8) - min(Optimal_Values_q_pi), min(Optimal_Values_q_pi_over_2) - min(Optimal_Values_q_pi), min(Optimal_Values_q_5pi_over_8) - min(Optimal_Values_q_pi), min(Optimal_Values_q_3pi_over_4) - min(Optimal_Values_q_pi), min(Optimal_Values_q_7pi_over_8) - min(Optimal_Values_q_pi), 0]

# %%
#Nf = 7 (Δ = 0.9)

#q = 0
Energies_8_Layer_q0 = np.loadtxt(r'/mnt/c/Users/Saavanth Velury/Desktop/Quasiparticle VQE/16 Qubit Data (Final)/Delta = nine-tenths/Nf = 7/q = 0/8 Layers/16_Qubit_XXZ_8_Layer_HVA_Optimal_Values_BOBYQA_7_Filled_States_Periodic_BC_PH_State_8_Three_Parameters_Delta_0.9.txt')
Optimal_Values_8_Layer_q0 = min(Energies_8_Layer_q0)

#q = pi/8
Energies_8_Layer_q_pi_over_8 = np.loadtxt(r'/mnt/c/Users/Saavanth Velury/Desktop/Quasiparticle VQE/16 Qubit Data (Final)/Delta = nine-tenths/Nf = 7/q = pi over 8/8 Layers/16_Qubit_XXZ_8_Layer_HVA_Optimal_Values_BOBYQA_7_Filled_States_Periodic_BC_PH_State_Three_Parameters_Delta_0.9.txt')
Optimal_Values_8_Layer_q_pi_over_8 = min(Energies_8_Layer_q_pi_over_8)

#q = pi/4
Energies_8_Layer_q_pi_over_4 = np.loadtxt(r'/mnt/c/Users/Saavanth Velury/Desktop/Quasiparticle VQE/16 Qubit Data (Final)/Delta = nine-tenths/Nf = 7/q = pi over 4/8 Layers/16_Qubit_XXZ_8_Layer_HVA_Optimal_Values_BOBYQA_7_Filled_States_Periodic_BC_PH_State_2_Three_Parameters_Delta_0.9.txt')
Optimal_Values_8_Layer_q_pi_over_4 = min(Energies_8_Layer_q_pi_over_4)

#q = 3pi/8
Energies_8_Layer_q_3pi_over_8 = np.loadtxt(r'/mnt/c/Users/Saavanth Velury/Desktop/Quasiparticle VQE/16 Qubit Data (Final)/Delta = nine-tenths/Nf = 7/q = 3pi over 8/8 Layers/16_Qubit_XXZ_8_Layer_HVA_Optimal_Values_BOBYQA_7_Filled_States_Periodic_BC_PH_State_3_Three_Parameters_Delta_0.9.txt')
Optimal_Values_8_Layer_q_3pi_over_8 = min(Energies_8_Layer_q_3pi_over_8)

#q = pi/2
Energies_8_Layer_q_pi_over_2 = np.loadtxt(r'/mnt/c/Users/Saavanth Velury/Desktop/Quasiparticle VQE/16 Qubit Data (Final)/Delta = nine-tenths/Nf = 7/q = pi over 2/8 Layers/16_Qubit_XXZ_8_Layer_HVA_Optimal_Values_BOBYQA_7_Filled_States_Periodic_BC_PH_State_4_Three_Parameters_Delta_0.9.txt')
Optimal_Values_8_Layer_q_pi_over_2 = min(Energies_8_Layer_q_pi_over_2)

#q = 5pi/8
Energies_8_Layer_q_5pi_over_8 = np.loadtxt(r'/mnt/c/Users/Saavanth Velury/Desktop/Quasiparticle VQE/16 Qubit Data (Final)/Delta = nine-tenths/Nf = 7/q = 5pi over 8/8 Layers/16_Qubit_XXZ_8_Layer_HVA_Optimal_Values_BOBYQA_7_Filled_States_Periodic_BC_PH_State_5_Three_Parameters_Delta_0.9.txt')
Optimal_Values_8_Layer_q_5pi_over_8 = min(Energies_8_Layer_q_5pi_over_8)

#q = 3pi/4
Energies_8_Layer_q_3pi_over_4 = np.loadtxt(r'/mnt/c/Users/Saavanth Velury/Desktop/Quasiparticle VQE/16 Qubit Data (Final)/Delta = nine-tenths/Nf = 7/q = 3pi over 4/8 Layers/16_Qubit_XXZ_8_Layer_HVA_Optimal_Values_BOBYQA_7_Filled_States_Periodic_BC_PH_State_6_Three_Parameters_Delta_0.9.txt')
Optimal_Values_8_Layer_q_3pi_over_4 = min(Energies_8_Layer_q_3pi_over_4)

#q = 7pi/8
Energies_8_Layer_q_7pi_over_8 = np.loadtxt(r'/mnt/c/Users/Saavanth Velury/Desktop/Quasiparticle VQE/16 Qubit Data (Final)/Delta = nine-tenths/Nf = 7/q = 7pi over 8/8 Layers/16_Qubit_XXZ_8_Layer_HVA_Optimal_Values_BOBYQA_7_Filled_States_Periodic_BC_PH_State_7_Three_Parameters_Delta_0.9.txt')
Optimal_Values_8_Layer_q_7pi_over_8 = min(Energies_8_Layer_q_7pi_over_8)

#q = pi
Energies_8_Layer_q_pi = np.loadtxt(r'/mnt/c/Users/Saavanth Velury/Desktop/Quasiparticle VQE/16 Qubit Data (Final)/Delta = nine-tenths/Nf = 7/q = pi/8 Layers/16_Qubit_XXZ_8_Layer_HVA_Optimal_Values_BOBYQA_7_Filled_States_Periodic_Boundary_Conditions_Three_Parameters_Delta_0.9.txt')
Optimal_Values_8_Layer_q_pi = min(Energies_8_Layer_q_pi)

# %%
ED_Values_Delta_Nine_Tenths = [0, -24.408674+26.645038, -22.559145+26.645038, -21.396668+26.645038, -21.102838+26.645038, -21.725242+26.645038, -23.171830+26.645038, -25.226388+26.645038, -23.591005+26.645038, -25.226388+26.645038, -23.171830+26.645038, -21.725242+26.645038, -21.102838+26.645038, -21.396668+26.645038, -22.559145+26.645038, -24.408674+26.645038, 0]

# %%
VQE_Values_Delta_Nine_Tenths = [0, -24.32101388-Optimal_Values_8_Layer_q_pi, -22.44073257-Optimal_Values_8_Layer_q_pi, -21.20877297-Optimal_Values_8_Layer_q_pi, -20.93690881-Optimal_Values_8_Layer_q_pi, -21.54348280-Optimal_Values_8_Layer_q_pi, -23.06286219-Optimal_Values_8_Layer_q_pi, -25.13497821-Optimal_Values_8_Layer_q_pi, Optimal_Values_8_Layer_q0-Optimal_Values_8_Layer_q_pi, Optimal_Values_8_Layer_q_pi_over_8-Optimal_Values_8_Layer_q_pi, Optimal_Values_8_Layer_q_pi_over_4-Optimal_Values_8_Layer_q_pi, Optimal_Values_8_Layer_q_3pi_over_8-Optimal_Values_8_Layer_q_pi, Optimal_Values_8_Layer_q_pi_over_2-Optimal_Values_8_Layer_q_pi, Optimal_Values_8_Layer_q_5pi_over_8-Optimal_Values_8_Layer_q_pi, Optimal_Values_8_Layer_q_3pi_over_4-Optimal_Values_8_Layer_q_pi, Optimal_Values_8_Layer_q_7pi_over_8-Optimal_Values_8_Layer_q_pi, 0]

# %%
# Momentum points
q = np.array([-np.pi, -7*np.pi/8, -3*np.pi/4, -5*np.pi/8, -np.pi/2, -3*np.pi/8, -np.pi/4, -np.pi/8, 0, np.pi/8, np.pi/4, 3*np.pi/8, np.pi/2, 5*np.pi/8, 3*np.pi/4, 7*np.pi/8, np.pi])

# Ground‐state energies
E0_ED_0p1  = -20.730872
E0_VQE_0p1 = -20.726121
E0_ED_0p5  = -23.491255
E0_VQE_0p5 = -23.456225
E0_ED_0p9 = -26.645038
E0_VQE_0p9 = -26.585088

# Dispersion *relative* to the ground state (so first entry is 0 offset)
disp_ED_0p1  = np.array(ED_Values_Delta_One_Tenth)
disp_VQE_0p1 = np.array(VQE_Values_Delta_One_Tenth)
disp_ED_0p5  = np.array(ED_Values_Delta_One_Half)
disp_VQE_0p5 = np.array(VQE_Values_Delta_One_Half)
disp_ED_0p9 = np.array(ED_Values_Delta_Nine_Tenths)
disp_VQE_0p9 = np.array(VQE_Values_Delta_Nine_Tenths)

# Build *actual* energy arrays by adding back the ground‐state
E_ED_0p1   = E0_ED_0p1  + disp_ED_0p1
E_VQE_0p1  = E0_VQE_0p1 + disp_VQE_0p1
E_ED_0p5   = E0_ED_0p5  + disp_ED_0p5
E_VQE_0p5  = E0_VQE_0p5 + disp_VQE_0p5
E_ED_0p9   = E0_ED_0p9  + disp_ED_0p9
E_VQE_0p9  = E0_VQE_0p9 + disp_VQE_0p9

# --- Plotting ---
fig, ax = plt.subplots(figsize=(12,12))

c_ED_0p1   = "#0000FF"   
c_VQE_0p1  = "#FF0000"   
c_ED_0p5   = "#00CC00"   
c_VQE_0p5  = "#800080"  
c_ED_0p9   = "#FFA500"
c_VQE_0p9  = "#00FFFF"

bg = ax.patch.get_facecolor()

major_q = np.array([-np.pi, -3*np.pi/4, -np.pi/2, -np.pi/4, 0, np.pi/4,  np.pi/2,  3*np.pi/4,  np.pi])
# ED (filled markers)
ax.plot(q, E_ED_0p1, linestyle='-', linewidth=4, color=c_ED_0p1, alpha=0.25, zorder=1)
ax.scatter(q, E_ED_0p1, s=15**2, facecolor=c_ED_0p1, edgecolor=c_ED_0p1, linewidth=1, alpha=1, zorder=4, label=r'ED, $\Delta=0.1$')
ax.plot(q, E_ED_0p5, linestyle='-', linewidth=4, color=c_ED_0p5, alpha=0.25, zorder=1)
ax.scatter(q, E_ED_0p5, s=15**2, facecolor=c_ED_0p5, edgecolor=c_ED_0p5, linewidth=1, alpha=1, zorder=4, label=r'ED, $\Delta=0.5$')
ax.plot(q, E_ED_0p9, linestyle='-', linewidth=4, color=c_ED_0p9, alpha=0.25, zorder=1)
ax.scatter(q, E_ED_0p9, s=15**2, facecolor=c_ED_0p9, edgecolor=c_ED_0p9, linewidth=1, alpha=1, zorder=4, label=r'ED, $\Delta=0.9$')

# VQE (open markers)
ax.scatter(q, E_VQE_0p1, s=30**2, facecolor=bg, edgecolor='none', zorder=2)
ax.scatter(q, E_VQE_0p1, s=30**2, facecolor='none', edgecolor=c_VQE_0p1, linewidth=2, zorder=3, label=r'VQE, $\Delta=0.1$')
ax.scatter(q, E_VQE_0p5, s=30**2, facecolor=bg, edgecolor='none', zorder=2)
ax.scatter(q, E_VQE_0p5, s=30**2, facecolor='none', edgecolor=c_VQE_0p5, linewidth=2, zorder=3, label=r'VQE, $\Delta=0.5$')
ax.scatter(q, E_VQE_0p9, s=30**2, facecolor=bg, edgecolor='none', zorder=2)
ax.scatter(q, E_VQE_0p9, s=30**2, facecolor='none', edgecolor=c_VQE_0p9, linewidth=2, zorder=3, label=r'VQE, $\Delta=0.9$')

# Axis formatting
ax.set_xlabel(r'$q$', fontsize=30, fontweight='bold')
ax.set_ylabel(r'$E(q)$', fontsize=30, fontweight='bold')       
ax.set_xticks(major_q)
ax.set_xticklabels([r'$-\pi$', r'$-\tfrac{3\pi}{4}$', r'$-\tfrac{\pi}{2}$', r'$-\tfrac{\pi}{4}$', r'$0$', r'$\tfrac{\pi}{4}$', r'$\tfrac{\pi}{2}$', r'$\tfrac{3\pi}{4}$', r'$\pi$'], fontsize=30, fontweight='bold')
ax.set_yticklabels(ax.get_yticks(), fontsize=30, fontweight='bold')

# Inset textbox
text_props = dict(boxstyle='round', facecolor='white', alpha=0.8, pad=0.3)
ax.text(0.645, 0.975,
        r'$N_{F}=7\;(S_{z}=-1)$',
        transform=ax.transAxes,
        ha='right', va='top',
        fontsize=28.5,
        fontweight='bold',
        bbox=text_props)

#leg = ax.legend(frameon=True, framealpha=1, fancybox = True)
#for text in leg.get_texts():
    #text.set_fontweight('bold')
    #text.set_fontsize(30)

#frame = leg.get_frame()
#frame.set_edgecolor('black')
#frame.set_linewidth(1.2) 
#frame.set_facecolor('white')

plt.tight_layout()
#plt.savefig('XXZ_Dispersion_16_Qubit_Not_Half_Filling.pdf', dpi=300, bbox_inches='tight')
plt.show()

# %%
#Save Arrays
np.savetxt('ED_Values_7_Filled_States_Delta_One_Tenth_16_Qubit.txt', ED_Values_Delta_One_Tenth)
np.savetxt('VQE_Values_7_Filled_States_Delta_One_Tenth_16_Qubit.txt', VQE_Values_Delta_One_Tenth)
np.savetxt('ED_Values_7_Filled_States_Delta_One_Half_16_Qubit.txt', ED_Values_Delta_One_Half)
np.savetxt('VQE_Values_7_Filled_States_Delta_One_Half_16_Qubit.txt', VQE_Values_Delta_One_Half)
np.savetxt('ED_Values_7_Filled_States_Delta_Nine_Tenths_16_Qubit.txt', ED_Values_Delta_Nine_Tenths)
np.savetxt('VQE_Values_7_Filled_States_Delta_Nine_Tenths_16_Qubit.txt', VQE_Values_Delta_Nine_Tenths)
