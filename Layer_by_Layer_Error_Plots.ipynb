# %%
import numpy as np
from matplotlib import pyplot as plt
import matplotlib as mpl
from matplotlib.ticker import LogFormatterMathtext
from matplotlib.lines import Line2D
plt.rcParams.update({
    "text.usetex": True,
    "text.latex.preamble": r"\usepackage{amsmath}",
    "font.family": "serif",
    "font.serif": ["Computer Modern"],
    "pdf.fonttype": 42,
    "ps.fonttype": 42,
    "font.size": 30,
    'font.weight': 'bold',
    'axes.titleweight': 'bold',
    'axes.labelweight': 'bold',
    'xtick.major.width': 5,
    'ytick.major.width': 5,
    'xtick.minor.width': 5,
    'ytick.minor.width': 5,
    'xtick.major.size': 25,
    'ytick.major.size': 25,
    'xtick.minor.size': 15,
    'ytick.minor.size': 15,
    'axes.linewidth': 5
})

# %%
#Load Data

#8 Qubit Energy Errors (4 Filled States)
Energy_Errors_8_Qubit_4_Filled_States_q_0 = np.loadtxt(r'/mnt/c/Users/Saavanth Velury/Desktop/Quasiparticle VQE/8 Qubit Data (Error Data)/Energy_Errors_8_Qubit_4_Filled_States_Delta_0.5_Layer_by_Layer_q=0.txt')
Energy_Errors_8_Qubit_4_Filled_States_q_pi_over_4 = np.loadtxt(r'/mnt/c/Users/Saavanth Velury/Desktop/Quasiparticle VQE/8 Qubit Data (Error Data)/Energy_Errors_8_Qubit_4_Filled_States_Delta_0.5_Layer_by_Layer_q=pi_over_4.txt')
Energy_Errors_8_Qubit_4_Filled_States_q_pi_over_2 = np.loadtxt(r'/mnt/c/Users/Saavanth Velury/Desktop/Quasiparticle VQE/8 Qubit Data (Error Data)/Energy_Errors_8_Qubit_4_Filled_States_Delta_0.5_Layer_by_Layer_q=pi_over_2.txt')
Energy_Errors_8_Qubit_4_Filled_States_q_3pi_over_4 = np.loadtxt(r'/mnt/c/Users/Saavanth Velury/Desktop/Quasiparticle VQE/8 Qubit Data (Error Data)/Energy_Errors_8_Qubit_4_Filled_States_Delta_0.5_Layer_by_Layer_q=3pi_over_4.txt')
Energy_Errors_8_Qubit_4_Filled_States_q_pi = np.loadtxt(r'/mnt/c/Users/Saavanth Velury/Desktop/Quasiparticle VQE/8 Qubit Data (Error Data)/Energy_Errors_8_Qubit_4_Filled_States_Delta_0.5_Layer_by_Layer_q=pi.txt')

#8 Qubit Energy Errors (3 Filled States)
Energy_Errors_8_Qubit_3_Filled_States_q_0 = np.loadtxt(r'/mnt/c/Users/Saavanth Velury/Desktop/Quasiparticle VQE/8 Qubit Data (Error Data)/Energy_Errors_8_Qubit_3_Filled_States_Delta_0.5_Layer_by_Layer_q=0.txt')
Energy_Errors_8_Qubit_3_Filled_States_q_pi_over_4 = np.loadtxt(r'/mnt/c/Users/Saavanth Velury/Desktop/Quasiparticle VQE/8 Qubit Data (Error Data)/Energy_Errors_8_Qubit_3_Filled_States_Delta_0.5_Layer_by_Layer_q=pi_over_4.txt')
Energy_Errors_8_Qubit_3_Filled_States_q_pi_over_2 = np.loadtxt(r'/mnt/c/Users/Saavanth Velury/Desktop/Quasiparticle VQE/8 Qubit Data (Error Data)/Energy_Errors_8_Qubit_3_Filled_States_Delta_0.5_Layer_by_Layer_q=pi_over_2.txt')
Energy_Errors_8_Qubit_3_Filled_States_q_3pi_over_4 = np.loadtxt(r'/mnt/c/Users/Saavanth Velury/Desktop/Quasiparticle VQE/8 Qubit Data (Error Data)/Energy_Errors_8_Qubit_3_Filled_States_Delta_0.5_Layer_by_Layer_q=3pi_over_4.txt')
Energy_Errors_8_Qubit_3_Filled_States_q_pi = np.loadtxt(r'/mnt/c/Users/Saavanth Velury/Desktop/Quasiparticle VQE/8 Qubit Data (Error Data)/Energy_Errors_8_Qubit_3_Filled_States_Delta_0.5_Layer_by_Layer_q=pi.txt')

#16 Qubit Energy Errors (8 Filled States)
Energy_Errors_16_Qubit_8_Filled_States_q_0 = np.loadtxt(r'/mnt/c/Users/Saavanth Velury/Desktop/Quasiparticle VQE/16 Qubit Data (Error Data)/Energy_Errors_16_Qubit_8_Filled_States_Delta_0.5_Layer_by_Layer_q=0.txt')
Energy_Errors_16_Qubit_8_Filled_States_q_pi_over_8 = np.loadtxt(r'/mnt/c/Users/Saavanth Velury/Desktop/Quasiparticle VQE/16 Qubit Data (Error Data)/Energy_Errors_16_Qubit_8_Filled_States_Delta_0.5_Layer_by_Layer_q=pi_over_8.txt')
Energy_Errors_16_Qubit_8_Filled_States_q_pi_over_4 = np.loadtxt(r'/mnt/c/Users/Saavanth Velury/Desktop/Quasiparticle VQE/16 Qubit Data (Error Data)/Energy_Errors_16_Qubit_8_Filled_States_Delta_0.5_Layer_by_Layer_q=pi_over_4.txt')
Energy_Errors_16_Qubit_8_Filled_States_q_3pi_over_8 = np.loadtxt(r'/mnt/c/Users/Saavanth Velury/Desktop/Quasiparticle VQE/16 Qubit Data (Error Data)/Energy_Errors_16_Qubit_8_Filled_States_Delta_0.5_Layer_by_Layer_q=3pi_over_8.txt')
Energy_Errors_16_Qubit_8_Filled_States_q_pi_over_2 = np.loadtxt(r'/mnt/c/Users/Saavanth Velury/Desktop/Quasiparticle VQE/16 Qubit Data (Error Data)/Energy_Errors_16_Qubit_8_Filled_States_Delta_0.5_Layer_by_Layer_q=pi_over_2.txt')
Energy_Errors_16_Qubit_8_Filled_States_q_5pi_over_8 = np.loadtxt(r'/mnt/c/Users/Saavanth Velury/Desktop/Quasiparticle VQE/16 Qubit Data (Error Data)/Energy_Errors_16_Qubit_8_Filled_States_Delta_0.5_Layer_by_Layer_q=5pi_over_8.txt')
Energy_Errors_16_Qubit_8_Filled_States_q_3pi_over_4 = np.loadtxt(r'/mnt/c/Users/Saavanth Velury/Desktop/Quasiparticle VQE/16 Qubit Data (Error Data)/Energy_Errors_16_Qubit_8_Filled_States_Delta_0.5_Layer_by_Layer_q=3pi_over_4.txt')
Energy_Errors_16_Qubit_8_Filled_States_q_7pi_over_8 = np.loadtxt(r'/mnt/c/Users/Saavanth Velury/Desktop/Quasiparticle VQE/16 Qubit Data (Error Data)/Energy_Errors_16_Qubit_8_Filled_States_Delta_0.5_Layer_by_Layer_q=7pi_over_8.txt')
Energy_Errors_16_Qubit_8_Filled_States_q_pi = np.loadtxt(r'/mnt/c/Users/Saavanth Velury/Desktop/Quasiparticle VQE/16 Qubit Data (Error Data)/Energy_Errors_16_Qubit_8_Filled_States_Delta_0.5_Layer_by_Layer_q=pi.txt')

#16 Qubit Energy Errors (7 Filled States)
Energy_Errors_16_Qubit_7_Filled_States_q_0 = np.loadtxt(r'/mnt/c/Users/Saavanth Velury/Desktop/Quasiparticle VQE/16 Qubit Data (Error Data)/Energy_Errors_16_Qubit_7_Filled_States_Delta_0.5_Layer_by_Layer_q=0.txt')
Energy_Errors_16_Qubit_7_Filled_States_q_pi_over_8 = np.loadtxt(r'/mnt/c/Users/Saavanth Velury/Desktop/Quasiparticle VQE/16 Qubit Data (Error Data)/Energy_Errors_16_Qubit_7_Filled_States_Delta_0.5_Layer_by_Layer_q=pi_over_8.txt')
Energy_Errors_16_Qubit_7_Filled_States_q_pi_over_4 = np.loadtxt(r'/mnt/c/Users/Saavanth Velury/Desktop/Quasiparticle VQE/16 Qubit Data (Error Data)/Energy_Errors_16_Qubit_7_Filled_States_Delta_0.5_Layer_by_Layer_q=pi_over_4.txt')
Energy_Errors_16_Qubit_7_Filled_States_q_3pi_over_8 = np.loadtxt(r'/mnt/c/Users/Saavanth Velury/Desktop/Quasiparticle VQE/16 Qubit Data (Error Data)/Energy_Errors_16_Qubit_7_Filled_States_Delta_0.5_Layer_by_Layer_q=3pi_over_8.txt')
Energy_Errors_16_Qubit_7_Filled_States_q_pi_over_2 = np.loadtxt(r'/mnt/c/Users/Saavanth Velury/Desktop/Quasiparticle VQE/16 Qubit Data (Error Data)/Energy_Errors_16_Qubit_7_Filled_States_Delta_0.5_Layer_by_Layer_q=pi_over_2.txt')
Energy_Errors_16_Qubit_7_Filled_States_q_5pi_over_8 = np.loadtxt(r'/mnt/c/Users/Saavanth Velury/Desktop/Quasiparticle VQE/16 Qubit Data (Error Data)/Energy_Errors_16_Qubit_7_Filled_States_Delta_0.5_Layer_by_Layer_q=5pi_over_8.txt')
Energy_Errors_16_Qubit_7_Filled_States_q_3pi_over_4 = np.loadtxt(r'/mnt/c/Users/Saavanth Velury/Desktop/Quasiparticle VQE/16 Qubit Data (Error Data)/Energy_Errors_16_Qubit_7_Filled_States_Delta_0.5_Layer_by_Layer_q=3pi_over_4.txt')
Energy_Errors_16_Qubit_7_Filled_States_q_7pi_over_8 = np.loadtxt(r'/mnt/c/Users/Saavanth Velury/Desktop/Quasiparticle VQE/16 Qubit Data (Error Data)/Energy_Errors_16_Qubit_7_Filled_States_Delta_0.5_Layer_by_Layer_q=7pi_over_8.txt')
Energy_Errors_16_Qubit_7_Filled_States_q_pi = np.loadtxt(r'/mnt/c/Users/Saavanth Velury/Desktop/Quasiparticle VQE/16 Qubit Data (Error Data)/Energy_Errors_16_Qubit_7_Filled_States_Delta_0.5_Layer_by_Layer_q=pi.txt')

# %%
#Load Data

#8 Qubit Fidelity Errors (4 Filled States)
Fidelity_Errors_8_Qubit_4_Filled_States_q_0 = np.loadtxt(r'/mnt/c/Users/Saavanth Velury/Desktop/Quasiparticle VQE/8 Qubit Data (Error Data)/Fidelity_Errors_8_Qubit_4_Filled_States_Delta_0.5_Layer_by_Layer_q=0.txt')
Fidelity_Errors_8_Qubit_4_Filled_States_q_pi_over_4 = np.loadtxt(r'/mnt/c/Users/Saavanth Velury/Desktop/Quasiparticle VQE/8 Qubit Data (Error Data)/Fidelity_Errors_8_Qubit_4_Filled_States_Delta_0.5_Layer_by_Layer_q=pi_over_4.txt')
Fidelity_Errors_8_Qubit_4_Filled_States_q_pi_over_2 = np.loadtxt(r'/mnt/c/Users/Saavanth Velury/Desktop/Quasiparticle VQE/8 Qubit Data (Error Data)/Fidelity_Errors_8_Qubit_4_Filled_States_Delta_0.5_Layer_by_Layer_q=pi_over_2.txt')
Fidelity_Errors_8_Qubit_4_Filled_States_q_3pi_over_4 = np.loadtxt(r'/mnt/c/Users/Saavanth Velury/Desktop/Quasiparticle VQE/8 Qubit Data (Error Data)/Fidelity_Errors_8_Qubit_4_Filled_States_Delta_0.5_Layer_by_Layer_q=3pi_over_4.txt')
Fidelity_Errors_8_Qubit_4_Filled_States_q_pi = np.loadtxt(r'/mnt/c/Users/Saavanth Velury/Desktop/Quasiparticle VQE/8 Qubit Data (Error Data)/Fidelity_Errors_8_Qubit_4_Filled_States_Delta_0.5_Layer_by_Layer_q=pi.txt')

#8 Qubit Fidelity Errors (3 Filled States)
Fidelity_Errors_8_Qubit_3_Filled_States_q_0 = np.loadtxt(r'/mnt/c/Users/Saavanth Velury/Desktop/Quasiparticle VQE/8 Qubit Data (Error Data)/Fidelity_Errors_8_Qubit_3_Filled_States_Delta_0.5_Layer_by_Layer_q=0.txt')
Fidelity_Errors_8_Qubit_3_Filled_States_q_pi_over_4 = np.loadtxt(r'/mnt/c/Users/Saavanth Velury/Desktop/Quasiparticle VQE/8 Qubit Data (Error Data)/Fidelity_Errors_8_Qubit_3_Filled_States_Delta_0.5_Layer_by_Layer_q=pi_over_4.txt')
Fidelity_Errors_8_Qubit_3_Filled_States_q_pi_over_2 = np.loadtxt(r'/mnt/c/Users/Saavanth Velury/Desktop/Quasiparticle VQE/8 Qubit Data (Error Data)/Fidelity_Errors_8_Qubit_3_Filled_States_Delta_0.5_Layer_by_Layer_q=pi_over_2.txt')
Fidelity_Errors_8_Qubit_3_Filled_States_q_3pi_over_4 = np.loadtxt(r'/mnt/c/Users/Saavanth Velury/Desktop/Quasiparticle VQE/8 Qubit Data (Error Data)/Fidelity_Errors_8_Qubit_3_Filled_States_Delta_0.5_Layer_by_Layer_q=3pi_over_4.txt')
Fidelity_Errors_8_Qubit_3_Filled_States_q_pi = np.loadtxt(r'/mnt/c/Users/Saavanth Velury/Desktop/Quasiparticle VQE/8 Qubit Data (Error Data)/Fidelity_Errors_8_Qubit_3_Filled_States_Delta_0.5_Layer_by_Layer_q=pi.txt')

#16 Qubit Fidelity Errors (8 Filled States)
Fidelity_Errors_16_Qubit_8_Filled_States_q_0 = np.loadtxt(r'/mnt/c/Users/Saavanth Velury/Desktop/Quasiparticle VQE/16 Qubit Data (Error Data)/Fidelity_Errors_16_Qubit_8_Filled_States_Delta_0.5_Layer_by_Layer_q=0.txt')
Fidelity_Errors_16_Qubit_8_Filled_States_q_pi_over_8 = np.loadtxt(r'/mnt/c/Users/Saavanth Velury/Desktop/Quasiparticle VQE/16 Qubit Data (Error Data)/Fidelity_Errors_16_Qubit_8_Filled_States_Delta_0.5_Layer_by_Layer_q=pi_over_8.txt')
Fidelity_Errors_16_Qubit_8_Filled_States_q_pi_over_4 = np.loadtxt(r'/mnt/c/Users/Saavanth Velury/Desktop/Quasiparticle VQE/16 Qubit Data (Error Data)/Fidelity_Errors_16_Qubit_8_Filled_States_Delta_0.5_Layer_by_Layer_q=pi_over_4.txt')
Fidelity_Errors_16_Qubit_8_Filled_States_q_3pi_over_8 = np.loadtxt(r'/mnt/c/Users/Saavanth Velury/Desktop/Quasiparticle VQE/16 Qubit Data (Error Data)/Fidelity_Errors_16_Qubit_8_Filled_States_Delta_0.5_Layer_by_Layer_q=3pi_over_8.txt')
Fidelity_Errors_16_Qubit_8_Filled_States_q_pi_over_2 = np.loadtxt(r'/mnt/c/Users/Saavanth Velury/Desktop/Quasiparticle VQE/16 Qubit Data (Error Data)/Fidelity_Errors_16_Qubit_8_Filled_States_Delta_0.5_Layer_by_Layer_q=pi_over_2.txt')
Fidelity_Errors_16_Qubit_8_Filled_States_q_5pi_over_8 = np.loadtxt(r'/mnt/c/Users/Saavanth Velury/Desktop/Quasiparticle VQE/16 Qubit Data (Error Data)/Fidelity_Errors_16_Qubit_8_Filled_States_Delta_0.5_Layer_by_Layer_q=5pi_over_8.txt')
Fidelity_Errors_16_Qubit_8_Filled_States_q_3pi_over_4 = np.loadtxt(r'/mnt/c/Users/Saavanth Velury/Desktop/Quasiparticle VQE/16 Qubit Data (Error Data)/Fidelity_Errors_16_Qubit_8_Filled_States_Delta_0.5_Layer_by_Layer_q=3pi_over_4.txt')
Fidelity_Errors_16_Qubit_8_Filled_States_q_7pi_over_8 = np.loadtxt(r'/mnt/c/Users/Saavanth Velury/Desktop/Quasiparticle VQE/16 Qubit Data (Error Data)/Fidelity_Errors_16_Qubit_8_Filled_States_Delta_0.5_Layer_by_Layer_q=7pi_over_8.txt')
Fidelity_Errors_16_Qubit_8_Filled_States_q_pi = np.loadtxt(r'/mnt/c/Users/Saavanth Velury/Desktop/Quasiparticle VQE/16 Qubit Data (Error Data)/Fidelity_Errors_16_Qubit_8_Filled_States_Delta_0.5_Layer_by_Layer_q=pi.txt')

#16 Qubit Fidelity Errors (7 Filled States)
Fidelity_Errors_16_Qubit_7_Filled_States_q_0 = np.loadtxt(r'/mnt/c/Users/Saavanth Velury/Desktop/Quasiparticle VQE/16 Qubit Data (Error Data)/Fidelity_Errors_16_Qubit_7_Filled_States_Delta_0.5_Layer_by_Layer_q=0.txt')
Fidelity_Errors_16_Qubit_7_Filled_States_q_pi_over_8 = np.loadtxt(r'/mnt/c/Users/Saavanth Velury/Desktop/Quasiparticle VQE/16 Qubit Data (Error Data)/Fidelity_Errors_16_Qubit_7_Filled_States_Delta_0.5_Layer_by_Layer_q=pi_over_8.txt')
Fidelity_Errors_16_Qubit_7_Filled_States_q_pi_over_4 = np.loadtxt(r'/mnt/c/Users/Saavanth Velury/Desktop/Quasiparticle VQE/16 Qubit Data (Error Data)/Fidelity_Errors_16_Qubit_7_Filled_States_Delta_0.5_Layer_by_Layer_q=pi_over_4.txt')
Fidelity_Errors_16_Qubit_7_Filled_States_q_3pi_over_8 = np.loadtxt(r'/mnt/c/Users/Saavanth Velury/Desktop/Quasiparticle VQE/16 Qubit Data (Error Data)/Fidelity_Errors_16_Qubit_7_Filled_States_Delta_0.5_Layer_by_Layer_q=3pi_over_8.txt')
Fidelity_Errors_16_Qubit_7_Filled_States_q_pi_over_2 = np.loadtxt(r'/mnt/c/Users/Saavanth Velury/Desktop/Quasiparticle VQE/16 Qubit Data (Error Data)/Fidelity_Errors_16_Qubit_7_Filled_States_Delta_0.5_Layer_by_Layer_q=pi_over_2.txt')
Fidelity_Errors_16_Qubit_7_Filled_States_q_5pi_over_8 = np.loadtxt(r'/mnt/c/Users/Saavanth Velury/Desktop/Quasiparticle VQE/16 Qubit Data (Error Data)/Fidelity_Errors_16_Qubit_7_Filled_States_Delta_0.5_Layer_by_Layer_q=5pi_over_8.txt')
Fidelity_Errors_16_Qubit_7_Filled_States_q_3pi_over_4 = np.loadtxt(r'/mnt/c/Users/Saavanth Velury/Desktop/Quasiparticle VQE/16 Qubit Data (Error Data)/Fidelity_Errors_16_Qubit_7_Filled_States_Delta_0.5_Layer_by_Layer_q=3pi_over_4.txt')
Fidelity_Errors_16_Qubit_7_Filled_States_q_7pi_over_8 = np.loadtxt(r'/mnt/c/Users/Saavanth Velury/Desktop/Quasiparticle VQE/16 Qubit Data (Error Data)/Fidelity_Errors_16_Qubit_7_Filled_States_Delta_0.5_Layer_by_Layer_q=7pi_over_8.txt')
Fidelity_Errors_16_Qubit_7_Filled_States_q_pi = np.loadtxt(r'/mnt/c/Users/Saavanth Velury/Desktop/Quasiparticle VQE/16 Qubit Data (Error Data)/Fidelity_Errors_16_Qubit_7_Filled_States_Delta_0.5_Layer_by_Layer_q=pi.txt')

# %%
# ─── USER‐TWEAKABLE SPACING, SIZE, & PADDING ─────────────────────────────────
fig_width, fig_height = 30, 18

# carve out 65% of the width for the 2×2 axes, leaving 35% for legends
left, right, bottom, top = 0.05, 0.65, 0.05, 0.95

# extra horizontal & vertical padding between panels
wspace, hspace = 0.3, 0.5

# panel‐label position (in axes fraction coords)
panel_label_pos = dict(
    x = -0.2,   # negative moves left of axes; try -0.10…-0.20
    y = 1.10     # >1 moves above title; try 1.05…1.15
)

# legend internal spacing & border
legend_spacing = dict(
    labelspacing  = 0.5,  # vertical space between entries
    borderpad     = 0.5   # padding between text block & frame
)

# legend handle/text padding and border thickness
legend_handletextpad = 0.5  # space between marker and text
legend_border_width   = 5.0  # linewidth of the legend frame
# ─────────────────────────────────────────────────────────────────────────────

# marker & legend style
marker_size        = 25
legend_fs          = 75
legend_markerscale = 1.5
panel_label_fs     = 90
tick_fs            = 50
title_fs           = 60
label_fs           = 50

legend_anchor = (1.02, 0.5)
legend_loc    = 'upper left'

legend_kwargs = dict(
    fontsize       = legend_fs,
    markerscale    = legend_markerscale,
    frameon        = True,
    edgecolor      = 'black',
    facecolor      = 'white',
    handletextpad  = legend_handletextpad,
    labelspacing   = legend_spacing['labelspacing'],
    borderpad      = legend_spacing['borderpad']
)

# data placeholders (replace with your actual arrays)
layers_8  = np.arange(1, 9)
layers_16 = np.arange(1, 6)

EE_8_4_q0    = Energy_Errors_8_Qubit_4_Filled_States_q_0
EE_8_4_qpi4  = Energy_Errors_8_Qubit_4_Filled_States_q_pi_over_4
EE_8_4_qpi2  = Energy_Errors_8_Qubit_4_Filled_States_q_pi_over_2

EE_8_3_qpi   = Energy_Errors_8_Qubit_3_Filled_States_q_pi
EE_8_3_qpi4  = Energy_Errors_8_Qubit_3_Filled_States_q_pi_over_4
EE_8_3_qpi2  = Energy_Errors_8_Qubit_3_Filled_States_q_pi_over_2

EE_16_8_q0    = Energy_Errors_16_Qubit_8_Filled_States_q_0
EE_16_8_qpi8  = Energy_Errors_16_Qubit_8_Filled_States_q_pi_over_8
EE_16_8_qpi4  = Energy_Errors_16_Qubit_8_Filled_States_q_pi_over_4
EE_16_8_q3pi8 = Energy_Errors_16_Qubit_8_Filled_States_q_3pi_over_8
EE_16_8_qpi2  = Energy_Errors_16_Qubit_8_Filled_States_q_pi_over_2

EE_16_7_qpi   = Energy_Errors_16_Qubit_7_Filled_States_q_pi
EE_16_7_qpi8  = Energy_Errors_16_Qubit_7_Filled_States_q_pi_over_8
EE_16_7_qpi4  = Energy_Errors_16_Qubit_7_Filled_States_q_pi_over_4
EE_16_7_q3pi8 = Energy_Errors_16_Qubit_7_Filled_States_q_3pi_over_8
EE_16_7_qpi2  = Energy_Errors_16_Qubit_7_Filled_States_q_pi_over_2

marker_kwargs      = dict(markersize=marker_size, linestyle='none')
panel_label_kwargs = dict(fontsize=panel_label_fs, fontweight='bold')

def style_axes(ax, title):
    ax.set_yscale('log')
    ax.yaxis.set_major_formatter(LogFormatterMathtext())
    ax.tick_params(labelsize=tick_fs)
    ax.set_title(title, fontsize=title_fs, pad=20)
    lbl = rf'\textbf{{({style_axes.next_label})}}'
    ax.text(
        panel_label_pos['x'], panel_label_pos['y'], lbl,
        transform=ax.transAxes,
        ha='left', va='bottom',
        **panel_label_kwargs
    )
    style_axes.next_label = chr(ord(style_axes.next_label) + 1)

style_axes.next_label = 'a'

fig, axes = plt.subplots(2, 2, figsize=(fig_width, fig_height))

# ── Panel (a) ────────────────────────────────────────────────────────────────
ax = axes[0,0]
ax.plot(layers_8, EE_8_4_q0,   'o', color='C0', **marker_kwargs)
ax.plot(layers_8, EE_8_4_qpi4, '^', color='C1', **marker_kwargs)
ax.plot(layers_8, EE_8_4_qpi2, 'v', color='C2', **marker_kwargs)
ax.set_xticks(layers_8)
ax.set_ylabel(
    r'$(E_{\mathrm{VQE}}(\boldsymbol{\theta}^*)-E_{\mathrm{ED}})/|E_{\mathrm{ED}}|$',
    fontsize=label_fs,
    labelpad=30
)
style_axes(ax, r'$\mathcal{N}_{F}=4\;(S_{z}=0)$')

# ── Panel (b) ────────────────────────────────────────────────────────────────
ax = axes[0,1]
ax.plot(layers_8, EE_8_3_qpi,   'o', color='red',   **marker_kwargs)
ax.plot(layers_8, EE_8_3_qpi4, '^', color='C1',     **marker_kwargs)
ax.plot(layers_8, EE_8_3_qpi2, 'v', color='C2',     **marker_kwargs)
ax.set_xticks(layers_8)
style_axes(ax, r'$\mathcal{N}_{F}=3\;(S_{z}=-1)$')

#legend_handles_b = [
    #Line2D([], [], marker='o', color='C0', linestyle='none',
           #markersize=marker_size, label=r'$q=0$'),
    #Line2D([], [], marker='o', color='red', linestyle='none',
           #markersize=marker_size, label=r'$q=\pi$'),
    #Line2D([], [], marker='s', color='C1', linestyle='none',
           #markersize=marker_size, label=r'$q=\tfrac{\pi}{4}$'),
    #Line2D([], [], marker='^', color='C2', linestyle='none',
           #markersize=marker_size, label=r'$q=\tfrac{\pi}{2}$'),
#]

#legb = ax.legend(
    #handles=legend_handles_b,
    #bbox_to_anchor=legend_anchor,
    #loc=legend_loc,
    #**legend_kwargs
#)
#legb.get_frame().set_linewidth(legend_border_width)

legend_handles_d = [
    Line2D([], [], marker='o', color='C0', linestyle='none',
           markersize=marker_size, label=r'$q=0$'),
    Line2D([], [], marker='o', color='red', linestyle='none',
           markersize=marker_size, label=r'$q=\pi$'),
    Line2D([], [], marker='s', color='C3', linestyle='none',
           markersize=marker_size, label=r'$q=\tfrac{\pi}{8}$'),
    Line2D([], [], marker='^', color='C1', linestyle='none',
           markersize=marker_size, label=r'$q=\tfrac{\pi}{4}$'),
    Line2D([], [], marker='d', color='C4', linestyle='none',
           markersize=marker_size, label=r'$q=\tfrac{3\pi}{8}$'),
    Line2D([], [], marker='v', color='C2', linestyle='none',
           markersize=marker_size, label=r'$q=\tfrac{\pi}{2}$'),
]

legd = ax.legend(
    handles=legend_handles_d,
    bbox_to_anchor=legend_anchor,
    loc=legend_loc,
    **legend_kwargs
)
legd.get_frame().set_linewidth(legend_border_width)

# ── Panel (c) ────────────────────────────────────────────────────────────────
ax = axes[1,0]
ax.plot(layers_16, EE_16_8_q0,    'o', color='C0', **marker_kwargs)
ax.plot(layers_16, EE_16_8_qpi8,  's', color='C3', **marker_kwargs)
ax.plot(layers_16, EE_16_8_qpi4,  '^', color='C1', **marker_kwargs)
ax.plot(layers_16, EE_16_8_q3pi8, 'd', color='C4', **marker_kwargs)
ax.plot(layers_16, EE_16_8_qpi2,  'v', color='C2', **marker_kwargs)
ax.set_xticks(layers_16)
ax.set_xlabel('Number of Layers', fontsize=label_fs)
ax.set_ylabel(
    r'$(E_{\mathrm{VQE}}(\boldsymbol{\theta}^*)-E_{\mathrm{ED}})/|E_{\mathrm{ED}}|$',
    fontsize=label_fs,
    labelpad=30
)
style_axes(ax, r'$\mathcal{N}_{F}=8\;(S_{z}=0)$')

# ── Panel (d) ────────────────────────────────────────────────────────────────
ax = axes[1,1]
ax.plot(layers_16, EE_16_7_qpi,    'o', color='red',   **marker_kwargs)
ax.plot(layers_16, EE_16_7_qpi8,   's', color='C3',     **marker_kwargs)
ax.plot(layers_16, EE_16_7_qpi4,   '^', color='C1',     **marker_kwargs)
ax.plot(layers_16, EE_16_7_q3pi8,  'd', color='C4',     **marker_kwargs)
ax.plot(layers_16, EE_16_7_qpi2,   'v', color='C2',     **marker_kwargs)
ax.set_xticks(layers_16)
ax.set_xlabel('Number of Layers', fontsize=label_fs)
style_axes(ax, r'$\mathcal{N}_{F}=7\;(S_{z}=-1)$')

#legend_handles_d = [
    #Line2D([], [], marker='o', color='C0', linestyle='none',
           #markersize=marker_size, label=r'$q=0$'),
    #Line2D([], [], marker='o', color='red', linestyle='none',
           #markersize=marker_size, label=r'$q=\pi$'),
    #Line2D([], [], marker='s', color='C1', linestyle='none',
           #markersize=marker_size, label=r'$q=\tfrac{\pi}{8}$'),
    #Line2D([], [], marker='^', color='C2', linestyle='none',
           #markersize=marker_size, label=r'$q=\tfrac{\pi}{4}$'),
    #Line2D([], [], marker='d', color='C3', linestyle='none',
           #markersize=marker_size, label=r'$q=\tfrac{3\pi}{8}$'),
    #Line2D([], [], marker='v', color='C4', linestyle='none',
           #markersize=marker_size, label=r'$q=\tfrac{\pi}{2}$'),
#]

#legend_anchor_d = (1.02, 1.10)

#legd = ax.legend(
    #handles=legend_handles_d,
    #bbox_to_anchor=legend_anchor_d,
    #loc=legend_loc,
    #**legend_kwargs
#)
#legd.get_frame().set_linewidth(legend_border_width)

# carve out the grid & legends
fig.subplots_adjust(
    left=left, right=right,
    bottom=bottom, top=top,
    wspace=wspace, hspace=hspace
)

fig.savefig("Layer by Layer Energy Error Plots.pdf", bbox_inches='tight')
plt.show()

# %%
# ─── USER‐TWEAKABLE SPACING, SIZE, & PADDING ─────────────────────────────────
fig_width, fig_height = 30, 18

# carve out 65% of the width for the 2×2 axes, leaving 35% for legends
left, right, bottom, top = 0.05, 0.65, 0.05, 0.95

# extra horizontal & vertical padding between panels
wspace, hspace = 0.3, 0.5

# panel‐label position (in axes fraction coords)
panel_label_pos = dict(
    x = -0.2,   # negative moves left of axes; try -0.10…-0.20
    y = 1.10     # >1 moves above title; try 1.05…1.15
)

# legend internal spacing & border
legend_spacing = dict(
    labelspacing  = 0.5,  # vertical space between entries
    borderpad     = 0.5   # padding between text block & frame
)

# legend handle/text padding and border thickness
legend_handletextpad = 0.5  # space between marker and text
legend_border_width   = 5.0  # linewidth of the legend frame
# ─────────────────────────────────────────────────────────────────────────────

# marker & legend style
marker_size        = 25
legend_fs          = 75
legend_markerscale = 1.5
panel_label_fs     = 90
tick_fs            = 50
title_fs           = 60
label_fs           = 50

legend_anchor = (1.02, 0.5)
legend_loc    = 'upper left'

legend_kwargs = dict(
    fontsize       = legend_fs,
    markerscale    = legend_markerscale,
    frameon        = True,
    edgecolor      = 'black',
    facecolor      = 'white',
    handletextpad  = legend_handletextpad,
    labelspacing   = legend_spacing['labelspacing'],
    borderpad      = legend_spacing['borderpad']
)

# data placeholders (replace with your actual arrays)
layers_8  = np.arange(1, 9)
layers_16 = np.arange(1, 6)

FE_8_4_q0    = Fidelity_Errors_8_Qubit_4_Filled_States_q_0
FE_8_4_qpi4  = Fidelity_Errors_8_Qubit_4_Filled_States_q_pi_over_4
FE_8_4_qpi2  = Fidelity_Errors_8_Qubit_4_Filled_States_q_pi_over_2

FE_8_3_qpi   = Fidelity_Errors_8_Qubit_3_Filled_States_q_pi
FE_8_3_qpi4  = Fidelity_Errors_8_Qubit_3_Filled_States_q_pi_over_4
FE_8_3_qpi2  = Fidelity_Errors_8_Qubit_3_Filled_States_q_pi_over_2

FE_16_8_q0    = Fidelity_Errors_16_Qubit_8_Filled_States_q_0
FE_16_8_qpi8  = Fidelity_Errors_16_Qubit_8_Filled_States_q_pi_over_8
FE_16_8_qpi4  = Fidelity_Errors_16_Qubit_8_Filled_States_q_pi_over_4
FE_16_8_q3pi8 = Fidelity_Errors_16_Qubit_8_Filled_States_q_3pi_over_8
FE_16_8_qpi2  = Fidelity_Errors_16_Qubit_8_Filled_States_q_pi_over_2

FE_16_7_qpi   = Fidelity_Errors_16_Qubit_7_Filled_States_q_pi
FE_16_7_qpi8  = Fidelity_Errors_16_Qubit_7_Filled_States_q_pi_over_8
FE_16_7_qpi4  = Fidelity_Errors_16_Qubit_7_Filled_States_q_pi_over_4
FE_16_7_q3pi8 = Fidelity_Errors_16_Qubit_7_Filled_States_q_3pi_over_8
FE_16_7_qpi2  = Fidelity_Errors_16_Qubit_7_Filled_States_q_pi_over_2

marker_kwargs      = dict(markersize=marker_size, linestyle='none')
panel_label_kwargs = dict(fontsize=panel_label_fs, fontweight='bold')

def style_axes(ax, title):
    ax.set_yscale('log')
    ax.yaxis.set_major_formatter(LogFormatterMathtext())
    ax.tick_params(labelsize=tick_fs)
    ax.set_title(title, fontsize=title_fs, pad=20)
    lbl = rf'\textbf{{({style_axes.next_label})}}'
    ax.text(
        panel_label_pos['x'], panel_label_pos['y'], lbl,
        transform=ax.transAxes,
        ha='left', va='bottom',
        **panel_label_kwargs
    )
    style_axes.next_label = chr(ord(style_axes.next_label) + 1)

style_axes.next_label = 'a'

fig, axes = plt.subplots(2, 2, figsize=(fig_width, fig_height))

# ── Panel (a) ────────────────────────────────────────────────────────────────
ax = axes[0,0]
ax.plot(layers_8, FE_8_4_q0,   'o', color='C0', **marker_kwargs)
ax.plot(layers_8, FE_8_4_qpi4, '^', color='C1', **marker_kwargs)
ax.plot(layers_8, FE_8_4_qpi2, 'v', color='C2', **marker_kwargs)
ax.set_xticks(layers_8)
ax.set_ylabel(
    r'$1-\mathcal{F}$',
    fontsize=label_fs,
    labelpad=30
)
style_axes(ax, r'$\mathcal{N}_{F}=4\;(S_{z}=0)$')

# ── Panel (b) ────────────────────────────────────────────────────────────────
ax = axes[0,1]
ax.plot(layers_8, FE_8_3_qpi,   'o', color='red',   **marker_kwargs)
ax.plot(layers_8, FE_8_3_qpi4, '^', color='C1',     **marker_kwargs)
ax.plot(layers_8, FE_8_3_qpi2, 'v', color='C2',     **marker_kwargs)
ax.set_xticks(layers_8)
style_axes(ax, r'$\mathcal{N}_{F}=3\;(S_{z}=-1)$')

#legend_handles_b = [
    #Line2D([], [], marker='o', color='C0', linestyle='none',
           #markersize=marker_size, label=r'$q=0$'),
    #Line2D([], [], marker='o', color='red', linestyle='none',
           #markersize=marker_size, label=r'$q=\pi$'),
    #Line2D([], [], marker='s', color='C1', linestyle='none',
           #markersize=marker_size, label=r'$q=\tfrac{\pi}{4}$'),
    #Line2D([], [], marker='^', color='C2', linestyle='none',
           #markersize=marker_size, label=r'$q=\tfrac{\pi}{2}$'),
#]

#legb = ax.legend(
    #handles=legend_handles_b,
    #bbox_to_anchor=legend_anchor,
    #loc=legend_loc,
    #**legend_kwargs
#)
#legb.get_frame().set_linewidth(legend_border_width)

legend_handles_d = [
    Line2D([], [], marker='o', color='C0', linestyle='none',
           markersize=marker_size, label=r'$q=0$'),
    Line2D([], [], marker='o', color='red', linestyle='none',
           markersize=marker_size, label=r'$q=\pi$'),
    Line2D([], [], marker='s', color='C3', linestyle='none',
           markersize=marker_size, label=r'$q=\tfrac{\pi}{8}$'),
    Line2D([], [], marker='^', color='C1', linestyle='none',
           markersize=marker_size, label=r'$q=\tfrac{\pi}{4}$'),
    Line2D([], [], marker='d', color='C4', linestyle='none',
           markersize=marker_size, label=r'$q=\tfrac{3\pi}{8}$'),
    Line2D([], [], marker='v', color='C2', linestyle='none',
           markersize=marker_size, label=r'$q=\tfrac{\pi}{2}$'),
]

legd = ax.legend(
    handles=legend_handles_d,
    bbox_to_anchor=legend_anchor,
    loc=legend_loc,
    **legend_kwargs
)
legd.get_frame().set_linewidth(legend_border_width)

# ── Panel (c) ────────────────────────────────────────────────────────────────
ax = axes[1,0]
ax.plot(layers_16, FE_16_8_q0,    'o', color='C0', **marker_kwargs)
ax.plot(layers_16, FE_16_8_qpi8,  's', color='C3', **marker_kwargs)
ax.plot(layers_16, FE_16_8_qpi4,  '^', color='C1', **marker_kwargs)
ax.plot(layers_16, FE_16_8_q3pi8, 'd', color='C4', **marker_kwargs)
ax.plot(layers_16, FE_16_8_qpi2,  'v', color='C2', **marker_kwargs)
ax.set_xticks(layers_16)
ax.set_xlabel('Number of Layers', fontsize=label_fs)
ax.set_ylabel(
    r'$1-\mathcal{F}$',
    fontsize=label_fs,
    labelpad=30
)
style_axes(ax, r'$\mathcal{N}_{F}=8\;(S_{z}=0)$')

# ── Panel (d) ────────────────────────────────────────────────────────────────
ax = axes[1,1]
ax.plot(layers_16, FE_16_7_qpi,    'o', color='red',   **marker_kwargs)
ax.plot(layers_16, FE_16_7_qpi8,   's', color='C3',     **marker_kwargs)
ax.plot(layers_16, FE_16_7_qpi4,   '^', color='C1',     **marker_kwargs)
ax.plot(layers_16, FE_16_7_q3pi8,  'd', color='C4',     **marker_kwargs)
ax.plot(layers_16, FE_16_7_qpi2,   'v', color='C2',     **marker_kwargs)
ax.set_xticks(layers_16)
ax.set_xlabel('Number of Layers', fontsize=label_fs)
style_axes(ax, r'$\mathcal{N}_{F}=7\;(S_{z}=-1)$')

#legend_handles_d = [
    #Line2D([], [], marker='o', color='C0', linestyle='none',
           #markersize=marker_size, label=r'$q=0$'),
    #Line2D([], [], marker='o', color='red', linestyle='none',
           #markersize=marker_size, label=r'$q=\pi$'),
    #Line2D([], [], marker='s', color='C1', linestyle='none',
           #markersize=marker_size, label=r'$q=\tfrac{\pi}{8}$'),
    #Line2D([], [], marker='^', color='C2', linestyle='none',
           #markersize=marker_size, label=r'$q=\tfrac{\pi}{4}$'),
    #Line2D([], [], marker='d', color='C3', linestyle='none',
           #markersize=marker_size, label=r'$q=\tfrac{3\pi}{8}$'),
    #Line2D([], [], marker='v', color='C4', linestyle='none',
           #markersize=marker_size, label=r'$q=\tfrac{\pi}{2}$'),
#]

#legend_anchor_d = (1.02, 1.10)

#legd = ax.legend(
    #handles=legend_handles_d,
    #bbox_to_anchor=legend_anchor_d,
    #loc=legend_loc,
    #**legend_kwargs
#)
#legd.get_frame().set_linewidth(legend_border_width)

# carve out the grid & legends
fig.subplots_adjust(
    left=left, right=right,
    bottom=bottom, top=top,
    wspace=wspace, hspace=hspace
)

fig.savefig("Layer by Layer Fidelity Error Plots.pdf", bbox_inches='tight')
plt.show()
